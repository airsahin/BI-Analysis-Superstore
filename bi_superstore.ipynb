# %% [markdown]
# ### Index
# 1.  [Load & Discover Data](#1)<br>
# #### Review Columns and Values
# 2.  [PurchaseId Column ](#2) <br>
# 3.  [PurchaseDate - ShipDate Columns](#3) <br>
# 4.  [ShipMode Column](#4) <br>
# 5.  [CustomerId Column](#5) <br>
# 6.  [CustomerName Column](#6) <br>
# 7.  [Segment Column](#7) <br>
# 8.  [Country Column](#8) <br>
# 9.  [City Column](#9) <br>
# 10. [FirstName-LastName & CustomerId Matches](#10) <br>
# 11. [State Column](#11) <br>
# 12. [PostalCode Column](#12) <br>
# 13. [Region Column](#13) <br>
# 14. [ProductId Column](#14) <br>
# 15. [Category Column](#15) <br>
# 16. [SubCategory Column](#16) <br>
# 17. [ProductName Column](#17) <br>
# 18. [Create SupplierPrice and CatalogPrice Columns](#18) <br>
# 19. [ProductName-ProductId Pairs Review](#19) <br>
# 20. [Sales, Quantity, Discount, Profit Columns](#20) <br>
# #### Create Data Frames for SQLite Tables
# 21. [PurchaseId-ProductId Composite PK for Sales Table](#21) <br>
# 22. [Create Data Frames](#22) <br>
# 23. [CustomerLocation  CustomerId Ratio](#23) <br>
# 24. [Create and Populate Tables](#24) <br>
# 25. [Run Queries to discover data](#25-run-some-queries-to-discover-data) <br>
# 26. [More Insights](#26) <br>

# %% [markdown]
# ### 1: Load & Discover Data<a id="1"></a>

# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
import sqlite3
from sqlite3 import Error

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %%
# Check encoding of dataset

import chardet

with open('Sample-Superstore.csv', 'rb') as file:
    rawdata = file.read(10000)
    result = chardet.detect(rawdata)
    
result
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
# Load the data 

df = pd.read_csv('Sample-Superstore.csv', sep=',', header=0, encoding='ISO-8859-1').copy()

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.head().T
# Out:
#                                                0  \
# Row ID                                         1
# Order ID                          CA-2016-152156
# Order Date                             11/8/2016
# Ship Date                             11/11/2016
# Ship Mode                           Second Class
# Customer ID                             CG-12520
# Customer Name                        Claire Gute
# Segment                                 Consumer
# Country                            United States
# City                                   Henderson
# State                                   Kentucky
# Postal Code                                42420
# Region                                     South
# Product ID                       FUR-BO-10001798
# Category                               Furniture
# Sub-Category                           Bookcases
# Product Name   Bush Somerset Collection Bookcase
# Sales                                     261.96
# Quantity                                       2
# Discount                                     0.0
# Profit                                   41.9136
#
#                                                                1  \
# Row ID                                                         2
# Order ID                                          CA-2016-152156
# Order Date                                             11/8/2016
# Ship Date                                             11/11/2016
# Ship Mode                                           Second Class
# Customer ID                                             CG-12520
# Customer Name                                        Claire Gute
# Segment                                                 Consumer
# Country                                            United States
# City                                                   Henderson
# State                                                   Kentucky
# Postal Code                                                42420
# Region                                                     South
# Product ID                                       FUR-CH-10000454
# Category                                               Furniture
# Sub-Category                                              Chairs
# Product Name   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# Sales                                                     731.94
# Quantity                                                       3
# Discount                                                     0.0
# Profit                                                   219.582
#
#                                                                2  \
# Row ID                                                         3
# Order ID                                          CA-2016-138688
# Order Date                                             6/12/2016
# Ship Date                                              6/16/2016
# Ship Mode                                           Second Class
# Customer ID                                             DV-13045
# Customer Name                                    Darrin Van Huff
# Segment                                                Corporate
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# Postal Code                                                90036
# Region                                                      West
# Product ID                                       OFF-LA-10000240
# Category                                         Office Supplies
# Sub-Category                                              Labels
# Product Name   Self-Adhesive Address Labels for Typewriters b...
# Sales                                                      14.62
# Quantity                                                       2
# Discount                                                     0.0
# Profit                                                    6.8714
#
#                                                            3  \
# Row ID                                                     4
# Order ID                                      US-2015-108966
# Order Date                                        10/11/2015
# Ship Date                                         10/18/2015
# Ship Mode                                     Standard Class
# Customer ID                                         SO-20335
# Customer Name                                 Sean O'Donnell
# Segment                                             Consumer
# Country                                        United States
# City                                         Fort Lauderdale
# State                                                Florida
# Postal Code                                            33311
# Region                                                 South
# Product ID                                   FUR-TA-10000577
# Category                                           Furniture
# Sub-Category                                          Tables
# Product Name   Bretford CR4500 Series Slim Rectangular Table
# Sales                                               957.5775
# Quantity                                                   5
# Discount                                                0.45
# Profit                                              -383.031
#
#                                             4
# Row ID                                      5
# Order ID                       US-2015-108966
# Order Date                         10/11/2015
# Ship Date                          10/18/2015
# Ship Mode                      Standard Class
# Customer ID                          SO-20335
# Customer Name                  Sean O'Donnell
# Segment                              Consumer
# Country                         United States
# City                          Fort Lauderdale
# State                                 Florida
# Postal Code                             33311
# Region                                  South
# Product ID                    OFF-ST-10000760
# Category                      Office Supplies
# Sub-Category                          Storage
# Product Name   Eldon Fold 'N Roll Cart System
# Sales                                  22.368
# Quantity                                    2
# Discount                                  0.2
# Profit                                 2.5164

# %%
df = df.drop(columns=['Row ID'])

# %%
# Rename columns 

df.rename(columns={
    'Order ID': 'PurchaseId',
    'Order Date': 'PurchaseDate',
    'Ship Date': 'ShipDate',
    'Ship Mode': 'ShipMode',  
    'Customer ID': 'CustomerId',
    'Customer Name': 'CustomerName',
    'Segment': 'Segment',
    'Country': 'Country',
    'City': 'City',
    'State': 'State',
    'Postal Code': 'PostalCode',
    'Region': 'Region',
    'Product ID': 'ProductId',
    'Category': 'Category',
    'Sub-Category': 'SubCategory',
    'Product Name': 'ProductName',
    'Sales': 'Sales',
    'Quantity': 'Quantity',
    'Discount': 'Discount',
    'Profit': 'Profit'
}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    9994 non-null   object
#  1   PurchaseDate  9994 non-null   object
#  2   ShipDate      9994 non-null   object
#  3   ShipMode      9994 non-null   object
#  4   CustomerId    9994 non-null   object
#  5   CustomerName  9994 non-null   object
#  6   Segment       9994 non-null   object
#  7   Country       9994 non-null   object
#  8   City          9994 non-null   object
#  9   State         9994 non-null   object
#  10  PostalCode    9994 non-null   int64
#  11  Region        9994 non-null   object
#  12  ProductId     9994 non-null   object
#  13  Category      9994 non-null   object
#  14  SubCategory   9994 non-null   object
#  15  ProductName   9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   int64
#  18  Discount      9994 non-null   float64
#  19  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(15)
# memory usage: 1.5+ MB

# %%
df.dtypes
# Out:
# PurchaseId       object
# PurchaseDate     object
# ShipDate         object
# ShipMode         object
# CustomerId       object
# CustomerName     object
# Segment          object
# Country          object
# City             object
# State            object
# PostalCode        int64
# Region           object
# ProductId        object
# Category         object
# SubCategory      object
# ProductName      object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
# Convert data types for columns 

df['PurchaseId'] = df['PurchaseId'].astype(str)

df['PurchaseDate'] = pd.to_datetime(df['PurchaseDate'])  

df['ShipDate'] = pd.to_datetime(df['ShipDate'])  

df['ShipMode'] = df['ShipMode'].astype(str)

df['CustomerId'] = df['CustomerId'].astype(str)

df['CustomerName'] = df['CustomerName'].astype(str)

df['Segment'] = df['Segment'].astype(str)

df['Country'] = df['Country'].astype(str)

df['City'] = df['City'].astype(str)

df['State'] = df['State'].astype(str)

df['PostalCode'] = df['PostalCode'].astype(str)  

df['Region'] = df['Region'].astype(str)

df['ProductId'] = df['ProductId'].astype(str)

df['Category'] = df['Category'].astype(str)

df['SubCategory'] = df['SubCategory'].astype(str)

df['ProductName'] = df['ProductName'].astype(str)

df['Sales'] = df['Sales'].astype(float)  

df['Quantity'] = df['Quantity'].astype(int)

df['Discount'] = df['Discount'].astype(float)

df['Profit'] = df['Profit'].astype(float)

# %%
df.isna().sum()
# Out:
# PurchaseId      0
# PurchaseDate    0
# ShipDate        0
# ShipMode        0
# CustomerId      0
# CustomerName    0
# Segment         0
# Country         0
# City            0
# State           0
# PostalCode      0
# Region          0
# ProductId       0
# Category        0
# SubCategory     0
# ProductName     0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.nunique()
# Out:
# PurchaseId      5009
# PurchaseDate    1237
# ShipDate        1334
# ShipMode           4
# CustomerId       793
# CustomerName     793
# Segment            3
# Country            1
# City             531
# State             49
# PostalCode       631
# Region             4
# ProductId       1862
# Category           3
# SubCategory       17
# ProductName     1850
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df.columns
# Out:
# Index(['PurchaseId', 'PurchaseDate', 'ShipDate', 'ShipMode', 'CustomerId',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductId', 'Category', 'SubCategory', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### 2: PurchaseId<a id="2"></a>

# %%
# check if entries have the same format like in dataframe

import re

pattern = r'^[A-Z]{2}-\d{4}-\d{6}$'

df[~df['PurchaseId'].str.match(pattern)]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# Trim whitespaces

df['PurchaseId'] = df['PurchaseId'].str.strip()

# %%
# Ensure that the case is uppercase across all entries.

df['PurchaseId'] = df['PurchaseId'].str.upper()

# %%
# Check if there is any unexpected characters or symbols 

df[df['PurchaseId'].str.contains(r'[^A-Z0-9-]')]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# Check if the year starts with 20 and followed with same pattern 

df[~df['PurchaseId'].str.contains(r'-20\d{2}-')]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %% [markdown]
# ### 3: PurchaseDate - ShipDate<a id="3"></a>

# %%
# ensure that the PurchaseDate is always earlier than the ShipDate 

df[df['PurchaseDate'] > df['ShipDate']]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# check entries where OrderDate and ShipDate is same

df_order_ship_same = df[df['PurchaseDate'] == df['ShipDate']]

df_order_ship_same.head()
# Out:
#          PurchaseId PurchaseDate   ShipDate  ShipMode CustomerId  \
# 366  CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 367  CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 368  CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 369  CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 657  US-2016-156097   2016-09-19 2016-09-19  Same Day   EH-14125
#
#           CustomerName      Segment        Country        City        State  \
# 366    Michael Kennedy    Corporate  United States  Manchester  Connecticut
# 367    Michael Kennedy    Corporate  United States  Manchester  Connecticut
# 368    Michael Kennedy    Corporate  United States  Manchester  Connecticut
# 369    Michael Kennedy    Corporate  United States  Manchester  Connecticut
# 657  Eugene Hildebrand  Home Office  United States      Aurora     Illinois
#
#     PostalCode   Region        ProductId         Category SubCategory  \
# 366       6040     East  OFF-BI-10002412  Office Supplies     Binders
# 367       6040     East  OFF-SU-10001225  Office Supplies    Supplies
# 368       6040     East  OFF-ST-10002406  Office Supplies     Storage
# 369       6040     East  FUR-BO-10002545        Furniture   Bookcases
# 657      60505  Central  FUR-CH-10001215        Furniture      Chairs
#
#                                            ProductName     Sales  Quantity  \
# 366  Wilson Jones Snap Scratch Pad Binder Tool fo...    23.200         4
# 367                                     Staple remover     7.360         2
# 368                           Pizazz Global Quick File   104.790         7
# 369  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...  1043.920         4
# 657      Global Troy Executive Leather Low-Back Tilter   701.372         2
#
#      Discount    Profit
# 366       0.0   10.4400
# 367       0.0    0.1472
# 368       0.0   29.3412
# 369       0.0  271.4192
# 657       0.3  -50.0980

# %%
df_order_ship_same.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 519 entries, 366 to 9963
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    519 non-null    object
#  1   PurchaseDate  519 non-null    datetime64[ns]
#  2   ShipDate      519 non-null    datetime64[ns]
#  3   ShipMode      519 non-null    object
#  4   CustomerId    519 non-null    object
#  5   CustomerName  519 non-null    object
#  6   Segment       519 non-null    object
#  7   Country       519 non-null    object
#  8   City          519 non-null    object
#  9   State         519 non-null    object
#  10  PostalCode    519 non-null    object
#  11  Region        519 non-null    object
#  12  ProductId     519 non-null    object
#  13  Category      519 non-null    object
#  14  SubCategory   519 non-null    object
#  15  ProductName   519 non-null    object
#  16  Sales         519 non-null    float64
#  17  Quantity      519 non-null    int32
#  18  Discount      519 non-null    float64
#  19  Profit        519 non-null    float64
# dtypes: datetime64[ns](2), float64(3), int32(1), object(14)
# memory usage: 83.1+ KB

# %% [markdown]
# #### 519 rows have the same Order Date and Ship Date which are the Same Day shipment.
# #### No cases of Ship Date occurring before Order Date.
# #### All entries in these columns are consistent.

# %% [markdown]
# ## 4: ShipMode<a id="4"></a>

# %%
# check unique values in ShipMode column

df['ShipMode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
# Ensure that the values are consistently spelled and capitalized.

df['ShipMode'] = df['ShipMode'].str.strip().str.title()

# %%
# Review distribution of 'ShipMode' values

df['ShipMode'].value_counts()
# Out:
# ShipMode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %% [markdown]
# ## 5: CustomerId<a id="5"></a>

# %%
# Make sure all CustomerId values follow a consistent format 

valid_id_pattern = r'^[A-Z]{2}-\d{5}$'

df[~df['CustomerId'].str.match(valid_id_pattern)].T
# Out:
#                                                            261   \
# PurchaseId                                       US-2017-155299
# PurchaseDate                                2017-06-08 00:00:00
# ShipDate                                    2017-06-12 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dl-13600
# CustomerName                                       Dorris liebe
# Segment                                               Corporate
# Country                                           United States
# City                                                   Pasadena
# State                                                     Texas
# PostalCode                                                77506
# Region                                                  Central
# ProductId                                       OFF-AP-10002203
# Category                                        Office Supplies
# SubCategory                                          Appliances
# ProductName   Eureka Disposable Bags for Sanitaire Vibra Gro...
# Sales                                                     1.624
# Quantity                                                      2
# Discount                                                    0.8
# Profit                                                   -4.466
#
#                                                     701   \
# PurchaseId                                CA-2017-114552
# PurchaseDate                         2017-09-02 00:00:00
# ShipDate                             2017-09-08 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      Dl-13600
# CustomerName                                Dorris liebe
# Segment                                        Corporate
# Country                                    United States
# City                                           Cleveland
# State                                               Ohio
# PostalCode                                         44105
# Region                                              East
# ProductId                                FUR-FU-10002960
# Category                                       Furniture
# SubCategory                                  Furnishings
# ProductName   Eldon 200 Class Desk Accessories, Burgundy
# Sales                                             15.072
# Quantity                                               3
# Discount                                             0.2
# Profit                                            4.1448
#
#                                                715                  1489  \
# PurchaseId                           CA-2014-153150       CA-2014-136280
# PurchaseDate                    2014-07-01 00:00:00  2014-11-29 00:00:00
# ShipDate                        2014-07-06 00:00:00  2014-12-06 00:00:00
# ShipMode                               Second Class       Standard Class
# CustomerId                                 Dl-13600             Co-12640
# CustomerName                           Dorris liebe           Corey-Lock
# Segment                                   Corporate             Consumer
# Country                               United States        United States
# City                                        Seattle         Philadelphia
# State                                    Washington         Pennsylvania
# PostalCode                                    98105                19143
# Region                                         West                 East
# ProductId                           OFF-BI-10003355      OFF-LA-10000452
# Category                            Office Supplies      Office Supplies
# SubCategory                                 Binders               Labels
# ProductName   Cardinal Holdit Business Card Pockets            Avery 488
# Sales                                         19.92                 5.04
# Quantity                                          5                    2
# Discount                                        0.2                  0.2
# Profit                                        6.972                1.764
#
#                                                      1900  \
# PurchaseId                                 CA-2016-140543
# PurchaseDate                          2016-06-29 00:00:00
# ShipDate                              2016-07-03 00:00:00
# ShipMode                                     Second Class
# CustomerId                                       Co-12640
# CustomerName                                   Corey-Lock
# Segment                                          Consumer
# Country                                     United States
# City                                             Florence
# State                                      South Carolina
# PostalCode                                          29501
# Region                                              South
# ProductId                                 OFF-ST-10000563
# Category                                  Office Supplies
# SubCategory                                       Storage
# ProductName   Fellowes Bankers Box Stor/Drawer Steel Plus
# Sales                                              191.88
# Quantity                                                6
# Discount                                              0.0
# Profit                                             19.188
#
#                                                    2760  \
# PurchaseId                               CA-2014-129574
# PurchaseDate                        2014-05-26 00:00:00
# ShipDate                            2014-05-29 00:00:00
# ShipMode                                    First Class
# CustomerId                                     Dp-13240
# CustomerName                                Dean percer
# Segment                                     Home Office
# Country                                   United States
# City                                             Murray
# State                                              Utah
# PostalCode                                        84107
# Region                                             West
# ProductId                               OFF-PA-10002893
# Category                                Office Supplies
# SubCategory                                       Paper
# ProductName   Wirebound Service Call Books, 5 1/2" x 4"
# Sales                                              48.4
# Quantity                                              5
# Discount                                            0.0
# Profit                                           23.232
#
#                                          2877                 2878  \
# PurchaseId                     CA-2016-152072       CA-2016-152072
# PurchaseDate              2016-01-15 00:00:00  2016-01-15 00:00:00
# ShipDate                  2016-01-19 00:00:00  2016-01-19 00:00:00
# ShipMode                       Standard Class       Standard Class
# CustomerId                           Dp-13240             Dp-13240
# CustomerName                      Dean percer          Dean percer
# Segment                           Home Office          Home Office
# Country                         United States        United States
# City                                Westfield            Westfield
# State                              New Jersey           New Jersey
# PostalCode                               7090                 7090
# Region                                   East                 East
# ProductId                     OFF-EN-10003040      OFF-AR-10001573
# Category                      Office Supplies      Office Supplies
# SubCategory                         Envelopes                  Art
# ProductName   Quality Park Security Envelopes      American Pencil
# Sales                                   52.34                 4.66
# Quantity                                    2                    2
# Discount                                  0.0                  0.0
# Profit                                24.5998               1.3514
#
#                                           2879                     2966  \
# PurchaseId                      CA-2016-152072           CA-2014-162866
# PurchaseDate               2016-01-15 00:00:00      2014-12-27 00:00:00
# ShipDate                   2016-01-19 00:00:00      2014-12-31 00:00:00
# ShipMode                        Standard Class           Standard Class
# CustomerId                            Dp-13240                 Co-12640
# CustomerName                       Dean percer               Corey-Lock
# Segment                            Home Office                 Consumer
# Country                          United States            United States
# City                                 Westfield                   Skokie
# State                               New Jersey                 Illinois
# PostalCode                                7090                    60076
# Region                                    East                  Central
# ProductId                      TEC-AC-10000844          FUR-FU-10001473
# Category                            Technology                Furniture
# SubCategory                        Accessories              Furnishings
# ProductName   Logitech Gaming G510s - Keyboard  DAX Wood Document Frame
# Sales                                   254.97                   32.952
# Quantity                                     3                        6
# Discount                                   0.0                      0.6
# Profit                                 91.7892                 -19.7712
#
#                              2967                 3362  \
# PurchaseId         CA-2014-162866       CA-2015-139962
# PurchaseDate  2014-12-27 00:00:00  2015-12-13 00:00:00
# ShipDate      2014-12-31 00:00:00  2015-12-20 00:00:00
# ShipMode           Standard Class       Standard Class
# CustomerId               Co-12640             Dp-13240
# CustomerName           Corey-Lock          Dean percer
# Segment                  Consumer          Home Office
# Country             United States        United States
# City                       Skokie               Revere
# State                    Illinois        Massachusetts
# PostalCode                  60076                 2151
# Region                    Central                 East
# ProductId         OFF-ST-10002562      OFF-PA-10004451
# Category          Office Supplies      Office Supplies
# SubCategory               Storage                Paper
# ProductName         Staple magnet            Xerox 222
# Sales                      30.016                19.44
# Quantity                        4                    3
# Discount                      0.2                  0.0
# Profit                     3.0016               9.3312
#
#                                                            3363  \
# PurchaseId                                       CA-2015-139962
# PurchaseDate                                2015-12-13 00:00:00
# ShipDate                                    2015-12-20 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                     Revere
# State                                             Massachusetts
# PostalCode                                                 2151
# Region                                                     East
# ProductId                                       OFF-BI-10004738
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   Flexible Leather- Look Classic Collection Ring...
# Sales                                                     37.88
# Quantity                                                      2
# Discount                                                    0.0
# Profit                                                    18.94
#
#                                             3385                 3386  \
# PurchaseId                        CA-2017-148404       CA-2017-148404
# PurchaseDate                 2017-10-07 00:00:00  2017-10-07 00:00:00
# ShipDate                     2017-10-11 00:00:00  2017-10-11 00:00:00
# ShipMode                          Standard Class       Standard Class
# CustomerId                              Dp-13240             Dp-13240
# CustomerName                         Dean percer          Dean percer
# Segment                              Home Office          Home Office
# Country                            United States        United States
# City                                   Charlotte            Charlotte
# State                             North Carolina       North Carolina
# PostalCode                                 28205                28205
# Region                                     South                South
# ProductId                        OFF-ST-10003208      OFF-FA-10003112
# Category                         Office Supplies      Office Supplies
# SubCategory                              Storage            Fasteners
# ProductName   Adjustable Depth Letter/Legal Cart              Staples
# Sales                                    580.672               18.936
# Quantity                                       4                    3
# Discount                                     0.2                  0.2
# Profit                                   65.3256               5.9175
#
#                                          3387  \
# PurchaseId                     CA-2017-148404
# PurchaseDate              2017-10-07 00:00:00
# ShipDate                  2017-10-11 00:00:00
# ShipMode                       Standard Class
# CustomerId                           Dp-13240
# CustomerName                      Dean percer
# Segment                           Home Office
# Country                         United States
# City                                Charlotte
# State                          North Carolina
# PostalCode                              28205
# Region                                  South
# ProductId                     TEC-PH-10004447
# Category                           Technology
# SubCategory                            Phones
# ProductName   Toshiba IPT2010-SD IP Telephone
# Sales                                 222.384
# Quantity                                    2
# Discount                                  0.2
# Profit                                16.6788
#
#                                              3388                        3389  \
# PurchaseId                         CA-2017-148404              CA-2017-148404
# PurchaseDate                  2017-10-07 00:00:00         2017-10-07 00:00:00
# ShipDate                      2017-10-11 00:00:00         2017-10-11 00:00:00
# ShipMode                           Standard Class              Standard Class
# CustomerId                               Dp-13240                    Dp-13240
# CustomerName                          Dean percer                 Dean percer
# Segment                               Home Office                 Home Office
# Country                             United States               United States
# City                                    Charlotte                   Charlotte
# State                              North Carolina              North Carolina
# PostalCode                                  28205                       28205
# Region                                      South                       South
# ProductId                         OFF-BI-10002854             FUR-TA-10001039
# Category                          Office Supplies                   Furniture
# SubCategory                               Binders                      Tables
# ProductName   Performers Binder/Pad Holder, Black  KI Adjustable-Height Table
# Sales                                      50.454                     154.764
# Quantity                                        6                           3
# Discount                                      0.7                         0.4
# Profit                                    -33.636                    -36.1116
#
#                                    4000  \
# PurchaseId               CA-2014-116834
# PurchaseDate        2014-10-11 00:00:00
# ShipDate            2014-10-16 00:00:00
# ShipMode                 Standard Class
# CustomerId                     Dp-13240
# CustomerName                Dean percer
# Segment                     Home Office
# Country                   United States
# City                            Seattle
# State                        Washington
# PostalCode                        98115
# Region                             West
# ProductId               FUR-FU-10001196
# Category                      Furniture
# SubCategory                 Furnishings
# ProductName   DAX Cubicle Frames - 8x10
# Sales                             63.47
# Quantity                             11
# Discount                            0.0
# Profit                           19.041
#
#                                                            4001  \
# PurchaseId                                       CA-2014-116834
# PurchaseDate                                2014-10-11 00:00:00
# ShipDate                                    2014-10-16 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                    Seattle
# State                                                Washington
# PostalCode                                                98115
# Region                                                     West
# ProductId                                       TEC-AC-10002942
# Category                                             Technology
# SubCategory                                         Accessories
# ProductName   WD My Passport Ultra 1TB Portable External Har...
# Sales                                                     345.0
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                    58.65
#
#                                                            4084  \
# PurchaseId                                       CA-2017-163692
# PurchaseDate                                2017-09-07 00:00:00
# ShipDate                                    2017-09-09 00:00:00
# ShipMode                                            First Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                    Phoenix
# State                                                   Arizona
# PostalCode                                                85023
# Region                                                     West
# ProductId                                       OFF-BI-10003291
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   Wilson Jones Leather-Like Binders with DublLoc...
# Sales                                                     7.857
# Quantity                                                      3
# Discount                                                    0.7
# Profit                                                  -6.0237
#
#                                                       4643  \
# PurchaseId                                  CA-2015-147501
# PurchaseDate                           2015-08-02 00:00:00
# ShipDate                               2015-08-06 00:00:00
# ShipMode                                    Standard Class
# CustomerId                                        Co-12640
# CustomerName                                    Corey-Lock
# Segment                                           Consumer
# Country                                      United States
# City                                               Seattle
# State                                           Washington
# PostalCode                                           98105
# Region                                                West
# ProductId                                  OFF-BI-10002003
# Category                                   Office Supplies
# SubCategory                                        Binders
# ProductName   Ibico Presentation Index for Binding Systems
# Sales                                                6.368
# Quantity                                                 2
# Discount                                               0.2
# Profit                                              2.1492
#
#                                 4644  \
# PurchaseId            CA-2015-147501
# PurchaseDate     2015-08-02 00:00:00
# ShipDate         2015-08-06 00:00:00
# ShipMode              Standard Class
# CustomerId                  Co-12640
# CustomerName              Corey-Lock
# Segment                     Consumer
# Country                United States
# City                         Seattle
# State                     Washington
# PostalCode                     98105
# Region                          West
# ProductId            TEC-MA-10001972
# Category                  Technology
# SubCategory                 Machines
# ProductName   Okidata C331dn Printer
# Sales                          558.4
# Quantity                           2
# Discount                         0.2
# Profit                         41.88
#
#                                                            4734  \
# PurchaseId                                       CA-2016-120530
# PurchaseDate                                2016-04-07 00:00:00
# ShipDate                                    2016-04-12 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dl-13600
# CustomerName                                       Dorris liebe
# Segment                                               Corporate
# Country                                           United States
# City                                              New York City
# State                                                  New York
# PostalCode                                                10035
# Region                                                     East
# ProductId                                       FUR-CH-10000454
# Category                                              Furniture
# SubCategory                                              Chairs
# ProductName   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# Sales                                                   658.746
# Quantity                                                      3
# Discount                                                    0.1
# Profit                                                  146.388
#
#                                            5006  \
# PurchaseId                       CA-2015-169796
# PurchaseDate                2015-11-09 00:00:00
# ShipDate                    2015-11-14 00:00:00
# ShipMode                         Standard Class
# CustomerId                             Dp-13240
# CustomerName                        Dean percer
# Segment                             Home Office
# Country                           United States
# City                              New York City
# State                                  New York
# PostalCode                                10035
# Region                                     East
# ProductId                       TEC-MA-10000045
# Category                             Technology
# SubCategory                            Machines
# ProductName   Zebra ZM400 Thermal Label Printer
# Sales                                    2321.9
# Quantity                                      2
# Discount                                    0.0
# Profit                                 1114.512
#
#                                                            5007  \
# PurchaseId                                       CA-2015-169796
# PurchaseDate                                2015-11-09 00:00:00
# ShipDate                                    2015-11-14 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                              New York City
# State                                                  New York
# PostalCode                                                10035
# Region                                                     East
# ProductId                                       OFF-ST-10001505
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Perma STOR-ALL Hanging File Box, 13 1/8"W x 12...
# Sales                                                     17.94
# Quantity                                                      3
# Discount                                                    0.0
# Profit                                                   3.0498
#
#                                                 5283                 5284  \
# PurchaseId                            CA-2014-133424       CA-2014-133424
# PurchaseDate                     2014-03-30 00:00:00  2014-03-30 00:00:00
# ShipDate                         2014-04-04 00:00:00  2014-04-04 00:00:00
# ShipMode                              Standard Class       Standard Class
# CustomerId                                  Dl-13600             Dl-13600
# CustomerName                            Dorris liebe         Dorris liebe
# Segment                                    Corporate            Corporate
# Country                                United States        United States
# City                                         Seattle              Seattle
# State                                     Washington           Washington
# PostalCode                                     98105                98105
# Region                                          West                 West
# ProductId                            OFF-ST-10002957      OFF-LA-10002312
# Category                             Office Supplies      Office Supplies
# SubCategory                                  Storage               Labels
# ProductName   Sterilite Show Offs Storage Containers            Avery 490
# Sales                                          15.84                 44.4
# Quantity                                           3                    3
# Discount                                         0.0                  0.0
# Profit                                           0.0                 22.2
#
#                                                       5316  \
# PurchaseId                                  US-2017-162558
# PurchaseDate                           2017-10-02 00:00:00
# ShipDate                               2017-10-05 00:00:00
# ShipMode                                       First Class
# CustomerId                                        Dp-13240
# CustomerName                                   Dean percer
# Segment                                        Home Office
# Country                                      United States
# City                                             Knoxville
# State                                            Tennessee
# PostalCode                                           37918
# Region                                               South
# ProductId                                  FUR-FU-10002364
# Category                                         Furniture
# SubCategory                                    Furnishings
# ProductName   Eldon Expressions Wood Desk Accessories, Oak
# Sales                                               11.808
# Quantity                                                 2
# Discount                                               0.2
# Profit                                              1.3284
#
#                                           5317                 5318  \
# PurchaseId                      US-2017-162558       US-2017-162558
# PurchaseDate               2017-10-02 00:00:00  2017-10-02 00:00:00
# ShipDate                   2017-10-05 00:00:00  2017-10-05 00:00:00
# ShipMode                           First Class          First Class
# CustomerId                            Dp-13240             Dp-13240
# CustomerName                       Dean percer          Dean percer
# Segment                            Home Office          Home Office
# Country                          United States        United States
# City                                 Knoxville            Knoxville
# State                                Tennessee            Tennessee
# PostalCode                               37918                37918
# Region                                   South                South
# ProductId                      FUR-FU-10004864      OFF-PA-10003172
# Category                             Furniture      Office Supplies
# SubCategory                        Furnishings                Paper
# ProductName   Eldon 500 Class Desk Accessories           Xerox 1996
# Sales                                    9.656               20.736
# Quantity                                     1                    4
# Discount                                   0.2                  0.2
# Profit                                  1.5691               7.2576
#
#                                             5319  \
# PurchaseId                        US-2017-162558
# PurchaseDate                 2017-10-02 00:00:00
# ShipDate                     2017-10-05 00:00:00
# ShipMode                             First Class
# CustomerId                              Dp-13240
# CustomerName                         Dean percer
# Segment                              Home Office
# Country                            United States
# City                                   Knoxville
# State                                  Tennessee
# PostalCode                                 37918
# Region                                     South
# ProductId                        OFF-BI-10000977
# Category                         Office Supplies
# SubCategory                              Binders
# ProductName   Ibico Plastic Spiral Binding Combs
# Sales                                      27.36
# Quantity                                       3
# Discount                                     0.7
# Profit                                   -21.888
#
#                                                            5320  \
# PurchaseId                                       US-2017-162558
# PurchaseDate                                2017-10-02 00:00:00
# ShipDate                                    2017-10-05 00:00:00
# ShipMode                                            First Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                  Knoxville
# State                                                 Tennessee
# PostalCode                                                37918
# Region                                                    South
# ProductId                                       FUR-TA-10000198
# Category                                              Furniture
# SubCategory                                              Tables
# ProductName   Chromcraft Bull-Nose Wood Oval Conference Tabl...
# Sales                                                  2314.116
# Quantity                                                      7
# Discount                                                    0.4
# Profit                                               -1002.7836
#
#                                      5321  \
# PurchaseId                 US-2017-162558
# PurchaseDate          2017-10-02 00:00:00
# ShipDate              2017-10-05 00:00:00
# ShipMode                      First Class
# CustomerId                       Dp-13240
# CustomerName                  Dean percer
# Segment                       Home Office
# Country                     United States
# City                            Knoxville
# State                           Tennessee
# PostalCode                          37918
# Region                              South
# ProductId                 OFF-BI-10003984
# Category                  Office Supplies
# SubCategory                       Binders
# ProductName   Lock-Up Easel 'Spel-Binder'
# Sales                              34.236
# Quantity                                4
# Discount                              0.7
# Profit                           -26.2476
#
#                                                     5322                 5475  \
# PurchaseId                                US-2017-162558       CA-2017-169691
# PurchaseDate                         2017-10-02 00:00:00  2017-06-15 00:00:00
# ShipDate                             2017-10-05 00:00:00  2017-06-18 00:00:00
# ShipMode                                     First Class          First Class
# CustomerId                                      Dp-13240             Dp-13240
# CustomerName                                 Dean percer          Dean percer
# Segment                                      Home Office          Home Office
# Country                                    United States        United States
# City                                           Knoxville          Maple Grove
# State                                          Tennessee            Minnesota
# PostalCode                                         37918                55369
# Region                                             South              Central
# ProductId                                FUR-FU-10003691      OFF-LA-10002312
# Category                                       Furniture      Office Supplies
# SubCategory                                  Furnishings               Labels
# ProductName   Eldon Image Series Desk Accessories, Ebony            Avery 490
# Sales                                              19.76                 44.4
# Quantity                                               2                    3
# Discount                                             0.2                  0.0
# Profit                                             5.928                 22.2
#
#                                                            5476  \
# PurchaseId                                       CA-2017-169691
# PurchaseDate                                2017-06-15 00:00:00
# ShipDate                                    2017-06-18 00:00:00
# ShipMode                                            First Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                Maple Grove
# State                                                 Minnesota
# PostalCode                                                55369
# Region                                                  Central
# ProductId                                       OFF-ST-10001291
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Tenex Personal Self-Stacking Standard File Box...
# Sales                                                     84.55
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                  22.8285
#
#                              5477                                6104  \
# PurchaseId         CA-2017-169691                      US-2017-132381
# PurchaseDate  2017-06-15 00:00:00                 2017-08-22 00:00:00
# ShipDate      2017-06-18 00:00:00                 2017-08-24 00:00:00
# ShipMode              First Class                         First Class
# CustomerId               Dp-13240                            Dp-13240
# CustomerName          Dean percer                         Dean percer
# Segment               Home Office                         Home Office
# Country             United States                       United States
# City                  Maple Grove                        Philadelphia
# State                   Minnesota                        Pennsylvania
# PostalCode                  55369                               19143
# Region                    Central                                East
# ProductId         OFF-PA-10003022                     FUR-TA-10002356
# Category          Office Supplies                           Furniture
# SubCategory                 Paper                              Tables
# ProductName            Xerox 1992  Bevis Boat-Shaped Conference Table
# Sales                       17.94                             314.532
# Quantity                        3                                   2
# Discount                      0.0                                 0.4
# Profit                     8.7906                            -83.8752
#
#                                                            7919  \
# PurchaseId                                       CA-2017-139822
# PurchaseDate                                2017-09-15 00:00:00
# ShipDate                                    2017-09-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                  Waterbury
# State                                               Connecticut
# PostalCode                                                 6708
# Region                                                     East
# ProductId                                       OFF-ST-10000943
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Eldon ProFile File 'N Store Portable File Tub ...
# Sales                                                     38.62
# Quantity                                                      2
# Discount                                                    0.0
# Profit                                                  10.8136
#
#                                                            7920  \
# PurchaseId                                       CA-2017-139822
# PurchaseDate                                2017-09-15 00:00:00
# ShipDate                                    2017-09-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                  Waterbury
# State                                               Connecticut
# PostalCode                                                 6708
# Region                                                     East
# ProductId                                       TEC-AC-10001090
# Category                                             Technology
# SubCategory                                         Accessories
# ProductName   Micro Innovations Wireless Classic Keyboard wi...
# Sales                                                     59.98
# Quantity                                                      2
# Discount                                                    0.0
# Profit                                                  10.7964
#
#                                               8145                 8146
# PurchaseId                          US-2014-112949       US-2014-112949
# PurchaseDate                   2014-06-20 00:00:00  2014-06-20 00:00:00
# ShipDate                       2014-06-27 00:00:00  2014-06-27 00:00:00
# ShipMode                            Standard Class       Standard Class
# CustomerId                                Co-12640             Co-12640
# CustomerName                            Corey-Lock           Corey-Lock
# Segment                                   Consumer             Consumer
# Country                              United States        United States
# City                                        Lawton               Lawton
# State                                     Oklahoma             Oklahoma
# PostalCode                                   73505                73505
# Region                                     Central              Central
# ProductId                          OFF-AP-10001005      OFF-AR-10003469
# Category                           Office Supplies      Office Supplies
# SubCategory                             Appliances                  Art
# ProductName   Honeywell Quietcare HEPA Air Cleaner       Nontoxic Chalk
# Sales                                        471.9                 3.52
# Quantity                                         6                    2
# Discount                                       0.0                  0.0
# Profit                                     155.727               1.6896

# %% [markdown]
# #### There seem to be upper-lower case issues for CustomerId.

# %%
# Convert all 'CustomerId' values to uppercase

df['CustomerId'] = df['CustomerId'].str.upper()

# %%
# Confirm Changes

df[~df['CustomerId'].str.match(valid_id_pattern)]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# Clean probable leading or trailing spaces.

df['CustomerId'] = df['CustomerId'].str.strip()

# %% [markdown]
# ### All values in CustomerId column have the same format now

# %% [markdown]
# ## 6: CustomerName<a id="6"></a>

# %%
# Trim whitespaces from 'CustomerName' values

df['CustomerName'] = df['CustomerName'].str.strip()

# Convert 'CustomerName' values to title case

df['CustomerName'] = df['CustomerName'].str.title()

# %% [markdown]
# #### Noticed some names which have hypnes in between such as: Corey-Lock

# %%
# Noticed some names which have hypnes in between such as: Corey-Lock
# Regular expression pattern to detect hyphenated names

hyphenated_pattern = r'\b\w+-\w+\b'

# Function to check if a name contains a hyphen

def contains_hyphen(name):
    return bool(re.search(hyphenated_pattern, name))

# Apply the function to get a boolean Series

mask1 = df['CustomerName'].apply(contains_hyphen)

# %%
df['CustomerName'][mask1]
# Out:
# 1489    Corey-Lock
# 1900    Corey-Lock
# 2966    Corey-Lock
# 2967    Corey-Lock
# 4643    Corey-Lock
# 4644    Corey-Lock
# 8145    Corey-Lock
# 8146    Corey-Lock
# Name: CustomerName, dtype: object

# %% [markdown]
# It is the only Name with hypnes between names.

# %%
# Correct the specific entry "Corey-Lock" to "Corey Lock"

df.loc[df['CustomerName'] == 'Corey-Lock', 'CustomerName'] = 'Corey Lock'

# %%
# Also noticed some name with apostrophes, filter and review values to be sure that there is no issue 
# Regular expression pattern to detect names with apostrophes 

apostrophe_pattern = r"\b\w*'\w*\b"

# Function to check if a name contains an apostrophe

def contains_apostrophe(name):
    return bool(re.search(apostrophe_pattern, name))

# Apply the function to create a boolean mask

mask2 = df['CustomerName'].apply(contains_apostrophe)

df[mask2].T
# Out:
#                                                        3     \
# PurchaseId                                   US-2015-108966
# PurchaseDate                            2015-10-11 00:00:00
# ShipDate                                2015-10-18 00:00:00
# ShipMode                                     Standard Class
# CustomerId                                         SO-20335
# CustomerName                                 Sean O'Donnell
# Segment                                            Consumer
# Country                                       United States
# City                                        Fort Lauderdale
# State                                               Florida
# PostalCode                                            33311
# Region                                                South
# ProductId                                   FUR-TA-10000577
# Category                                          Furniture
# SubCategory                                          Tables
# ProductName   Bretford CR4500 Series Slim Rectangular Table
# Sales                                              957.5775
# Quantity                                                  5
# Discount                                               0.45
# Profit                                             -383.031
#
#                                         4     \
# PurchaseId                    US-2015-108966
# PurchaseDate             2015-10-11 00:00:00
# ShipDate                 2015-10-18 00:00:00
# ShipMode                      Standard Class
# CustomerId                          SO-20335
# CustomerName                  Sean O'Donnell
# Segment                             Consumer
# Country                        United States
# City                         Fort Lauderdale
# State                                Florida
# PostalCode                             33311
# Region                                 South
# ProductId                    OFF-ST-10000760
# Category                     Office Supplies
# SubCategory                          Storage
# ProductName   Eldon Fold 'N Roll Cart System
# Sales                                 22.368
# Quantity                                   2
# Discount                                 0.2
# Profit                                2.5164
#
#                                                            46    \
# PurchaseId                                       CA-2014-146703
# PurchaseDate                                2014-10-20 00:00:00
# ShipDate                                    2014-10-25 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             PO-18865
# CustomerName                                  Patrick O'Donnell
# Segment                                                Consumer
# Country                                           United States
# City                                                   Westland
# State                                                  Michigan
# PostalCode                                                48185
# Region                                                  Central
# ProductId                                       OFF-ST-10001713
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5...
# Sales                                                    211.96
# Quantity                                                      4
# Discount                                                    0.0
# Profit                                                   8.4784
#
#                                           85    \
# PurchaseId                      CA-2017-140088
# PurchaseDate               2017-05-28 00:00:00
# ShipDate                   2017-05-30 00:00:00
# ShipMode                          Second Class
# CustomerId                            PO-18865
# CustomerName                 Patrick O'Donnell
# Segment                               Consumer
# Country                          United States
# City                                  Columbia
# State                           South Carolina
# PostalCode                               29203
# Region                                   South
# ProductId                      FUR-CH-10000863
# Category                             Furniture
# SubCategory                             Chairs
# ProductName   Novimex Swivel Fabric Task Chair
# Sales                                   301.96
# Quantity                                     2
# Discount                                   0.0
# Profit                                 33.2156
#
#                                                  282                    326   \
# PurchaseId                             CA-2015-130890         US-2016-141544
# PurchaseDate                      2015-11-02 00:00:00    2016-08-30 00:00:00
# ShipDate                          2015-11-06 00:00:00    2016-09-01 00:00:00
# ShipMode                               Standard Class            First Class
# CustomerId                                   JO-15280               PO-18850
# CustomerName                            Jas O'Carroll        Patrick O'Brill
# Segment                                      Consumer               Consumer
# Country                                 United States          United States
# City                                      Los Angeles           Philadelphia
# State                                      California           Pennsylvania
# PostalCode                                      90004                  19143
# Region                                           West                   East
# ProductId                             FUR-TA-10002903        TEC-PH-10003645
# Category                                    Furniture             Technology
# SubCategory                                    Tables                 Phones
# ProductName   Bevis Round Bullnose 29" High Table Top  Aastra 57i VoIP phone
# Sales                                         1038.84                290.898
# Quantity                                            5                      3
# Discount                                          0.2                    0.4
# Profit                                         51.942               -67.8762
#
#                                                327   \
# PurchaseId                           US-2016-141544
# PurchaseDate                    2016-08-30 00:00:00
# ShipDate                        2016-09-01 00:00:00
# ShipMode                                First Class
# CustomerId                                 PO-18850
# CustomerName                        Patrick O'Brill
# Segment                                    Consumer
# Country                               United States
# City                                   Philadelphia
# State                                  Pennsylvania
# PostalCode                                    19143
# Region                                         East
# ProductId                           OFF-ST-10000675
# Category                            Office Supplies
# SubCategory                                 Storage
# ProductName   File Shuttle II and Handi-File, Black
# Sales                                        54.224
# Quantity                                          2
# Discount                                        0.2
# Profit                                        3.389
#
#                                                            328   \
# PurchaseId                                       US-2016-141544
# PurchaseDate                                2016-08-30 00:00:00
# ShipDate                                    2016-09-01 00:00:00
# ShipMode                                            First Class
# CustomerId                                             PO-18850
# CustomerName                                    Patrick O'Brill
# Segment                                                Consumer
# Country                                           United States
# City                                               Philadelphia
# State                                              Pennsylvania
# PostalCode                                                19143
# Region                                                     East
# ProductId                                       FUR-CH-10003312
# Category                                              Furniture
# SubCategory                                              Chairs
# ProductName   Hon 2090 Pillow Soft Series Mid Back Swivel/...
# Sales                                                   786.744
# Quantity                                                      4
# Discount                                                    0.3
# Profit                                                -258.5016
#
#                                               329   \
# PurchaseId                          US-2016-141544
# PurchaseDate                   2016-08-30 00:00:00
# ShipDate                       2016-09-01 00:00:00
# ShipMode                               First Class
# CustomerId                                PO-18850
# CustomerName                       Patrick O'Brill
# Segment                                   Consumer
# Country                              United States
# City                                  Philadelphia
# State                                 Pennsylvania
# PostalCode                                   19143
# Region                                        East
# ProductId                          OFF-LA-10001074
# Category                           Office Supplies
# SubCategory                                 Labels
# ProductName   Round Specialty Laser Printer Labels
# Sales                                       100.24
# Quantity                                        10
# Discount                                       0.2
# Profit                                      33.831
#
#                                                            330   \
# PurchaseId                                       US-2016-141544
# PurchaseDate                                2016-08-30 00:00:00
# ShipDate                                    2016-09-01 00:00:00
# ShipMode                                            First Class
# CustomerId                                             PO-18850
# CustomerName                                    Patrick O'Brill
# Segment                                                Consumer
# Country                                           United States
# City                                               Philadelphia
# State                                              Pennsylvania
# PostalCode                                                19143
# Region                                                     East
# ProductId                                       OFF-BI-10001524
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   GBC Premium Transparent Covers with Diagonal L...
# Sales                                                    37.764
# Quantity                                                      6
# Discount                                                    0.7
# Profit                                                 -27.6936
#
#                                            494   \
# PurchaseId                       US-2016-120929
# PurchaseDate                2016-03-18 00:00:00
# ShipDate                    2016-03-21 00:00:00
# ShipMode                           Second Class
# CustomerId                             RO-19780
# CustomerName                       Rose O'Brian
# Segment                                Consumer
# Country                           United States
# City                                    Memphis
# State                                 Tennessee
# PostalCode                                38109
# Region                                    South
# ProductId                       FUR-TA-10001857
# Category                              Furniture
# SubCategory                              Tables
# ProductName   Balt Solid Wood Rectangular Table
# Sales                                   189.882
# Quantity                                      3
# Discount                                    0.4
# Profit                                  -94.941
#
#                                         626   \
# PurchaseId                    CA-2017-163020
# PurchaseDate             2017-09-15 00:00:00
# ShipDate                 2017-09-19 00:00:00
# ShipMode                      Standard Class
# CustomerId                          MO-17800
# CustomerName                    Meg O'Connel
# Segment                          Home Office
# Country                        United States
# City                           New York City
# State                               New York
# PostalCode                             10009
# Region                                  East
# ProductId                    FUR-FU-10000221
# Category                           Furniture
# SubCategory                      Furnishings
# ProductName   Master Caster Door Stop, Brown
# Sales                                  35.56
# Quantity                                   7
# Discount                                 0.0
# Profit                               12.0904
#
#                                           669   \
# PurchaseId                      US-2017-106663
# PurchaseDate               2017-06-09 00:00:00
# ShipDate                   2017-06-13 00:00:00
# ShipMode                        Standard Class
# CustomerId                            MO-17800
# CustomerName                      Meg O'Connel
# Segment                            Home Office
# Country                          United States
# City                                   Chicago
# State                                 Illinois
# PostalCode                               60653
# Region                                 Central
# ProductId                      FUR-FU-10002759
# Category                             Furniture
# SubCategory                        Furnishings
# ProductName   12-1/2 Diameter Round Wall Clock
# Sales                                   23.976
# Quantity                                     3
# Discount                                   0.6
# Profit                                -14.3856
#
#                                                            670   \
# PurchaseId                                       US-2017-106663
# PurchaseDate                                2017-06-09 00:00:00
# ShipDate                                    2017-06-13 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             MO-17800
# CustomerName                                       Meg O'Connel
# Segment                                             Home Office
# Country                                           United States
# City                                                    Chicago
# State                                                  Illinois
# PostalCode                                                60653
# Region                                                  Central
# ProductId                                       FUR-TA-10000688
# Category                                              Furniture
# SubCategory                                              Tables
# ProductName   Chromcraft Bull-Nose Wood Round Conference Tab...
# Sales                                                   108.925
# Quantity                                                      1
# Discount                                                    0.5
# Profit                                                 -71.8905
#
#                                                            671   \
# PurchaseId                                       US-2017-106663
# PurchaseDate                                2017-06-09 00:00:00
# ShipDate                                    2017-06-13 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             MO-17800
# CustomerName                                       Meg O'Connel
# Segment                                             Home Office
# Country                                           United States
# City                                                    Chicago
# State                                                  Illinois
# PostalCode                                                60653
# Region                                                  Central
# ProductId                                       OFF-PA-10002377
# Category                                        Office Supplies
# SubCategory                                               Paper
# ProductName   Adams Telephone Message Book W/Dividers/Space ...
# Sales                                                    36.352
# Quantity                                                      8
# Discount                                                    0.2
# Profit                                                    11.36
#
#                                                            906   \
# PurchaseId                                       CA-2017-143259
# PurchaseDate                                2017-12-30 00:00:00
# ShipDate                                    2018-01-03 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PO-18865
# CustomerName                                  Patrick O'Donnell
# Segment                                                Consumer
# Country                                           United States
# City                                              New York City
# State                                                  New York
# PostalCode                                                10009
# Region                                                     East
# ProductId                                       FUR-BO-10003441
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName   Bush Westfield Collection Bookcases, Fully Ass...
# Sales                                                   323.136
# Quantity                                                      4
# Discount                                                    0.2
# Profit                                                  12.1176
#
#                                    907                                   908   \
# PurchaseId               CA-2017-143259                        CA-2017-143259
# PurchaseDate        2017-12-30 00:00:00                   2017-12-30 00:00:00
# ShipDate            2018-01-03 00:00:00                   2018-01-03 00:00:00
# ShipMode                 Standard Class                        Standard Class
# CustomerId                     PO-18865                              PO-18865
# CustomerName          Patrick O'Donnell                     Patrick O'Donnell
# Segment                        Consumer                              Consumer
# Country                   United States                         United States
# City                      New York City                         New York City
# State                          New York                              New York
# PostalCode                        10009                                 10009
# Region                             East                                  East
# ProductId               TEC-PH-10004774                       OFF-BI-10003684
# Category                     Technology                       Office Supplies
# SubCategory                      Phones                               Binders
# ProductName   Gear Head AU3700S Headset  Wilson Jones Legal Size Ring Binders
# Sales                             90.93                                52.776
# Quantity                              7                                     3
# Discount                            0.0                                   0.2
# Profit                           2.7279                                19.791
#
#                                                            1008  \
# PurchaseId                                       US-2017-106705
# PurchaseDate                                2017-12-26 00:00:00
# ShipDate                                    2018-01-01 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PO-18850
# CustomerName                                    Patrick O'Brill
# Segment                                                Consumer
# Country                                           United States
# City                                                 Burlington
# State                                                      Iowa
# PostalCode                                                52601
# Region                                                  Central
# ProductId                                       OFF-PA-10001509
# Category                                        Office Supplies
# SubCategory                                               Paper
# ProductName   Recycled Desk Saver Line "While You Were Out" ...
# Sales                                                     44.75
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                   20.585
#
#                              1015                        1041  \
# PurchaseId         CA-2015-133025              CA-2016-102981
# PurchaseDate  2015-09-17 00:00:00         2016-09-06 00:00:00
# ShipDate      2015-09-19 00:00:00         2016-09-09 00:00:00
# ShipMode             Second Class                Second Class
# CustomerId               MO-17800                    MO-17500
# CustomerName         Meg O'Connel               Mary O'Rourke
# Segment               Home Office                    Consumer
# Country             United States               United States
# City                  Los Angeles               New York City
# State                  California                    New York
# PostalCode                  90036                       10035
# Region                       West                        East
# ProductId         OFF-PA-10004100             TEC-AC-10004761
# Category          Office Supplies                  Technology
# SubCategory                 Paper                 Accessories
# ProductName             Xerox 216  Maxell 4.7GB DVD+RW 3/Pack
# Sales                        32.4                       31.86
# Quantity                        5                           2
# Discount                      0.0                         0.0
# Profit                     15.552                      11.151
#
#                                                            1042  \
# PurchaseId                                       CA-2016-102981
# PurchaseDate                                2016-09-06 00:00:00
# ShipDate                                    2016-09-09 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             MO-17500
# CustomerName                                      Mary O'Rourke
# Segment                                                Consumer
# Country                                           United States
# City                                              New York City
# State                                                  New York
# PostalCode                                                10035
# Region                                                     East
# ProductId                                       FUR-BO-10001811
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName   Atlantic Metals Mobile 5-Shelf Bookcases, Cust...
# Sales                                                   722.352
# Quantity                                                      3
# Discount                                                    0.2
# Profit                                                   90.294
#
#                                                        1241  \
# PurchaseId                                   CA-2016-128727
# PurchaseDate                            2016-08-29 00:00:00
# ShipDate                                2016-09-04 00:00:00
# ShipMode                                     Standard Class
# CustomerId                                         MO-17800
# CustomerName                                   Meg O'Connel
# Segment                                         Home Office
# Country                                       United States
# City                                          New York City
# State                                              New York
# PostalCode                                            10024
# Region                                                 East
# ProductId                                   TEC-PH-10003442
# Category                                         Technology
# SubCategory                                          Phones
# ProductName   Samsung Replacement EH64AVFWE Premium Headset
# Sales                                                  22.0
# Quantity                                                  4
# Discount                                                0.0
# Profit                                                  5.5
#
#                                        1604                 1605  \
# PurchaseId                   US-2016-115819       US-2016-115819
# PurchaseDate            2016-04-19 00:00:00  2016-04-19 00:00:00
# ShipDate                2016-04-24 00:00:00  2016-04-24 00:00:00
# ShipMode                       Second Class         Second Class
# CustomerId                         JO-15280             JO-15280
# CustomerName                  Jas O'Carroll        Jas O'Carroll
# Segment                            Consumer             Consumer
# Country                       United States        United States
# City                            Los Angeles          Los Angeles
# State                            California           California
# PostalCode                            90049                90049
# Region                                 West                 West
# ProductId                   TEC-PH-10004700      OFF-AR-10000823
# Category                         Technology      Office Supplies
# SubCategory                          Phones                  Art
# ProductName   PowerGen Dual USB Car Charger           Newell 307
# Sales                                 39.96                 5.46
# Quantity                                  5                    3
# Discount                                0.2                  0.0
# Profit                               12.987               1.5288
#
#                                                            1606  \
# PurchaseId                                       US-2016-115819
# PurchaseDate                                2016-04-19 00:00:00
# ShipDate                                    2016-04-24 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             JO-15280
# CustomerName                                      Jas O'Carroll
# Segment                                                Consumer
# Country                                           United States
# City                                                Los Angeles
# State                                                California
# PostalCode                                                90049
# Region                                                     West
# ProductId                                       OFF-AR-10004456
# Category                                        Office Supplies
# SubCategory                                                 Art
# ProductName   Panasonic KP-4ABK Battery-Operated Pencil Shar...
# Sales                                                      73.2
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                   21.228
#
#                                                            1607  \
# PurchaseId                                       US-2016-115819
# PurchaseDate                                2016-04-19 00:00:00
# ShipDate                                    2016-04-24 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             JO-15280
# CustomerName                                      Jas O'Carroll
# Segment                                                Consumer
# Country                                           United States
# City                                                Los Angeles
# State                                                California
# PostalCode                                                90049
# Region                                                     West
# ProductId                                       OFF-BI-10000050
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   Angle-D Binders with Locking Rings, Label Holders
# Sales                                                      5.84
# Quantity                                                      1
# Discount                                                    0.2
# Profit                                                    1.971
#
#                                                            1608  \
# PurchaseId                                       US-2016-115819
# PurchaseDate                                2016-04-19 00:00:00
# ShipDate                                    2016-04-24 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             JO-15280
# CustomerName                                      Jas O'Carroll
# Segment                                                Consumer
# Country                                           United States
# City                                                Los Angeles
# State                                                California
# PostalCode                                                90049
# Region                                                     West
# ProductId                                       OFF-PA-10002377
# Category                                        Office Supplies
# SubCategory                                               Paper
# ProductName   Adams Telephone Message Book W/Dividers/Space ...
# Sales                                                     22.72
# Quantity                                                      4
# Discount                                                    0.0
# Profit                                                   10.224
#
#                              1609                                       1750  \
# PurchaseId         US-2016-115819                             CA-2015-139094
# PurchaseDate  2016-04-19 00:00:00                        2015-11-22 00:00:00
# ShipDate      2016-04-24 00:00:00                        2015-11-27 00:00:00
# ShipMode             Second Class                             Standard Class
# CustomerId               JO-15280                                   MO-17800
# CustomerName        Jas O'Carroll                               Meg O'Connel
# Segment                  Consumer                                Home Office
# Country             United States                              United States
# City                  Los Angeles                                San Antonio
# State                  California                                      Texas
# PostalCode                  90049                                      78207
# Region                       West                                    Central
# ProductId         OFF-BI-10000591                            FUR-TA-10004607
# Category          Office Supplies                                  Furniture
# SubCategory               Binders                                     Tables
# ProductName   Avery Binder Labels  Hon 2111 Invitation Series Straight Table
# Sales                       9.336                                    206.962
# Quantity                        3                                          2
# Discount                      0.2                                        0.3
# Profit                     3.2676                                   -32.5226
#
#                                              1895  \
# PurchaseId                         CA-2015-109197
# PurchaseDate                  2015-12-31 00:00:00
# ShipDate                      2016-01-04 00:00:00
# ShipMode                           Standard Class
# CustomerId                               JO-15280
# CustomerName                        Jas O'Carroll
# Segment                                  Consumer
# Country                             United States
# City                                     Missoula
# State                                     Montana
# PostalCode                                  59801
# Region                                       West
# ProductId                         OFF-BI-10004632
# Category                          Office Supplies
# SubCategory                               Binders
# ProductName   Ibico Hi-Tech Manual Binding System
# Sales                                     487.984
# Quantity                                        2
# Discount                                      0.2
# Profit                                    152.495
#
#                                          2303                 2304  \
# PurchaseId                     CA-2017-157931       CA-2017-157931
# PurchaseDate              2017-09-17 00:00:00  2017-09-17 00:00:00
# ShipDate                  2017-09-22 00:00:00  2017-09-22 00:00:00
# ShipMode                         Second Class         Second Class
# CustomerId                           MO-17800             MO-17800
# CustomerName                     Meg O'Connel         Meg O'Connel
# Segment                           Home Office          Home Office
# Country                         United States        United States
# City                                  Roswell              Roswell
# State                                 Georgia              Georgia
# PostalCode                              30076                30076
# Region                                  South                South
# ProductId                     FUR-CH-10000785      OFF-PA-10000474
# Category                            Furniture      Office Supplies
# SubCategory                            Chairs                Paper
# ProductName   Global Ergonomic Managers Chair    Easy-staple paper
# Sales                                  723.92               106.32
# Quantity                                    4                    3
# Discount                                  0.0                  0.0
# Profit                               188.2192              49.9704
#
#                                                            3026  \
# PurchaseId                                       CA-2017-169054
# PurchaseDate                                2017-04-22 00:00:00
# ShipDate                                    2017-04-26 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             MO-17800
# CustomerName                                       Meg O'Connel
# Segment                                             Home Office
# Country                                           United States
# City                                               Philadelphia
# State                                              Pennsylvania
# PostalCode                                                19140
# Region                                                     East
# ProductId                                       FUR-FU-10001488
# Category                                              Furniture
# SubCategory                                         Furnishings
# ProductName   Tenex 46" x 60" Computer Anti-Static Chairmat,...
# Sales                                                   254.352
# Quantity                                                      3
# Discount                                                    0.2
# Profit                                                      0.0
#
#                                                            3373  \
# PurchaseId                                       CA-2015-161718
# PurchaseDate                                2015-12-04 00:00:00
# ShipDate                                    2015-12-10 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             SO-20335
# CustomerName                                     Sean O'Donnell
# Segment                                                Consumer
# Country                                           United States
# City                                                  Hempstead
# State                                                  New York
# PostalCode                                                11550
# Region                                                     East
# ProductId                                       FUR-FU-10002445
# Category                                              Furniture
# SubCategory                                         Furnishings
# ProductName   DAX Two-Tone Rosewood/Black Document Frame, De...
# Sales                                                     28.44
# Quantity                                                      3
# Discount                                                    0.0
# Profit                                                   11.376
#
#                                                          3374  \
# PurchaseId                                     CA-2015-161718
# PurchaseDate                              2015-12-04 00:00:00
# ShipDate                                  2015-12-10 00:00:00
# ShipMode                                       Standard Class
# CustomerId                                           SO-20335
# CustomerName                                   Sean O'Donnell
# Segment                                              Consumer
# Country                                         United States
# City                                                Hempstead
# State                                                New York
# PostalCode                                              11550
# Region                                                   East
# ProductId                                     FUR-CH-10002372
# Category                                            Furniture
# SubCategory                                            Chairs
# ProductName   Office Star - Ergonomically Designed Knee Chair
# Sales                                                  364.41
# Quantity                                                    5
# Discount                                                  0.1
# Profit                                                  8.098
#
#                                    3375  \
# PurchaseId               CA-2015-161718
# PurchaseDate        2015-12-04 00:00:00
# ShipDate            2015-12-10 00:00:00
# ShipMode                 Standard Class
# CustomerId                     SO-20335
# CustomerName             Sean O'Donnell
# Segment                        Consumer
# Country                   United States
# City                          Hempstead
# State                          New York
# PostalCode                        11550
# Region                             East
# ProductId               TEC-PH-10000376
# Category                     Technology
# SubCategory                      Phones
# ProductName   Square Credit Card Reader
# Sales                             39.96
# Quantity                              4
# Discount                            0.0
# Profit                          10.3896
#
#                                                            3376  \
# PurchaseId                                       CA-2015-161718
# PurchaseDate                                2015-12-04 00:00:00
# ShipDate                                    2015-12-10 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             SO-20335
# CustomerName                                     Sean O'Donnell
# Segment                                                Consumer
# Country                                           United States
# City                                                  Hempstead
# State                                                  New York
# PostalCode                                                11550
# Region                                                     East
# ProductId                                       FUR-CH-10002965
# Category                                              Furniture
# SubCategory                                              Chairs
# ProductName   Global Leather Highback Executive Chair with P...
# Sales                                                   361.764
# Quantity                                                      2
# Discount                                                    0.1
# Profit                                                  68.3332
#
#                                                            3444  \
# PurchaseId                                       CA-2016-116344
# PurchaseDate                                2016-07-29 00:00:00
# ShipDate                                    2016-08-02 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             JO-15145
# CustomerName                                      Jack O'Briant
# Segment                                               Corporate
# Country                                           United States
# City                                               Philadelphia
# State                                              Pennsylvania
# PostalCode                                                19140
# Region                                                     East
# ProductId                                       OFF-ST-10001713
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Gould Plastics 9-Pocket Panel Bin, 18-3/8w x 5...
# Sales                                                    84.784
# Quantity                                                      2
# Discount                                                    0.2
# Profit                                                 -16.9568
#
#                              3502                                    3503  \
# PurchaseId         CA-2017-125115                          CA-2017-125115
# PurchaseDate  2017-04-10 00:00:00                     2017-04-10 00:00:00
# ShipDate      2017-04-10 00:00:00                     2017-04-10 00:00:00
# ShipMode                 Same Day                                Same Day
# CustomerId               RD-19930                                RD-19930
# CustomerName    Russell D'Ascenzo                       Russell D'Ascenzo
# Segment                  Consumer                                Consumer
# Country             United States                           United States
# City                       Austin                                  Austin
# State                       Texas                                   Texas
# PostalCode                  78745                                   78745
# Region                    Central                                 Central
# ProductId         OFF-PA-10004101                         TEC-AC-10001714
# Category          Office Supplies                              Technology
# SubCategory                 Paper                             Accessories
# ProductName            Xerox 1894  Logitech MX Performance Wireless Mouse
# Sales                      10.368                                  95.736
# Quantity                        2                                       3
# Discount                      0.2                                     0.2
# Profit                     3.6288                                 20.3439
#
#                                 3554                              3555  \
# PurchaseId            CA-2014-120838                    CA-2014-120838
# PurchaseDate     2014-03-23 00:00:00               2014-03-23 00:00:00
# ShipDate         2014-03-26 00:00:00               2014-03-26 00:00:00
# ShipMode                Second Class                      Second Class
# CustomerId                  PO-18865                          PO-18865
# CustomerName       Patrick O'Donnell                 Patrick O'Donnell
# Segment                     Consumer                          Consumer
# Country                United States                     United States
# City                     Los Angeles                       Los Angeles
# State                     California                        California
# PostalCode                     90036                             90036
# Region                          West                              West
# ProductId            OFF-ST-10000585                   TEC-PH-10003484
# Category             Office Supplies                        Technology
# SubCategory                  Storage                            Phones
# ProductName   Economy Rollaway Files  Ooma Telo VoIP Home Phone System
# Sales                          330.4                           604.752
# Quantity                           2                                 6
# Discount                         0.0                               0.2
# Profit                        85.904                            37.797
#
#                                                            3951  \
# PurchaseId                                       CA-2014-121167
# PurchaseDate                                2014-11-28 00:00:00
# ShipDate                                    2014-11-30 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             MO-17500
# CustomerName                                      Mary O'Rourke
# Segment                                                Consumer
# Country                                           United States
# City                                                   Freeport
# State                                                  New York
# PostalCode                                                11520
# ...
# State                                                     Texas
# PostalCode                                                77070
# Region                                                  Central
# ProductId                                       TEC-PH-10003437
# Category                                             Technology
# SubCategory                                              Phones
# ProductName   Blue Parrot B250XT Professional Grade Wireless...
# Sales                                                    299.96
# Quantity                                                      5
# Discount                                                    0.2
# Profit                                                   37.495
#
#                                                       8959  \
# PurchaseId                                  CA-2017-150266
# PurchaseDate                           2017-11-25 00:00:00
# ShipDate                               2017-11-30 00:00:00
# ShipMode                                    Standard Class
# CustomerId                                        RO-19780
# CustomerName                                  Rose O'Brian
# Segment                                           Consumer
# Country                                      United States
# City                                               Houston
# State                                                Texas
# PostalCode                                           77070
# Region                                             Central
# ProductId                                  OFF-AP-10002867
# Category                                   Office Supplies
# SubCategory                                     Appliances
# ProductName   Fellowes Command Center 5-outlet power strip
# Sales                                                67.84
# Quantity                                                 5
# Discount                                               0.8
# Profit                                            -179.776
#
#                                                        8960  \
# PurchaseId                                   CA-2017-150266
# PurchaseDate                            2017-11-25 00:00:00
# ShipDate                                2017-11-30 00:00:00
# ShipMode                                     Standard Class
# CustomerId                                         RO-19780
# CustomerName                                   Rose O'Brian
# Segment                                            Consumer
# Country                                       United States
# City                                                Houston
# State                                                 Texas
# PostalCode                                            77070
# Region                                              Central
# ProductId                                   FUR-CH-10002126
# Category                                          Furniture
# SubCategory                                          Chairs
# ProductName   Hon Deluxe Fabric Upholstered Stacking Chairs
# Sales                                                853.93
# Quantity                                                  5
# Discount                                                0.3
# Profit                                              -24.398
#
#                                                 8961  \
# PurchaseId                            CA-2017-150266
# PurchaseDate                     2017-11-25 00:00:00
# ShipDate                         2017-11-30 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  RO-19780
# CustomerName                            Rose O'Brian
# Segment                                     Consumer
# Country                                United States
# City                                         Houston
# State                                          Texas
# PostalCode                                     77070
# Region                                       Central
# ProductId                            OFF-AR-10001761
# Category                             Office Supplies
# SubCategory                                      Art
# ProductName   Avery Hi-Liter Smear-Safe Highlighters
# Sales                                         18.688
# Quantity                                           4
# Discount                                         0.2
# Profit                                        3.7376
#
#                                                            9027  \
# PurchaseId                                       US-2016-152415
# PurchaseDate                                2016-09-17 00:00:00
# ShipDate                                    2016-09-22 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PO-18865
# CustomerName                                  Patrick O'Donnell
# Segment                                                Consumer
# Country                                           United States
# City                                                Marlborough
# State                                             Massachusetts
# PostalCode                                                 1752
# Region                                                     East
# ProductId                                       FUR-FU-10002597
# Category                                              Furniture
# SubCategory                                         Furnishings
# ProductName   C-Line Magnetic Cubicle Keepers, Clear Polypro...
# Sales                                                     14.82
# Quantity                                                      3
# Discount                                                    0.0
# Profit                                                   6.2244
#
#                                                            9028  \
# PurchaseId                                       US-2016-152415
# PurchaseDate                                2016-09-17 00:00:00
# ShipDate                                    2016-09-22 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PO-18865
# CustomerName                                  Patrick O'Donnell
# Segment                                                Consumer
# Country                                           United States
# City                                                Marlborough
# State                                             Massachusetts
# PostalCode                                                 1752
# Region                                                     East
# ProductId                                       FUR-FU-10004864
# Category                                              Furniture
# SubCategory                                         Furnishings
# ProductName   Howard Miller 14-1/2" Diameter Chrome Round Wa...
# Sales                                                    191.82
# Quantity                                                      3
# Discount                                                    0.0
# Profit                                                  61.3824
#
#                                               9252                 9253  \
# PurchaseId                          CA-2017-102309       CA-2017-102309
# PurchaseDate                   2017-09-23 00:00:00  2017-09-23 00:00:00
# ShipDate                       2017-09-25 00:00:00  2017-09-25 00:00:00
# ShipMode                              Second Class         Second Class
# CustomerId                                DO-13645             DO-13645
# CustomerName                        Doug O'Connell       Doug O'Connell
# Segment                                   Consumer             Consumer
# Country                              United States        United States
# City                                    Pine Bluff           Pine Bluff
# State                                     Arkansas             Arkansas
# PostalCode                                   71603                71603
# Region                                       South                South
# ProductId                          TEC-AC-10001114      OFF-PA-10002005
# Category                                Technology      Office Supplies
# SubCategory                            Accessories                Paper
# ProductName   Microsoft Wireless Mobile Mouse 4000            Xerox 225
# Sales                                       199.95                12.96
# Quantity                                         5                    2
# Discount                                       0.0                  0.0
# Profit                                      63.984               6.2208
#
#                                                     9352  \
# PurchaseId                                CA-2017-148411
# PurchaseDate                         2017-09-24 00:00:00
# ShipDate                             2017-09-26 00:00:00
# ShipMode                                     First Class
# CustomerId                                      RO-19780
# CustomerName                                Rose O'Brian
# Segment                                         Consumer
# Country                                    United States
# City                                             Chicago
# State                                           Illinois
# PostalCode                                         60623
# Region                                           Central
# ProductId                                FUR-CH-10003973
# Category                                       Furniture
# SubCategory                                       Chairs
# ProductName   GuestStacker Chair with Chrome Finish Legs
# Sales                                            520.464
# Quantity                                               2
# Discount                                             0.3
# Profit                                          -14.8704
#
#                                           9353  \
# PurchaseId                      CA-2017-148411
# PurchaseDate               2017-09-24 00:00:00
# ShipDate                   2017-09-26 00:00:00
# ShipMode                           First Class
# CustomerId                            RO-19780
# CustomerName                      Rose O'Brian
# Segment                               Consumer
# Country                          United States
# City                                   Chicago
# State                                 Illinois
# PostalCode                               60623
# Region                                 Central
# ProductId                      OFF-PA-10002109
# Category                       Office Supplies
# SubCategory                              Paper
# ProductName   Wirebound Voice Message Log Book
# Sales                                   11.424
# Quantity                                     3
# Discount                                   0.2
# Profit                                  3.7128
#
#                                          9376  \
# PurchaseId                     CA-2017-108756
# PurchaseDate              2017-12-25 00:00:00
# ShipDate                  2017-12-29 00:00:00
# ShipMode                       Standard Class
# CustomerId                           PO-18865
# CustomerName                Patrick O'Donnell
# Segment                              Consumer
# Country                         United States
# City                              East Orange
# State                              New Jersey
# PostalCode                               7017
# Region                                   East
# ProductId                     TEC-AC-10003237
# Category                           Technology
# SubCategory                       Accessories
# ProductName   Memorex Micro Travel Drive 4 GB
# Sales                                    31.8
# Quantity                                    3
# Discount                                  0.0
# Profit                                 13.674
#
#                                                            9427  \
# PurchaseId                                       CA-2014-167486
# PurchaseDate                                2014-11-27 00:00:00
# ShipDate                                    2014-12-01 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             JO-15145
# CustomerName                                      Jack O'Briant
# Segment                                               Corporate
# Country                                           United States
# City                                                    Buffalo
# State                                                  New York
# PostalCode                                                14215
# Region                                                     East
# ProductId                                       FUR-FU-10003268
# Category                                              Furniture
# SubCategory                                         Furnishings
# ProductName   Eldon Radial Chair Mat for Low to Medium Pile ...
# Sales                                                     199.9
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                    39.98
#
#                                   9450  \
# PurchaseId              CA-2017-145506
# PurchaseDate       2017-06-03 00:00:00
# ShipDate           2017-06-07 00:00:00
# ShipMode                Standard Class
# CustomerId                    MO-17800
# CustomerName              Meg O'Connel
# Segment                    Home Office
# Country                  United States
# City                           Spokane
# State                       Washington
# PostalCode                       99207
# Region                            West
# ProductId              OFF-ST-10004963
# Category               Office Supplies
# SubCategory                    Storage
# ProductName   Eldon Gobal File Keepers
# Sales                           136.26
# Quantity                             9
# Discount                           0.0
# Profit                          5.4504
#
#                                                            9691
# PurchaseId                                       CA-2015-130183
# PurchaseDate                                2015-11-13 00:00:00
# ShipDate                                    2015-11-17 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PO-18850
# CustomerName                                    Patrick O'Brill
# Segment                                                Consumer
# Country                                           United States
# City                                                    Houston
# State                                                     Texas
# PostalCode                                                77041
# Region                                                  Central
# ProductId                                       FUR-BO-10001811
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName   Atlantic Metals Mobile 5-Shelf Bookcases, Cust...
# Sales                                                  613.9992
# Quantity                                                      3
# Discount                                                   0.32
# Profit                                                 -18.0588

# %%
# Ensure there is space between name and surname 

# Regular expression pattern to detect names with at least one space 
space_pattern = r'\s'

# Function to check if a name contains a space
def contains_space(name):
    return bool(re.search(space_pattern, name))

# Apply the function to create a boolean mask
mask3 = df['CustomerName'].apply(contains_space)

# Filter the DataFrame to find names without spaces
df[~mask3]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# Split the CustomerName column based on the last space and create 2 columns as: FirstName, LastName

df[['FirstName', 'LastName']] = df['CustomerName'].str.rsplit(n=1, expand=True)

# %%
# Check the frequency distribution of names to identify common and rare names.

# Get frequency count of each name

first_name_counts = df['FirstName'].value_counts()

 # Display most common names
 
first_name_counts.tail(20)
# Out:
# FirstName
# Grant         6
# Angele        5
# Georgia       5
# Claire        5
# Aleksandra    5
# Melanie       5
# Astrea        5
# Victor        5
# Elpida        5
# Jenna         4
# Eileen        4
# Jasper        4
# Ionia         4
# Ritsa         3
# Thais         2
# Patricia      2
# Stefanie      2
# Anemone       2
# Jocasta       1
# Lela          1
# Name: count, dtype: int64

# %%
# Get frequency count of each lastname

last_name_counts = df['LastName'].value_counts()

 # Display least common lastnames

last_name_counts.tail(20)
# Out:
# LastName
# Caffey       4
# Taslimi      3
# Weirich      3
# Skaria       3
# Hightower    3
# Jenkins      3
# Shami        3
# Tron         3
# Thomas       3
# Hale         3
# Blacks       3
# Ratner       2
# Holloman     2
# Hirasaki     2
# Sissman      2
# Odegard      2
# Breyer       2
# Donovan      1
# Rupert       1
# Emerson      1
# Name: count, dtype: int64

# %%
# Function to check for unusual characters and patterns

def is_unusual_name(name):
    # Check for names with digits
    if re.search(r'[0-9]', name):  # Names with digits
        return True
    # Check for names with invalid special characters, excluding apostrophes and 'ö' since there are real names includes both
    if re.search(r'[^a-zA-Z\s\'ö-]', name):  # Names with invalid special characters
        return True
    # Check for unusually short or long names
    if len(name) < 2 or len(name) > 50:  # Unusually short or long names
        return True
    return False

# Apply function to identify unusual names

df['UnusualName'] = df['FirstName'].apply(is_unusual_name)

# Filter names flagged as unusual

unusual_names_df = df[df['UnusualName']]

unusual_names_df
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, UnusualName]
# Index: []

# %%
# Function to check for unusual characters and patterns
# included 'ö', 'ä', 'ü' as we have Eurepean names which have these characters 

def is_unusual_lastname(name):
    # Check for names with digits
    if re.search(r'[0-9]', name):
        return True
    # Check for names with invalid special characters, excluding apostrophes, 'ö', 'ä', 'ü', and hyphens
    if re.search(r'[^a-zA-Z\s\'öäü-]', name):  # Names with invalid special characters
        return True
    # Check for unusually short or long names
    if len(name) < 2 or len(name) > 50:  # Unusually short or long names
        return True
    return False

# Apply function to identify unusual last names

df['UnusualLastName'] = df['LastName'].apply(is_unusual_lastname)

# Filter names flagged as unusual

unusual_lastnames_df = df[df['UnusualLastName']]

# Display the DataFrame with unusual last names

unusual_lastnames_df.T
# Out:
#                                              912   \
# PurchaseId                         CA-2015-133627
# PurchaseDate                  2015-05-31 00:00:00
# ShipDate                      2015-06-07 00:00:00
# ShipMode                           Standard Class
# CustomerId                               SC-20050
# CustomerName                     Sample Company A
# Segment                               Home Office
# Country                             United States
# City                                      Norwich
# State                                 Connecticut
# PostalCode                                   6360
# Region                                       East
# ProductId                         FUR-FU-10001935
# Category                                Furniture
# SubCategory                           Furnishings
# ProductName      3M Hangers With Command Adhesive
# Sales                                        22.2
# Quantity                                        6
# Discount                                      0.0
# Profit                                      9.102
# FirstName                          Sample Company
# LastName                                        A
# UnusualName                                 False
# UnusualLastName                              True
#
#                                                               2004  \
# PurchaseId                                          US-2017-143028
# PurchaseDate                                   2017-04-11 00:00:00
# ShipDate                                       2017-04-18 00:00:00
# ShipMode                                            Standard Class
# CustomerId                                                SC-20050
# CustomerName                                      Sample Company A
# Segment                                                Home Office
# Country                                              United States
# City                                                       Lubbock
# State                                                        Texas
# PostalCode                                                   79424
# Region                                                     Central
# ProductId                                          OFF-BI-10004738
# Category                                           Office Supplies
# SubCategory                                                Binders
# ProductName      Flexible Leather- Look Classic Collection Ring...
# Sales                                                       11.364
# Quantity                                                         3
# Discount                                                       0.8
# Profit                                                     -17.046
# FirstName                                           Sample Company
# LastName                                                         A
# UnusualName                                                  False
# UnusualLastName                                               True
#
#                                              3661  \
# PurchaseId                         CA-2016-155005
# PurchaseDate                  2016-06-13 00:00:00
# ShipDate                      2016-06-15 00:00:00
# ShipMode                             Second Class
# CustomerId                               SC-20050
# CustomerName                     Sample Company A
# Segment                               Home Office
# Country                             United States
# City                                      Jackson
# State                                    Michigan
# PostalCode                                  49201
# Region                                    Central
# ProductId                         TEC-PH-10003484
# Category                               Technology
# SubCategory                                Phones
# ProductName      Ooma Telo VoIP Home Phone System
# Sales                                      377.97
# Quantity                                        3
# Discount                                      0.0
# Profit                                    94.4925
# FirstName                          Sample Company
# LastName                                        A
# UnusualName                                 False
# UnusualLastName                              True
#
#                                             4840                 4998  \
# PurchaseId                        CA-2017-154123       CA-2016-129238
# PurchaseDate                 2017-11-20 00:00:00  2016-01-31 00:00:00
# ShipDate                     2017-11-25 00:00:00  2016-02-04 00:00:00
# ShipMode                          Standard Class       Standard Class
# CustomerId                              SC-20050             SC-20050
# CustomerName                    Sample Company A     Sample Company A
# Segment                              Home Office          Home Office
# Country                            United States        United States
# City                                   Henderson          Los Angeles
# State                                   Kentucky           California
# PostalCode                                 42420                90045
# Region                                     South                 West
# ProductId                        FUR-FU-10000629      TEC-PH-10004120
# Category                               Furniture           Technology
# SubCategory                          Furnishings               Phones
# ProductName      9-3/4 Diameter Round Wall Clock      AT&T 1080 Phone
# Sales                                      27.58              109.592
# Quantity                                       2                    1
# Discount                                     0.0                  0.2
# Profit                                   11.5836               8.2194
# FirstName                         Sample Company       Sample Company
# LastName                                       A                    A
# UnusualName                                False                False
# UnusualLastName                             True                 True
#
#                                 4999  \
# PurchaseId            CA-2016-129238
# PurchaseDate     2016-01-31 00:00:00
# ShipDate         2016-02-04 00:00:00
# ShipMode              Standard Class
# CustomerId                  SC-20050
# CustomerName        Sample Company A
# Segment                  Home Office
# Country                United States
# City                     Los Angeles
# State                     California
# PostalCode                     90045
# Region                          West
# ProductId            OFF-PA-10002764
# Category             Office Supplies
# SubCategory                    Paper
# ProductName        Easy-staple paper
# Sales                           56.7
# Quantity                           5
# Discount                         0.0
# Profit                        27.783
# FirstName             Sample Company
# LastName                           A
# UnusualName                    False
# UnusualLastName                 True
#
#                                                               5635  \
# PurchaseId                                          CA-2017-123022
# PurchaseDate                                   2017-09-03 00:00:00
# ShipDate                                       2017-09-08 00:00:00
# ShipMode                                            Standard Class
# CustomerId                                                SC-20050
# CustomerName                                      Sample Company A
# Segment                                                Home Office
# Country                                              United States
# City                                                       La Mesa
# State                                                   California
# PostalCode                                                   91941
# Region                                                        West
# ProductId                                          OFF-BI-10002225
# Category                                           Office Supplies
# SubCategory                                                Binders
# ProductName      Square Ring Data Binders, Rigid 75 Pt. Covers,...
# Sales                                                        82.56
# Quantity                                                         5
# Discount                                                       0.2
# Profit                                                      28.896
# FirstName                                           Sample Company
# LastName                                                         A
# UnusualName                                                  False
# UnusualLastName                                               True
#
#                                                               5636  \
# PurchaseId                                          CA-2017-123022
# PurchaseDate                                   2017-09-03 00:00:00
# ShipDate                                       2017-09-08 00:00:00
# ShipMode                                            Standard Class
# CustomerId                                                SC-20050
# CustomerName                                      Sample Company A
# Segment                                                Home Office
# Country                                              United States
# City                                                       La Mesa
# State                                                   California
# PostalCode                                                   91941
# Region                                                        West
# ProductId                                          TEC-AC-10000474
# Category                                                Technology
# SubCategory                                            Accessories
# ProductName      Kensington Expert Mouse Optical USB Trackball ...
# Sales                                                       284.97
# Quantity                                                         3
# Discount                                                       0.0
# Profit                                                      85.491
# FirstName                                           Sample Company
# LastName                                                         A
# UnusualName                                                  False
# UnusualLastName                                               True
#
#                                                               7327  \
# PurchaseId                                          US-2014-131275
# PurchaseDate                                   2014-03-18 00:00:00
# ShipDate                                       2014-03-24 00:00:00
# ShipMode                                            Standard Class
# CustomerId                                                SC-20050
# CustomerName                                      Sample Company A
# Segment                                                Home Office
# Country                                              United States
# City                                                       Burbank
# State                                                   California
# PostalCode                                                   91505
# Region                                                        West
# ProductId                                          FUR-FU-10004597
# Category                                                 Furniture
# SubCategory                                            Furnishings
# ProductName      Eldon Cleatmat Chair Mats for Medium Pile Carpets
# Sales                                                        111.0
# Quantity                                                         2
# Discount                                                       0.0
# Profit                                                       14.43
# FirstName                                           Sample Company
# LastName                                                         A
# UnusualName                                                  False
# UnusualLastName                                               True
#
#                                                          7328  \
# PurchaseId                                     US-2014-131275
# PurchaseDate                              2014-03-18 00:00:00
# ShipDate                                  2014-03-24 00:00:00
# ShipMode                                       Standard Class
# CustomerId                                           SC-20050
# CustomerName                                 Sample Company A
# Segment                                           Home Office
# Country                                         United States
# City                                                  Burbank
# State                                              California
# PostalCode                                              91505
# Region                                                   West
# ProductId                                     TEC-MA-10001148
# Category                                           Technology
# SubCategory                                          Machines
# ProductName      Swingline SM12-08 MicroCut Jam Free Shredder
# Sales                                                1279.968
# Quantity                                                    4
# Discount                                                  0.2
# Profit                                               415.9896
# FirstName                                      Sample Company
# LastName                                                    A
# UnusualName                                             False
# UnusualLastName                                          True
#
#                                                   7329  \
# PurchaseId                              US-2014-131275
# PurchaseDate                       2014-03-18 00:00:00
# ShipDate                           2014-03-24 00:00:00
# ShipMode                                Standard Class
# CustomerId                                    SC-20050
# CustomerName                          Sample Company A
# Segment                                    Home Office
# Country                                  United States
# City                                           Burbank
# State                                       California
# PostalCode                                       91505
# Region                                            West
# ProductId                              OFF-ST-10000078
# Category                               Office Supplies
# SubCategory                                    Storage
# ProductName      Tennsco 6- and 18-Compartment Lockers
# Sales                                          1856.19
# Quantity                                             7
# Discount                                           0.0
# Profit                                        334.1142
# FirstName                               Sample Company
# LastName                                             A
# UnusualName                                      False
# UnusualLastName                                   True
#
#                                    9687  \
# PurchaseId               US-2017-130603
# PurchaseDate        2017-09-30 00:00:00
# ShipDate            2017-10-06 00:00:00
# ShipMode                 Standard Class
# CustomerId                     SC-20050
# CustomerName           Sample Company A
# Segment                     Home Office
# Country                   United States
# City                          Arlington
# State                             Texas
# PostalCode                        76017
# Region                          Central
# ProductId               OFF-BI-10000301
# Category                Office Supplies
# SubCategory                     Binders
# ProductName      GBC Instant Report Kit
# Sales                            11.646
# Quantity                              9
# Discount                            0.8
# Profit                          -17.469
# FirstName                Sample Company
# LastName                              A
# UnusualName                       False
# UnusualLastName                    True
#
#                                                               9769  \
# PurchaseId                                          CA-2016-123533
# PurchaseDate                                   2016-11-24 00:00:00
# ShipDate                                       2016-11-30 00:00:00
# ShipMode                                            Standard Class
# CustomerId                                                SC-20050
# CustomerName                                      Sample Company A
# Segment                                                Home Office
# Country                                              United States
# City                                                       Hialeah
# State                                                      Florida
# PostalCode                                                   33012
# Region                                                       South
# ProductId                                          FUR-BO-10001619
# Category                                                 Furniture
# SubCategory                                              Bookcases
# ProductName      O'Sullivan Cherrywood Estates Traditional Book...
# Sales                                                       339.92
# Quantity                                                         5
# Discount                                                       0.2
# Profit                                                       8.498
# FirstName                                           Sample Company
# LastName                                                         A
# UnusualName                                                  False
# UnusualLastName                                               True
#
#                                              9770  \
# PurchaseId                         CA-2016-123533
# PurchaseDate                  2016-11-24 00:00:00
# ShipDate                      2016-11-30 00:00:00
# ShipMode                           Standard Class
# CustomerId                               SC-20050
# CustomerName                     Sample Company A
# Segment                               Home Office
# Country                             United States
# City                                      Hialeah
# State                                     Florida
# PostalCode                                  33012
# Region                                      South
# ProductId                         OFF-PA-10001609
# Category                          Office Supplies
# SubCategory                                 Paper
# ProductName      Tops Wirebound Message Log Books
# Sales                                      10.528
# Quantity                                        4
# Discount                                      0.2
# Profit                                     3.4216
# FirstName                          Sample Company
# LastName                                        A
# UnusualName                                 False
# UnusualLastName                              True
#
#                                                               9771
# PurchaseId                                          CA-2016-123533
# PurchaseDate                                   2016-11-24 00:00:00
# ShipDate                                       2016-11-30 00:00:00
# ShipMode                                            Standard Class
# CustomerId                                                SC-20050
# CustomerName                                      Sample Company A
# Segment                                                Home Office
# Country                                              United States
# City                                                       Hialeah
# State                                                      Florida
# PostalCode                                                   33012
# Region                                                       South
# ProductId                                          OFF-AP-10002765
# Category                                           Office Supplies
# SubCategory                                             Appliances
# ProductName      Fellowes Advanced Computer Series Surge Protec...
# Sales                                                       42.384
# Quantity                                                         2
# Discount                                                       0.2
# Profit                                                      4.2384
# FirstName                                           Sample Company
# LastName                                                         A
# UnusualName                                                  False
# UnusualLastName                                               True

# %%
unusual_lastnames_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, 912 to 9771
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PurchaseId       15 non-null     object
#  1   PurchaseDate     15 non-null     datetime64[ns]
#  2   ShipDate         15 non-null     datetime64[ns]
#  3   ShipMode         15 non-null     object
#  4   CustomerId       15 non-null     object
#  5   CustomerName     15 non-null     object
#  6   Segment          15 non-null     object
#  7   Country          15 non-null     object
#  8   City             15 non-null     object
#  9   State            15 non-null     object
#  10  PostalCode       15 non-null     object
#  11  Region           15 non-null     object
#  12  ProductId        15 non-null     object
#  13  Category         15 non-null     object
#  14  SubCategory      15 non-null     object
#  15  ProductName      15 non-null     object
#  16  Sales            15 non-null     float64
#  17  Quantity         15 non-null     int32
#  18  Discount         15 non-null     float64
#  19  Profit           15 non-null     float64
#  20  FirstName        15 non-null     object
#  21  LastName         15 non-null     object
#  22  UnusualName      15 non-null     bool
#  23  UnusualLastName  15 non-null     bool
# dtypes: bool(2), datetime64[ns](2), float64(3), int32(1), object(16)
# memory usage: 3.2+ KB

# %%
# Identify and correct Sample Company entry in FirstName', 'LastName columns

df.loc[(df['FirstName'] == 'Sample Company') & (df['LastName'] == 'A'), ['FirstName', 'LastName']] = ['Sample', 'Company']

# %%
# Ensure that values are updated in CustomerName, FirstName', 'LastName columns


# Apply function to identify unusual last names

df['UnusualLastName'] = df['LastName'].apply(is_unusual_lastname)

# Filter names flagged as unusual

unusual_lastnames_df = df[df['UnusualLastName']]

# Display the DataFrame with unusual last names

unusual_lastnames_df
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, UnusualName, UnusualLastName]
# Index: []

# %%
# Sort the DataFrame alphabetically by 'FirstName' to check some values in FirstName column

sorted_df = df.sort_values(by='FirstName', ascending=True)

sorted_df['FirstName'].unique()
# Out:
# array(['Aaron', 'Adam', 'Adrian', 'Aimee', 'Alan', 'Alejandro',
#        'Aleksandra', 'Alex', 'Alice', 'Allen', 'Alyssa', 'Amy', 'Andrew',
#        'Andy', 'Anemone', 'Angele', 'Ann', 'Anna', 'Anne', 'Annie',
#        'Anthony', 'Arianne', 'Art', 'Arthur', 'Ashley', 'Astrea',
#        'Barbara', 'Barry', 'Bart', 'Becky', 'Ben', 'Benjamin', 'Berenike',
#        'Beth', 'Bill', 'Bobby', 'Brad', 'Bradley', 'Brenda', 'Brendan',
#        'Brian', 'Brooke', 'Brosina', 'Bruce', 'Bryan', 'Candace', 'Cari',
#        'Carl', 'Carlos', 'Carol', 'Caroline', 'Cassandra', 'Catherine',
#        'Cathy', 'Chad', 'Charles', 'Charlotte', 'Chloris', 'Chris',
#        'Christina', 'Christine', 'Christopher', 'Christy', 'Chuck',
#        'Cindy', 'Claire', 'Claudia', 'Clay', 'Clytie', 'Corey', 'Corinna',
#        'Craig', 'Cyma', 'Cynthia', 'Cyra', 'Damala', 'Dan', 'Dana',
#        'Daniel', 'Dario', 'Darren', 'Darrin', 'Darrin Van', 'Dave',
#        'David', 'Dean', 'Deanra', 'Deborah', 'Debra', 'Deirdre',
#        'Delfina', 'Denise', 'Dennis', 'Denny', 'Dianna', 'Dionis', 'Don',
#        'Dorothy', 'Dorris', 'Doug', 'Duane', 'Ed', 'Edward', 'Eileen',
#        'Eleni', 'Elizabeth', 'Ellis', 'Elpida', 'Emily', 'Eric', 'Erica',
#        'Erin', 'Eudokia', 'Eugene', 'Eva', 'Evan', 'Filia', 'Frank',
#        'Fred', 'Gary', 'Gene', 'George', 'Georgia', 'Giulietta', 'Grace',
#        'Grant', 'Greg', 'Guy', 'Hallie', 'Harold', 'Harry', 'Heather',
#        'Helen', 'Henia', 'Henry', 'Herbert', 'Hilary', 'Hunter', 'Ionia',
#        'Irene', 'Ivan', 'Jack', 'James', 'Jamie', 'Jane', 'Janet', 'Jas',
#        'Jason', 'Jasper', 'Jay', 'Jenna', 'Jennifer', 'Jeremy', 'Jessica',
#        'Jesus', 'Jill', 'Jim', 'Jocasta', 'Joe', 'Joel', 'John',
#        'Jonathan', 'Joni', 'Joseph', 'Joy', 'Julia', 'Juliana', 'Julie',
#        'Justin', 'Kalyca', 'Karen', 'Karl', 'Katharine', 'Katherine',
#        'Katrina', 'Kean', 'Keith', 'Kelly', 'Ken', 'Khloe', 'Kimberly',
#        'Kristen', 'Kristina', 'Kunst', 'Larry', 'Laura', 'Laurel',
#        'Lauren', 'Lela', 'Lena', 'Linda', 'Lindsay', 'Lisa', 'Liz',
#        'Logan', 'Lori', 'Luke', 'Lycoris', 'Lynn', 'Magdelene', 'Marc',
#        'Maria', 'Maribeth', 'Marina', 'Maris', 'Mark', 'Mark Van', 'Mary',
#        'Marybeth', 'Mathew', 'Matt', 'Matthew', 'Maureen', 'Maurice',
#        'Max', 'Maxwell', 'Maya', 'Meg', 'Melanie', 'Michael', 'Michelle',
#        'Mick', 'Mike', 'Mitch', 'Monica', 'Muhammed', 'Nancy', 'Naresj',
#        'Nat', 'Natalie', 'Nathan', 'Neil', 'Neola', 'Neoma', 'Nick',
#        'Nicole', 'Noah', 'Noel', 'Nona', 'Nora', 'Odella', 'Olvera',
#        'Pamela', 'Parhena', 'Patricia', 'Patrick', 'Paul', 'Paul Van',
#        'Pauline', 'Penelope', 'Pete', 'Peter', 'Philip', 'Philisse',
#        'Phillina', 'Phillip', 'Pierre', 'Quincy', 'Rachel', 'Ralph',
#        'Randy', 'Raymond', 'Resi', 'Ricardo', 'Richard', 'Rick', 'Ritsa',
#        'Rob', 'Robert', 'Roger', 'Roland', 'Rose', 'Ross', 'Roy', 'Ruben',
#        'Russell', 'Ryan', 'Sally', 'Sam', 'Sample', 'Sandra', 'Sanjit',
#        'Saphhira', 'Sara', 'Sarah', 'Scot', 'Scott', 'Sean', 'Seth',
#        'Shahid', 'Sharelle', 'Shaun', 'Sheri', 'Shirley', 'Shui',
#        'Sibella', 'Skye', 'Sonia', 'Speros', 'Stefania', 'Stefanie',
#        'Stephanie', 'Steve', 'Steven', 'Stewart', 'Stuart', 'Sue Ann',
#        'Sung', 'Susan', 'Suzanne', 'Sylvia', 'Tamara', 'Tanja', 'Ted',
#        'Thais', 'Thea', 'Theone', 'Theresa', 'Thomas', 'Tiffany', 'Tim',
#        'Toby', 'Todd', 'Tom', 'Tonja', 'Tony', 'Tracy', 'Troy', 'Trudy',
#        'Valerie', 'Vicky', 'Victor', 'Victoria', 'Vivek', 'Vivian',
#        'William', 'Xylona', 'Yana', 'Yoseph', 'Zuschuss'], dtype=object)

# %%
# Some Entries has Zuschuss as FirstName value which does not seem like a real name. 

# Step 1: Create a boolean mask where 'FirstName' is 'Zuschuss'
df_name_test = df['FirstName'] == 'Zuschuss'

# Step 2: Apply the mask to filter the DataFrame
filtered_df = df[df_name_test]

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, 18 to 8923
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PurchaseId       40 non-null     object
#  1   PurchaseDate     40 non-null     datetime64[ns]
#  2   ShipDate         40 non-null     datetime64[ns]
#  3   ShipMode         40 non-null     object
#  4   CustomerId       40 non-null     object
#  5   CustomerName     40 non-null     object
#  6   Segment          40 non-null     object
#  7   Country          40 non-null     object
#  8   City             40 non-null     object
#  9   State            40 non-null     object
#  10  PostalCode       40 non-null     object
#  11  Region           40 non-null     object
#  12  ProductId        40 non-null     object
#  13  Category         40 non-null     object
#  14  SubCategory      40 non-null     object
#  15  ProductName      40 non-null     object
#  16  Sales            40 non-null     float64
#  17  Quantity         40 non-null     int32
#  18  Discount         40 non-null     float64
#  19  Profit           40 non-null     float64
#  20  FirstName        40 non-null     object
#  21  LastName         40 non-null     object
#  22  UnusualName      40 non-null     bool
#  23  UnusualLastName  40 non-null     bool
# dtypes: bool(2), datetime64[ns](2), float64(3), int32(1), object(16)
# memory usage: 7.1+ KB

# %% [markdown]
# #### Entries with 'Zuschuss' as FirstName:
#
#     There are 40 records where the FirstName is 'Zuschuss'. These entries belong to 2 distinct customers.
#     We will not be removing or editing these records at this time, as we can not communicate and solve it with business owner. However, this has been noted.
#
# #### Entries with 'Sample Company' and 'A':
#
#     There are 15 records where the CustomerName is 'Sample Company' and the LastName is 'A'.
#     We have decided not to remove these records as they contain valuable information in other fields. This issue has also been noted for future correction.
#
# #### The FirstName, LastName, and CustomerName columns have been reviewed to ensure they have the correct format and do not contain unusual values.
# #### 8 Entry were corrected which include an invalid character(hypens) (1 Customer with 8 entries: Corey-Lock)

# %% [markdown]
# ## 7: Segment<a id="7"></a>

# %%
df['Segment'].unique()
# Out:
# array(['Consumer', 'Corporate', 'Home Office'], dtype=object)

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %% [markdown]
# ## 8: Country<a id="8"></a>

# %%
df['Country'].nunique()
# Out:
# 1

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %% [markdown]
# ## 9: City<a id="9"></a>

# %%
df.nunique()
# Out:
# PurchaseId         5009
# PurchaseDate       1237
# ShipDate           1334
# ShipMode              4
# CustomerId          793
# CustomerName        793
# Segment               3
# Country               1
# City                531
# State                49
# PostalCode          631
# Region                4
# ProductId          1862
# Category              3
# SubCategory          17
# ProductName        1850
# Sales              5825
# Quantity             14
# Discount             12
# Profit             7287
# FirstName           340
# LastName            588
# UnusualName           1
# UnusualLastName       1
# dtype: int64

# %%
# Create a new DataFrame that shows the count of each unique city in the City column

city_counts = df['City'].value_counts()

city_counts_df = city_counts.reset_index()
city_counts_df.columns = ['City', 'Count']

city_counts_df = city_counts_df.sort_values(by='Count', ascending=False)

city_counts_df
# Out:
#                   City  Count
# 0        New York City    915
# 1          Los Angeles    747
# 2         Philadelphia    537
# 3        San Francisco    510
# 4              Seattle    428
# ..                 ...    ...
# 483         Hagerstown      1
# 482  Arlington Heights      1
# 481            Baytown      1
# 479    San Luis Obispo      1
# 530          Manhattan      1
#
# [531 rows x 2 columns]

# %%
city_counts_df.head(50).T
# Out:
#                   0            1             2              3        4   \
# City   New York City  Los Angeles  Philadelphia  San Francisco  Seattle
# Count            915          747           537            510      428
#
#             5        6         7          8            9       10  \
# City   Houston  Chicago  Columbus  San Diego  Springfield  Dallas
# Count      377      314       222        170          163     157
#
#                  11       12      13        14       15        16      17  \
# City   Jacksonville  Detroit  Newark  Richmond  Jackson  Columbia  Aurora
# Count           125      115      95        90       82        81      68
#
#             18          19         20           21     22          23  \
# City   Phoenix  Long Beach  Arlington  San Antonio  Miami  Louisville
# Count       63          61         60           59     57          57
#
#               24         25         26        27         28         29  \
# City   Rochester  Charlotte  Henderson  Lakewood  Lancaster  Fairfield
# Count         53         52         51        49         46         45
#
#               30      31        32         33        35        36         34  \
# City   Milwaukee  Denver  Lawrence  Baltimore  Pasadena  San Jose  Cleveland
# Count         45      44        44         43        42        42         42
#
#                  37     38       39      40        41     42          43  \
# City   Fayetteville  Salem  Atlanta  Austin  Franklin  Tampa  Wilmington
# Count            41     40       39      39        37     36          36
#
#                44       45      46      47          48         49
# City   Huntsville  Decatur  Toledo  Tucson  Providence  Lafayette
# Count          36       35      32      32          31         31

# %%
city_counts_df.tail(50).T
# Out:
#                 496            527       526        525            524  \
# City   Redwood City  Missouri City  Glenview  San Mateo  Commerce City
# Count             1              1         1          1              1
#
#            522     515        521         520       519          518     517  \
# City   Holyoke  Normal  Goldsboro  Montebello  Waukesha  Orland Park  Conroe
# Count        1       1          1           1         1            1       1
#
#            516       497        480        495          468      474      473  \
# City   Abilene  Bartlett  Champaign  La Quinta  Tinley Park  Antioch  Ontario
# Count        1         1          1          1            1        1        1
#
#              472            471      470    469        467           476  \
# City   Melbourne  Atlantic City  Portage  Davis  Littleton  Ormond Beach
# Count          1              1        1      1          1             1
#
#                   466     465     464      463        462        461  \
# City   Citrus Heights  Linden  Rogers  Danbury  Iowa City  Kissimmee
# Count               1       1       1        1          1          1
#
#              475             477     494        487          493      492  \
# City   Deer Park  Jefferson City  Conway  Rock Hill  Port Orange  Margate
# Count          1               1       1          1            1        1
#
#             491            490         489       488           486  \
# City   Missoula  Lake Elsinore  Romeoville  Murrieta  Saint Peters
# Count         1              1           1         1             1
#
#               478       485     484         483                482      481  \
# City   Springdale  Aberdeen  Elyria  Hagerstown  Arlington Heights  Baytown
# Count           1         1       1           1                  1        1
#
#                    479        530
# City   San Luis Obispo  Manhattan
# Count                1          1

# %%
city_counts_df = city_counts_df.sort_values(by='City')

city_counts_df.head(50).T
# Out:
#             485      516    80           118         97     335        212  \
# City   Aberdeen  Abilene  Akron  Albuquerque  Alexandria  Allen  Allentown
# Count         1        1     21           14          16      4          7
#
#            407       167      58       345        272      474     210  \
# City   Altoona  Amarillo  Anaheim  Andover  Ann Arbor  Antioch  Apopka
# Count        2        10       27        4          5        1       7
#
#                 178       399        20                 482     340  \
# City   Apple Valley  Appleton  Arlington  Arlington Heights  Arvada
# Count             9         2         60                  1       4
#
#              225     192      39             471     70      17      40   \
# City   Asheville  Athens  Atlanta  Atlantic City  Auburn  Aurora  Austin
# Count          7       8       39              1      24      68      39
#
#             264          99         33      266       497      383      481  \
# City   Avondale  Bakersfield  Baltimore  Bangor  Bartlett  Bayonne  Baytown
# Count         6           16         43       5         1        3        1
#
#             280      269         166       251         386        268  \
# City   Beaumont  Bedford  Belleville  Bellevue  Bellingham  Bethlehem
# Count         5        5          10         6           3          5
#
#            369       498          106         353    320          259  \
# City   Beverly  Billings  Bloomington  Boca Raton  Boise  Bolingbrook
# Count        3         1           15           3      4            6
#
#                 241            152            154      424        103
# City   Bossier City  Bowling Green  Boynton Beach  Bozeman  Brentwood
# Count             6             10             10        2         16

# %%
city_counts_df.tail(50).T
# Out:
#             158            278     206          468     46        315  \
# City   Thornton  Thousand Oaks  Tigard  Tinley Park  Toledo  Torrance
# Count        10              5       8            1      32         4
#
#            125   55      47     63          451         432    284        357  \
# City   Trenton  Troy  Tucson  Tulsa  Tuscaloosa  Twin Falls  Tyler  Urbandale
# Count       13    29      32     26           2           2      5          3
#
#          195        509      252        293       203             98   \
# City   Utica  Vacaville  Vallejo  Vancouver  Vineland  Virginia Beach
# Count      8          1        6          5         8              16
#
#            321   257            440      294         153        147       514  \
# City   Visalia  Waco  Warner Robins  Warwick  Washington  Waterbury  Waterloo
# Count        4     6              2        5          10         11         1
#
#              162       519     309         164         444          300  \
# City   Watertown  Waukesha  Wausau  Waynesboro  West Allis  West Jordan
# Count         10         1       4          10           2            5
#
#                    356        238       122          93        215       513  \
# City   West Palm Beach  Westfield  Westland  Westminster  Wheeling  Whittier
# Count                3          6        13           17         7         1
#
#            218         43      233       358       382        275         305  \
# City   Wichita  Wilmington  Wilson  Woodbury  Woodland  Woodstock  Woonsocket
# Count        7          36       6         3         3          5           4
#
#            108   296      523   311
# City   Yonkers  York  Yucaipa  Yuma
# Count       15     5        1     4

# %%
df['City'] = df['City'].str.strip()

df['City'] = df['City'].str.replace(r'\s+', ' ', regex=True)

# %%
df['City'].nunique()
# Out:
# 531

# %% [markdown]
# ## 10: FirstName-LastName & CustomerId Matches<a id="10"></a>

# %% [markdown]
# ### First Letter of Customer Name and Surname should be the first 2 letters of CustomerId according to dataset

# %%
# Define a function to validate the CustomerId

def validate_customer_id(row):
    expected_prefix = row['FirstName'][0] + row['LastName'][0]
    return row['CustomerId'].startswith(expected_prefix)

df['ValidCustomerId'] = df.apply(validate_customer_id, axis=1)

# Filter rows where CustomerId does not follow the rule
invalid_customer_ids_df = df[~df['ValidCustomerId']]

invalid_customer_ids_df.head()
# Out:
#          PurchaseId PurchaseDate   ShipDate        ShipMode CustomerId  \
# 2    CA-2016-138688   2016-06-12 2016-06-16    Second Class   DV-13045
# 487  CA-2014-154627   2014-10-29 2014-10-31     First Class   SA-20830
# 788  CA-2015-115938   2015-06-26 2015-06-30  Standard Class   SA-20830
# 789  CA-2015-115938   2015-06-26 2015-06-30  Standard Class   SA-20830
# 790  CA-2015-115938   2015-06-26 2015-06-30  Standard Class   SA-20830
#
#         CustomerName    Segment        Country         City       State  \
# 2    Darrin Van Huff  Corporate  United States  Los Angeles  California
# 487     Sue Ann Reed   Consumer  United States      Chicago    Illinois
# 788     Sue Ann Reed   Consumer  United States     Richmond    Virginia
# 789     Sue Ann Reed   Consumer  United States     Richmond    Virginia
# 790     Sue Ann Reed   Consumer  United States     Richmond    Virginia
#
#     PostalCode   Region        ProductId         Category SubCategory  \
# 2        90036     West  OFF-LA-10000240  Office Supplies      Labels
# 487      60610  Central  TEC-PH-10001363       Technology      Phones
# 788      23223    South  OFF-BI-10001543  Office Supplies     Binders
# 789      23223    South  OFF-ST-10001321  Office Supplies     Storage
# 790      23223    South  OFF-BI-10001132  Office Supplies     Binders
#
#                                            ProductName     Sales  Quantity  \
# 2    Self-Adhesive Address Labels for Typewriters b...    14.620         2
# 487                                    Apple iPhone 5S  2735.952         6
# 788               GBC VeloBinder Manual Binding System   143.960         4
# 789        Decoflex Hanging Personal Folder File, Blue    15.420         1
# 790  Acco PRESSTEX Data Binder with Storage Hooks, ...    43.040         8
#
#      Discount    Profit   FirstName LastName  UnusualName  UnusualLastName  \
# 2         0.0    6.8714  Darrin Van     Huff        False            False
# 487       0.2  341.9940     Sue Ann     Reed        False            False
# 788       0.0   69.1008     Sue Ann     Reed        False            False
# 789       0.0    4.1634     Sue Ann     Reed        False            False
# 790       0.0   21.0896     Sue Ann     Reed        False            False
#
#      ValidCustomerId
# 2              False
# 487            False
# 788            False
# 789            False
# 790            False

# %%
invalid_customer_ids_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 66 entries, 2 to 9018
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PurchaseId       66 non-null     object
#  1   PurchaseDate     66 non-null     datetime64[ns]
#  2   ShipDate         66 non-null     datetime64[ns]
#  3   ShipMode         66 non-null     object
#  4   CustomerId       66 non-null     object
#  5   CustomerName     66 non-null     object
#  6   Segment          66 non-null     object
#  7   Country          66 non-null     object
#  8   City             66 non-null     object
#  9   State            66 non-null     object
#  10  PostalCode       66 non-null     object
#  11  Region           66 non-null     object
#  12  ProductId        66 non-null     object
#  13  Category         66 non-null     object
#  14  SubCategory      66 non-null     object
#  15  ProductName      66 non-null     object
#  16  Sales            66 non-null     float64
#  17  Quantity         66 non-null     int32
#  18  Discount         66 non-null     float64
#  19  Profit           66 non-null     float64
#  20  FirstName        66 non-null     object
#  21  LastName         66 non-null     object
#  22  UnusualName      66 non-null     bool
#  23  UnusualLastName  66 non-null     bool
#  24  ValidCustomerId  66 non-null     bool
# dtypes: bool(3), datetime64[ns](2), float64(3), int32(1), object(16)
# memory usage: 11.8+ KB

# %%
invalid_customer_ids_df['CustomerName'].value_counts()
# Out:
# CustomerName
# Sue Ann Reed       21
# Mark Van Huff      15
# Paul Van Hugh      13
# Darrin Van Huff     9
# Corey Lock          8
# Name: count, dtype: int64

# %%
# Correct the CustomerId values based on CustomerName

df.loc[df['CustomerName'] == 'Corey Lock', 'CustomerId'] = 'CL-12640'
df.loc[df['CustomerName'] == 'Sue Ann Reed', 'CustomerId'] = 'SR-20830'

# %%
# Darrin Van Huff
df.loc[df['CustomerName'] == 'Darrin Van Huff', ['FirstName', 'LastName']] = ['Darrin', 'Van Huff']

# Mark Van Huff
df.loc[df['CustomerName'] == 'Mark Van Huff', ['FirstName', 'LastName']] = ['Mark', 'Van Huff']

# Paul Van Hugh
df.loc[df['CustomerName'] == 'Paul Van Hugh', ['FirstName', 'LastName']] = ['Paul', 'Van Hugh']

# %%
# confirm changes

df['ValidCustomerId'] = df.apply(validate_customer_id, axis=1)

invalid_customer_ids_df = df[~df['ValidCustomerId']]

invalid_customer_ids_df
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, UnusualName, UnusualLastName, ValidCustomerId]
# Index: []

# %% [markdown]
# ### 66 records from 5 Customer were updated. Listed below:
# * Sue Ann Reed       21
# * Mark Van Huff      15
# * Paul Van Hugh      13
# * Darrin Van Huff     9
# * Corey Lock          8

# %%
df.columns
# Out:
# Index(['PurchaseId', 'PurchaseDate', 'ShipDate', 'ShipMode', 'CustomerId',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductId', 'Category', 'SubCategory', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'FirstName', 'LastName',
#        'UnusualName', 'UnusualLastName', 'ValidCustomerId'],
#       dtype='object')

# %%
df = df.drop(columns=['UnusualName', 'UnusualLastName', 'ValidCustomerId'])

df = df.reset_index(drop=True).copy()

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    9994 non-null   object
#  1   PurchaseDate  9994 non-null   datetime64[ns]
#  2   ShipDate      9994 non-null   datetime64[ns]
#  3   ShipMode      9994 non-null   object
#  4   CustomerId    9994 non-null   object
#  5   CustomerName  9994 non-null   object
#  6   Segment       9994 non-null   object
#  7   Country       9994 non-null   object
#  8   City          9994 non-null   object
#  9   State         9994 non-null   object
#  10  PostalCode    9994 non-null   object
#  11  Region        9994 non-null   object
#  12  ProductId     9994 non-null   object
#  13  Category      9994 non-null   object
#  14  SubCategory   9994 non-null   object
#  15  ProductName   9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   int32
#  18  Discount      9994 non-null   float64
#  19  Profit        9994 non-null   float64
#  20  FirstName     9994 non-null   object
#  21  LastName      9994 non-null   object
# dtypes: datetime64[ns](2), float64(3), int32(1), object(16)
# memory usage: 1.6+ MB

# %% [markdown]
# ## 11: State<a id="11"></a>

# %%
df['State'].nunique()
# Out:
# 49

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['State'] = df['State'].str.strip()

# %% [markdown]
# ## 12: PostalCode<a id="12"></a>

# %%
# Check if all PostalCode entries are numeric and have 5 digits

df['PostalCode_Check'] = df['PostalCode'].apply(lambda x: x.isdigit() and len(x) == 5)

# Display rows where PostalCode_Check is False

invalid_postal_codes_df = df[~df['PostalCode_Check']]

invalid_postal_codes_df.head(20).T
# Out:
#                                         185  \
# PurchaseId                   CA-2016-105018
# PurchaseDate            2016-11-28 00:00:00
# ShipDate                2016-12-02 00:00:00
# ShipMode                     Standard Class
# CustomerId                         SK-19990
# CustomerName                  Sally Knutson
# Segment                            Consumer
# Country                       United States
# City                              Fairfield
# State                           Connecticut
# PostalCode                             6824
# Region                                 East
# ProductId                   OFF-BI-10001890
# Category                    Office Supplies
# SubCategory                         Binders
# ProductName       Avery Poly Binder Pockets
# Sales                                  7.16
# Quantity                                  2
# Discount                                0.0
# Profit                               3.4368
# FirstName                             Sally
# LastName                            Knutson
# PostalCode_Check                      False
#
#                                                     197                  267  \
# PurchaseId                               CA-2017-107720       CA-2016-111010
# PurchaseDate                        2017-11-06 00:00:00  2016-01-22 00:00:00
# ShipDate                            2017-11-13 00:00:00  2016-01-28 00:00:00
# ShipMode                                 Standard Class       Standard Class
# CustomerId                                     VM-21685             PG-18895
# CustomerName                            Valerie Mitchum        Paul Gonzalez
# Segment                                     Home Office             Consumer
# Country                                   United States        United States
# City                                          Westfield           Morristown
# State                                        New Jersey           New Jersey
# PostalCode                                         7090                 7960
# Region                                             East                 East
# ProductId                               OFF-ST-10001414      OFF-FA-10003472
# Category                                Office Supplies      Office Supplies
# SubCategory                                     Storage            Fasteners
# ProductName       Decoflex Hanging Personal Folder File  Bagged Rubber Bands
# Sales                                             46.26                 7.56
# Quantity                                              3                    6
# Discount                                            0.0                  0.0
# Profit                                          12.0276               0.3024
# FirstName                                       Valerie                 Paul
# LastName                                        Mitchum             Gonzalez
# PostalCode_Check                                  False                False
#
#                                   298  \
# PurchaseId             CA-2016-142545
# PurchaseDate      2016-10-28 00:00:00
# ShipDate          2016-11-03 00:00:00
# ShipMode               Standard Class
# CustomerId                   JD-15895
# CustomerName         Jonathan Doherty
# Segment                     Corporate
# Country                 United States
# City                       Belleville
# State                      New Jersey
# PostalCode                       7109
# Region                           East
# ProductId             OFF-PA-10002105
# Category              Office Supplies
# SubCategory                     Paper
# ProductName                 Xerox 223
# Sales                            32.4
# Quantity                            5
# Discount                          0.0
# Profit                         15.552
# FirstName                    Jonathan
# LastName                      Doherty
# PostalCode_Check                False
#
#                                                                 299  \
# PurchaseId                                           CA-2016-142545
# PurchaseDate                                    2016-10-28 00:00:00
# ShipDate                                        2016-11-03 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 JD-15895
# CustomerName                                       Jonathan Doherty
# Segment                                                   Corporate
# Country                                               United States
# City                                                     Belleville
# State                                                    New Jersey
# PostalCode                                                     7109
# Region                                                         East
# ProductId                                           OFF-ST-10002756
# Category                                            Office Supplies
# SubCategory                                                 Storage
# ProductName       Tennsco Stur-D-Stor Boltless Shelving, 5 Shelv...
# Sales                                                       1082.48
# Quantity                                                          8
# Discount                                                        0.0
# Profit                                                      10.8248
# FirstName                                                  Jonathan
# LastName                                                    Doherty
# PostalCode_Check                                              False
#
#                                   300  \
# PurchaseId             CA-2016-142545
# PurchaseDate      2016-10-28 00:00:00
# ShipDate          2016-11-03 00:00:00
# ShipMode               Standard Class
# CustomerId                   JD-15895
# CustomerName         Jonathan Doherty
# Segment                     Corporate
# Country                 United States
# City                       Belleville
# State                      New Jersey
# PostalCode                       7109
# Region                           East
# ProductId             OFF-PA-10004243
# Category              Office Supplies
# SubCategory                     Paper
# ProductName                Xerox 1939
# Sales                           56.91
# Quantity                            3
# Discount                          0.0
# Profit                        27.3168
# FirstName                    Jonathan
# LastName                      Doherty
# PostalCode_Check                False
#
#                                                                 301  \
# PurchaseId                                           CA-2016-142545
# PurchaseDate                                    2016-10-28 00:00:00
# ShipDate                                        2016-11-03 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 JD-15895
# CustomerName                                       Jonathan Doherty
# Segment                                                   Corporate
# Country                                               United States
# City                                                     Belleville
# State                                                    New Jersey
# PostalCode                                                     7109
# Region                                                         East
# ProductId                                           FUR-FU-10001861
# Category                                                  Furniture
# SubCategory                                             Furnishings
# ProductName       Floodlight Indoor Halogen Bulbs, 1 Bulb per Pa...
# Sales                                                          77.6
# Quantity                                                          4
# Discount                                                        0.0
# Profit                                                       38.024
# FirstName                                                  Jonathan
# LastName                                                    Doherty
# PostalCode_Check                                              False
#
#                                                                 302  \
# PurchaseId                                           CA-2016-142545
# PurchaseDate                                    2016-10-28 00:00:00
# ShipDate                                        2016-11-03 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 JD-15895
# CustomerName                                       Jonathan Doherty
# Segment                                                   Corporate
# Country                                               United States
# City                                                     Belleville
# State                                                    New Jersey
# PostalCode                                                     7109
# Region                                                         East
# ProductId                                           OFF-BI-10002706
# Category                                            Office Supplies
# SubCategory                                                 Binders
# ProductName       Avery Premier Heavy-Duty Binder with Round Loc...
# Sales                                                         14.28
# Quantity                                                          1
# Discount                                                        0.0
# Profit                                                       6.5688
# FirstName                                                  Jonathan
# LastName                                                    Doherty
# PostalCode_Check                                              False
#
#                                                                 306  \
# PurchaseId                                           CA-2014-111003
# PurchaseDate                                    2014-06-01 00:00:00
# ShipDate                                        2014-06-06 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 CR-12625
# CustomerName                                            Corey Roper
# Segment                                                 Home Office
# Country                                               United States
# City                                                       Lakewood
# State                                                    New Jersey
# PostalCode                                                     8701
# Region                                                         East
# ProductId                                           OFF-BI-10001072
# Category                                            Office Supplies
# SubCategory                                                 Binders
# ProductName       GBC Clear Cover, 8-1/2 x 11, unpunched, 25 cov...
# Sales                                                         45.48
# Quantity                                                          3
# Discount                                                        0.0
# Profit                                                      20.9208
# FirstName                                                     Corey
# LastName                                                      Roper
# PostalCode_Check                                              False
#
#                                                                 307  \
# PurchaseId                                           CA-2014-111003
# PurchaseDate                                    2014-06-01 00:00:00
# ShipDate                                        2014-06-06 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 CR-12625
# CustomerName                                            Corey Roper
# Segment                                                 Home Office
# Country                                               United States
# City                                                       Lakewood
# State                                                    New Jersey
# PostalCode                                                     8701
# Region                                                         East
# ProductId                                           OFF-AR-10002135
# Category                                            Office Supplies
# SubCategory                                                     Art
# ProductName       Boston Heavy-Duty Trimline Electric Pencil Sha...
# Sales                                                         289.2
# Quantity                                                          6
# Discount                                                        0.0
# Profit                                                       83.868
# FirstName                                                     Corey
# LastName                                                      Roper
# PostalCode_Check                                              False
#
#                                                                 313  \
# PurchaseId                                           CA-2014-120887
# PurchaseDate                                    2014-09-27 00:00:00
# ShipDate                                        2014-10-03 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 TS-21205
# CustomerName                                            Thomas Seio
# Segment                                                   Corporate
# Country                                               United States
# City                                                     Hackensack
# State                                                    New Jersey
# PostalCode                                                     7601
# Region                                                         East
# ProductId                                           FUR-FU-10001588
# Category                                                  Furniture
# SubCategory                                             Furnishings
# ProductName       Deflect-o SuperTray Unbreakable Stackable Tray...
# Sales                                                         87.54
# Quantity                                                          3
# Discount                                                        0.0
# Profit                                                      37.6422
# FirstName                                                    Thomas
# LastName                                                       Seio
# PostalCode_Check                                              False
#
#                                                                 346  \
# PurchaseId                                           CA-2017-134306
# PurchaseDate                                    2017-07-08 00:00:00
# ShipDate                                        2017-07-12 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 TD-20995
# CustomerName                                          Tamara Dahlen
# Segment                                                    Consumer
# Country                                               United States
# City                                                         Lowell
# State                                                 Massachusetts
# PostalCode                                                     1852
# Region                                                         East
# ProductId                                           OFF-AR-10004027
# Category                                            Office Supplies
# SubCategory                                                     Art
# ProductName       Binney & Smith inkTank Erasable Desk Highlight...
# Sales                                                          7.56
# Quantity                                                          3
# Discount                                                        0.0
# Profit                                                       3.0996
# FirstName                                                    Tamara
# LastName                                                     Dahlen
# PostalCode_Check                                              False
#
#                                   347  \
# PurchaseId             CA-2017-134306
# PurchaseDate      2017-07-08 00:00:00
# ShipDate          2017-07-12 00:00:00
# ShipMode               Standard Class
# CustomerId                   TD-20995
# CustomerName            Tamara Dahlen
# Segment                      Consumer
# Country                 United States
# City                           Lowell
# State                   Massachusetts
# PostalCode                       1852
# Region                           East
# ProductId             OFF-PA-10000249
# Category              Office Supplies
# SubCategory                     Paper
# ProductName         Easy-staple paper
# Sales                           24.56
# Quantity                            2
# Discount                          0.0
# Profit                        11.5432
# FirstName                      Tamara
# LastName                       Dahlen
# PostalCode_Check                False
#
#                                                        348  \
# PurchaseId                                  CA-2017-134306
# PurchaseDate                           2017-07-08 00:00:00
# ShipDate                               2017-07-12 00:00:00
# ShipMode                                    Standard Class
# CustomerId                                        TD-20995
# CustomerName                                 Tamara Dahlen
# Segment                                           Consumer
# Country                                      United States
# City                                                Lowell
# State                                        Massachusetts
# PostalCode                                            1852
# Region                                                East
# ProductId                                  OFF-AR-10001374
# Category                                   Office Supplies
# SubCategory                                            Art
# ProductName       BIC Brite Liner Highlighters, Chisel Tip
# Sales                                                12.96
# Quantity                                                 2
# Discount                                               0.0
# Profit                                              4.1472
# FirstName                                           Tamara
# LastName                                            Dahlen
# PostalCode_Check                                     False
#
#                                                                 366  \
# PurchaseId                                           CA-2016-155516
# PurchaseDate                                    2016-10-21 00:00:00
# ShipDate                                        2016-10-21 00:00:00
# ShipMode                                                   Same Day
# CustomerId                                                 MK-17905
# CustomerName                                        Michael Kennedy
# Segment                                                   Corporate
# Country                                               United States
# City                                                     Manchester
# State                                                   Connecticut
# PostalCode                                                     6040
# Region                                                         East
# ProductId                                           OFF-BI-10002412
# Category                                            Office Supplies
# SubCategory                                                 Binders
# ProductName       Wilson Jones Snap Scratch Pad Binder Tool fo...
# Sales                                                          23.2
# Quantity                                                          4
# Discount                                                        0.0
# Profit                                                        10.44
# FirstName                                                   Michael
# LastName                                                    Kennedy
# PostalCode_Check                                              False
#
#                                   367                       368  \
# PurchaseId             CA-2016-155516            CA-2016-155516
# PurchaseDate      2016-10-21 00:00:00       2016-10-21 00:00:00
# ShipDate          2016-10-21 00:00:00       2016-10-21 00:00:00
# ShipMode                     Same Day                  Same Day
# CustomerId                   MK-17905                  MK-17905
# CustomerName          Michael Kennedy           Michael Kennedy
# Segment                     Corporate                 Corporate
# Country                 United States             United States
# City                       Manchester                Manchester
# State                     Connecticut               Connecticut
# PostalCode                       6040                      6040
# Region                           East                      East
# ProductId             OFF-SU-10001225           OFF-ST-10002406
# Category              Office Supplies           Office Supplies
# SubCategory                  Supplies                   Storage
# ProductName            Staple remover  Pizazz Global Quick File
# Sales                            7.36                    104.79
# Quantity                            2                         7
# Discount                          0.0                       0.0
# Profit                         0.1472                   29.3412
# FirstName                     Michael                   Michael
# LastName                      Kennedy                   Kennedy
# PostalCode_Check                False                     False
#
#                                                                 369  \
# PurchaseId                                           CA-2016-155516
# PurchaseDate                                    2016-10-21 00:00:00
# ShipDate                                        2016-10-21 00:00:00
# ShipMode                                                   Same Day
# CustomerId                                                 MK-17905
# CustomerName                                        Michael Kennedy
# Segment                                                   Corporate
# Country                                               United States
# City                                                     Manchester
# State                                                   Connecticut
# PostalCode                                                     6040
# Region                                                         East
# ProductId                                           FUR-BO-10002545
# Category                                                  Furniture
# SubCategory                                               Bookcases
# ProductName       Atlantic Metals Mobile 3-Shelf Bookcases, Cust...
# Sales                                                       1043.92
# Quantity                                                          4
# Discount                                                        0.0
# Profit                                                     271.4192
# FirstName                                                   Michael
# LastName                                                    Kennedy
# PostalCode_Check                                              False
#
#                                                                 377  \
# PurchaseId                                           US-2017-134481
# PurchaseDate                                    2017-08-27 00:00:00
# ShipDate                                        2017-09-01 00:00:00
# ShipMode                                             Standard Class
# CustomerId                                                 AR-10405
# CustomerName                                       Allen Rosenblatt
# Segment                                                   Corporate
# Country                                               United States
# City                                                       Franklin
# State                                                 Massachusetts
# PostalCode                                                     2038
# Region                                                         East
# ProductId                                           FUR-TA-10004915
# Category                                                  Furniture
# SubCategory                                                  Tables
# ProductName       Office Impressions End Table, 20-1/2"H x 24"W ...
# Sales                                                      1488.424
# Quantity                                                          7
# Discount                                                        0.3
# Profit                                                    -297.6848
# FirstName                                                     Allen
# LastName                                                 Rosenblatt
# PostalCode_Check                                              False
#
#                                                              395
# PurchaseId                                        CA-2017-165603
# PurchaseDate                                 2017-10-17 00:00:00
# ShipDate                                     2017-10-19 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              SS-20140
# CustomerName                                    Saphhira Shifley
# Segment                                                Corporate
# Country                                            United States
# City                                                     Warwick
# State                                               Rhode Island
# PostalCode                                                  2886
# Region                                                      East
# ProductId                                        OFF-ST-10000798
# Category                                         Office Supplies
# SubCategory                                              Storage
# ProductName       2300 Heavy-Duty Transfer File Systems by Perma
# Sales                                                      49.96
# Quantity                                                       2
# Discount                                                     0.0
# Profit                                                    9.4924
# FirstName                                               Saphhira
# LastName                                                 Shifley
# PostalCode_Check                                           False

# %%
invalid_postal_codes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 449 entries, 185 to 9969
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PurchaseId        449 non-null    object
#  1   PurchaseDate      449 non-null    datetime64[ns]
#  2   ShipDate          449 non-null    datetime64[ns]
#  3   ShipMode          449 non-null    object
#  4   CustomerId        449 non-null    object
#  5   CustomerName      449 non-null    object
#  6   Segment           449 non-null    object
#  7   Country           449 non-null    object
#  8   City              449 non-null    object
#  9   State             449 non-null    object
#  10  PostalCode        449 non-null    object
#  11  Region            449 non-null    object
#  12  ProductId         449 non-null    object
#  13  Category          449 non-null    object
#  14  SubCategory       449 non-null    object
#  15  ProductName       449 non-null    object
#  16  Sales             449 non-null    float64
#  17  Quantity          449 non-null    int32
#  18  Discount          449 non-null    float64
#  19  Profit            449 non-null    float64
#  20  FirstName         449 non-null    object
#  21  LastName          449 non-null    object
#  22  PostalCode_Check  449 non-null    bool
# dtypes: bool(1), datetime64[ns](2), float64(3), int32(1), object(16)
# memory usage: 79.4+ KB

# %% [markdown]
# #### There are 449 entries which have 4 digit Postalcode in USA,
# #### standard ZIP codes typically have 5 digits. However, leading zeros are common in certain regions, meaning that a ZIP code like "04356" is indeed valid
# #### we will keep ZIP codes as strings in DataFrame to preserve any leading zeros and add 0 to the begining of the codes with 4 digits

# %%
# Make all PostalCodes have 5 digits

df['PostalCode'] = df['PostalCode'].str.zfill(5)

# %%
# Confirm Changes

df['PostalCode_Check'] = df['PostalCode'].apply(lambda x: x.isdigit() and len(x) == 5)

# Display rows where PostalCode_Check is False

invalid_postal_codes_df = df[~df['PostalCode_Check']]

invalid_postal_codes_df
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, PostalCode_Check]
# Index: []

# %% [markdown]
# ## 13: Region<a id="13"></a>

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %% [markdown]
# ## 14: ProductId<a id="14"></a>

# %%
# ensure that the ProductId column starts with the same three letters of the Category column

df['ProductIdLower'] = df['ProductId'].str.lower()
df['CategoryLower'] = df['Category'].str.lower()

# Extract the first 3 characters from the lowercase versions

df['ProductIdPrefix'] = df['ProductIdLower'].str[:3]
df['CategoryPrefix'] = df['CategoryLower'].str[:3]

# Check if the prefixes match

df['Match'] = df['ProductIdPrefix'] == df['CategoryPrefix']

# Filter rows where ProductId and Category prefixes do not match

mismatched_entries = df[~df['Match']]

mismatched_entries
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, PostalCode_Check, ProductIdLower, CategoryLower, ProductIdPrefix, CategoryPrefix, Match]
# Index: []

# %%
# Drop unnecessary columns
df = df.drop(columns=['PostalCode_Check', 'ProductIdLower', 'CategoryLower',
                      'ProductIdPrefix', 'CategoryPrefix', 'Match'])

# %%
# ensure that the two-letter code after the first hyphen in ProductId matches the first two letters of SubCategory

df['ProductIdLower'] = df['ProductId'].str.lower()
df['SubCategoryLower'] = df['SubCategory'].str.lower()

# Extract the two-letter code after the first hyphen in ProductId

df['ProductIdCode'] = df['ProductIdLower'].apply(lambda x: x.split('-')[1])

# Extract the first two characters of SubCategory

df['SubCategoryCode'] = df['SubCategoryLower'].str[:2]

# Check if the codes match

df['Match'] = df['ProductIdCode'] == df['SubCategoryCode']

# Filter rows where the codes do not match

mismatched_entries = df[~df['Match']]

mismatched_entries
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, ProductIdLower, SubCategoryLower, ProductIdCode, SubCategoryCode, Match]
# Index: []

# %%
df = df.drop(columns=['ProductIdLower', 'SubCategoryLower', 'ProductIdCode',
                      'SubCategoryCode', 'Match'])

df = df.reset_index(drop=True)

# %% [markdown]
# ## 15: Category<a id="15"></a>

# %%
df['Category'].nunique()
# Out:
# 3

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %% [markdown]
# ## 16: SubCategory<a id="16"></a>

# %%
df['SubCategory'].nunique()
# Out:
# 17

# %%
df['SubCategory'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['SubCategory'].value_counts()
# Out:
# SubCategory
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %% [markdown]
# ## 17: ProductName<a id="17"></a>

# %%
df['ProductName'].nunique()
# Out:
# 1850

# %%
# Get the counts of each unique ProductName
product_name_counts = df['ProductName'].value_counts()

# Create a new DataFrame from the counts
ProductName_df = product_name_counts.reset_index()
ProductName_df.columns = ['ProductName', 'Count']

# Sort the DataFrame alphabetically by ProductName
ProductName_df = ProductName_df.sort_values(by='ProductName').reset_index(drop=True)

ProductName_df.head(50).T
# Out:
#                                                             0   \
# ProductName  "While you Were Out" Message Book, One Form pe...
# Count                                                        3
#
#                                                    1   \
# ProductName  #10 Gummed Flap White Envelopes, 100/Box
# Count                                               4
#
#                                         2   \
# ProductName  #10 Self-Seal White Envelopes
# Count                                    4
#
#                                                      3   \
# ProductName  #10 White Business Envelopes,4 1/8 x 9 1/2
# Count                                                 7
#
#                                                   4   \
# ProductName  #10- 4 1/8" x 9 1/2" Recycled Envelopes
# Count                                             10
#
#                                                        5   \
# ProductName  #10- 4 1/8" x 9 1/2" Security-Tint Envelopes
# Count                                                   8
#
#                                                             6   \
# ProductName  #10-4 1/8" x 9 1/2" Premium Diagonal Seam Enve...
# Count                                                        2
#
#                                              7   \
# ProductName  #6 3/4 Gummed Flap White Envelopes
# Count                                         4
#
#                                                             8   \
# ProductName  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# Count                                                        6
#
#                                                             9   \
# ProductName  1/4 Fold Party Design Invitations & White Enve...
# Count                                                        2
#
#                                    10                                11  \
# ProductName  12 Colored Short Pencils  12-1/2 Diameter Round Wall Clock
# Count                               3                                 8
#
#                                                        12  \
# ProductName  14-7/8 x 11 Blue Bar Computer Printout Paper
# Count                                                   4
#
#                                                          13  \
# ProductName  2300 Heavy-Duty Transfer File Systems by Perma
# Count                                                     4
#
#                                                     14  \
# ProductName  24 Capacity Maxi Data Binder Racks, Pearl
# Count                                                4
#
#                                    15                  16  \
# ProductName  24-Hour Round Wall Clock  3-ring staple pack
# Count                               6                   6
#
#                                                             17  \
# ProductName  3.6 Cubic Foot Counter Height Office Refrigerator
# Count                                                        5
#
#                                    18  \
# ProductName  36X48 HARDFLOOR CHAIRMAT
# Count                               6
#
#                                                            19  \
# ProductName  3D Systems Cube Printer, 2nd Generation, Magenta
# Count                                                       2
#
#                                                          20  \
# ProductName  3D Systems Cube Printer, 2nd Generation, White
# Count                                                     2
#
#                                            21                     22  \
# ProductName  3M Hangers With Command Adhesive  3M Office Air Cleaner
# Count                                       8                      2
#
#                               23                                  24  \
# ProductName  3M Organizer Strips  3M Polarizing Light Filter Sleeves
# Count                          7                                   4
#
#                                                             25  \
# ProductName  3M Polarizing Task Lamp with Clamp Arm, Light ...
# Count                                                        4
#
#                                                             26  \
# ProductName  3M Replacement Filter for Office Air Cleaner f...
# Count                                                        4
#
#                             27                            28  \
# ProductName  4009 Highlighters  4009 Highlighters by Sanford
# Count                        1                             8
#
#                                   29                            30  \
# ProductName  50 Colored Long Pencils  6" Cubicle Wall Clock, Black
# Count                              5                             4
#
#                                           31  \
# ProductName  9-3/4 Diameter Round Wall Clock
# Count                                      8
#
#                                            32                       33  \
# ProductName  ACCOHIDE 3-Ring Binder, Blue, 1"  ACCOHIDE Binder by Acco
# Count                                      13                        4
#
#                                                            34  \
# ProductName  APC 7 Outlet Network SurgeArrest Surge Protector
# Count                                                       8
#
#                                                             35  \
# ProductName  ARKON Windshield Dashboard Air Vent Car Mount ...
# Count                                                        4
#
#                                  36                      37               38  \
# ProductName  AT&T 1070 Corded Phone  AT&T 1080 Corded phone  AT&T 1080 Phone
# Count                             3                       7                3
#
#                                         39                 40           41  \
# ProductName  AT&T 17929 Lendline Telephone  AT&T 841000 Phone  AT&T CL2909
# Count                                   10                  7            3
#
#                        42                                43  \
# ProductName  AT&T CL82213  AT&T CL83451 4-Handset Telephone
# Count                   5                                 4
#
#                             44                 45            46  \
# ProductName  AT&T EL51110 DECT  AT&T SB67148 SynJ  AT&T TR1909W
# Count                        1                  3             4
#
#                                 47                                   48  \
# ProductName  Aastra 57i VoIP phone  Aastra 6757i CT Wireless VoIP phone
# Count                            7                                    6
#
#                             49
# ProductName  Acco 3-Hole Punch
# Count                        9

# %%
ProductName_df.tail(50).T
# Out:
#                   1800       1801       1802       1803       1804      1805  \
# ProductName  Xerox 205  Xerox 206  Xerox 207  Xerox 208  Xerox 209  Xerox 21
# Count                4          5          2          2          5         7
#
#                   1806       1807       1808       1809       1810       1811  \
# ProductName  Xerox 210  Xerox 211  Xerox 212  Xerox 213  Xerox 214  Xerox 215
# Count                6          4          7          6          9          2
#
#                   1812       1813       1814       1815      1816       1817  \
# ProductName  Xerox 216  Xerox 217  Xerox 218  Xerox 219  Xerox 22  Xerox 220
# Count                8          8          5          4         3          8
#
#                   1818       1819       1820       1821       1822       1823  \
# ProductName  Xerox 221  Xerox 222  Xerox 223  Xerox 224  Xerox 225  Xerox 226
# Count                4          7          3          6          9         11
#
#                   1824       1825       1826      1827       1828       1829  \
# ProductName  Xerox 227  Xerox 228  Xerox 229  Xerox 23  Xerox 230  Xerox 231
# Count                8          4          3         6          5          5
#
#                   1830                                               1831  \
# ProductName  Xerox 232  Xerox 4200 Series MultiUse Premium Copy Paper ...
# Count                4                                                  8
#
#                                    1832  \
# ProductName  Xerox Blank Computer Paper
# Count                                 1
#
#                                                   1833  \
# ProductName  Xerox Color Copier Paper, 11" x 17", Ream
# Count                                                6
#
#                                                           1834        1835  \
# ProductName  Xerox WorkCentre 6505DN Laser Multifunction Pr...  Xiaomi Mi3
# Count                                                        1           1
#
#                                                          1836  \
# ProductName  XtraLife ClearVue Slant-D Ring Binder, White, 3"
# Count                                                      10
#
#                                                           1837  \
# ProductName  XtraLife ClearVue Slant-D Ring Binders by Card...
# Count                                                        5
#
#                                                           1838  \
# ProductName  Zebra GK420t Direct Thermal/Thermal Transfer P...
# Count                                                        1
#
#                                                           1839  \
# ProductName  Zebra GX420t Direct Thermal/Thermal Transfer P...
# Count                                                        3
#
#                                           1840  \
# ProductName  Zebra ZM400 Thermal Label Printer
# Count                                        2
#
#                                               1841  \
# ProductName  Zebra Zazzle Fluorescent Highlighters
# Count                                            6
#
#                                    1842                               1843  \
# ProductName  Zipper Ring Binder Pockets  i.Sound Portable Power - 8000 mAh
# Count                                13                                  5
#
#                                                  1844  \
# ProductName  iHome FM Clock Radio with Lightning Dock
# Count                                               5
#
#                                                           1845  \
# ProductName  iKross Bluetooth Portable Keyboard + Cell Phon...
# Count                                                        5
#
#                                    1846                 1847  \
# ProductName  iOttie HLCRIO102 Car Mount  iOttie XL Car Mount
# Count                                 5                    2
#
#                                                           1848  \
# ProductName  invisibleSHIELD by ZAGG Smudge-Free Screen Pro...
# Count                                                        7
#
#                                            1849
# ProductName  netTALK DUO VoIP Telephone Service
# Count                                         7

# %% [markdown]
# #### There are entries which start with # symbol, we will erase this from the beginning of the product name.
# #### There are also entries with i(small) letter which locate themself after letter Z (capital), i should be capitol letter to be able to sort ProductNames alphabetically.

# %%
df['ProductName'] = df['ProductName'].str.lstrip('#')

# %%
df['ProductName'] = df['ProductName'].str.strip()

# %%
df['ProductName'] = df['ProductName'].str.title()

# %%
# Confirm Changes 

product_name_counts = df['ProductName'].value_counts()

ProductName_df = product_name_counts.reset_index()
ProductName_df.columns = ['ProductName', 'Count']

ProductName_df = ProductName_df.sort_values(by='ProductName').reset_index(drop=True)

ProductName_df.head(20).T
# Out:
#                                                             0   \
# ProductName  "While You Were Out" Message Book, One Form Pe...
# Count                                                        3
#
#                                                             1   \
# ProductName  1.7 Cubic Foot Compact "Cube" Office Refrigera...
# Count                                                        6
#
#                                                             2   \
# ProductName  1/4 Fold Party Design Invitations & White Enve...
# Count                                                        2
#
#                                                   3   \
# ProductName  10 Gummed Flap White Envelopes, 100/Box
# Count                                              4
#
#                                        4   \
# ProductName  10 Self-Seal White Envelopes
# Count                                   4
#
#                                                     5   \
# ProductName  10 White Business Envelopes,4 1/8 X 9 1/2
# Count                                                7
#
#                                                  6   \
# ProductName  10- 4 1/8" X 9 1/2" Recycled Envelopes
# Count                                            10
#
#                                                       7   \
# ProductName  10- 4 1/8" X 9 1/2" Security-Tint Envelopes
# Count                                                  8
#
#                                                             8   \
# ProductName  10-4 1/8" X 9 1/2" Premium Diagonal Seam Envel...
# Count                                                        2
#
#                                    9                                 10  \
# ProductName  12 Colored Short Pencils  12-1/2 Diameter Round Wall Clock
# Count                               3                                 8
#
#                                                        11  \
# ProductName  14-7/8 X 11 Blue Bar Computer Printout Paper
# Count                                                   4
#
#                                                          12  \
# ProductName  2300 Heavy-Duty Transfer File Systems By Perma
# Count                                                     4
#
#                                                     13  \
# ProductName  24 Capacity Maxi Data Binder Racks, Pearl
# Count                                                4
#
#                                    14                  15  \
# ProductName  24-Hour Round Wall Clock  3-Ring Staple Pack
# Count                               6                   6
#
#                                                             16  \
# ProductName  3.6 Cubic Foot Counter Height Office Refrigerator
# Count                                                        5
#
#                                    17  \
# ProductName  36X48 Hardfloor Chairmat
# Count                               6
#
#                                                            18  \
# ProductName  3D Systems Cube Printer, 2Nd Generation, Magenta
# Count                                                       2
#
#                                                          19
# ProductName  3D Systems Cube Printer, 2Nd Generation, White
# Count                                                     2

# %%
ProductName_df.tail(20).T
# Out:
#                   1830       1831       1832       1833      1834       1835  \
# ProductName  Xerox 226  Xerox 227  Xerox 228  Xerox 229  Xerox 23  Xerox 230
# Count               11          8          4          3         6          5
#
#                   1836       1837  \
# ProductName  Xerox 231  Xerox 232
# Count                5          4
#
#                                                           1838  \
# ProductName  Xerox 4200 Series Multiuse Premium Copy Paper ...
# Count                                                        8
#
#                                    1839  \
# ProductName  Xerox Blank Computer Paper
# Count                                 1
#
#                                                   1840  \
# ProductName  Xerox Color Copier Paper, 11" X 17", Ream
# Count                                                6
#
#                                                           1841        1842  \
# ProductName  Xerox Workcentre 6505Dn Laser Multifunction Pr...  Xiaomi Mi3
# Count                                                        1           1
#
#                                                          1843  \
# ProductName  Xtralife Clearvue Slant-D Ring Binder, White, 3"
# Count                                                      10
#
#                                                           1844  \
# ProductName  Xtralife Clearvue Slant-D Ring Binders By Card...
# Count                                                        5
#
#                                                           1845  \
# ProductName  Zebra Gk420T Direct Thermal/Thermal Transfer P...
# Count                                                        1
#
#                                                           1846  \
# ProductName  Zebra Gx420T Direct Thermal/Thermal Transfer P...
# Count                                                        3
#
#                                               1847  \
# ProductName  Zebra Zazzle Fluorescent Highlighters
# Count                                            6
#
#                                           1848                        1849
# ProductName  Zebra Zm400 Thermal Label Printer  Zipper Ring Binder Pockets
# Count                                        2                          13

# %%
## 1 entry left which does not start with a number or letter, ("While You Were Out"). 
## Edit entries with "While You Were Out"  manually

# Filtering the DataFrame to find the row(s) containing the While you Were Out in product name

filtered_df= df[df['ProductName'].str.contains("While you Were Out", case=False, na=False)]

filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21 entries, 220 to 8323
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    21 non-null     object
#  1   PurchaseDate  21 non-null     datetime64[ns]
#  2   ShipDate      21 non-null     datetime64[ns]
#  3   ShipMode      21 non-null     object
#  4   CustomerId    21 non-null     object
#  5   CustomerName  21 non-null     object
#  6   Segment       21 non-null     object
#  7   Country       21 non-null     object
#  8   City          21 non-null     object
#  9   State         21 non-null     object
#  10  PostalCode    21 non-null     object
#  11  Region        21 non-null     object
#  12  ProductId     21 non-null     object
#  13  Category      21 non-null     object
#  14  SubCategory   21 non-null     object
#  15  ProductName   21 non-null     object
#  16  Sales         21 non-null     float64
#  17  Quantity      21 non-null     int32
#  18  Discount      21 non-null     float64
#  19  Profit        21 non-null     float64
#  20  FirstName     21 non-null     object
#  21  LastName      21 non-null     object
# dtypes: datetime64[ns](2), float64(3), int32(1), object(16)
# memory usage: 3.7+ KB

# %%
filtered_df['ProductName'].unique()
# Out:
# array(['While You Were Out Pads, 50 Per Pad, 4 X 5 1/4, Green Cycle',
#        'Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"',
#        'Message Book, Standard Line "While You Were Out", 5 1/2" X 4", 200 Sets/Book',
#        '"While You Were Out" Message Book, One Form Per Page',
#        'Adams "While You Were Out" Message Pads',
#        'Standard Line \x93While You Were Out\x94 Hardbound Telephone Message Book'],
#       dtype=object)

# %%
# Update specific entries in the ProductName column

df.loc[df['ProductName'] == 'Recycled Desk Saver Line "While You Were Out" Book, 5 1/2" X 4"', 'ProductName'] = 'Recycled Desk Saver Line, While You Were Out, Book, 5 1/2" X 4"'

df.loc[df['ProductName'] == '"While You Were Out" Message Book, One Form Per Page', 'ProductName'] = 'While You Were Out, Message Book, One Form Per Page'

df.loc[df['ProductName'] == 'Adams "While You Were Out" Message Pads', 'ProductName'] = 'Adams, While You Were Out, Message Pads'

df.loc[df['ProductName'] == 'Standard Line \x93While You Were Out\x94 Hardbound Telephone Message Book', 'ProductName'] = 'Standard Line, While You Were Out, Hardbound Telephone Message Book'

# %%
# Confirm Changes 

product_name_counts = df['ProductName'].value_counts()

ProductName_df = product_name_counts.reset_index()
ProductName_df.columns = ['ProductName', 'Count']

ProductName_df = ProductName_df.sort_values(by='ProductName').reset_index(drop=True)

ProductName_df
# Out:
#                                             ProductName  Count
# 0     1.7 Cubic Foot Compact "Cube" Office Refrigera...      6
# 1     1/4 Fold Party Design Invitations & White Enve...      2
# 2               10 Gummed Flap White Envelopes, 100/Box      4
# 3                          10 Self-Seal White Envelopes      4
# 4             10 White Business Envelopes,4 1/8 X 9 1/2      7
# ...                                                 ...    ...
# 1845  Zebra Gk420T Direct Thermal/Thermal Transfer P...      1
# 1846  Zebra Gx420T Direct Thermal/Thermal Transfer P...      3
# 1847              Zebra Zazzle Fluorescent Highlighters      6
# 1848                  Zebra Zm400 Thermal Label Printer      2
# 1849                         Zipper Ring Binder Pockets     13
#
# [1850 rows x 2 columns]

# %%
df.nunique()
# Out:
# PurchaseId      5009
# PurchaseDate    1237
# ShipDate        1334
# ShipMode           4
# CustomerId       793
# CustomerName     793
# Segment            3
# Country            1
# City             531
# State             49
# PostalCode       631
# Region             4
# ProductId       1862
# Category           3
# SubCategory       17
# ProductName     1850
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# FirstName        337
# LastName         588
# dtype: int64

# %% [markdown]
# ## 18: Create CatalogPrice and SupplierPrice Columns<a id="18"></a>

# %%
# CatalogPrice
df['CatalogPrice'] = (df['Sales'] / (df['Quantity'] * (1 - df['Discount']))).round(2)

# SupplierPrice
df['SupplierPrice'] = (df['CatalogPrice'] - (df['Profit'] / df['Quantity'])).round(2)

# Ensure no negative SupplierPrice values
df.loc[df['SupplierPrice'] < 0, 'SupplierPrice'] = 0

# %%
df = df.copy().reset_index(drop=True)

# %%
df.head(10).T
# Out:
#                                                0  \
# PurchaseId                        CA-2016-152156
# PurchaseDate                 2016-11-08 00:00:00
# ShipDate                     2016-11-11 00:00:00
# ShipMode                            Second Class
# CustomerId                              CG-12520
# CustomerName                         Claire Gute
# Segment                                 Consumer
# Country                            United States
# City                                   Henderson
# State                                   Kentucky
# PostalCode                                 42420
# Region                                     South
# ProductId                        FUR-BO-10001798
# Category                               Furniture
# SubCategory                            Bookcases
# ProductName    Bush Somerset Collection Bookcase
# Sales                                     261.96
# Quantity                                       2
# Discount                                     0.0
# Profit                                   41.9136
# FirstName                                 Claire
# LastName                                    Gute
# CatalogPrice                              130.98
# SupplierPrice                             110.02
#
#                                                                1  \
# PurchaseId                                        CA-2016-152156
# PurchaseDate                                 2016-11-08 00:00:00
# ShipDate                                     2016-11-11 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              CG-12520
# CustomerName                                         Claire Gute
# Segment                                                 Consumer
# Country                                            United States
# City                                                   Henderson
# State                                                   Kentucky
# PostalCode                                                 42420
# Region                                                     South
# ProductId                                        FUR-CH-10000454
# Category                                               Furniture
# SubCategory                                               Chairs
# ProductName    Hon Deluxe Fabric Upholstered Stacking Chairs,...
# Sales                                                     731.94
# Quantity                                                       3
# Discount                                                     0.0
# Profit                                                   219.582
# FirstName                                                 Claire
# LastName                                                    Gute
# CatalogPrice                                              243.98
# SupplierPrice                                             170.79
#
#                                                                2  \
# PurchaseId                                        CA-2016-138688
# PurchaseDate                                 2016-06-12 00:00:00
# ShipDate                                     2016-06-16 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              DV-13045
# CustomerName                                     Darrin Van Huff
# Segment                                                Corporate
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# PostalCode                                                 90036
# Region                                                      West
# ProductId                                        OFF-LA-10000240
# Category                                         Office Supplies
# SubCategory                                               Labels
# ProductName    Self-Adhesive Address Labels For Typewriters B...
# Sales                                                      14.62
# Quantity                                                       2
# Discount                                                     0.0
# Profit                                                    6.8714
# FirstName                                                 Darrin
# LastName                                                Van Huff
# CatalogPrice                                                7.31
# SupplierPrice                                               3.87
#
#                                                            3  \
# PurchaseId                                    US-2015-108966
# PurchaseDate                             2015-10-11 00:00:00
# ShipDate                                 2015-10-18 00:00:00
# ShipMode                                      Standard Class
# CustomerId                                          SO-20335
# CustomerName                                  Sean O'Donnell
# Segment                                             Consumer
# Country                                        United States
# City                                         Fort Lauderdale
# State                                                Florida
# PostalCode                                             33311
# Region                                                 South
# ProductId                                    FUR-TA-10000577
# Category                                           Furniture
# SubCategory                                           Tables
# ProductName    Bretford Cr4500 Series Slim Rectangular Table
# Sales                                               957.5775
# Quantity                                                   5
# Discount                                                0.45
# Profit                                              -383.031
# FirstName                                               Sean
# LastName                                           O'Donnell
# CatalogPrice                                          348.21
# SupplierPrice                                         424.82
#
#                                             4  \
# PurchaseId                     US-2015-108966
# PurchaseDate              2015-10-11 00:00:00
# ShipDate                  2015-10-18 00:00:00
# ShipMode                       Standard Class
# CustomerId                           SO-20335
# CustomerName                   Sean O'Donnell
# Segment                              Consumer
# Country                         United States
# City                          Fort Lauderdale
# State                                 Florida
# PostalCode                              33311
# Region                                  South
# ProductId                     OFF-ST-10000760
# Category                      Office Supplies
# SubCategory                           Storage
# ProductName    Eldon Fold 'N Roll Cart System
# Sales                                  22.368
# Quantity                                    2
# Discount                                  0.2
# Profit                                 2.5164
# FirstName                                Sean
# LastName                            O'Donnell
# CatalogPrice                            13.98
# SupplierPrice                           12.72
#
#                                                                5  \
# PurchaseId                                        CA-2014-115812
# PurchaseDate                                 2014-06-09 00:00:00
# ShipDate                                     2014-06-14 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              BH-11710
# CustomerName                                     Brosina Hoffman
# Segment                                                 Consumer
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# PostalCode                                                 90032
# Region                                                      West
# ProductId                                        FUR-FU-10001487
# Category                                               Furniture
# SubCategory                                          Furnishings
# ProductName    Eldon Expressions Wood And Plastic Desk Access...
# Sales                                                      48.86
# Quantity                                                       7
# Discount                                                     0.0
# Profit                                                   14.1694
# FirstName                                                Brosina
# LastName                                                 Hoffman
# CatalogPrice                                                6.98
# SupplierPrice                                               4.96
#
#                                  6                               7  \
# PurchaseId          CA-2014-115812                  CA-2014-115812
# PurchaseDate   2014-06-09 00:00:00             2014-06-09 00:00:00
# ShipDate       2014-06-14 00:00:00             2014-06-14 00:00:00
# ShipMode            Standard Class                  Standard Class
# CustomerId                BH-11710                        BH-11710
# CustomerName       Brosina Hoffman                 Brosina Hoffman
# Segment                   Consumer                        Consumer
# Country              United States                   United States
# City                   Los Angeles                     Los Angeles
# State                   California                      California
# PostalCode                   90032                           90032
# Region                        West                            West
# ProductId          OFF-AR-10002833                 TEC-PH-10002275
# Category           Office Supplies                      Technology
# SubCategory                    Art                          Phones
# ProductName             Newell 322  Mitel 5320 Ip Phone Voip Phone
# Sales                         7.28                         907.152
# Quantity                         4                               6
# Discount                       0.0                             0.2
# Profit                      1.9656                         90.7152
# FirstName                  Brosina                         Brosina
# LastName                   Hoffman                         Hoffman
# CatalogPrice                  1.82                          188.99
# SupplierPrice                 1.33                          173.87
#
#                                                                8  \
# PurchaseId                                        CA-2014-115812
# PurchaseDate                                 2014-06-09 00:00:00
# ShipDate                                     2014-06-14 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              BH-11710
# CustomerName                                     Brosina Hoffman
# Segment                                                 Consumer
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# PostalCode                                                 90032
# Region                                                      West
# ProductId                                        OFF-BI-10003910
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Dxl Angle-View Binders With Locking Rings By S...
# Sales                                                     18.504
# Quantity                                                       3
# Discount                                                     0.2
# Profit                                                    5.7825
# FirstName                                                Brosina
# LastName                                                 Hoffman
# CatalogPrice                                                7.71
# SupplierPrice                                               5.78
#
#                                               9
# PurchaseId                       CA-2014-115812
# PurchaseDate                2014-06-09 00:00:00
# ShipDate                    2014-06-14 00:00:00
# ShipMode                         Standard Class
# CustomerId                             BH-11710
# CustomerName                    Brosina Hoffman
# Segment                                Consumer
# Country                           United States
# City                                Los Angeles
# State                                California
# PostalCode                                90032
# Region                                     West
# ProductId                       OFF-AP-10002892
# Category                        Office Supplies
# SubCategory                          Appliances
# ProductName    Belkin F5C206Vtel 6 Outlet Surge
# Sales                                     114.9
# Quantity                                      5
# Discount                                    0.0
# Profit                                    34.47
# FirstName                               Brosina
# LastName                                Hoffman
# CatalogPrice                              22.98
# SupplierPrice                             16.09

# %%
df.head(20).T
# Out:
#                                               0   \
# PurchaseId                        CA-2016-152156
# PurchaseDate                 2016-11-08 00:00:00
# ShipDate                     2016-11-11 00:00:00
# ShipMode                            Second Class
# CustomerId                              CG-12520
# CustomerName                         Claire Gute
# Segment                                 Consumer
# Country                            United States
# City                                   Henderson
# State                                   Kentucky
# PostalCode                                 42420
# Region                                     South
# ProductId                        FUR-BO-10001798
# Category                               Furniture
# SubCategory                            Bookcases
# ProductName    Bush Somerset Collection Bookcase
# Sales                                     261.96
# Quantity                                       2
# Discount                                     0.0
# Profit                                   41.9136
# FirstName                                 Claire
# LastName                                    Gute
# CatalogPrice                              130.98
# SupplierPrice                             110.02
#
#                                                               1   \
# PurchaseId                                        CA-2016-152156
# PurchaseDate                                 2016-11-08 00:00:00
# ShipDate                                     2016-11-11 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              CG-12520
# CustomerName                                         Claire Gute
# Segment                                                 Consumer
# Country                                            United States
# City                                                   Henderson
# State                                                   Kentucky
# PostalCode                                                 42420
# Region                                                     South
# ProductId                                        FUR-CH-10000454
# Category                                               Furniture
# SubCategory                                               Chairs
# ProductName    Hon Deluxe Fabric Upholstered Stacking Chairs,...
# Sales                                                     731.94
# Quantity                                                       3
# Discount                                                     0.0
# Profit                                                   219.582
# FirstName                                                 Claire
# LastName                                                    Gute
# CatalogPrice                                              243.98
# SupplierPrice                                             170.79
#
#                                                               2   \
# PurchaseId                                        CA-2016-138688
# PurchaseDate                                 2016-06-12 00:00:00
# ShipDate                                     2016-06-16 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              DV-13045
# CustomerName                                     Darrin Van Huff
# Segment                                                Corporate
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# PostalCode                                                 90036
# Region                                                      West
# ProductId                                        OFF-LA-10000240
# Category                                         Office Supplies
# SubCategory                                               Labels
# ProductName    Self-Adhesive Address Labels For Typewriters B...
# Sales                                                      14.62
# Quantity                                                       2
# Discount                                                     0.0
# Profit                                                    6.8714
# FirstName                                                 Darrin
# LastName                                                Van Huff
# CatalogPrice                                                7.31
# SupplierPrice                                               3.87
#
#                                                           3   \
# PurchaseId                                    US-2015-108966
# PurchaseDate                             2015-10-11 00:00:00
# ShipDate                                 2015-10-18 00:00:00
# ShipMode                                      Standard Class
# CustomerId                                          SO-20335
# CustomerName                                  Sean O'Donnell
# Segment                                             Consumer
# Country                                        United States
# City                                         Fort Lauderdale
# State                                                Florida
# PostalCode                                             33311
# Region                                                 South
# ProductId                                    FUR-TA-10000577
# Category                                           Furniture
# SubCategory                                           Tables
# ProductName    Bretford Cr4500 Series Slim Rectangular Table
# Sales                                               957.5775
# Quantity                                                   5
# Discount                                                0.45
# Profit                                              -383.031
# FirstName                                               Sean
# LastName                                           O'Donnell
# CatalogPrice                                          348.21
# SupplierPrice                                         424.82
#
#                                            4   \
# PurchaseId                     US-2015-108966
# PurchaseDate              2015-10-11 00:00:00
# ShipDate                  2015-10-18 00:00:00
# ShipMode                       Standard Class
# CustomerId                           SO-20335
# CustomerName                   Sean O'Donnell
# Segment                              Consumer
# Country                         United States
# City                          Fort Lauderdale
# State                                 Florida
# PostalCode                              33311
# Region                                  South
# ProductId                     OFF-ST-10000760
# Category                      Office Supplies
# SubCategory                           Storage
# ProductName    Eldon Fold 'N Roll Cart System
# Sales                                  22.368
# Quantity                                    2
# Discount                                  0.2
# Profit                                 2.5164
# FirstName                                Sean
# LastName                            O'Donnell
# CatalogPrice                            13.98
# SupplierPrice                           12.72
#
#                                                               5   \
# PurchaseId                                        CA-2014-115812
# PurchaseDate                                 2014-06-09 00:00:00
# ShipDate                                     2014-06-14 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              BH-11710
# CustomerName                                     Brosina Hoffman
# Segment                                                 Consumer
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# PostalCode                                                 90032
# Region                                                      West
# ProductId                                        FUR-FU-10001487
# Category                                               Furniture
# SubCategory                                          Furnishings
# ProductName    Eldon Expressions Wood And Plastic Desk Access...
# Sales                                                      48.86
# Quantity                                                       7
# Discount                                                     0.0
# Profit                                                   14.1694
# FirstName                                                Brosina
# LastName                                                 Hoffman
# CatalogPrice                                                6.98
# SupplierPrice                                               4.96
#
#                                 6                               7   \
# PurchaseId          CA-2014-115812                  CA-2014-115812
# PurchaseDate   2014-06-09 00:00:00             2014-06-09 00:00:00
# ShipDate       2014-06-14 00:00:00             2014-06-14 00:00:00
# ShipMode            Standard Class                  Standard Class
# CustomerId                BH-11710                        BH-11710
# CustomerName       Brosina Hoffman                 Brosina Hoffman
# Segment                   Consumer                        Consumer
# Country              United States                   United States
# City                   Los Angeles                     Los Angeles
# State                   California                      California
# PostalCode                   90032                           90032
# Region                        West                            West
# ProductId          OFF-AR-10002833                 TEC-PH-10002275
# Category           Office Supplies                      Technology
# SubCategory                    Art                          Phones
# ProductName             Newell 322  Mitel 5320 Ip Phone Voip Phone
# Sales                         7.28                         907.152
# Quantity                         4                               6
# Discount                       0.0                             0.2
# Profit                      1.9656                         90.7152
# FirstName                  Brosina                         Brosina
# LastName                   Hoffman                         Hoffman
# CatalogPrice                  1.82                          188.99
# SupplierPrice                 1.33                          173.87
#
#                                                               8   \
# PurchaseId                                        CA-2014-115812
# PurchaseDate                                 2014-06-09 00:00:00
# ShipDate                                     2014-06-14 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              BH-11710
# CustomerName                                     Brosina Hoffman
# Segment                                                 Consumer
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# PostalCode                                                 90032
# Region                                                      West
# ProductId                                        OFF-BI-10003910
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Dxl Angle-View Binders With Locking Rings By S...
# Sales                                                     18.504
# Quantity                                                       3
# Discount                                                     0.2
# Profit                                                    5.7825
# FirstName                                                Brosina
# LastName                                                 Hoffman
# CatalogPrice                                                7.71
# SupplierPrice                                               5.78
#
#                                              9   \
# PurchaseId                       CA-2014-115812
# PurchaseDate                2014-06-09 00:00:00
# ShipDate                    2014-06-14 00:00:00
# ShipMode                         Standard Class
# CustomerId                             BH-11710
# CustomerName                    Brosina Hoffman
# Segment                                Consumer
# Country                           United States
# City                                Los Angeles
# State                                California
# PostalCode                                90032
# Region                                     West
# ProductId                       OFF-AP-10002892
# Category                        Office Supplies
# SubCategory                          Appliances
# ProductName    Belkin F5C206Vtel 6 Outlet Surge
# Sales                                     114.9
# Quantity                                      5
# Discount                                    0.0
# Profit                                    34.47
# FirstName                               Brosina
# LastName                                Hoffman
# CatalogPrice                              22.98
# SupplierPrice                             16.09
#
#                                                      10  \
# PurchaseId                               CA-2014-115812
# PurchaseDate                        2014-06-09 00:00:00
# ShipDate                            2014-06-14 00:00:00
# ShipMode                                 Standard Class
# CustomerId                                     BH-11710
# CustomerName                            Brosina Hoffman
# Segment                                        Consumer
# Country                                   United States
# City                                        Los Angeles
# State                                        California
# PostalCode                                        90032
# Region                                             West
# ProductId                               FUR-TA-10001539
# Category                                      Furniture
# SubCategory                                      Tables
# ProductName    Chromcraft Rectangular Conference Tables
# Sales                                          1706.184
# Quantity                                              9
# Discount                                            0.2
# Profit                                          85.3092
# FirstName                                       Brosina
# LastName                                        Hoffman
# CatalogPrice                                     236.97
# SupplierPrice                                    227.49
#
#                                                           11  \
# PurchaseId                                    CA-2014-115812
# PurchaseDate                             2014-06-09 00:00:00
# ShipDate                                 2014-06-14 00:00:00
# ShipMode                                      Standard Class
# CustomerId                                          BH-11710
# CustomerName                                 Brosina Hoffman
# Segment                                             Consumer
# Country                                        United States
# City                                             Los Angeles
# State                                             California
# PostalCode                                             90032
# Region                                                  West
# ProductId                                    TEC-PH-10002033
# Category                                          Technology
# SubCategory                                           Phones
# ProductName    Konftel 250 Conference Phone - Charcoal Black
# Sales                                                911.424
# Quantity                                                   4
# Discount                                                 0.2
# Profit                                               68.3568
# FirstName                                            Brosina
# LastName                                             Hoffman
# CatalogPrice                                          284.82
# SupplierPrice                                         267.73
#
#                                 12  \
# PurchaseId          CA-2017-114412
# PurchaseDate   2017-04-15 00:00:00
# ShipDate       2017-04-20 00:00:00
# ShipMode            Standard Class
# CustomerId                AA-10480
# CustomerName          Andrew Allen
# Segment                   Consumer
# Country              United States
# City                       Concord
# State               North Carolina
# PostalCode                   28027
# Region                       South
# ProductId          OFF-PA-10002365
# Category           Office Supplies
# SubCategory                  Paper
# ProductName             Xerox 1967
# Sales                       15.552
# Quantity                         3
# Discount                       0.2
# Profit                      5.4432
# FirstName                   Andrew
# LastName                     Allen
# CatalogPrice                  6.48
# SupplierPrice                 4.67
#
#                                                         13  \
# PurchaseId                                  CA-2016-161389
# PurchaseDate                           2016-12-05 00:00:00
# ShipDate                               2016-12-10 00:00:00
# ShipMode                                    Standard Class
# CustomerId                                        IM-15070
# CustomerName                                  Irene Maddox
# Segment                                           Consumer
# Country                                      United States
# City                                               Seattle
# State                                           Washington
# PostalCode                                           98103
# Region                                                West
# ProductId                                  OFF-BI-10003656
# Category                                   Office Supplies
# SubCategory                                        Binders
# ProductName    Fellowes Pb200 Plastic Comb Binding Machine
# Sales                                              407.976
# Quantity                                                 3
# Discount                                               0.2
# Profit                                            132.5922
# FirstName                                            Irene
# LastName                                            Maddox
# CatalogPrice                                        169.99
# SupplierPrice                                       125.79
#
#                                                               14  \
# PurchaseId                                        US-2015-118983
# PurchaseDate                                 2015-11-22 00:00:00
# ShipDate                                     2015-11-26 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              HP-14815
# CustomerName                                       Harold Pawlan
# Segment                                              Home Office
# Country                                            United States
# City                                                  Fort Worth
# State                                                      Texas
# PostalCode                                                 76106
# Region                                                   Central
# ProductId                                        OFF-AP-10002311
# Category                                         Office Supplies
# SubCategory                                           Appliances
# ProductName    Holmes Replacement Filter For Hepa Air Cleaner...
# Sales                                                      68.81
# Quantity                                                       5
# Discount                                                     0.8
# Profit                                                  -123.858
# FirstName                                                 Harold
# LastName                                                  Pawlan
# CatalogPrice                                               68.81
# SupplierPrice                                              93.58
#
#                                                              15  \
# PurchaseId                                       US-2015-118983
# PurchaseDate                                2015-11-22 00:00:00
# ShipDate                                    2015-11-26 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             HP-14815
# CustomerName                                      Harold Pawlan
# Segment                                             Home Office
# Country                                           United States
# City                                                 Fort Worth
# State                                                     Texas
# PostalCode                                                76106
# Region                                                  Central
# ProductId                                       OFF-BI-10000756
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName    Storex Duratech Recycled Plastic Frosted Binders
# Sales                                                     2.544
# Quantity                                                      3
# Discount                                                    0.8
# Profit                                                   -3.816
# FirstName                                                Harold
# LastName                                                 Pawlan
# CatalogPrice                                               4.24
# SupplierPrice                                              5.51
#
#                                                               16  \
# PurchaseId                                        CA-2014-105893
# PurchaseDate                                 2014-11-11 00:00:00
# ShipDate                                     2014-11-18 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              PK-19075
# CustomerName                                           Pete Kriz
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Madison
# State                                                  Wisconsin
# PostalCode                                                 53711
# Region                                                   Central
# ProductId                                        OFF-ST-10004186
# Category                                         Office Supplies
# SubCategory                                              Storage
# ProductName    Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H X...
# Sales                                                     665.88
# Quantity                                                       6
# Discount                                                     0.0
# Profit                                                   13.3176
# FirstName                                                   Pete
# LastName                                                    Kriz
# CatalogPrice                                              110.98
# SupplierPrice                                             108.76
#
#                                        17                   18  \
# PurchaseId                 CA-2014-167164       CA-2014-143336
# PurchaseDate          2014-05-13 00:00:00  2014-08-27 00:00:00
# ShipDate              2014-05-15 00:00:00  2014-09-01 00:00:00
# ShipMode                     Second Class         Second Class
# CustomerId                       AG-10270             ZD-21925
# CustomerName              Alejandro Grove   Zuschuss Donatelli
# Segment                          Consumer             Consumer
# Country                     United States        United States
# City                          West Jordan        San Francisco
# State                                Utah           California
# PostalCode                          84084                94109
# Region                               West                 West
# ProductId                 OFF-ST-10000107      OFF-AR-10003056
# Category                  Office Supplies      Office Supplies
# SubCategory                       Storage                  Art
# ProductName    Fellowes Super Stor/Drawer           Newell 341
# Sales                                55.5                 8.56
# Quantity                                2                    2
# Discount                              0.0                  0.0
# Profit                               9.99               2.4824
# FirstName                       Alejandro             Zuschuss
# LastName                            Grove            Donatelli
# CatalogPrice                        27.75                 4.28
# SupplierPrice                       22.76                 3.04
#
#                                     19
# PurchaseId              CA-2014-143336
# PurchaseDate       2014-08-27 00:00:00
# ShipDate           2014-09-01 00:00:00
# ShipMode                  Second Class
# CustomerId                    ZD-21925
# CustomerName        Zuschuss Donatelli
# Segment                       Consumer
# Country                  United States
# City                     San Francisco
# State                       California
# PostalCode                       94109
# Region                            West
# ProductId              TEC-PH-10001949
# Category                    Technology
# SubCategory                     Phones
# ProductName    Cisco Spa 501G Ip Phone
# Sales                           213.48
# Quantity                             3
# Discount                           0.2
# Profit                          16.011
# FirstName                     Zuschuss
# LastName                     Donatelli
# CatalogPrice                     88.95
# SupplierPrice                    83.61

# %% [markdown]
# ## 19: ProductName-ProductId Pairs<a id="19"></a>

# %% [markdown]
# ### Review the unmatch of number of unique values between ProductId (1862) and ProductName (1850) columns

# %%
# check if there are duplicated ProductId values in unique ProductName values

# Count unique ProductId for each ProductName

product_name_counts = df.groupby('ProductName')['ProductId'].nunique().reset_index()

product_name_counts.columns = ['ProductName', 'UniqueProductIdCount']

# Find ProductNames which have more than one ProductId

non_unique_products = product_name_counts[product_name_counts['UniqueProductIdCount'] > 1]


if not non_unique_products.empty:
    print("Non-unique ProductNames:")
    print(non_unique_products)
else:
    print("All ProductNames are unique for ProductIds.")
# Out:
# Non-unique ProductNames:
#                                         ProductName  UniqueProductIdCount
# 5            10- 4 1/8" X 9 1/2" Recycled Envelopes                     2
# 258                         Avery Non-Stick Binders                     2
# 536                               Easy-Staple Paper                     8
# 590                     Eldon Wave Desk Accessories                     2
# 962                      Ki Adjustable-Height Table                     2
# 1223                          Okidata C610N Printer                     2
# 1254  Peel & Seel Recycled Catalog Envelopes, Brown                     2
# 1303                       Prang Drawing Pencil Set                     2
# 1499                                Staple Envelope                     9
# 1500                                  Staple Holder                     3
# 1501                                  Staple Magnet                     2
# 1502                                 Staple Remover                     3
# 1503                     Staple-Based Wall Hangings                     2
# 1505                                        Staples                    10
# 1506                        Staples In Misc. Colors                     7
# 1517                        Storex Dura Pro Binders                     2

# %%
non_unique_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 5 to 1517
# Data columns (total 2 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductName           16 non-null     object
#  1   UniqueProductIdCount  16 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 384.0+ bytes

# %%
# Get the list of ProductNames with more than one unique ProductId

affected_product_names = non_unique_products['ProductName']

# Filter the main DataFrame to include only rows with these ProductNames

affected_entries = df[df['ProductName'].isin(affected_product_names)]

affected_entries.shape[0]
# Out:
# 314

# %% [markdown]
# #### There are 16 ProductName which have multiple ProductId values
# #### Total number of entries with these names is 314 of all entries
# #### We will check ProductName values if they are same product or not

# %%
# check some examples to understand the issue

df_id_name = df[df['ProductName'] == '10- 4 1/8" X 9 1/2" Recycled Envelopes']

df_id_name = df_id_name.sort_values(by='SupplierPrice')

df_id_name.head(20).T
# Out:
#                                                  1989  \
# PurchaseId                             CA-2015-127509
# PurchaseDate                      2015-11-09 00:00:00
# ShipDate                          2015-11-13 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   AS-10090
# CustomerName                       Adam Shillingsburg
# Segment                                      Consumer
# Country                                 United States
# City                                      Springfield
# State                                        Missouri
# PostalCode                                      65807
# Region                                        Central
# ProductId                             OFF-EN-10000781
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                           26.22
# Quantity                                            3
# Discount                                          0.0
# Profit                                        12.3234
# FirstName                                        Adam
# LastName                                Shillingsburg
# CatalogPrice                                     8.74
# SupplierPrice                                    4.63
#
#                                                  2446  \
# PurchaseId                             CA-2015-100573
# PurchaseDate                      2015-09-25 00:00:00
# ShipDate                          2015-10-01 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   AM-10705
# CustomerName                           Anne Mcfarland
# Segment                                      Consumer
# Country                                 United States
# City                                      Los Angeles
# State                                      California
# PostalCode                                      90004
# Region                                           West
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                           17.48
# Quantity                                            2
# Discount                                          0.0
# Profit                                         8.2156
# FirstName                                        Anne
# LastName                                    Mcfarland
# CatalogPrice                                     8.74
# SupplierPrice                                    4.63
#
#                                                  2948  \
# PurchaseId                             CA-2017-169859
# PurchaseDate                      2017-12-14 00:00:00
# ShipDate                          2017-12-18 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   MP-18175
# CustomerName                           Mike Pelletier
# Segment                                   Home Office
# Country                                 United States
# City                                        San Diego
# State                                      California
# PostalCode                                      92024
# Region                                           West
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                            43.7
# Quantity                                            5
# Discount                                          0.0
# Profit                                         20.539
# FirstName                                        Mike
# LastName                                    Pelletier
# CatalogPrice                                     8.74
# SupplierPrice                                    4.63
#
#                                                  4378  \
# PurchaseId                             CA-2015-140830
# PurchaseDate                      2015-11-30 00:00:00
# ShipDate                          2015-12-02 00:00:00
# ShipMode                                 Second Class
# CustomerId                                   PS-18970
# CustomerName                           Paul Stevenson
# Segment                                   Home Office
# Country                                 United States
# City                                        Henderson
# State                                        Kentucky
# PostalCode                                      42420
# Region                                          South
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                           17.48
# Quantity                                            2
# Discount                                          0.0
# Profit                                         8.2156
# FirstName                                        Paul
# LastName                                    Stevenson
# CatalogPrice                                     8.74
# SupplierPrice                                    4.63
#
#                                                  5216  \
# PurchaseId                             US-2017-159562
# PurchaseDate                      2017-09-09 00:00:00
# ShipDate                          2017-09-15 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   JB-16000
# CustomerName                                Joy Bell-
# Segment                                      Consumer
# Country                                 United States
# City                                        Roseville
# State                                        Michigan
# PostalCode                                      48066
# Region                                        Central
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                           17.48
# Quantity                                            2
# Discount                                          0.0
# Profit                                         8.2156
# FirstName                                         Joy
# LastName                                        Bell-
# CatalogPrice                                     8.74
# SupplierPrice                                    4.63
#
#                                                  7720  \
# PurchaseId                             CA-2015-108588
# PurchaseDate                      2015-01-05 00:00:00
# ShipDate                          2015-01-10 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   BG-11695
# CustomerName                        Brooke Gillingham
# Segment                                     Corporate
# Country                                 United States
# City                                    New York City
# State                                        New York
# PostalCode                                      10009
# Region                                           East
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                           17.48
# Quantity                                            2
# Discount                                          0.0
# Profit                                         8.2156
# FirstName                                      Brooke
# LastName                                   Gillingham
# CatalogPrice                                     8.74
# SupplierPrice                                    4.63
#
#                                                  985   \
# PurchaseId                             CA-2017-100314
# PurchaseDate                      2017-09-29 00:00:00
# ShipDate                          2017-10-05 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   AS-10630
# CustomerName                               Ann Steele
# Segment                                   Home Office
# Country                                 United States
# City                                         Pasadena
# State                                           Texas
# PostalCode                                      77506
# Region                                        Central
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                          27.968
# Quantity                                            4
# Discount                                          0.2
# Profit                                         9.4392
# FirstName                                         Ann
# LastName                                       Steele
# CatalogPrice                                     8.74
# SupplierPrice                                    6.38
#
#                                                  4992  \
# PurchaseId                             CA-2015-153038
# PurchaseDate                      2015-12-18 00:00:00
# ShipDate                          2015-12-25 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   RB-19645
# CustomerName                           Robert Barroso
# Segment                                     Corporate
# Country                                 United States
# City                                          Memphis
# State                                       Tennessee
# PostalCode                                      38109
# Region                                          South
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                          55.936
# Quantity                                            8
# Discount                                          0.2
# Profit                                        18.8784
# FirstName                                      Robert
# LastName                                      Barroso
# CatalogPrice                                     8.74
# SupplierPrice                                    6.38
#
#                                                  5688  \
# PurchaseId                             CA-2014-131541
# PurchaseDate                      2014-07-28 00:00:00
# ShipDate                          2014-07-28 00:00:00
# ShipMode                                     Same Day
# CustomerId                                   CK-12205
# CustomerName                      Chloris Kastensmidt
# Segment                                      Consumer
# Country                                 United States
# City                                           Apopka
# State                                         Florida
# PostalCode                                      32712
# Region                                          South
# ProductId                             OFF-EN-10000781
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                          48.944
# Quantity                                            7
# Discount                                          0.2
# Profit                                        16.5186
# FirstName                                     Chloris
# LastName                                  Kastensmidt
# CatalogPrice                                     8.74
# SupplierPrice                                    6.38
#
#                                                  6301
# PurchaseId                             US-2014-161305
# PurchaseDate                      2014-06-06 00:00:00
# ShipDate                          2014-06-12 00:00:00
# ShipMode                               Standard Class
# CustomerId                                   SB-20170
# CustomerName                               Sarah Bern
# Segment                                      Consumer
# Country                                 United States
# City                                          Chicago
# State                                        Illinois
# PostalCode                                      60623
# Region                                        Central
# ProductId                             OFF-EN-10000461
# Category                              Office Supplies
# SubCategory                                 Envelopes
# ProductName    10- 4 1/8" X 9 1/2" Recycled Envelopes
# Sales                                          13.984
# Quantity                                            2
# Discount                                          0.2
# Profit                                         4.7196
# FirstName                                       Sarah
# LastName                                         Bern
# CatalogPrice                                     8.74
# SupplierPrice                                    6.38

# %%
df_id_name[['PurchaseId', 'PurchaseDate', 'ProductId', 'ProductName', 'CatalogPrice', 'SupplierPrice']]
# Out:
#           PurchaseId PurchaseDate        ProductId  \
# 1989  CA-2015-127509   2015-11-09  OFF-EN-10000781
# 2446  CA-2015-100573   2015-09-25  OFF-EN-10000461
# 2948  CA-2017-169859   2017-12-14  OFF-EN-10000461
# 4378  CA-2015-140830   2015-11-30  OFF-EN-10000461
# 5216  US-2017-159562   2017-09-09  OFF-EN-10000461
# 7720  CA-2015-108588   2015-01-05  OFF-EN-10000461
# 985   CA-2017-100314   2017-09-29  OFF-EN-10000461
# 4992  CA-2015-153038   2015-12-18  OFF-EN-10000461
# 5688  CA-2014-131541   2014-07-28  OFF-EN-10000781
# 6301  US-2014-161305   2014-06-06  OFF-EN-10000461
#
#                                  ProductName  CatalogPrice  SupplierPrice
# 1989  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           4.63
# 2446  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           4.63
# 2948  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           4.63
# 4378  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           4.63
# 5216  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           4.63
# 7720  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           4.63
# 985   10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           6.38
# 4992  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           6.38
# 5688  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           6.38
# 6301  10- 4 1/8" X 9 1/2" Recycled Envelopes          8.74           6.38

# %%
df_id_name.value_counts('ProductId')
# Out:
# ProductId
# OFF-EN-10000461    8
# OFF-EN-10000781    2
# Name: count, dtype: int64

# %%
df_id_name = df[df['ProductName'] == 'Avery Non-Stick Binders']

df_id_name = df_id_name.sort_values(by='SupplierPrice')

df_id_name.head(20).T
# Out:
#                                   6268                     2531  \
# PurchaseId              CA-2015-115392           CA-2014-111500
# PurchaseDate       2015-10-01 00:00:00      2014-08-17 00:00:00
# ShipDate           2015-10-04 00:00:00      2014-08-21 00:00:00
# ShipMode                  Second Class           Standard Class
# CustomerId                    RM-19675                 DJ-13510
# CustomerName             Robert Marley                Don Jones
# Segment                    Home Office                Corporate
# Country                  United States            United States
# City                         Cambridge              Little Rock
# State                    Massachusetts                 Arkansas
# PostalCode                       02138                    72209
# Region                            East                    South
# ProductId              OFF-BI-10000829          OFF-BI-10000829
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            22.45                    17.96
# Quantity                             5                        4
# Discount                           0.0                      0.0
# Profit                          10.327                   8.2616
# FirstName                       Robert                      Don
# LastName                        Marley                    Jones
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     2.42                     2.42
#
#                                   5386                     7010  \
# PurchaseId              CA-2017-152786           US-2014-135881
# PurchaseDate       2017-03-12 00:00:00      2014-05-23 00:00:00
# ShipDate           2017-03-17 00:00:00      2014-05-27 00:00:00
# ShipMode                Standard Class           Standard Class
# CustomerId                    GA-14725                 GT-14710
# CustomerName             Guy Armstrong                Greg Tran
# Segment                       Consumer                 Consumer
# Country                  United States            United States
# City                            Rogers            New York City
# State                         Arkansas                 New York
# PostalCode                       72756                    10035
# Region                           South                     East
# ProductId              OFF-BI-10000829          OFF-BI-10000829
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            40.41                    17.96
# Quantity                             9                        5
# Discount                           0.0                      0.2
# Profit                         18.5886                    5.837
# FirstName                          Guy                     Greg
# LastName                     Armstrong                     Tran
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     2.42                     3.32
#
#                                   5522                     2651  \
# PurchaseId              CA-2016-110982           CA-2017-112515
# PurchaseDate       2016-06-05 00:00:00      2017-09-17 00:00:00
# ShipDate           2016-06-07 00:00:00      2017-09-21 00:00:00
# ShipMode                   First Class             Second Class
# CustomerId                    CK-12205                 AS-10225
# CustomerName       Chloris Kastensmidt        Alan Schoenberger
# Segment                       Consumer                Corporate
# Country                  United States            United States
# City                       Santa Clara                    Provo
# State                       California                     Utah
# PostalCode                       95051                    84604
# Region                            West                     West
# ProductId              OFF-BI-10000829          OFF-BI-10000829
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                           21.552                   10.776
# Quantity                             6                        3
# Discount                           0.2                      0.2
# Profit                          7.0044                   3.5022
# FirstName                      Chloris                     Alan
# LastName                   Kastensmidt             Schoenberger
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     3.32                     3.32
#
#                                   3099                     336   \
# PurchaseId              CA-2017-131233           CA-2015-137946
# PurchaseDate       2017-04-14 00:00:00      2015-09-01 00:00:00
# ShipDate           2017-04-19 00:00:00      2015-09-04 00:00:00
# ShipMode                Standard Class             Second Class
# CustomerId                    CS-12355                 DB-13615
# CustomerName      Christine Sundaresam            Doug Bickford
# Segment                       Consumer                 Consumer
# Country                  United States            United States
# City                     New York City              Los Angeles
# State                         New York               California
# PostalCode                       10024                    90045
# Region                            East                     West
# ProductId              OFF-BI-10000829          OFF-BI-10004140
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                           10.776                   14.368
# Quantity                             3                        4
# Discount                           0.2                      0.2
# Profit                          3.5022                     4.49
# FirstName                    Christine                     Doug
# LastName                    Sundaresam                 Bickford
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     3.32                     3.37
#
#                                   5143                     5114  \
# PurchaseId              CA-2016-111213           CA-2016-150658
# PurchaseDate       2016-04-01 00:00:00      2016-11-17 00:00:00
# ShipDate           2016-04-05 00:00:00      2016-11-22 00:00:00
# ShipMode                Standard Class           Standard Class
# CustomerId                    FP-14320                 MS-17365
# CustomerName               Frank Preis      Maribeth Schnelling
# Segment                       Consumer                 Consumer
# Country                  United States            United States
# City                     New York City                 Carlsbad
# State                         New York               New Mexico
# PostalCode                       10009                    88220
# Region                            East                     West
# ProductId              OFF-BI-10004140          OFF-BI-10004140
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            3.592                   10.776
# Quantity                             1                        3
# Discount                           0.2                      0.2
# Profit                          1.1225                   3.3675
# FirstName                        Frank                 Maribeth
# LastName                         Preis               Schnelling
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     3.37                     3.37
#
#                                   4274                     3842  \
# PurchaseId              CA-2015-142692           CA-2014-101931
# PurchaseDate       2015-10-23 00:00:00      2014-10-28 00:00:00
# ShipDate           2015-10-28 00:00:00      2014-10-31 00:00:00
# ShipMode                Standard Class              First Class
# CustomerId                    AG-10495                 TS-21370
# CustomerName           Andrew Gjertsen             Todd Sumrall
# Segment                      Corporate                Corporate
# Country                  United States            United States
# City                           Seattle              Los Angeles
# State                       Washington               California
# PostalCode                       98105                    90049
# Region                            West                     West
# ProductId              OFF-BI-10004140          OFF-BI-10004140
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            3.592                    7.184
# Quantity                             1                        2
# Discount                           0.2                      0.2
# Profit                          1.1225                    2.245
# FirstName                       Andrew                     Todd
# LastName                      Gjertsen                  Sumrall
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     3.37                     3.37
#
#                                   1848                     4844  \
# PurchaseId              CA-2017-128370           US-2014-128685
# PurchaseDate       2017-09-10 00:00:00      2014-04-04 00:00:00
# ShipDate           2017-09-10 00:00:00      2014-04-05 00:00:00
# ShipMode                      Same Day              First Class
# CustomerId                    FH-14275                 MZ-17515
# CustomerName              Frank Hawley                Mary Zewe
# Segment                      Corporate                Corporate
# Country                  United States            United States
# City                       Los Angeles              Los Angeles
# State                       California               California
# PostalCode                       90004                    90008
# Region                            West                     West
# ProductId              OFF-BI-10004140          OFF-BI-10004140
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            7.184                    7.184
# Quantity                             2                        2
# Discount                           0.2                      0.2
# Profit                           2.245                    2.245
# FirstName                        Frank                     Mary
# LastName                        Hawley                     Zewe
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     3.37                     3.37
#
#                                   7191                     3687  \
# PurchaseId              CA-2016-116918           CA-2016-108567
# PurchaseDate       2016-10-01 00:00:00      2016-05-20 00:00:00
# ShipDate           2016-10-06 00:00:00      2016-05-24 00:00:00
# ShipMode                  Second Class           Standard Class
# CustomerId                    JK-15205                 DB-13210
# CustomerName              Jamie Kunitz              Dean Braden
# Segment                       Consumer                 Consumer
# Country                  United States            United States
# City                           Hialeah         Port Saint Lucie
# State                          Florida                  Florida
# PostalCode                       33012                    34952
# Region                           South                    South
# ProductId              OFF-BI-10004140          OFF-BI-10004140
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            5.388                    2.694
# Quantity                             4                        2
# Discount                           0.7                      0.7
# Profit                           -4.49                   -2.245
# FirstName                        Jamie                     Dean
# LastName                        Kunitz                   Braden
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     5.61                     5.61
#
#                                   5486                     2167  \
# PurchaseId              CA-2015-156608           CA-2016-154018
# PurchaseDate       2015-10-24 00:00:00      2016-10-13 00:00:00
# ShipDate           2015-10-29 00:00:00      2016-10-19 00:00:00
# ShipMode                Standard Class           Standard Class
# CustomerId                    MT-18070                 HA-14920
# CustomerName             Michelle Tran           Helen Andreada
# Segment                    Home Office                 Consumer
# Country                  United States            United States
# City                       San Antonio                   Laredo
# State                            Texas                    Texas
# PostalCode                       78207                    78041
# Region                         Central                  Central
# ProductId              OFF-BI-10004140          OFF-BI-10004140
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            3.592                    6.286
# Quantity                             4                        7
# Discount                           0.8                      0.8
# Profit                          -6.286                 -11.0005
# FirstName                     Michelle                    Helen
# LastName                          Tran                 Andreada
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     6.06                     6.06
#
#                                   1102                     7548
# PurchaseId              US-2017-145863           CA-2014-103492
# PurchaseDate       2017-04-21 00:00:00      2014-10-10 00:00:00
# ShipDate           2017-04-27 00:00:00      2014-10-15 00:00:00
# ShipMode                Standard Class           Standard Class
# CustomerId                    RP-19390                 CM-12715
# CustomerName              Resi Pölking           Craig Molinari
# Segment                       Consumer                Corporate
# Country                  United States            United States
# City                           Houston               Huntsville
# State                            Texas                    Texas
# PostalCode                       77041                    77340
# Region                         Central                  Central
# ProductId              OFF-BI-10004140          OFF-BI-10004140
# Category               Office Supplies          Office Supplies
# SubCategory                    Binders                  Binders
# ProductName    Avery Non-Stick Binders  Avery Non-Stick Binders
# Sales                            2.694                    0.898
# Quantity                             3                        1
# Discount                           0.8                      0.8
# Profit                         -4.7145                  -1.5715
# FirstName                         Resi                    Craig
# LastName                       Pölking                 Molinari
# CatalogPrice                      4.49                     4.49
# SupplierPrice                     6.06                     6.06

# %% [markdown]
# ### Both ProductId values have same CatalogPrice but different SupplierPrices. Hard to detect if It is same product or 2 different products.
#
# * Despite having the same ProductId, CatalogPrice and ProductName, there are differences at SupplierPrices which shows they may be different products.
# * they may also be the same product which is coming with different prices in different times.

# %%
# Filter the DataFrame to include only rows where ProductName is 'Easy-Staple Paper'
df_id_name = df[df['ProductName'] == 'Easy-Staple Paper']

# Sort by SupplierPrice (ascending order by default)
df_id_name = df_id_name.sort_values(by='SupplierPrice')

# Display the first 50 rows transposed for better readability
df_id_name.head(10).T
# Out:
#                               5896                 8669                 9965  \
# PurchaseId          CA-2014-168305       CA-2015-158918       CA-2016-146374
# PurchaseDate   2014-11-01 00:00:00  2015-12-20 00:00:00  2016-12-05 00:00:00
# ShipDate       2014-11-08 00:00:00  2015-12-25 00:00:00  2016-12-10 00:00:00
# ShipMode            Standard Class         Second Class         Second Class
# CustomerId                PL-18925             AI-10855             HE-14800
# CustomerName            Paul Lucas       Arianne Irving         Harold Engle
# Segment                Home Office             Consumer            Corporate
# Country              United States        United States        United States
# City                   Los Angeles          Los Angeles               Newark
# State                   California           California             Delaware
# PostalCode                   90049                90036                19711
# Region                        West                 West                 East
# ProductId          OFF-PA-10004947      OFF-PA-10004947      OFF-PA-10000349
# Category           Office Supplies      Office Supplies      Office Supplies
# SubCategory                  Paper                Paper                Paper
# ProductName      Easy-Staple Paper    Easy-Staple Paper    Easy-Staple Paper
# Sales                         21.4                17.12                 4.98
# Quantity                         5                    4                    1
# Discount                       0.0                  0.0                  0.0
# Profit                        9.63                7.704               2.3406
# FirstName                     Paul              Arianne               Harold
# LastName                     Lucas               Irving                Engle
# CatalogPrice                  4.28                 4.28                 4.98
# SupplierPrice                 2.35                 2.35                 2.64
#
#                               1080                 1702                 3653  \
# PurchaseId          CA-2015-110016       CA-2015-114069       CA-2017-109960
# PurchaseDate   2015-11-29 00:00:00  2015-07-13 00:00:00  2017-12-09 00:00:00
# ShipDate       2015-12-04 00:00:00  2015-07-15 00:00:00  2017-12-11 00:00:00
# ShipMode            Standard Class         Second Class         Second Class
# CustomerId                BT-11395             ND-18370             DB-13210
# CustomerName            Bill Tyler    Natalie Decherney          Dean Braden
# Segment                  Corporate             Consumer             Consumer
# Country              United States        United States        United States
# City                       Detroit        New York City              Detroit
# State                     Michigan             New York             Michigan
# PostalCode                   48227                10035                48234
# Region                     Central                 East              Central
# ProductId          OFF-PA-10000349      OFF-PA-10000349      OFF-PA-10000349
# Category           Office Supplies      Office Supplies      Office Supplies
# SubCategory                  Paper                Paper                Paper
# ProductName      Easy-Staple Paper    Easy-Staple Paper    Easy-Staple Paper
# Sales                        19.92                 9.96                14.94
# Quantity                         4                    2                    3
# Discount                       0.0                  0.0                  0.0
# Profit                      9.3624               4.6812               7.0218
# FirstName                     Bill              Natalie                 Dean
# LastName                     Tyler            Decherney               Braden
# CatalogPrice                  4.98                 4.98                 4.98
# SupplierPrice                 2.64                 2.64                 2.64
#
#                               4930                 2601                 7468  \
# PurchaseId          US-2014-138828       CA-2016-165848       CA-2014-138100
# PurchaseDate   2014-09-02 00:00:00  2016-06-04 00:00:00  2014-09-15 00:00:00
# ShipDate       2014-09-03 00:00:00  2016-06-04 00:00:00  2014-09-20 00:00:00
# ShipMode               First Class             Same Day       Standard Class
# CustomerId                KD-16345             EN-13780             AA-10315
# CustomerName      Katherine Ducich        Edward Nazzal           Alex Avila
# Segment                   Consumer             Consumer             Consumer
# Country              United States        United States        United States
# City                 New York City        New York City        New York City
# State                     New York             New York             New York
# PostalCode                   10009                10035                10011
# Region                        East                 East                 East
# ProductId          OFF-PA-10000349      OFF-PA-10000349      OFF-PA-10000349
# Category           Office Supplies      Office Supplies      Office Supplies
# SubCategory                  Paper                Paper                Paper
# ProductName      Easy-Staple Paper    Easy-Staple Paper    Easy-Staple Paper
# Sales                        14.94                14.94                14.94
# Quantity                         3                    3                    3
# Discount                       0.0                  0.0                  0.0
# Profit                      7.0218               7.0218               7.0218
# FirstName                Katherine               Edward                 Alex
# LastName                    Ducich               Nazzal                Avila
# CatalogPrice                  4.98                 4.98                 4.98
# SupplierPrice                 2.64                 2.64                 2.64
#
#                               1747
# PurchaseId          CA-2016-155670
# PurchaseDate   2016-08-13 00:00:00
# ShipDate       2016-08-17 00:00:00
# ShipMode              Second Class
# CustomerId                EM-14065
# CustomerName             Erin Mull
# Segment                   Consumer
# Country              United States
# City                  Jacksonville
# State               North Carolina
# PostalCode                   28540
# Region                       South
# ProductId          OFF-PA-10004947
# Category           Office Supplies
# SubCategory                  Paper
# ProductName      Easy-Staple Paper
# Sales                       10.272
# Quantity                         3
# Discount                       0.2
# Profit                        3.21
# FirstName                     Erin
# LastName                      Mull
# CatalogPrice                  4.28
# SupplierPrice                 3.21

# %%
df_id_name.value_counts('ProductId')
# Out:
# ProductId
# OFF-PA-10000474    12
# OFF-PA-10000349     9
# OFF-PA-10000249     6
# OFF-PA-10003127     6
# OFF-PA-10001685     5
# OFF-PA-10002764     3
# OFF-PA-10004947     3
# OFF-PA-10000565     2
# Name: count, dtype: int64

# %%
df_id_name[['PurchaseId', 'PurchaseDate', 'ProductId', 'ProductName', 'CatalogPrice', 'SupplierPrice']].sort_values(by=['ProductId','PurchaseDate'])
# Out:
#           PurchaseId PurchaseDate        ProductId        ProductName  \
# 2734  CA-2015-129770   2015-02-21  OFF-PA-10000249  Easy-Staple Paper
# 8573  CA-2015-164623   2015-10-20  OFF-PA-10000249  Easy-Staple Paper
# 7101  CA-2016-144337   2016-08-01  OFF-PA-10000249  Easy-Staple Paper
# 8147  US-2017-146822   2017-06-09  OFF-PA-10000249  Easy-Staple Paper
# 347   CA-2017-134306   2017-07-08  OFF-PA-10000249  Easy-Staple Paper
# 34    CA-2017-107727   2017-10-19  OFF-PA-10000249  Easy-Staple Paper
# 4930  US-2014-138828   2014-09-02  OFF-PA-10000349  Easy-Staple Paper
# 7468  CA-2014-138100   2014-09-15  OFF-PA-10000349  Easy-Staple Paper
# 9418  CA-2014-148285   2014-10-27  OFF-PA-10000349  Easy-Staple Paper
# 4131  CA-2015-111703   2015-07-02  OFF-PA-10000349  Easy-Staple Paper
# 1702  CA-2015-114069   2015-07-13  OFF-PA-10000349  Easy-Staple Paper
# 1080  CA-2015-110016   2015-11-29  OFF-PA-10000349  Easy-Staple Paper
# 2601  CA-2016-165848   2016-06-04  OFF-PA-10000349  Easy-Staple Paper
# 9965  CA-2016-146374   2016-12-05  OFF-PA-10000349  Easy-Staple Paper
# 3653  CA-2017-109960   2017-12-09  OFF-PA-10000349  Easy-Staple Paper
# 8596  CA-2014-111934   2014-05-05  OFF-PA-10000474  Easy-Staple Paper
# 1028  CA-2014-163552   2014-07-11  OFF-PA-10000474  Easy-Staple Paper
# 7090  CA-2015-119480   2015-01-09  OFF-PA-10000474  Easy-Staple Paper
# 9880  CA-2015-104297   2015-05-29  OFF-PA-10000474  Easy-Staple Paper
# 283   CA-2015-130883   2015-09-26  OFF-PA-10000474  Easy-Staple Paper
# 8008  CA-2015-110863   2015-11-17  OFF-PA-10000474  Easy-Staple Paper
# 3446  CA-2016-158869   2016-08-06  OFF-PA-10000474  Easy-Staple Paper
# 2667  CA-2016-111794   2016-10-01  OFF-PA-10000474  Easy-Staple Paper
# 8997  CA-2017-122763   2017-03-20  OFF-PA-10000474  Easy-Staple Paper
# 8415  CA-2017-107265   2017-04-06  OFF-PA-10000474  Easy-Staple Paper
# 666   CA-2017-132682   2017-06-08  OFF-PA-10000474  Easy-Staple Paper
# 2304  CA-2017-157931   2017-09-17  OFF-PA-10000474  Easy-Staple Paper
# 4360  CA-2016-127642   2016-05-21  OFF-PA-10000565  Easy-Staple Paper
# 9498  CA-2017-118213   2017-11-05  OFF-PA-10000565  Easy-Staple Paper
# 1874  CA-2014-147914   2014-06-04  OFF-PA-10001685  Easy-Staple Paper
# 1451  CA-2016-133711   2016-11-26  OFF-PA-10001685  Easy-Staple Paper
# 1225  CA-2016-126004   2016-12-04  OFF-PA-10001685  Easy-Staple Paper
# 3357  CA-2017-100335   2017-09-07  OFF-PA-10001685  Easy-Staple Paper
# 9239  CA-2017-110310   2017-10-27  OFF-PA-10001685  Easy-Staple Paper
# 4999  CA-2016-129238   2016-01-31  OFF-PA-10002764  Easy-Staple Paper
# 7640  CA-2017-104885   2017-03-02  OFF-PA-10002764  Easy-Staple Paper
# 5903  US-2017-153948   2017-11-06  OFF-PA-10002764  Easy-Staple Paper
# 5810  US-2015-163279   2015-03-22  OFF-PA-10003127  Easy-Staple Paper
# 7461  US-2015-136987   2015-04-11  OFF-PA-10003127  Easy-Staple Paper
# 1083  US-2016-143819   2016-03-01  OFF-PA-10003127  Easy-Staple Paper
# 9530  CA-2017-111759   2017-07-08  OFF-PA-10003127  Easy-Staple Paper
# 4254  CA-2017-163160   2017-10-13  OFF-PA-10003127  Easy-Staple Paper
# 3046  CA-2017-125290   2017-11-06  OFF-PA-10003127  Easy-Staple Paper
# 5896  CA-2014-168305   2014-11-01  OFF-PA-10004947  Easy-Staple Paper
# 8669  CA-2015-158918   2015-12-20  OFF-PA-10004947  Easy-Staple Paper
# 1747  CA-2016-155670   2016-08-13  OFF-PA-10004947  Easy-Staple Paper
#
#       CatalogPrice  SupplierPrice
# 2734         12.28           6.51
# 8573         12.28           6.51
# 7101         12.28           8.96
# 8147         12.28           6.51
# 347          12.28           6.51
# 34           12.28           8.96
# 4930          4.98           2.64
# 7468          4.98           2.64
# 9418          4.98           3.64
# 4131          4.98           3.64
# 1702          4.98           2.64
# 1080          4.98           2.64
# 2601          4.98           2.64
# 9965          4.98           2.64
# 3653          4.98           2.64
# 8596         35.44          18.78
# 1028         35.44          18.78
# 7090         35.44          18.78
# 9880         35.44          25.87
# 283          35.44          25.87
# 8008         35.44          18.78
# 3446         35.44          18.78
# 2667         35.44          25.87
# 8997         35.44          25.87
# 8415         35.44          18.78
# 666          35.44          25.87
# 2304         35.44          18.78
# 4360         55.98          28.55
# 9498         55.98          28.55
# 1874         10.14           7.20
# 1451         10.14           5.17
# 1225         10.14           5.17
# 3357         10.14           7.20
# 9239         10.14           7.20
# 4999         11.34           5.78
# 7640         11.34           5.78
# 5903         11.34           5.78
# 5810         26.38          14.25
# 7461         26.38          14.25
# 1083         26.38          14.25
# 9530         26.38          14.25
# 4254         26.38          19.52
# 3046         26.38          14.25
# 5896          4.28           2.35
# 8669          4.28           2.35
# 1747          4.28           3.21

# %% [markdown]
# #### 8 different ProductId with a big Price difference(from 2.35 to 28.55) sharing same name.

# %%
# Run same function to see ProductId values which have multiple ProductNames

# Count unique ProductName per ProductId
product_id_counts = df.groupby('ProductId')['ProductName'].nunique().reset_index()

# Rename columns for clarity
product_id_counts.columns = ['ProductId', 'UniqueProductNameCount']

# Find ProductNames associated with more than one ProductId
non_unique_products = product_id_counts[product_id_counts['UniqueProductNameCount'] > 1]

# Check if there are any such products
if not non_unique_products.empty:
    print("Non-unique ProductNames:")
    print(non_unique_products)
else:
    print("All ProductNames are unique across ProductIds.")
# Out:
# Non-unique ProductNames:
#             ProductId  UniqueProductNameCount
# 18    FUR-BO-10002213                       2
# 65    FUR-CH-10001146                       2
# 183   FUR-FU-10001473                       2
# 284   FUR-FU-10004017                       2
# 290   FUR-FU-10004091                       2
# 295   FUR-FU-10004270                       2
# 310   FUR-FU-10004848                       2
# 311   FUR-FU-10004864                       2
# 387   OFF-AP-10000576                       2
# 506   OFF-AR-10001149                       2
# 721   OFF-BI-10002026                       2
# 831   OFF-BI-10004632                       2
# 832   OFF-BI-10004654                       2
# 1044  OFF-PA-10000357                       2
# 1049  OFF-PA-10000477                       2
# 1064  OFF-PA-10000659                       2
# 1086  OFF-PA-10001166                       2
# 1144  OFF-PA-10001970                       2
# 1156  OFF-PA-10002195                       2
# 1168  OFF-PA-10002377                       2
# 1198  OFF-PA-10003022                       2
# 1331  OFF-ST-10001228                       2
# 1418  OFF-ST-10004950                       2
# 1517  TEC-AC-10002049                       2
# 1533  TEC-AC-10002550                       2
# 1569  TEC-AC-10003832                       2
# 1632  TEC-MA-10001148                       2
# 1728  TEC-PH-10001530                       2
# 1740  TEC-PH-10001795                       2
# 1759  TEC-PH-10002200                       2
# 1763  TEC-PH-10002310                       2
# 1843  TEC-PH-10004531                       2

# %%
non_unique_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32 entries, 18 to 1843
# Data columns (total 2 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ProductId               32 non-null     object
#  1   UniqueProductNameCount  32 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 768.0+ bytes

# %%
# Get unique ProductId values from non_unique_products

non_unique_product_ids = non_unique_products['ProductId'].unique()  

# Filter the main DataFrame where ProductId is in non_unique_products

matching_rows = df[df['ProductId'].isin(non_unique_product_ids)]

matching_rows.shape[0]
# Out:
# 337

# %%
df_id_name = df[df['ProductId'] == 'FUR-BO-10002213']

df_id_name = df_id_name.sort_values(by='SupplierPrice')

df_id_name.head(20).T
# Out:
#                                                            2808  \
# PurchaseId                                       CA-2015-148635
# PurchaseDate                                2015-07-25 00:00:00
# ShipDate                                    2015-07-27 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             MH-18025
# CustomerName                                 Michelle Huthwaite
# Segment                                                Consumer
# Country                                           United States
# City                                                    Seattle
# State                                                Washington
# PostalCode                                                98115
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                     704.9
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                   56.392
# FirstName                                              Michelle
# LastName                                              Huthwaite
# CatalogPrice                                             140.98
# SupplierPrice                                             129.7
#
#                                                            5079  \
# PurchaseId                                       US-2017-133312
# PurchaseDate                                2017-11-25 00:00:00
# ShipDate                                    2017-11-29 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             BD-11500
# CustomerName                                    Bradley Drucker
# Segment                                                Consumer
# Country                                           United States
# City                                              San Francisco
# State                                                California
# PostalCode                                                94122
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   359.499
# Quantity                                                      3
# Discount                                                   0.15
# Profit                                                 -29.6058
# FirstName                                               Bradley
# LastName                                                Drucker
# CatalogPrice                                             140.98
# SupplierPrice                                            150.85
#
#                                                            8712  \
# PurchaseId                                       US-2015-145422
# PurchaseDate                                2015-12-03 00:00:00
# ShipDate                                    2015-12-07 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PW-19240
# CustomerName                                       Pierre Wener
# Segment                                                Consumer
# Country                                           United States
# City                                              San Francisco
# State                                                California
# PostalCode                                                94110
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   359.499
# Quantity                                                      3
# Discount                                                   0.15
# Profit                                                 -29.6058
# FirstName                                                Pierre
# LastName                                                  Wener
# CatalogPrice                                             140.98
# SupplierPrice                                            150.85
#
#                                                            2471  \
# PurchaseId                                       US-2016-135923
# PurchaseDate                                2016-01-22 00:00:00
# ShipDate                                    2016-01-28 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             CM-11935
# CustomerName                                      Carlos Meador
# Segment                                                Consumer
# Country                                           United States
# City                                               Fayetteville
# State                                            North Carolina
# PostalCode                                                28314
# Region                                                    South
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   451.136
# Quantity                                                      4
# Discount                                                    0.2
# Profit                                                 -67.6704
# FirstName                                                Carlos
# LastName                                                 Meador
# CatalogPrice                                             140.98
# SupplierPrice                                             157.9
#
#                                                 2115  \
# PurchaseId                            CA-2015-164882
# PurchaseDate                     2015-10-31 00:00:00
# ShipDate                         2015-10-31 00:00:00
# ShipMode                                    Same Day
# CustomerId                                  SG-20080
# CustomerName                          Sandra Glassco
# Segment                                     Consumer
# Country                                United States
# City                                        Redlands
# State                                     California
# PostalCode                                     92374
# Region                                          West
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        425.833
# Quantity                                           1
# Discount                                        0.15
# Profit                                       20.0392
# FirstName                                     Sandra
# LastName                                     Glassco
# CatalogPrice                                  500.98
# SupplierPrice                                 480.94
#
#                                                 9649  \
# PurchaseId                            CA-2016-107104
# PurchaseDate                     2016-11-26 00:00:00
# ShipDate                         2016-11-30 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  MS-17365
# CustomerName                     Maribeth Schnelling
# Segment                                     Consumer
# Country                                United States
# City                                     Los Angeles
# State                                     California
# PostalCode                                     90045
# Region                                          West
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                       3406.664
# Quantity                                           8
# Discount                                        0.15
# Profit                                      160.3136
# FirstName                                   Maribeth
# LastName                                  Schnelling
# CatalogPrice                                  500.98
# SupplierPrice                                 480.94
#
#                                                 5918  \
# PurchaseId                            US-2015-126977
# PurchaseDate                     2015-09-17 00:00:00
# ShipDate                         2015-09-23 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  PF-19120
# CustomerName                            Peter Fuller
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10035
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        2003.92
# Quantity                                           5
# Discount                                         0.2
# Profit                                       -25.049
# FirstName                                      Peter
# LastName                                      Fuller
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
#
#                                                 6535  \
# PurchaseId                            CA-2014-128209
# PurchaseDate                     2014-11-17 00:00:00
# ShipDate                         2014-11-22 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  GT-14710
# CustomerName                               Greg Tran
# Segment                                     Consumer
# Country                                United States
# City                                         Buffalo
# State                                       New York
# PostalCode                                     14215
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        4007.84
# Quantity                                          10
# Discount                                         0.2
# Profit                                       -50.098
# FirstName                                       Greg
# LastName                                        Tran
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
#
#                                                 9395  \
# PurchaseId                            CA-2014-125997
# PurchaseDate                     2014-09-20 00:00:00
# ShipDate                         2014-09-23 00:00:00
# ShipMode                                 First Class
# CustomerId                                  MW-18220
# CustomerName                            Mitch Webber
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10011
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        801.568
# Quantity                                           2
# Discount                                         0.2
# Profit                                      -10.0196
# FirstName                                      Mitch
# LastName                                      Webber
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
#
#                                                 9583
# PurchaseId                            CA-2017-116127
# PurchaseDate                     2017-06-25 00:00:00
# ShipDate                         2017-06-27 00:00:00
# ShipMode                                Second Class
# CustomerId                                  SB-20185
# CustomerName                             Sarah Brown
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10024
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        400.784
# Quantity                                           1
# Discount                                         0.2
# Profit                                       -5.0098
# FirstName                                      Sarah
# LastName                                       Brown
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99

# %% [markdown]
# #### They are 2 different products with different names and price difference shows it. SupplierPrices has changed within the time for both products too.

# %%
unique_pairs = df[['ProductId', 'ProductName']].drop_duplicates()

unique_pairs.shape[0]
# Out:
# 1894

# %% [markdown]
# ### Despite SupplierPrice may vary, CatalogPrice is always same. So we will take this as reference to standardize ProductId values.

# %%
# Group by ProductId and check unique CatalogPrice values for each group

catalog_price_counts = df.groupby('ProductId')['CatalogPrice'].nunique().reset_index()

# Filter to find ProductIds with more than 1 unique CatalogPrice

non_standard_product_ids = catalog_price_counts[catalog_price_counts['CatalogPrice'] > 1]

# Merge back with the original DataFrame to see the details of these ProductId-CatalogPrice pairs

non_standard_products = df[df['ProductId'].isin(non_standard_product_ids['ProductId'])]

non_standard_products = non_standard_products.sort_values(by='ProductId')

# Display the non-standard ProductId entries

non_standard_products.head(20).T
# Out:
#                                                            5079  \
# PurchaseId                                       US-2017-133312
# PurchaseDate                                2017-11-25 00:00:00
# ShipDate                                    2017-11-29 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             BD-11500
# CustomerName                                    Bradley Drucker
# Segment                                                Consumer
# Country                                           United States
# City                                              San Francisco
# State                                                California
# PostalCode                                                94122
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   359.499
# Quantity                                                      3
# Discount                                                   0.15
# Profit                                                 -29.6058
# FirstName                                               Bradley
# LastName                                                Drucker
# CatalogPrice                                             140.98
# SupplierPrice                                            150.85
#
#                                                            2471  \
# PurchaseId                                       US-2016-135923
# PurchaseDate                                2016-01-22 00:00:00
# ShipDate                                    2016-01-28 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             CM-11935
# CustomerName                                      Carlos Meador
# Segment                                                Consumer
# Country                                           United States
# City                                               Fayetteville
# State                                            North Carolina
# PostalCode                                                28314
# Region                                                    South
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   451.136
# Quantity                                                      4
# Discount                                                    0.2
# Profit                                                 -67.6704
# FirstName                                                Carlos
# LastName                                                 Meador
# CatalogPrice                                             140.98
# SupplierPrice                                             157.9
#
#                                                 9649  \
# PurchaseId                            CA-2016-107104
# PurchaseDate                     2016-11-26 00:00:00
# ShipDate                         2016-11-30 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  MS-17365
# CustomerName                     Maribeth Schnelling
# Segment                                     Consumer
# Country                                United States
# City                                     Los Angeles
# State                                     California
# PostalCode                                     90045
# Region                                          West
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                       3406.664
# Quantity                                           8
# Discount                                        0.15
# Profit                                      160.3136
# FirstName                                   Maribeth
# LastName                                  Schnelling
# CatalogPrice                                  500.98
# SupplierPrice                                 480.94
#
#                                                 9583  \
# PurchaseId                            CA-2017-116127
# PurchaseDate                     2017-06-25 00:00:00
# ShipDate                         2017-06-27 00:00:00
# ShipMode                                Second Class
# CustomerId                                  SB-20185
# CustomerName                             Sarah Brown
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10024
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        400.784
# Quantity                                           1
# Discount                                         0.2
# Profit                                       -5.0098
# FirstName                                      Sarah
# LastName                                       Brown
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
#
#                                                 9395  \
# PurchaseId                            CA-2014-125997
# PurchaseDate                     2014-09-20 00:00:00
# ShipDate                         2014-09-23 00:00:00
# ShipMode                                 First Class
# CustomerId                                  MW-18220
# CustomerName                            Mitch Webber
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10011
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        801.568
# Quantity                                           2
# Discount                                         0.2
# Profit                                      -10.0196
# FirstName                                      Mitch
# LastName                                      Webber
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
#
#                                                 5918  \
# PurchaseId                            US-2015-126977
# PurchaseDate                     2015-09-17 00:00:00
# ShipDate                         2015-09-23 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  PF-19120
# CustomerName                            Peter Fuller
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10035
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        2003.92
# Quantity                                           5
# Discount                                         0.2
# Profit                                       -25.049
# FirstName                                      Peter
# LastName                                      Fuller
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
#
#                                                            2808  \
# PurchaseId                                       CA-2015-148635
# PurchaseDate                                2015-07-25 00:00:00
# ShipDate                                    2015-07-27 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             MH-18025
# CustomerName                                 Michelle Huthwaite
# Segment                                                Consumer
# Country                                           United States
# City                                                    Seattle
# State                                                Washington
# PostalCode                                                98115
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                     704.9
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                   56.392
# FirstName                                              Michelle
# LastName                                              Huthwaite
# CatalogPrice                                             140.98
# SupplierPrice                                             129.7
#
#                                                 6535  \
# PurchaseId                            CA-2014-128209
# PurchaseDate                     2014-11-17 00:00:00
# ShipDate                         2014-11-22 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  GT-14710
# CustomerName                               Greg Tran
# Segment                                     Consumer
# Country                                United States
# City                                         Buffalo
# State                                       New York
# PostalCode                                     14215
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        4007.84
# Quantity                                          10
# Discount                                         0.2
# Profit                                       -50.098
# FirstName                                       Greg
# LastName                                        Tran
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
#
#                                                            8712  \
# PurchaseId                                       US-2015-145422
# PurchaseDate                                2015-12-03 00:00:00
# ShipDate                                    2015-12-07 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PW-19240
# CustomerName                                       Pierre Wener
# Segment                                                Consumer
# Country                                           United States
# City                                              San Francisco
# State                                                California
# PostalCode                                                94110
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   359.499
# Quantity                                                      3
# Discount                                                   0.15
# Profit                                                 -29.6058
# FirstName                                                Pierre
# LastName                                                  Wener
# CatalogPrice                                             140.98
# SupplierPrice                                            150.85
#
#                                                 2115  \
# PurchaseId                            CA-2015-164882
# PurchaseDate                     2015-10-31 00:00:00
# ShipDate                         2015-10-31 00:00:00
# ShipMode                                    Same Day
# CustomerId                                  SG-20080
# CustomerName                          Sandra Glassco
# Segment                                     Consumer
# Country                                United States
# City                                        Redlands
# State                                     California
# PostalCode                                     92374
# Region                                          West
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        425.833
# Quantity                                           1
# Discount                                        0.15
# Profit                                       20.0392
# FirstName                                     Sandra
# LastName                                     Glassco
# CatalogPrice                                  500.98
# SupplierPrice                                 480.94
#
#                                    8456                      7940  \
# PurchaseId               US-2017-118556            CA-2016-146325
# PurchaseDate        2017-05-28 00:00:00       2016-12-14 00:00:00
# ShipDate            2017-06-02 00:00:00       2016-12-17 00:00:00
# ShipMode                   Second Class               First Class
# CustomerId                     TH-21235                  DS-13180
# CustomerName              Tiffany House               David Smith
# Segment                       Corporate                 Corporate
# Country                   United States             United States
# City                            Chicago                 San Diego
# State                          Illinois                California
# PostalCode                        60653                     92037
# Region                          Central                      West
# ProductId               FUR-CH-10001146           FUR-CH-10001146
# Category                      Furniture                 Furniture
# SubCategory                      Chairs                    Chairs
# ProductName    Global Task Chair, Black  Global Task Chair, Black
# Sales                           106.869                    81.424
# Quantity                              3                         2
# Discount                            0.3                       0.2
# Profit                         -29.0073                   -9.1602
# FirstName                       Tiffany                     David
# LastName                          House                     Smith
# CatalogPrice                      50.89                     50.89
# SupplierPrice                     60.56                     55.47
#
#                                                       1267  \
# PurchaseId                                  US-2014-167738
# PurchaseDate                           2014-12-24 00:00:00
# ShipDate                               2014-12-29 00:00:00
# ShipMode                                    Standard Class
# CustomerId                                        JC-16105
# CustomerName                               Julie Creighton
# Segment                                          Corporate
# Country                                      United States
# City                                           Los Angeles
# State                                           California
# PostalCode                                           90045
# Region                                                West
# ProductId                                  FUR-CH-10001146
# Category                                         Furniture
# SubCategory                                         Chairs
# ProductName    Global Value Mid-Back Manager'S Chair, Gray
# Sales                                              292.272
# Quantity                                                 6
# Discount                                               0.2
# Profit                                              18.267
# FirstName                                            Julie
# LastName                                         Creighton
# CatalogPrice                                         60.89
# SupplierPrice                                        57.85
#
#                                                       4559  \
# PurchaseId                                  CA-2014-110219
# PurchaseDate                           2014-05-05 00:00:00
# ShipDate                               2014-05-08 00:00:00
# ShipMode                                       First Class
# CustomerId                                        EB-13870
# CustomerName                                   Emily Burns
# Segment                                           Consumer
# Country                                      United States
# City                                           San Antonio
# State                                                Texas
# PostalCode                                           78207
# Region                                             Central
# ProductId                                  FUR-CH-10001146
# Category                                         Furniture
# SubCategory                                         Chairs
# ProductName    Global Value Mid-Back Manager'S Chair, Gray
# Sales                                              127.869
# Quantity                                                 3
# Discount                                               0.3
# Profit                                             -9.1335
# FirstName                                            Emily
# LastName                                             Burns
# CatalogPrice                                         60.89
# SupplierPrice                                        63.93
#
#                                                       1067  \
# PurchaseId                                  CA-2016-157686
# PurchaseDate                           2016-10-01 00:00:00
# ShipDate                               2016-10-02 00:00:00
# ShipMode                                       First Class
# CustomerId                                        BD-11620
# CustomerName                               Brian Decherney
# Segment                                           Consumer
# Country                                      United States
# City                                         San Francisco
# State                                           California
# PostalCode                                           94122
# Region                                                West
# ProductId                                  FUR-CH-10001146
# Category                                         Furniture
# SubCategory                                         Chairs
# ProductName    Global Value Mid-Back Manager'S Chair, Gray
# Sales                                              194.848
# Quantity                                                 4
# Discount                                               0.2
# Profit                                              12.178
# FirstName                                            Brian
# LastName                                         Decherney
# CatalogPrice                                         60.89
# SupplierPrice                                        57.85
#
#                                    6742  \
# PurchaseId               US-2017-101784
# PurchaseDate        2017-07-06 00:00:00
# ShipDate            2017-07-11 00:00:00
# ShipMode                 Standard Class
# CustomerId                     PO-18850
# CustomerName            Patrick O'Brill
# Segment                        Consumer
# Country                   United States
# City                        Los Angeles
# State                        California
# PostalCode                        90008
# Region                             West
# ProductId               FUR-CH-10001146
# Category                      Furniture
# SubCategory                      Chairs
# ProductName    Global Task Chair, Black
# Sales                           122.136
# Quantity                              3
# Discount                            0.2
# Profit                         -13.7403
# FirstName                       Patrick
# LastName                        O'Brill
# CatalogPrice                      50.89
# SupplierPrice                     55.47
#
#                                                       8891  \
# PurchaseId                                  CA-2016-162159
# PurchaseDate                           2016-09-16 00:00:00
# ShipDate                               2016-09-18 00:00:00
# ShipMode                                       First Class
# CustomerId                                        CR-12625
# CustomerName                                   Corey Roper
# Segment                                        Home Office
# Country                                      United States
# City                                              Columbus
# State                                              Georgia
# PostalCode                                           31907
# Region                                               South
# ProductId                                  FUR-CH-10001146
# Category                                         Furniture
# SubCategory                                         Chairs
# ProductName    Global Value Mid-Back Manager'S Chair, Gray
# Sales                                               121.78
# Quantity                                                 2
# Discount                                               0.0
# Profit                                              30.445
# FirstName                                            Corey
# LastName                                             Roper
# CatalogPrice                                         60.89
# SupplierPrice                                        45.67
#
#                                                       1881  \
# PurchaseId                                  CA-2015-109512
# PurchaseDate                           2015-03-05 00:00:00
# ShipDate                               2015-03-05 00:00:00
# ShipMode                                          Same Day
# CustomerId                                        LF-17185
# CustomerName                                   Luke Foster
# Segment                                           Consumer
# Country                                      United States
# City                                         New York City
# State                                             New York
# PostalCode                                           10011
# Region                                                East
# ProductId                                  FUR-CH-10001146
# Category                                         Furniture
# SubCategory                                         Chairs
# ProductName    Global Value Mid-Back Manager'S Chair, Gray
# Sales                                              383.607
# Quantity                                                 7
# Discount                                               0.1
# Profit                                             63.9345
# FirstName                                             Luke
# LastName                                            Foster
# CatalogPrice                                         60.89
# SupplierPrice                                        51.76
#
#                                                       2003  \
# PurchaseId                                  CA-2017-163510
# PurchaseDate                           2017-12-25 00:00:00
# ShipDate                               2017-12-28 00:00:00
# ShipMode                                      Second Class
# CustomerId                                        JW-15955
# CustomerName                                Joni Wasserman
# Segment                                           Consumer
# Country                                      United States
# City                                            Louisville
# State                                             Kentucky
# PostalCode                                           40214
# Region                                               South
# ProductId                                  FUR-CH-10001146
# Category                                         Furniture
# SubCategory                                         Chairs
# ProductName    Global Value Mid-Back Manager'S Chair, Gray
# Sales                                               304.45
# Quantity                                                 5
# Discount                                               0.0
# Profit                                             76.1125
# FirstName                                             Joni
# LastName                                         Wasserman
# CatalogPrice                                         60.89
# SupplierPrice                                        45.67
#
#                                                       9254
# PurchaseId                                  CA-2014-168368
# PurchaseDate                           2014-02-11 00:00:00
# ShipDate                               2014-02-15 00:00:00
# ShipMode                                      Second Class
# CustomerId                                        GA-14725
# CustomerName                                 Guy Armstrong
# Segment                                           Consumer
# Country                                      United States
# City                                              Columbia
# State                                             Missouri
# PostalCode                                           65203
# Region                                             Central
# ProductId                                  FUR-CH-10001146
# Category                                         Furniture
# SubCategory                                         Chairs
# ProductName    Global Value Mid-Back Manager'S Chair, Gray
# Sales                                                60.89
# Quantity                                                 1
# Discount                                               0.0
# Profit                                             15.2225
# FirstName                                              Guy
# LastName                                         Armstrong
# CatalogPrice                                         60.89
# SupplierPrice                                        45.67

# %%
non_standard_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 337 entries, 5079 to 8970
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PurchaseId     337 non-null    object
#  1   PurchaseDate   337 non-null    datetime64[ns]
#  2   ShipDate       337 non-null    datetime64[ns]
#  3   ShipMode       337 non-null    object
#  4   CustomerId     337 non-null    object
#  5   CustomerName   337 non-null    object
#  6   Segment        337 non-null    object
#  7   Country        337 non-null    object
#  8   City           337 non-null    object
#  9   State          337 non-null    object
#  10  PostalCode     337 non-null    object
#  11  Region         337 non-null    object
#  12  ProductId      337 non-null    object
#  13  Category       337 non-null    object
#  14  SubCategory    337 non-null    object
#  15  ProductName    337 non-null    object
#  16  Sales          337 non-null    float64
#  17  Quantity       337 non-null    int32
#  18  Discount       337 non-null    float64
#  19  Profit         337 non-null    float64
#  20  FirstName      337 non-null    object
#  21  LastName       337 non-null    object
#  22  CatalogPrice   337 non-null    float64
#  23  SupplierPrice  337 non-null    float64
# dtypes: datetime64[ns](2), float64(5), int32(1), object(16)
# memory usage: 64.5+ KB

# %%
non_standard_products.nunique()
# Out:
# PurchaseId       324
# PurchaseDate     281
# ShipDate         283
# ShipMode           4
# CustomerId       273
# CustomerName     273
# Segment            3
# Country            1
# City             136
# State             39
# PostalCode       176
# Region             4
# ProductId         32
# Category           3
# SubCategory       11
# ProductName       64
# Sales            265
# Quantity          13
# Discount           9
# Profit           273
# FirstName        175
# LastName         236
# CatalogPrice      62
# SupplierPrice    143
# dtype: int64

# %% [markdown]
# ## 32 ProductId values has different CatalogPrices which effects 337 entries in total
# ## We will create new ProductId values if a ProductId has different CatalogPrice.

# %%
# find the biggest value in productids columns last 6 digits 

def get_last_6_digits(product_id):
    return int(product_id[-6:])

# Extract the last 6 digits for each ProductId

df['Last6Digits'] = df['ProductId'].apply(get_last_6_digits)

df['Last6Digits'].max()
# Out:
# 4999

# %% [markdown]
# #### 4999 is the max value for the last digits of ProductId values, we will start from 5000 to create new ones so there will not be duplicates as old values are smaller than 5000.
# #### Last 4 digits will start from 5000 and increase 1 by 1.

# %%
# Function to generate new ProductId by incrementing last 4 digits

def generate_new_product_id(base_product_id, increment):
    prefix = base_product_id[:-4]
    new_suffix = f'{increment:04d}'
    return prefix + new_suffix

# Create a unique identifier for each combination of ProductId and CatalogPrice

df['UniqueID'] = df.groupby(['ProductId', 'CatalogPrice']).ngroup()

# Initialize the new ProductId column with original values

df['NewProductId'] = df['ProductId']

# Start incrementing from 5000

start_increment = 5000

# Update ProductId values with incremented suffix

df['NewProductId'] = df.apply(lambda row: generate_new_product_id(row['ProductId'], start_increment + row['UniqueID']), axis=1)

# Drop the unnecessary columns

df.drop(columns=['UniqueID'], inplace=True)

# %%
df_id_name = df[df['ProductId'] == 'FUR-BO-10002213']

df_id_name = df_id_name.sort_values(by='SupplierPrice')

df_id_name.head(20).T
# Out:
#                                                            2808  \
# PurchaseId                                       CA-2015-148635
# PurchaseDate                                2015-07-25 00:00:00
# ShipDate                                    2015-07-27 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             MH-18025
# CustomerName                                 Michelle Huthwaite
# Segment                                                Consumer
# Country                                           United States
# City                                                    Seattle
# State                                                Washington
# PostalCode                                                98115
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                     704.9
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                   56.392
# FirstName                                              Michelle
# LastName                                              Huthwaite
# CatalogPrice                                             140.98
# SupplierPrice                                             129.7
# Last6Digits                                                2213
# NewProductId                                    FUR-BO-10005018
#
#                                                            5079  \
# PurchaseId                                       US-2017-133312
# PurchaseDate                                2017-11-25 00:00:00
# ShipDate                                    2017-11-29 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             BD-11500
# CustomerName                                    Bradley Drucker
# Segment                                                Consumer
# Country                                           United States
# City                                              San Francisco
# State                                                California
# PostalCode                                                94122
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   359.499
# Quantity                                                      3
# Discount                                                   0.15
# Profit                                                 -29.6058
# FirstName                                               Bradley
# LastName                                                Drucker
# CatalogPrice                                             140.98
# SupplierPrice                                            150.85
# Last6Digits                                                2213
# NewProductId                                    FUR-BO-10005018
#
#                                                            8712  \
# PurchaseId                                       US-2015-145422
# PurchaseDate                                2015-12-03 00:00:00
# ShipDate                                    2015-12-07 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             PW-19240
# CustomerName                                       Pierre Wener
# Segment                                                Consumer
# Country                                           United States
# City                                              San Francisco
# State                                                California
# PostalCode                                                94110
# Region                                                     West
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   359.499
# Quantity                                                      3
# Discount                                                   0.15
# Profit                                                 -29.6058
# FirstName                                                Pierre
# LastName                                                  Wener
# CatalogPrice                                             140.98
# SupplierPrice                                            150.85
# Last6Digits                                                2213
# NewProductId                                    FUR-BO-10005018
#
#                                                            2471  \
# PurchaseId                                       US-2016-135923
# PurchaseDate                                2016-01-22 00:00:00
# ShipDate                                    2016-01-28 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             CM-11935
# CustomerName                                      Carlos Meador
# Segment                                                Consumer
# Country                                           United States
# City                                               Fayetteville
# State                                            North Carolina
# PostalCode                                                28314
# Region                                                    South
# ProductId                                       FUR-BO-10002213
# Category                                              Furniture
# SubCategory                                           Bookcases
# ProductName    Sauder Forest Hills Library, Woodland Oak Finish
# Sales                                                   451.136
# Quantity                                                      4
# Discount                                                    0.2
# Profit                                                 -67.6704
# FirstName                                                Carlos
# LastName                                                 Meador
# CatalogPrice                                             140.98
# SupplierPrice                                             157.9
# Last6Digits                                                2213
# NewProductId                                    FUR-BO-10005018
#
#                                                 2115  \
# PurchaseId                            CA-2015-164882
# PurchaseDate                     2015-10-31 00:00:00
# ShipDate                         2015-10-31 00:00:00
# ShipMode                                    Same Day
# CustomerId                                  SG-20080
# CustomerName                          Sandra Glassco
# Segment                                     Consumer
# Country                                United States
# City                                        Redlands
# State                                     California
# PostalCode                                     92374
# Region                                          West
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        425.833
# Quantity                                           1
# Discount                                        0.15
# Profit                                       20.0392
# FirstName                                     Sandra
# LastName                                     Glassco
# CatalogPrice                                  500.98
# SupplierPrice                                 480.94
# Last6Digits                                     2213
# NewProductId                         FUR-BO-10005019
#
#                                                 9649  \
# PurchaseId                            CA-2016-107104
# PurchaseDate                     2016-11-26 00:00:00
# ShipDate                         2016-11-30 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  MS-17365
# CustomerName                     Maribeth Schnelling
# Segment                                     Consumer
# Country                                United States
# City                                     Los Angeles
# State                                     California
# PostalCode                                     90045
# Region                                          West
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                       3406.664
# Quantity                                           8
# Discount                                        0.15
# Profit                                      160.3136
# FirstName                                   Maribeth
# LastName                                  Schnelling
# CatalogPrice                                  500.98
# SupplierPrice                                 480.94
# Last6Digits                                     2213
# NewProductId                         FUR-BO-10005019
#
#                                                 5918  \
# PurchaseId                            US-2015-126977
# PurchaseDate                     2015-09-17 00:00:00
# ShipDate                         2015-09-23 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  PF-19120
# CustomerName                            Peter Fuller
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10035
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        2003.92
# Quantity                                           5
# Discount                                         0.2
# Profit                                       -25.049
# FirstName                                      Peter
# LastName                                      Fuller
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
# Last6Digits                                     2213
# NewProductId                         FUR-BO-10005019
#
#                                                 6535  \
# PurchaseId                            CA-2014-128209
# PurchaseDate                     2014-11-17 00:00:00
# ShipDate                         2014-11-22 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  GT-14710
# CustomerName                               Greg Tran
# Segment                                     Consumer
# Country                                United States
# City                                         Buffalo
# State                                       New York
# PostalCode                                     14215
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        4007.84
# Quantity                                          10
# Discount                                         0.2
# Profit                                       -50.098
# FirstName                                       Greg
# LastName                                        Tran
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
# Last6Digits                                     2213
# NewProductId                         FUR-BO-10005019
#
#                                                 9395  \
# PurchaseId                            CA-2014-125997
# PurchaseDate                     2014-09-20 00:00:00
# ShipDate                         2014-09-23 00:00:00
# ShipMode                                 First Class
# CustomerId                                  MW-18220
# CustomerName                            Mitch Webber
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10011
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        801.568
# Quantity                                           2
# Discount                                         0.2
# Profit                                      -10.0196
# FirstName                                      Mitch
# LastName                                      Webber
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
# Last6Digits                                     2213
# NewProductId                         FUR-BO-10005019
#
#                                                 9583
# PurchaseId                            CA-2017-116127
# PurchaseDate                     2017-06-25 00:00:00
# ShipDate                         2017-06-27 00:00:00
# ShipMode                                Second Class
# CustomerId                                  SB-20185
# CustomerName                             Sarah Brown
# Segment                                     Consumer
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10024
# Region                                          East
# ProductId                            FUR-BO-10002213
# Category                                   Furniture
# SubCategory                                Bookcases
# ProductName    Dmi Eclipse Executive Suite Bookcases
# Sales                                        400.784
# Quantity                                           1
# Discount                                         0.2
# Profit                                       -5.0098
# FirstName                                      Sarah
# LastName                                       Brown
# CatalogPrice                                  500.98
# SupplierPrice                                 505.99
# Last6Digits                                     2213
# NewProductId                         FUR-BO-10005019

# %%
df.nunique()
# Out:
# PurchaseId       5009
# PurchaseDate     1237
# ShipDate         1334
# ShipMode            4
# CustomerId        793
# CustomerName      793
# Segment             3
# Country             1
# City              531
# State              49
# PostalCode        631
# Region              4
# ProductId        1862
# Category            3
# SubCategory        17
# ProductName      1850
# Sales            5825
# Quantity           14
# Discount           12
# Profit           7287
# FirstName         337
# LastName          588
# CatalogPrice     1095
# SupplierPrice    2851
# Last6Digits      1595
# NewProductId     1894
# dtype: int64

# %%
# Check the the max value in New ProductId column
# Extract the last 6 digits for each ProductId
df['New_Last6Digits'] = df['NewProductId'].apply(get_last_6_digits)

df['New_Last6Digits'].max()
# Out:
# 6893

# %%
# Confirm changes by checking NewProductId and CatalogPrice Pairs

# Group by ProductId and check unique CatalogPrice values for each group

catalog_price_counts = df.groupby('NewProductId')['CatalogPrice'].nunique().reset_index()

# Filter to find ProductIds with more than 1 unique CatalogPrice

non_standard_product_ids = catalog_price_counts[catalog_price_counts['CatalogPrice'] > 1]

# Merge back with the original DataFrame to see the details of these ProductId-CatalogPrice pairs

non_standard_products = df[df['NewProductId'].isin(non_standard_product_ids['NewProductId'])]

non_standard_products = non_standard_products.sort_values(by='NewProductId')

non_standard_products.head(20)
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, CatalogPrice, SupplierPrice, Last6Digits, NewProductId, New_Last6Digits]
# Index: []

# %%
df.drop(columns=['New_Last6Digits', 'Last6Digits'], inplace=True)

# %% [markdown]
# #### 32 New ProductId values have been created which shared same ID but had different CatalogPrices and ProductNames.
# #### We have 1894 Unique ProductId, it was 32 less before
# #### Some entries have different ProductId and Pricing but have the same name but we dont have chance to check it or correct it.
# #### So we will not edit Productnames additionally.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PurchaseId     9994 non-null   object
#  1   PurchaseDate   9994 non-null   datetime64[ns]
#  2   ShipDate       9994 non-null   datetime64[ns]
#  3   ShipMode       9994 non-null   object
#  4   CustomerId     9994 non-null   object
#  5   CustomerName   9994 non-null   object
#  6   Segment        9994 non-null   object
#  7   Country        9994 non-null   object
#  8   City           9994 non-null   object
#  9   State          9994 non-null   object
#  10  PostalCode     9994 non-null   object
#  11  Region         9994 non-null   object
#  12  ProductId      9994 non-null   object
#  13  Category       9994 non-null   object
#  14  SubCategory    9994 non-null   object
#  15  ProductName    9994 non-null   object
#  16  Sales          9994 non-null   float64
#  17  Quantity       9994 non-null   int32
#  18  Discount       9994 non-null   float64
#  19  Profit         9994 non-null   float64
#  20  FirstName      9994 non-null   object
#  21  LastName       9994 non-null   object
#  22  CatalogPrice   9994 non-null   float64
#  23  SupplierPrice  9994 non-null   float64
#  24  NewProductId   9994 non-null   object
# dtypes: datetime64[ns](2), float64(5), int32(1), object(17)
# memory usage: 1.9+ MB

# %%
df.isna().sum()
# Out:
# PurchaseId       0
# PurchaseDate     0
# ShipDate         0
# ShipMode         0
# CustomerId       0
# CustomerName     0
# Segment          0
# Country          0
# City             0
# State            0
# PostalCode       0
# Region           0
# ProductId        0
# Category         0
# SubCategory      0
# ProductName      0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# FirstName        0
# LastName         0
# CatalogPrice     0
# SupplierPrice    0
# NewProductId     0
# dtype: int64

# %% [markdown]
# ## 20: Sales, Quantity, Discount, Profit Columns  <a id="20"></a>

# %%
df['Sales'] = df['Sales'].round(2)

df['Profit'] = df['Profit'].round(2)

# %%
df.describe()
# Out:
#                         PurchaseDate                       ShipDate  \
# count                           9994                           9994
# mean   2016-04-30 00:07:12.259355648  2016-05-03 23:06:58.571142912
# min              2014-01-03 00:00:00            2014-01-07 00:00:00
# 25%              2015-05-23 00:00:00            2015-05-27 00:00:00
# 50%              2016-06-26 00:00:00            2016-06-29 00:00:00
# 75%              2017-05-14 00:00:00            2017-05-18 00:00:00
# max              2017-12-30 00:00:00            2018-01-05 00:00:00
# std                              NaN                            NaN
#
#               Sales     Quantity     Discount       Profit  CatalogPrice  \
# count   9994.000000  9994.000000  9994.000000  9994.000000   9994.000000
# mean     229.857980     3.789574     0.156203    28.656848     75.571127
# min        0.440000     1.000000     0.000000 -6599.980000      0.990000
# 25%       17.280000     2.000000     0.000000     1.730000      6.480000
# 50%       54.490000     3.000000     0.200000     8.665000     19.980000
# 75%      209.940000     5.000000     0.200000    29.360000     76.980000
# max    22638.480000    14.000000     0.800000  8399.980000   7546.160000
# std      623.245104     2.225110     0.206452   234.260149    188.961461
#
#        SupplierPrice
# count    9994.000000
# mean       67.771666
# min         0.540000
# 25%         4.670000
# 50%        15.670000
# 75%        67.290000
# max      7848.010000
# std       182.428200

# %%
# view the 20 highest values in the Payment column

df.nlargest(20, 'Sales').T
# Out:
#                                                             2697  \
# PurchaseId                                        CA-2014-145317
# PurchaseDate                                 2014-03-18 00:00:00
# ShipDate                                     2014-03-23 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              SM-20320
# CustomerName                                         Sean Miller
# Segment                                              Home Office
# Country                                            United States
# City                                                Jacksonville
# State                                                    Florida
# PostalCode                                                 32216
# Region                                                     South
# ProductId                                        TEC-MA-10002412
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Cisco Telepresence System Ex90 Videoconferenci...
# Sales                                                   22638.48
# Quantity                                                       6
# Discount                                                     0.5
# Profit                                                  -1811.08
# FirstName                                                   Sean
# LastName                                                  Miller
# CatalogPrice                                             7546.16
# SupplierPrice                                            7848.01
# NewProductId                                     TEC-MA-10006669
#
#                                                 6826  \
# PurchaseId                            CA-2016-118689
# PurchaseDate                     2016-10-02 00:00:00
# ShipDate                         2016-10-09 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  TC-20980
# CustomerName                            Tamara Chand
# Segment                                    Corporate
# Country                                United States
# City                                       Lafayette
# State                                        Indiana
# PostalCode                                     47905
# Region                                       Central
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       17499.95
# Quantity                                           5
# Discount                                         0.0
# Profit                                       8399.98
# FirstName                                     Tamara
# LastName                                       Chand
# CatalogPrice                                 3499.99
# SupplierPrice                                1819.99
# NewProductId                         TEC-CO-10006640
#
#                                                 8153  \
# PurchaseId                            CA-2017-140151
# PurchaseDate                     2017-03-23 00:00:00
# ShipDate                         2017-03-25 00:00:00
# ShipMode                                 First Class
# CustomerId                                  RB-19360
# CustomerName                            Raymond Buch
# Segment                                     Consumer
# Country                                United States
# City                                         Seattle
# State                                     Washington
# PostalCode                                     98115
# Region                                          West
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       13999.96
# Quantity                                           4
# Discount                                         0.0
# Profit                                       6719.98
# FirstName                                    Raymond
# LastName                                        Buch
# CatalogPrice                                 3499.99
# SupplierPrice                                1819.99
# NewProductId                         TEC-CO-10006640
#
#                                                 2623  \
# PurchaseId                            CA-2017-127180
# PurchaseDate                     2017-10-22 00:00:00
# ShipDate                         2017-10-24 00:00:00
# ShipMode                                 First Class
# CustomerId                                  TA-21385
# CustomerName                            Tom Ashbrook
# Segment                                  Home Office
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10024
# Region                                          East
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       11199.97
# Quantity                                           4
# Discount                                         0.2
# Profit                                       3919.99
# FirstName                                        Tom
# LastName                                    Ashbrook
# CatalogPrice                                 3499.99
# SupplierPrice                                2519.99
# NewProductId                         TEC-CO-10006640
#
#                                                 4190  \
# PurchaseId                            CA-2017-166709
# PurchaseDate                     2017-11-17 00:00:00
# ShipDate                         2017-11-22 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  HL-15040
# CustomerName                            Hunter Lopez
# Segment                                     Consumer
# Country                                United States
# City                                          Newark
# State                                       Delaware
# PostalCode                                     19711
# Region                                          East
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       10499.97
# Quantity                                           3
# Discount                                         0.0
# Profit                                       5039.99
# FirstName                                     Hunter
# LastName                                       Lopez
# CatalogPrice                                 3499.99
# SupplierPrice                                1819.99
# NewProductId                         TEC-CO-10006640
#
#                                                            9039  \
# PurchaseId                                       CA-2016-117121
# PurchaseDate                                2016-12-17 00:00:00
# ShipDate                                    2016-12-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             AB-10105
# CustomerName                                      Adrian Barton
# Segment                                                Consumer
# Country                                           United States
# City                                                    Detroit
# State                                                  Michigan
# PostalCode                                                48205
# Region                                                  Central
# ProductId                                       OFF-BI-10000545
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName    Gbc Ibimaster 500 Manual Proclick Binding System
# Sales                                                   9892.74
# Quantity                                                     13
# Discount                                                    0.0
# Profit                                                  4946.37
# FirstName                                                Adrian
# LastName                                                 Barton
# CatalogPrice                                             760.98
# SupplierPrice                                            380.49
# NewProductId                                    OFF-BI-10005667
#
#                                                4098  \
# PurchaseId                           CA-2014-116904
# PurchaseDate                    2014-09-23 00:00:00
# ShipDate                        2014-09-28 00:00:00
# ShipMode                             Standard Class
# CustomerId                                 SC-20095
# CustomerName                           Sanjit Chand
# Segment                                    Consumer
# Country                               United States
# City                                    Minneapolis
# State                                     Minnesota
# PostalCode                                    55407
# Region                                      Central
# ProductId                           OFF-BI-10001120
# Category                            Office Supplies
# SubCategory                                 Binders
# ProductName    Ibico Epk-21 Electric Binding System
# Sales                                       9449.95
# Quantity                                          5
# Discount                                        0.0
# Profit                                      4630.48
# FirstName                                    Sanjit
# LastName                                      Chand
# CatalogPrice                                1889.99
# SupplierPrice                                963.89
# NewProductId                        OFF-BI-10005692
#
#                                                            4277  \
# PurchaseId                                       US-2016-107440
# PurchaseDate                                2016-04-16 00:00:00
# ShipDate                                    2016-04-20 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             BS-11365
# CustomerName                                       Bill Shonely
# Segment                                               Corporate
# Country                                           United States
# City                                                   Lakewood
# State                                                New Jersey
# PostalCode                                                08701
# Region                                                     East
# ProductId                                       TEC-MA-10001047
# Category                                             Technology
# SubCategory                                            Machines
# ProductName    3D Systems Cube Printer, 2Nd Generation, Magenta
# Sales                                                   9099.93
# Quantity                                                      7
# Discount                                                    0.0
# Profit                                                  2365.98
# FirstName                                                  Bill
# LastName                                                Shonely
# CatalogPrice                                            1299.99
# SupplierPrice                                            961.99
# NewProductId                                    TEC-MA-10006656
#
#                                                             8488  \
# PurchaseId                                        CA-2016-158841
# PurchaseDate                                 2016-02-02 00:00:00
# ShipDate                                     2016-02-04 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              SE-20110
# CustomerName                                        Sanjit Engle
# Segment                                                 Consumer
# Country                                            United States
# City                                                   Arlington
# State                                                   Virginia
# PostalCode                                                 22204
# Region                                                     South
# ProductId                                        TEC-MA-10001127
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Hp Designjet T520 Inkjet Large Format Printer ...
# Sales                                                    8749.95
# Quantity                                                       5
# Discount                                                     0.0
# Profit                                                   2799.98
# FirstName                                                 Sanjit
# LastName                                                   Engle
# CatalogPrice                                             1749.99
# SupplierPrice                                            1189.99
# NewProductId                                     TEC-MA-10006657
#
#                                                 6425  \
# PurchaseId                            CA-2016-143714
# PurchaseDate                     2016-05-23 00:00:00
# ShipDate                         2016-05-27 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  CC-12370
# CustomerName                      Christopher Conant
# Segment                                     Consumer
# Country                                United States
# City                                    Philadelphia
# State                                   Pennsylvania
# PostalCode                                     19120
# Region                                          East
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                        8399.98
# Quantity                                           4
# Discount                                         0.4
# Profit                                        1120.0
# FirstName                                Christopher
# LastName                                      Conant
# CatalogPrice                                 3499.99
# SupplierPrice                                3219.99
# NewProductId                         TEC-CO-10006640
#
#                                                       2505  \
# PurchaseId                                  CA-2014-143917
# PurchaseDate                           2014-07-25 00:00:00
# ShipDate                               2014-07-27 00:00:00
# ShipMode                                      Second Class
# CustomerId                                        KL-16645
# CustomerName                                  Ken Lonsdale
# Segment                                           Consumer
# Country                                      United States
# City                                         San Francisco
# State                                           California
# PostalCode                                           94122
# Region                                                West
# ProductId                                  OFF-SU-10000151
# Category                                   Office Supplies
# SubCategory                                       Supplies
# ProductName    High Speed Automatic Electric Letter Opener
# Sales                                              8187.65
# Quantity                                                 5
# Discount                                               0.0
# Profit                                              327.51
# FirstName                                              Ken
# LastName                                          Lonsdale
# CatalogPrice                                       1637.53
# SupplierPrice                                      1572.03
# NewProductId                               OFF-SU-10006443
#
#                                                     165   \
# PurchaseId                                CA-2014-139892
# PurchaseDate                         2014-09-08 00:00:00
# ShipDate                             2014-09-12 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      BM-11140
# CustomerName                                Becky Martin
# Segment                                         Consumer
# Country                                    United States
# City                                         San Antonio
# State                                              Texas
# PostalCode                                         78207
# Region                                           Central
# ProductId                                TEC-MA-10000822
# Category                                      Technology
# SubCategory                                     Machines
# ProductName    Lexmark Mx611Dhe Monochrome Laser Printer
# Sales                                            8159.95
# Quantity                                               8
# Discount                                             0.4
# Profit                                          -1359.99
# FirstName                                          Becky
# LastName                                          Martin
# CatalogPrice                                     1699.99
# SupplierPrice                                    1869.99
# NewProductId                             TEC-MA-10006650
#
#                                                     683   \
# PurchaseId                                US-2017-168116
# PurchaseDate                         2017-11-04 00:00:00
# ShipDate                             2017-11-04 00:00:00
# ShipMode                                        Same Day
# CustomerId                                      GT-14635
# CustomerName                              Grant Thornton
# Segment                                        Corporate
# Country                                    United States
# City                                          Burlington
# State                                     North Carolina
# PostalCode                                         27217
# Region                                             South
# ProductId                                TEC-MA-10004125
# Category                                      Technology
# SubCategory                                     Machines
# ProductName    Cubify Cubex 3D Printer Triple Head Print
# Sales                                            7999.98
# Quantity                                               4
# Discount                                             0.5
# Profit                                          -3839.99
# FirstName                                          Grant
# LastName                                        Thornton
# CatalogPrice                                     3999.99
# SupplierPrice                                    4959.99
# NewProductId                             TEC-MA-10006696
#
#                                                             6626  \
# PurchaseId                                        CA-2014-145541
# PurchaseDate                                 2014-12-14 00:00:00
# ShipDate                                     2014-12-21 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              TB-21400
# CustomerName                                    Tom Boeckenhauer
# Segment                                                 Consumer
# Country                                            United States
# City                                               New York City
# State                                                   New York
# PostalCode                                                 10024
# Region                                                      East
# ProductId                                        TEC-MA-10001127
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Hp Designjet T520 Inkjet Large Format Printer ...
# Sales                                                    6999.96
# Quantity                                                       4
# Discount                                                     0.0
# Profit                                                   2239.99
# FirstName                                                    Tom
# LastName                                            Boeckenhauer
# CatalogPrice                                             1749.99
# SupplierPrice                                            1189.99
# NewProductId                                     TEC-MA-10006657
#
#                                                             509   \
# PurchaseId                                        CA-2015-145352
# PurchaseDate                                 2015-03-16 00:00:00
# ShipDate                                     2015-03-22 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              CM-12385
# CustomerName                                Christopher Martinez
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Atlanta
# State                                                    Georgia
# PostalCode                                                 30318
# Region                                                     South
# ProductId                                        OFF-BI-10003527
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Fellowes Pb500 Electric Punch Plastic Comb Bin...
# Sales                                                    6354.95
# Quantity                                                       5
# Discount                                                     0.0
# Profit                                                   3177.48
# FirstName                                            Christopher
# LastName                                                Martinez
# CatalogPrice                                             1270.99
# SupplierPrice                                              635.5
# NewProductId                                     OFF-BI-10005787
#
#                                                     6520  \
# PurchaseId                                CA-2017-138289
# PurchaseDate                         2017-01-16 00:00:00
# ShipDate                             2017-01-18 00:00:00
# ShipMode                                    Second Class
# CustomerId                                      AR-10540
# CustomerName                                 Andy Reiter
# Segment                                         Consumer
# Country                                    United States
# City                                             Jackson
# State                                           Michigan
# PostalCode                                         49201
# Region                                           Central
# ProductId                                OFF-BI-10004995
# Category                                 Office Supplies
# SubCategory                                      Binders
# ProductName    Gbc Docubind P400 Electric Binding System
# Sales                                            5443.96
# Quantity                                               4
# Discount                                             0.0
# Profit                                           2504.22
# FirstName                                           Andy
# LastName                                          Reiter
# CatalogPrice                                     1360.99
# SupplierPrice                                     734.93
# NewProductId                             OFF-BI-10005858
#
#                                                7666  \
# PurchaseId                           US-2016-140158
# PurchaseDate                    2016-10-04 00:00:00
# ShipDate                        2016-10-08 00:00:00
# ShipMode                             Standard Class
# CustomerId                                 DR-12940
# CustomerName                          Daniel Raglin
# Segment                                 Home Office
# Country                               United States
# City                                     Providence
# State                                  Rhode Island
# PostalCode                                    02908
# Region                                         East
# ProductId                           TEC-CO-10001449
# Category                                 Technology
# SubCategory                                 Copiers
# ProductName    Hewlett Packard Laserjet 3310 Copier
# Sales                                       5399.91
# Quantity                                          9
# Discount                                        0.0
# Profit                                      2591.96
# FirstName                                    Daniel
# LastName                                     Raglin
# CatalogPrice                                 599.99
# SupplierPrice                                311.99
# NewProductId                        TEC-CO-10006630
#
#                                                            6340  \
# PurchaseId                                       CA-2017-143112
# PurchaseDate                                2017-10-05 00:00:00
# ShipDate                                    2017-10-09 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             TS-21370
# CustomerName                                       Todd Sumrall
# Segment                                               Corporate
# Country                                           United States
# City                                              New York City
# State                                                  New York
# PostalCode                                                10035
# Region                                                     East
# ProductId                                       TEC-MA-10001047
# Category                                             Technology
# SubCategory                                            Machines
# ProductName    3D Systems Cube Printer, 2Nd Generation, Magenta
# Sales                                                   5199.96
# Quantity                                                      4
# Discount                                                    0.0
# Profit                                                  1351.99
# FirstName                                                  Todd
# LastName                                                Sumrall
# CatalogPrice                                            1299.99
# SupplierPrice                                            961.99
# NewProductId                                    TEC-MA-10006656
#
#                                                             8858  \
# PurchaseId                                        CA-2017-135909
# PurchaseDate                                 2017-10-13 00:00:00
# ShipDate                                     2017-10-20 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              JW-15220
# CustomerName                                           Jane Waco
# Segment                                                Corporate
# Country                                            United States
# City                                                  Sacramento
# State                                                 California
# PostalCode                                                 95823
# Region                                                      West
# ProductId                                        OFF-BI-10003527
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Fellowes Pb500 Electric Punch Plastic Comb Bin...
# Sales                                                    5083.96
# Quantity                                                       5
# Discount                                                     0.2
# Profit                                                   1906.48
# FirstName                                                   Jane
# LastName                                                    Waco
# CatalogPrice                                             1270.99
# SupplierPrice                                             889.69
# NewProductId                                     OFF-BI-10005787
#
#                                                       5884
# PurchaseId                                  CA-2016-136301
# PurchaseDate                           2016-03-13 00:00:00
# ShipDate                               2016-03-15 00:00:00
# ShipMode                                      Second Class
# CustomerId                                        EH-13765
# CustomerName                                  Edward Hooks
# Segment                                          Corporate
# Country                                      United States
# City                                         San Francisco
# State                                           California
# PostalCode                                           94109
# Region                                                West
# ProductId                                  OFF-SU-10000151
# Category                                   Office Supplies
# SubCategory                                       Supplies
# ProductName    High Speed Automatic Electric Letter Opener
# Sales                                              4912.59
# Quantity                                                 3
# Discount                                               0.0
# Profit                                               196.5
# FirstName                                           Edward
# LastName                                             Hooks
# CatalogPrice                                       1637.53
# SupplierPrice                                      1572.03
# NewProductId                               OFF-SU-10006443

# %%
# view the 20 lowest values in the Payment column

df.nsmallest(20, 'Sales').T
# Out:
#                                                             4101  \
# PurchaseId                                        US-2017-102288
# PurchaseDate                                 2017-06-19 00:00:00
# ShipDate                                     2017-06-23 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              ZC-21910
# CustomerName                                    Zuschuss Carroll
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Houston
# State                                                      Texas
# PostalCode                                                 77095
# Region                                                   Central
# ProductId                                        OFF-AP-10002906
# Category                                         Office Supplies
# SubCategory                                           Appliances
# ProductName    Hoover Replacement Belt For Commercial Guardsm...
# Sales                                                       0.44
# Quantity                                                       1
# Discount                                                     0.8
# Profit                                                     -1.11
# FirstName                                               Zuschuss
# LastName                                                 Carroll
# CatalogPrice                                                2.22
# SupplierPrice                                               3.33
# NewProductId                                     OFF-AP-10005447
#
#                                                    9292  \
# PurchaseId                               CA-2017-124114
# PurchaseDate                        2017-03-02 00:00:00
# ShipDate                            2017-03-02 00:00:00
# ShipMode                                       Same Day
# CustomerId                                     RS-19765
# CustomerName                             Roland Schwarz
# Segment                                       Corporate
# Country                                   United States
# City                                               Waco
# State                                             Texas
# PostalCode                                        76706
# Region                                          Central
# ProductId                               OFF-BI-10004022
# Category                                Office Supplies
# SubCategory                                     Binders
# ProductName    Acco Suede Grain Vinyl Round Ring Binder
# Sales                                              0.56
# Quantity                                              1
# Discount                                            0.8
# Profit                                            -0.95
# FirstName                                        Roland
# LastName                                        Schwarz
# CatalogPrice                                       2.78
# SupplierPrice                                      3.73
# NewProductId                            OFF-BI-10005813
#
#                                                             8658  \
# PurchaseId                                        CA-2016-168361
# PurchaseDate                                 2016-06-21 00:00:00
# ShipDate                                     2016-06-25 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              KB-16600
# CustomerName                                         Ken Brennan
# Segment                                                Corporate
# Country                                            United States
# City                                                     Chicago
# State                                                   Illinois
# PostalCode                                                 60623
# Region                                                   Central
# ProductId                                        OFF-BI-10003727
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Avery Durable Slant Ring Binders With Label Ho...
# Sales                                                       0.84
# Quantity                                                       1
# Discount                                                     0.8
# Profit                                                     -1.34
# FirstName                                                    Ken
# LastName                                                 Brennan
# CatalogPrice                                                4.18
# SupplierPrice                                               5.52
# NewProductId                                     OFF-BI-10005802
#
#                                         4711                 2106  \
# PurchaseId                    CA-2014-112403       US-2014-152723
# PurchaseDate             2014-03-31 00:00:00  2014-09-26 00:00:00
# ShipDate                 2014-03-31 00:00:00  2014-09-26 00:00:00
# ShipMode                            Same Day             Same Day
# CustomerId                          JO-15280             HG-14965
# CustomerName                   Jas O'Carroll        Henry Goldwyn
# Segment                             Consumer            Corporate
# Country                        United States        United States
# City                            Philadelphia             Mesquite
# State                           Pennsylvania                Texas
# PostalCode                             19120                75150
# Region                                  East              Central
# ProductId                    OFF-BI-10003529      OFF-BI-10003460
# Category                     Office Supplies      Office Supplies
# SubCategory                          Binders              Binders
# ProductName    Avery Round Ring Poly Binders    Acco 3-Hole Punch
# Sales                                   0.85                 0.88
# Quantity                                   1                    1
# Discount                                 0.7                  0.8
# Profit                                  -0.6                 -1.4
# FirstName                                Jas                Henry
# LastName                           O'Carroll              Goldwyn
# CatalogPrice                            2.84                 4.38
# SupplierPrice                           3.44                 5.78
# NewProductId                 OFF-BI-10005788      OFF-BI-10005785
#
#                                   7548  \
# PurchaseId              CA-2014-103492
# PurchaseDate       2014-10-10 00:00:00
# ShipDate           2014-10-15 00:00:00
# ShipMode                Standard Class
# CustomerId                    CM-12715
# CustomerName            Craig Molinari
# Segment                      Corporate
# Country                  United States
# City                        Huntsville
# State                            Texas
# PostalCode                       77340
# Region                         Central
# ProductId              OFF-BI-10004140
# Category               Office Supplies
# SubCategory                    Binders
# ProductName    Avery Non-Stick Binders
# Sales                              0.9
# Quantity                             1
# Discount                           0.8
# Profit                           -1.57
# FirstName                        Craig
# LastName                      Molinari
# CatalogPrice                      4.49
# SupplierPrice                     6.06
# NewProductId           OFF-BI-10005818
#
#                                                             8033  \
# PurchaseId                                        CA-2015-119690
# PurchaseDate                                 2015-06-25 00:00:00
# ShipDate                                     2015-06-28 00:00:00
# ShipMode                                             First Class
# CustomerId                                              MV-17485
# CustomerName                                       Mark Van Huff
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Houston
# State                                                      Texas
# PostalCode                                                 77041
# Region                                                   Central
# ProductId                                        OFF-BI-10000201
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Avery Triangle Shaped Sheet Lifters, Black, 2/...
# Sales                                                       0.98
# Quantity                                                       2
# Discount                                                     0.8
# Profit                                                     -1.48
# FirstName                                                   Mark
# LastName                                                Van Huff
# CatalogPrice                                                2.46
# SupplierPrice                                                3.2
# NewProductId                                     OFF-BI-10005655
#
#                                     2761  \
# PurchaseId                CA-2017-126536
# PurchaseDate         2017-10-12 00:00:00
# ShipDate             2017-10-14 00:00:00
# ShipMode                     First Class
# CustomerId                      NK-18490
# CustomerName                Neil Knudson
# Segment                      Home Office
# Country                    United States
# City                       San Francisco
# State                         California
# PostalCode                         94110
# Region                              West
# ProductId                TEC-AC-10003709
# Category                      Technology
# SubCategory                  Accessories
# ProductName    Maxell 4.7Gb Dvd-R 5/Pack
# Sales                               0.99
# Quantity                               1
# Discount                             0.0
# Profit                              0.44
# FirstName                           Neil
# LastName                         Knudson
# CatalogPrice                        0.99
# SupplierPrice                       0.55
# NewProductId             TEC-AC-10006593
#
#                                                        8024  \
# PurchaseId                                   CA-2014-129189
# PurchaseDate                            2014-07-21 00:00:00
# ShipDate                                2014-07-25 00:00:00
# ShipMode                                     Standard Class
# CustomerId                                         HM-14860
# CustomerName                                    Harry Marie
# Segment                                           Corporate
# Country                                       United States
# City                                                 Dallas
# State                                                 Texas
# PostalCode                                            75217
# Region                                              Central
# ProductId                                   OFF-BI-10000494
# Category                                    Office Supplies
# SubCategory                                         Binders
# ProductName    Acco Economy Flexible Poly Round Ring Binder
# Sales                                                  1.04
# Quantity                                                  1
# Discount                                                0.8
# Profit                                                -1.83
# FirstName                                             Harry
# LastName                                              Marie
# CatalogPrice                                           5.22
# SupplierPrice                                          7.05
# NewProductId                                OFF-BI-10005666
#
#                                                   976   \
# PurchaseId                              US-2017-100209
# PurchaseDate                       2017-07-09 00:00:00
# ShipDate                           2017-07-15 00:00:00
# ShipMode                                Standard Class
# CustomerId                                    TD-20995
# CustomerName                             Tamara Dahlen
# Segment                                       Consumer
# Country                                  United States
# City                                          Portland
# State                                           Oregon
# PostalCode                                       97206
# Region                                            West
# ProductId                              OFF-BI-10002012
# Category                               Office Supplies
# SubCategory                                    Binders
# ProductName    Wilson Jones Easy Flow Ii Sheet Lifters
# Sales                                             1.08
# Quantity                                             2
# Discount                                           0.7
# Profit                                           -0.79
# FirstName                                       Tamara
# LastName                                        Dahlen
# CatalogPrice                                       1.8
# SupplierPrice                                      2.2
# NewProductId                           OFF-BI-10005730
#
#                                                   1332  \
# PurchaseId                              CA-2014-122567
# PurchaseDate                       2014-02-16 00:00:00
# ShipDate                           2014-02-21 00:00:00
# ShipMode                                Standard Class
# CustomerId                                    MN-17935
# CustomerName                            Michael Nguyen
# Segment                                       Consumer
# Country                                  United States
# City                                            Dallas
# State                                            Texas
# PostalCode                                       75220
# Region                                         Central
# ProductId                              OFF-BI-10002012
# Category                               Office Supplies
# SubCategory                                    Binders
# ProductName    Wilson Jones Easy Flow Ii Sheet Lifters
# Sales                                             1.08
# Quantity                                             3
# Discount                                           0.8
# Profit                                           -1.73
# FirstName                                      Michael
# LastName                                        Nguyen
# CatalogPrice                                       1.8
# SupplierPrice                                     2.38
# NewProductId                           OFF-BI-10005730
#
#                                                   4933  \
# PurchaseId                              CA-2015-106978
# PurchaseDate                       2015-09-28 00:00:00
# ShipDate                           2015-10-04 00:00:00
# ShipMode                                Standard Class
# CustomerId                                    ZC-21910
# CustomerName                          Zuschuss Carroll
# Segment                                       Consumer
# Country                                  United States
# City                                            Aurora
# State                                         Colorado
# PostalCode                                       80013
# Region                                            West
# ProductId                              OFF-BI-10002012
# Category                               Office Supplies
# SubCategory                                    Binders
# ProductName    Wilson Jones Easy Flow Ii Sheet Lifters
# Sales                                             1.08
# Quantity                                             2
# Discount                                           0.7
# Profit                                           -0.79
# FirstName                                     Zuschuss
# LastName                                       Carroll
# CatalogPrice                                       1.8
# SupplierPrice                                      2.2
# NewProductId                           OFF-BI-10005730
#
#                                                    987                  2605  \
# PurchaseId                               CA-2015-146829       CA-2014-112718
# PurchaseDate                        2015-03-10 00:00:00  2014-12-16 00:00:00
# ShipDate                            2015-03-10 00:00:00  2014-12-21 00:00:00
# ShipMode                                       Same Day       Standard Class
# CustomerId                                     TS-21340             KN-16450
# CustomerName                              Toby Swindell          Kean Nguyen
# Segment                                        Consumer            Corporate
# Country                                   United States        United States
# City                                            Houston         Jacksonville
# State                                             Texas              Florida
# PostalCode                                        77041                32216
# Region                                          Central                South
# ProductId                               OFF-BI-10004022      OFF-BI-10000591
# Category                                Office Supplies      Office Supplies
# SubCategory                                     Binders              Binders
# ProductName    Acco Suede Grain Vinyl Round Ring Binder  Avery Binder Labels
# Sales                                              1.11                 1.17
# Quantity                                              2                    1
# Discount                                            0.8                  0.7
# Profit                                            -1.89                -0.86
# FirstName                                          Toby                 Kean
# LastName                                       Swindell               Nguyen
# CatalogPrice                                       2.78                 3.89
# SupplierPrice                                      3.73                 4.75
# NewProductId                            OFF-BI-10005813      OFF-BI-10005669
#
#                                                         1112  \
# PurchaseId                                    US-2016-110156
# PurchaseDate                             2016-11-19 00:00:00
# ShipDate                                 2016-11-24 00:00:00
# ShipMode                                      Standard Class
# CustomerId                                          EH-13945
# CustomerName                                   Eric Hoffmann
# Segment                                             Consumer
# Country                                        United States
# City                                                 Houston
# State                                                  Texas
# PostalCode                                             77041
# Region                                               Central
# ProductId                                    OFF-BI-10002609
# Category                                     Office Supplies
# SubCategory                                          Binders
# ProductName    Avery Hidden Tab Dividers For Binding Systems
# Sales                                                   1.19
# Quantity                                                   2
# Discount                                                 0.8
# Profit                                                 -2.03
# FirstName                                               Eric
# LastName                                            Hoffmann
# CatalogPrice                                            2.98
# SupplierPrice                                           3.99
# NewProductId                                 OFF-BI-10005754
#
#                                                     1685  \
# PurchaseId                                CA-2017-149489
# PurchaseDate                         2017-04-24 00:00:00
# ShipDate                             2017-04-27 00:00:00
# ShipMode                                     First Class
# CustomerId                                      DK-12835
# CustomerName                             Damala Kotsonis
# Segment                                        Corporate
# Country                                    United States
# City                                        Philadelphia
# State                                       Pennsylvania
# PostalCode                                         19143
# Region                                              East
# ProductId                                OFF-BI-10002813
# Category                                 Office Supplies
# SubCategory                                      Binders
# ProductName    Avery Reinforcements For Hole-Punch Pages
# Sales                                               1.19
# Quantity                                               2
# Discount                                             0.7
# Profit                                             -0.99
# FirstName                                         Damala
# LastName                                        Kotsonis
# CatalogPrice                                        1.98
# SupplierPrice                                       2.48
# NewProductId                             OFF-BI-10005760
#
#                                   4874  \
# PurchaseId              CA-2017-164042
# PurchaseDate       2017-05-23 00:00:00
# ShipDate           2017-05-27 00:00:00
# ShipMode                Standard Class
# CustomerId                    KL-16645
# CustomerName              Ken Lonsdale
# Segment                       Consumer
# Country                  United States
# City                           Houston
# State                            Texas
# PostalCode                       77095
# Region                         Central
# ProductId              OFF-BI-10001922
# Category               Office Supplies
# SubCategory                    Binders
# ProductName    Storex Dura Pro Binders
# Sales                             1.19
# Quantity                             1
# Discount                           0.8
# Profit                           -1.96
# FirstName                          Ken
# LastName                      Lonsdale
# CatalogPrice                      5.94
# SupplierPrice                      7.9
# NewProductId           OFF-BI-10005726
#
#                                                     6089  \
# PurchaseId                                US-2017-162068
# PurchaseDate                         2017-12-28 00:00:00
# ShipDate                             2017-12-31 00:00:00
# ShipMode                                    Second Class
# CustomerId                                      PC-18745
# CustomerName                              Pamela Coakley
# Segment                                        Corporate
# Country                                    United States
# City                                            Loveland
# State                                           Colorado
# PostalCode                                         80538
# Region                                              West
# ProductId                                OFF-BI-10002813
# Category                                 Office Supplies
# SubCategory                                      Binders
# ProductName    Avery Reinforcements For Hole-Punch Pages
# Sales                                               1.19
# Quantity                                               2
# Discount                                             0.7
# Profit                                             -0.99
# FirstName                                         Pamela
# LastName                                         Coakley
# CatalogPrice                                        1.98
# SupplierPrice                                       2.48
# NewProductId                             OFF-BI-10005760
#
#                                                             3325  \
# PurchaseId                                        CA-2014-165309
# PurchaseDate                                 2014-11-11 00:00:00
# ShipDate                                     2014-11-15 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              KD-16270
# CustomerName                                       Karen Daniels
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Houston
# State                                                      Texas
# PostalCode                                                 77095
# Region                                                   Central
# ProductId                                        OFF-BI-10001267
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Universal Recycled Hanging Pressboard Report B...
# Sales                                                       1.23
# Quantity                                                       1
# Discount                                                     0.8
# Profit                                                     -1.97
# FirstName                                                  Karen
# LastName                                                 Daniels
# CatalogPrice                                                6.17
# SupplierPrice                                               8.14
# NewProductId                                     OFF-BI-10005698
#
#                                                        5206
# PurchaseId                                   CA-2015-102015
# PurchaseDate                            2015-09-12 00:00:00
# ShipDate                                2015-09-18 00:00:00
# ShipMode                                     Standard Class
# CustomerId                                         TM-21010
# CustomerName                                 Tamara Manning
# Segment                                            Consumer
# Country                                       United States
# City                                                 Auburn
# State                                              New York
# PostalCode                                            13021
# Region                                                 East
# ProductId                                   OFF-FA-10000490
# Category                                    Office Supplies
# SubCategory                                       Fasteners
# ProductName    Oic Binder Clips, Mini, 1/4" Capacity, Black
# Sales                                                  1.24
# Quantity                                                  1
# Discount                                                0.0
# Profit                                                 0.58
# FirstName                                            Tamara
# LastName                                            Manning
# CatalogPrice                                           1.24
# SupplierPrice                                          0.66
# NewProductId                                OFF-FA-10005918

# %%
# view the 20 highest values in the Discount column

df.nlargest(20, 'Discount').T
# Out:
#                                                              14   \
# PurchaseId                                        US-2015-118983
# PurchaseDate                                 2015-11-22 00:00:00
# ShipDate                                     2015-11-26 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              HP-14815
# CustomerName                                       Harold Pawlan
# Segment                                              Home Office
# Country                                            United States
# City                                                  Fort Worth
# State                                                      Texas
# PostalCode                                                 76106
# Region                                                   Central
# ProductId                                        OFF-AP-10002311
# Category                                         Office Supplies
# SubCategory                                           Appliances
# ProductName    Holmes Replacement Filter For Hepa Air Cleaner...
# Sales                                                      68.81
# Quantity                                                       5
# Discount                                                     0.8
# Profit                                                   -123.86
# FirstName                                                 Harold
# LastName                                                  Pawlan
# CatalogPrice                                               68.81
# SupplierPrice                                              93.58
# NewProductId                                     OFF-AP-10005430
#
#                                                             15   \
# PurchaseId                                       US-2015-118983
# PurchaseDate                                2015-11-22 00:00:00
# ShipDate                                    2015-11-26 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             HP-14815
# CustomerName                                      Harold Pawlan
# Segment                                             Home Office
# Country                                           United States
# City                                                 Fort Worth
# State                                                     Texas
# PostalCode                                                76106
# Region                                                  Central
# ProductId                                       OFF-BI-10000756
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName    Storex Duratech Recycled Plastic Frosted Binders
# Sales                                                      2.54
# Quantity                                                      3
# Discount                                                    0.8
# Profit                                                    -3.82
# FirstName                                                Harold
# LastName                                                 Pawlan
# CatalogPrice                                               4.24
# SupplierPrice                                              5.51
# NewProductId                                    OFF-BI-10005673
#
#                                75   \
# PurchaseId          US-2017-118038
# PurchaseDate   2017-12-09 00:00:00
# ShipDate       2017-12-11 00:00:00
# ShipMode               First Class
# CustomerId                KB-16600
# CustomerName           Ken Brennan
# Segment                  Corporate
# Country              United States
# City                       Houston
# State                        Texas
# PostalCode                   77041
# Region                     Central
# ProductId          OFF-BI-10004182
# Category           Office Supplies
# SubCategory                Binders
# ProductName        Economy Binders
# Sales                         1.25
# Quantity                         3
# Discount                       0.8
# Profit                       -1.93
# FirstName                      Ken
# LastName                   Brennan
# CatalogPrice                  2.08
# SupplierPrice                 2.72
# NewProductId       OFF-BI-10005820
#
#                                                          101  \
# PurchaseId                                    CA-2016-158568
# PurchaseDate                             2016-08-29 00:00:00
# ShipDate                                 2016-09-02 00:00:00
# ShipMode                                      Standard Class
# CustomerId                                          RB-19465
# CustomerName                                    Rick Bensley
# Segment                                          Home Office
# Country                                        United States
# City                                                 Chicago
# State                                               Illinois
# PostalCode                                             60610
# Region                                               Central
# ProductId                                    OFF-BI-10002609
# Category                                     Office Supplies
# SubCategory                                          Binders
# ProductName    Avery Hidden Tab Dividers For Binding Systems
# Sales                                                   1.79
# Quantity                                                   3
# Discount                                                 0.8
# Profit                                                 -3.04
# FirstName                                               Rick
# LastName                                             Bensley
# CatalogPrice                                            2.98
# SupplierPrice                                           3.99
# NewProductId                                 OFF-BI-10005754
#
#                                                         169  \
# PurchaseId                                   CA-2014-139892
# PurchaseDate                            2014-09-08 00:00:00
# ShipDate                                2014-09-12 00:00:00
# ShipMode                                     Standard Class
# CustomerId                                         BM-11140
# CustomerName                                   Becky Martin
# Segment                                            Consumer
# Country                                       United States
# City                                            San Antonio
# State                                                 Texas
# PostalCode                                            78207
# Region                                              Central
# ProductId                                   OFF-AP-10002518
# Category                                    Office Supplies
# SubCategory                                      Appliances
# ProductName    Kensington 7 Outlet Masterpiece Power Center
# Sales                                                177.98
# Quantity                                                  5
# Discount                                                0.8
# Profit                                              -453.85
# FirstName                                             Becky
# LastName                                             Martin
# CatalogPrice                                         177.98
# SupplierPrice                                        268.75
# NewProductId                                OFF-AP-10005437
#
#                                                              174  \
# PurchaseId                                        US-2014-100853
# PurchaseDate                                 2014-09-14 00:00:00
# ShipDate                                     2014-09-19 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              JB-15400
# CustomerName                                    Jennifer Braxton
# Segment                                                Corporate
# Country                                            United States
# City                                                     Chicago
# State                                                   Illinois
# PostalCode                                                 60623
# Region                                                   Central
# ProductId                                        OFF-AP-10000891
# Category                                         Office Supplies
# SubCategory                                           Appliances
# ProductName    Kensington 7 Outlet Masterpiece Homeoffice Pow...
# Sales                                                      52.45
# Quantity                                                       2
# Discount                                                     0.8
# Profit                                                   -131.12
# FirstName                                               Jennifer
# LastName                                                 Braxton
# CatalogPrice                                              131.12
# SupplierPrice                                             196.68
# NewProductId                                     OFF-AP-10005402
#
#                                                              176  \
# PurchaseId                                        US-2017-152366
# PurchaseDate                                 2017-04-21 00:00:00
# ShipDate                                     2017-04-25 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              SJ-20500
# CustomerName                                     Shirley Jackson
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Houston
# State                                                      Texas
# PostalCode                                                 77036
# Region                                                   Central
# ProductId                                        OFF-AP-10002684
# Category                                         Office Supplies
# SubCategory                                           Appliances
# ProductName    Acco 7-Outlet Masterpiece Power Center, Wihtou...
# Sales                                                      97.26
# Quantity                                                       4
# Discount                                                     0.8
# Profit                                                   -243.16
# FirstName                                                Shirley
# LastName                                                 Jackson
# CatalogPrice                                              121.58
# SupplierPrice                                             182.37
# NewProductId                                     OFF-AP-10005442
#
#                                                 203  \
# PurchaseId                           US-2017-116701
# PurchaseDate                    2017-12-17 00:00:00
# ShipDate                        2017-12-21 00:00:00
# ShipMode                               Second Class
# CustomerId                                 LC-17140
# CustomerName                           Logan Currie
# Segment                                    Consumer
# Country                               United States
# City                                         Dallas
# State                                         Texas
# PostalCode                                    75220
# Region                                      Central
# ProductId                           OFF-AP-10003217
# Category                            Office Supplies
# SubCategory                              Appliances
# ProductName    Eureka Sanitaire  Commercial Upright
# Sales                                         66.28
# Quantity                                          2
# Discount                                        0.8
# Profit                                      -178.97
# FirstName                                     Logan
# LastName                                     Currie
# CatalogPrice                                 165.71
# SupplierPrice                                255.19
# NewProductId                        OFF-AP-10005453
#
#                                                              261  \
# PurchaseId                                        US-2017-155299
# PurchaseDate                                 2017-06-08 00:00:00
# ShipDate                                     2017-06-12 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              DL-13600
# CustomerName                                        Dorris Liebe
# Segment                                                Corporate
# Country                                            United States
# City                                                    Pasadena
# State                                                      Texas
# PostalCode                                                 77506
# Region                                                   Central
# ProductId                                        OFF-AP-10002203
# Category                                         Office Supplies
# SubCategory                                           Appliances
# ProductName    Eureka Disposable Bags For Sanitaire Vibra Gro...
# Sales                                                       1.62
# Quantity                                                       2
# Discount                                                     0.8
# Profit                                                     -4.47
# FirstName                                                 Dorris
# LastName                                                   Liebe
# CatalogPrice                                                4.06
# SupplierPrice                                               6.29
# NewProductId                                     OFF-AP-10005427
#
#                                280                  378  \
# PurchaseId          US-2015-161991       CA-2015-130792
# PurchaseDate   2015-09-26 00:00:00  2015-04-28 00:00:00
# ShipDate       2015-09-28 00:00:00  2015-05-05 00:00:00
# ShipMode              Second Class       Standard Class
# CustomerId                SC-20725             RA-19915
# CustomerName     Steven Cartwright    Russell Applegate
# Segment                   Consumer             Consumer
# Country              United States        United States
# City                       Houston              Houston
# State                        Texas                Texas
# PostalCode                   77070                77095
# Region                     Central              Central
# ProductId          OFF-BI-10004967      OFF-AP-10000696
# Category           Office Supplies      Office Supplies
# SubCategory                Binders           Appliances
# ProductName     Round Ring Binders  Holmes Odor Grabber
# Sales                         2.08                 8.65
# Quantity                         5                    3
# Discount                       0.8                  0.8
# Profit                       -3.43               -20.33
# FirstName                   Steven              Russell
# LastName                Cartwright            Applegate
# CatalogPrice                  2.08                14.42
# SupplierPrice                 2.77                 21.2
# NewProductId       OFF-BI-10005856      OFF-AP-10005399
#
#                                                              380  \
# PurchaseId                                        CA-2015-130792
# PurchaseDate                                 2015-04-28 00:00:00
# ShipDate                                     2015-05-05 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              RA-19915
# CustomerName                                   Russell Applegate
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Houston
# State                                                      Texas
# PostalCode                                                 77095
# Region                                                   Central
# ProductId                                        OFF-BI-10000309
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Gbc Twin Loop Wire Binding Elements, 9/16" Spi...
# Sales                                                      12.18
# Quantity                                                       4
# Discount                                                     0.8
# Profit                                                    -18.87
# FirstName                                                Russell
# LastName                                               Applegate
# CatalogPrice                                               15.22
# SupplierPrice                                              19.94
# NewProductId                                     OFF-BI-10005660
#
#                                                             393  \
# PurchaseId                                       US-2014-134971
# PurchaseDate                                2014-06-07 00:00:00
# ShipDate                                    2014-06-10 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             BP-11095
# CustomerName                                       Bart Pistole
# Segment                                               Corporate
# Country                                           United States
# City                                                     Peoria
# State                                                  Illinois
# PostalCode                                                61604
# Region                                                  Central
# ProductId                                       OFF-BI-10003982
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName    Wilson Jones Century Plastic Molded Ring Binders
# Sales                                                     12.46
# Quantity                                                      3
# Discount                                                    0.8
# Profit                                                   -20.56
# FirstName                                                  Bart
# LastName                                                Pistole
# CatalogPrice                                              20.77
# SupplierPrice                                             27.62
# NewProductId                                    OFF-BI-10005809
#
#                                       469  \
# PurchaseId                 US-2016-100419
# PurchaseDate          2016-12-16 00:00:00
# ShipDate              2016-12-20 00:00:00
# ShipMode                     Second Class
# CustomerId                       CC-12670
# CustomerName               Craig Carreira
# Segment                          Consumer
# Country                     United States
# City                              Chicago
# State                            Illinois
# PostalCode                          60610
# Region                            Central
# ProductId                 OFF-BI-10002194
# Category                  Office Supplies
# SubCategory                       Binders
# ProductName    Cardinal Hold-It Cd Pocket
# Sales                                4.79
# Quantity                                3
# Discount                              0.8
# Profit                               -7.9
# FirstName                           Craig
# LastName                         Carreira
# CatalogPrice                         7.98
# SupplierPrice                       10.61
# NewProductId              OFF-BI-10005740
#
#                                                              521  \
# PurchaseId                                        CA-2015-157812
# PurchaseDate                                 2015-03-22 00:00:00
# ShipDate                                     2015-03-26 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              DB-13210
# CustomerName                                         Dean Braden
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Houston
# State                                                      Texas
# PostalCode                                                 77041
# Region                                                   Central
# ProductId                                        OFF-BI-10000285
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Xtralife Clearvue Slant-D Ring Binders By Card...
# Sales                                                      14.11
# Quantity                                                       9
# Discount                                                     0.8
# Profit                                                    -21.17
# FirstName                                                   Dean
# LastName                                                  Braden
# CatalogPrice                                                7.84
# SupplierPrice                                              10.19
# NewProductId                                     OFF-BI-10005658
#
#                                                  536  \
# PurchaseId                            US-2017-122637
# PurchaseDate                     2017-09-03 00:00:00
# ShipDate                         2017-09-08 00:00:00
# ShipMode                                Second Class
# CustomerId                                  EP-13915
# CustomerName                              Emily Phan
# Segment                                     Consumer
# Country                                United States
# City                                         Chicago
# State                                       Illinois
# PostalCode                                     60653
# Region                                       Central
# ProductId                            OFF-BI-10002429
# Category                             Office Supplies
# SubCategory                                  Binders
# ProductName    Premier Elliptical Ring Binder, Black
# Sales                                          42.62
# Quantity                                           7
# Discount                                         0.8
# Profit                                        -68.19
# FirstName                                      Emily
# LastName                                        Phan
# CatalogPrice                                   30.44
# SupplierPrice                                  40.18
# NewProductId                         OFF-BI-10005748
#
#                                                              549  \
# PurchaseId                                        CA-2015-113173
# PurchaseDate                                 2015-11-15 00:00:00
# ShipDate                                     2015-11-17 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              DK-13225
# CustomerName                                           Dean Katz
# Segment                                                Corporate
# Country                                            United States
# City                                                     Chicago
# State                                                   Illinois
# PostalCode                                                 60653
# Region                                                   Central
# ProductId                                        OFF-BI-10004738
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Flexible Leather- Look Classic Collection Ring...
# Sales                                                      11.36
# Quantity                                                       3
# Discount                                                     0.8
# Profit                                                    -17.05
# FirstName                                                   Dean
# LastName                                                    Katz
# CatalogPrice                                               18.94
# SupplierPrice                                              24.62
# NewProductId                                     OFF-BI-10005849
#
#                                                            621  \
# PurchaseId                                      US-2014-111171
# PurchaseDate                               2014-12-26 00:00:00
# ShipDate                                   2014-12-31 00:00:00
# ShipMode                                        Standard Class
# CustomerId                                            CA-12265
# CustomerName                                Christina Anderson
# Segment                                               Consumer
# Country                                          United States
# City                                                   Chicago
# State                                                 Illinois
# PostalCode                                               60610
# Region                                                 Central
# ProductId                                      OFF-BI-10002103
# Category                                       Office Supplies
# SubCategory                                            Binders
# ProductName    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# Sales                                                     8.69
# Quantity                                                     5
# Discount                                                   0.8
# Profit                                                  -14.77
# FirstName                                            Christina
# LastName                                              Anderson
# CatalogPrice                                              8.69
# SupplierPrice                                            11.64
# NewProductId                                   OFF-BI-10005737
#
#                                                              658  \
# PurchaseId                                        US-2016-156097
# PurchaseDate                                 2016-09-19 00:00:00
# ShipDate                                     2016-09-19 00:00:00
# ShipMode                                                Same Day
# CustomerId                                              EH-14125
# CustomerName                                   Eugene Hildebrand
# Segment                                              Home Office
# Country                                            United States
# City                                                      Aurora
# State                                                   Illinois
# PostalCode                                                 60505
# Region                                                   Central
# ProductId                                        OFF-BI-10004654
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Avery Binding System Hidden Tab Executive Styl...
# Sales                                                       2.31
# Quantity                                                       2
# Discount                                                     0.8
# Profit                                                     -3.46
# FirstName                                                 Eugene
# LastName                                              Hildebrand
# CatalogPrice                                                5.77
# SupplierPrice                                                7.5
# NewProductId                                     OFF-BI-10005844
#
#                                             662
# PurchaseId                       CA-2015-146563
# PurchaseDate                2015-08-24 00:00:00
# ShipDate                    2015-08-28 00:00:00
# ShipMode                         Standard Class
# CustomerId                             CB-12025
# CustomerName                  Cassandra Brandow
# Segment                                Consumer
# Country                           United States
# City                                  Arlington
# State                                     Texas
# PostalCode                                76017
# Region                                  Central
# ProductId                       OFF-BI-10003981
# Category                        Office Supplies
# SubCategory                             Binders
# ProductName    Avery Durable Plastic 1" Binders
# Sales                                      2.72
# Quantity                                      3
# Discount                                    0.8
# Profit                                    -4.22
# FirstName                             Cassandra
# LastName                                Brandow
# CatalogPrice                               4.54
# SupplierPrice                              5.95
# NewProductId                    OFF-BI-10005808

# %%
# view the 20 highest values in the Profit column

df.nlargest(20, 'Profit').T
# Out:
#                                                 6826  \
# PurchaseId                            CA-2016-118689
# PurchaseDate                     2016-10-02 00:00:00
# ShipDate                         2016-10-09 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  TC-20980
# CustomerName                            Tamara Chand
# Segment                                    Corporate
# Country                                United States
# City                                       Lafayette
# State                                        Indiana
# PostalCode                                     47905
# Region                                       Central
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       17499.95
# Quantity                                           5
# Discount                                         0.0
# Profit                                       8399.98
# FirstName                                     Tamara
# LastName                                       Chand
# CatalogPrice                                 3499.99
# SupplierPrice                                1819.99
# NewProductId                         TEC-CO-10006640
#
#                                                 8153  \
# PurchaseId                            CA-2017-140151
# PurchaseDate                     2017-03-23 00:00:00
# ShipDate                         2017-03-25 00:00:00
# ShipMode                                 First Class
# CustomerId                                  RB-19360
# CustomerName                            Raymond Buch
# Segment                                     Consumer
# Country                                United States
# City                                         Seattle
# State                                     Washington
# PostalCode                                     98115
# Region                                          West
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       13999.96
# Quantity                                           4
# Discount                                         0.0
# Profit                                       6719.98
# FirstName                                    Raymond
# LastName                                        Buch
# CatalogPrice                                 3499.99
# SupplierPrice                                1819.99
# NewProductId                         TEC-CO-10006640
#
#                                                 4190  \
# PurchaseId                            CA-2017-166709
# PurchaseDate                     2017-11-17 00:00:00
# ShipDate                         2017-11-22 00:00:00
# ShipMode                              Standard Class
# CustomerId                                  HL-15040
# CustomerName                            Hunter Lopez
# Segment                                     Consumer
# Country                                United States
# City                                          Newark
# State                                       Delaware
# PostalCode                                     19711
# Region                                          East
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       10499.97
# Quantity                                           3
# Discount                                         0.0
# Profit                                       5039.99
# FirstName                                     Hunter
# LastName                                       Lopez
# CatalogPrice                                 3499.99
# SupplierPrice                                1819.99
# NewProductId                         TEC-CO-10006640
#
#                                                            9039  \
# PurchaseId                                       CA-2016-117121
# PurchaseDate                                2016-12-17 00:00:00
# ShipDate                                    2016-12-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             AB-10105
# CustomerName                                      Adrian Barton
# Segment                                                Consumer
# Country                                           United States
# City                                                    Detroit
# State                                                  Michigan
# PostalCode                                                48205
# Region                                                  Central
# ProductId                                       OFF-BI-10000545
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName    Gbc Ibimaster 500 Manual Proclick Binding System
# Sales                                                   9892.74
# Quantity                                                     13
# Discount                                                    0.0
# Profit                                                  4946.37
# FirstName                                                Adrian
# LastName                                                 Barton
# CatalogPrice                                             760.98
# SupplierPrice                                            380.49
# NewProductId                                    OFF-BI-10005667
#
#                                                4098  \
# PurchaseId                           CA-2014-116904
# PurchaseDate                    2014-09-23 00:00:00
# ShipDate                        2014-09-28 00:00:00
# ShipMode                             Standard Class
# CustomerId                                 SC-20095
# CustomerName                           Sanjit Chand
# Segment                                    Consumer
# Country                               United States
# City                                    Minneapolis
# State                                     Minnesota
# PostalCode                                    55407
# Region                                      Central
# ProductId                           OFF-BI-10001120
# Category                            Office Supplies
# SubCategory                                 Binders
# ProductName    Ibico Epk-21 Electric Binding System
# Sales                                       9449.95
# Quantity                                          5
# Discount                                        0.0
# Profit                                      4630.48
# FirstName                                    Sanjit
# LastName                                      Chand
# CatalogPrice                                1889.99
# SupplierPrice                                963.89
# NewProductId                        OFF-BI-10005692
#
#                                                 2623  \
# PurchaseId                            CA-2017-127180
# PurchaseDate                     2017-10-22 00:00:00
# ShipDate                         2017-10-24 00:00:00
# ShipMode                                 First Class
# CustomerId                                  TA-21385
# CustomerName                            Tom Ashbrook
# Segment                                  Home Office
# Country                                United States
# City                                   New York City
# State                                       New York
# PostalCode                                     10024
# Region                                          East
# ProductId                            TEC-CO-10004722
# Category                                  Technology
# SubCategory                                  Copiers
# ProductName    Canon Imageclass 2200 Advanced Copier
# Sales                                       11199.97
# Quantity                                           4
# Discount                                         0.2
# Profit                                       3919.99
# FirstName                                        Tom
# LastName                                    Ashbrook
# CatalogPrice                                 3499.99
# SupplierPrice                                2519.99
# NewProductId                         TEC-CO-10006640
#
#                                                             509   \
# PurchaseId                                        CA-2015-145352
# PurchaseDate                                 2015-03-16 00:00:00
# ShipDate                                     2015-03-22 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              CM-12385
# CustomerName                                Christopher Martinez
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Atlanta
# State                                                    Georgia
# PostalCode                                                 30318
# Region                                                     South
# ProductId                                        OFF-BI-10003527
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Fellowes Pb500 Electric Punch Plastic Comb Bin...
# Sales                                                    6354.95
# Quantity                                                       5
# Discount                                                     0.0
# Profit                                                   3177.48
# FirstName                                            Christopher
# LastName                                                Martinez
# CatalogPrice                                             1270.99
# SupplierPrice                                              635.5
# NewProductId                                     OFF-BI-10005787
#
#                                                             8488  \
# PurchaseId                                        CA-2016-158841
# PurchaseDate                                 2016-02-02 00:00:00
# ShipDate                                     2016-02-04 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              SE-20110
# CustomerName                                        Sanjit Engle
# Segment                                                 Consumer
# Country                                            United States
# City                                                   Arlington
# State                                                   Virginia
# PostalCode                                                 22204
# Region                                                     South
# ProductId                                        TEC-MA-10001127
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Hp Designjet T520 Inkjet Large Format Printer ...
# Sales                                                    8749.95
# Quantity                                                       5
# Discount                                                     0.0
# Profit                                                   2799.98
# FirstName                                                 Sanjit
# LastName                                                   Engle
# CatalogPrice                                             1749.99
# SupplierPrice                                            1189.99
# NewProductId                                     TEC-MA-10006657
#
#                                                7666  \
# PurchaseId                           US-2016-140158
# PurchaseDate                    2016-10-04 00:00:00
# ShipDate                        2016-10-08 00:00:00
# ShipMode                             Standard Class
# CustomerId                                 DR-12940
# CustomerName                          Daniel Raglin
# Segment                                 Home Office
# Country                               United States
# City                                     Providence
# State                                  Rhode Island
# PostalCode                                    02908
# Region                                         East
# ProductId                           TEC-CO-10001449
# Category                                 Technology
# SubCategory                                 Copiers
# ProductName    Hewlett Packard Laserjet 3310 Copier
# Sales                                       5399.91
# Quantity                                          9
# Discount                                        0.0
# Profit                                      2591.96
# FirstName                                    Daniel
# LastName                                     Raglin
# CatalogPrice                                 599.99
# SupplierPrice                                311.99
# NewProductId                        TEC-CO-10006630
#
#                                                     6520  \
# PurchaseId                                CA-2017-138289
# PurchaseDate                         2017-01-16 00:00:00
# ShipDate                             2017-01-18 00:00:00
# ShipMode                                    Second Class
# CustomerId                                      AR-10540
# CustomerName                                 Andy Reiter
# Segment                                         Consumer
# Country                                    United States
# City                                             Jackson
# State                                           Michigan
# PostalCode                                         49201
# Region                                           Central
# ProductId                                OFF-BI-10004995
# Category                                 Office Supplies
# SubCategory                                      Binders
# ProductName    Gbc Docubind P400 Electric Binding System
# Sales                                            5443.96
# Quantity                                               4
# Discount                                             0.0
# Profit                                           2504.22
# FirstName                                           Andy
# LastName                                          Reiter
# CatalogPrice                                     1360.99
# SupplierPrice                                     734.93
# NewProductId                             OFF-BI-10005858
#
#                                             1085  \
# PurchaseId                        US-2016-143819
# PurchaseDate                 2016-03-01 00:00:00
# ShipDate                     2016-03-05 00:00:00
# ShipMode                          Standard Class
# CustomerId                              KD-16270
# CustomerName                       Karen Daniels
# Segment                                 Consumer
# Country                            United States
# City                                     Yonkers
# State                                   New York
# PostalCode                                 10701
# Region                                      East
# ProductId                        TEC-MA-10003979
# Category                              Technology
# SubCategory                             Machines
# ProductName    Ativa V4110Mdd Micro-Cut Shredder
# Sales                                    4899.93
# Quantity                                       7
# Discount                                     0.0
# Profit                                   2400.97
# FirstName                                  Karen
# LastName                                 Daniels
# CatalogPrice                              699.99
# SupplierPrice                             356.99
# NewProductId                     TEC-MA-10006693
#
#                                                            4277  \
# PurchaseId                                       US-2016-107440
# PurchaseDate                                2016-04-16 00:00:00
# ShipDate                                    2016-04-20 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             BS-11365
# CustomerName                                       Bill Shonely
# Segment                                               Corporate
# Country                                           United States
# City                                                   Lakewood
# State                                                New Jersey
# PostalCode                                                08701
# Region                                                     East
# ProductId                                       TEC-MA-10001047
# Category                                             Technology
# SubCategory                                            Machines
# ProductName    3D Systems Cube Printer, 2Nd Generation, Magenta
# Sales                                                   9099.93
# Quantity                                                      7
# Discount                                                    0.0
# Profit                                                  2365.98
# FirstName                                                  Bill
# LastName                                                Shonely
# CatalogPrice                                            1299.99
# SupplierPrice                                            961.99
# NewProductId                                    TEC-MA-10006656
#
#                                              8990  \
# PurchaseId                         US-2015-128587
# PurchaseDate                  2015-12-24 00:00:00
# ShipDate                      2015-12-30 00:00:00
# ShipMode                           Standard Class
# CustomerId                               HM-14860
# CustomerName                          Harry Marie
# Segment                                 Corporate
# Country                             United States
# City                                  Springfield
# State                                    Missouri
# PostalCode                                  65807
# Region                                    Central
# ProductId                         TEC-CO-10003763
# Category                               Technology
# SubCategory                               Copiers
# ProductName    Canon Pc1060 Personal Laser Copier
# Sales                                     4899.93
# Quantity                                        7
# Discount                                      0.0
# Profit                                    2302.97
# FirstName                                   Harry
# LastName                                    Marie
# CatalogPrice                               699.99
# SupplierPrice                              370.99
# NewProductId                      TEC-CO-10006637
#
#                                                             6626  \
# PurchaseId                                        CA-2014-145541
# PurchaseDate                                 2014-12-14 00:00:00
# ShipDate                                     2014-12-21 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              TB-21400
# CustomerName                                    Tom Boeckenhauer
# Segment                                                 Consumer
# Country                                            United States
# City                                               New York City
# State                                                   New York
# PostalCode                                                 10024
# Region                                                      East
# ProductId                                        TEC-MA-10001127
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Hp Designjet T520 Inkjet Large Format Printer ...
# Sales                                                    6999.96
# Quantity                                                       4
# Discount                                                     0.0
# Profit                                                   2239.99
# FirstName                                                    Tom
# LastName                                            Boeckenhauer
# CatalogPrice                                             1749.99
# SupplierPrice                                            1189.99
# NewProductId                                     TEC-MA-10006657
#
#                                             8204  \
# PurchaseId                        CA-2015-114811
# PurchaseDate                 2015-11-08 00:00:00
# ShipDate                     2015-11-08 00:00:00
# ShipMode                                Same Day
# CustomerId                              KD-16495
# CustomerName                       Keith Dawkins
# Segment                                Corporate
# Country                            United States
# City                               New York City
# State                                   New York
# PostalCode                                 10024
# Region                                      East
# ProductId                        TEC-MA-10000045
# Category                              Technology
# SubCategory                             Machines
# ProductName    Zebra Zm400 Thermal Label Printer
# Sales                                     4643.8
# Quantity                                       4
# Discount                                     0.0
# Profit                                   2229.02
# FirstName                                  Keith
# LastName                                 Dawkins
# CatalogPrice                             1160.95
# SupplierPrice                             603.69
# NewProductId                     TEC-MA-10006643
#
#                                                             318   \
# PurchaseId                                        CA-2014-164973
# PurchaseDate                                 2014-11-04 00:00:00
# ShipDate                                     2014-11-09 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              NM-18445
# CustomerName                                        Nathan Mautz
# Segment                                              Home Office
# Country                                            United States
# City                                               New York City
# State                                                   New York
# PostalCode                                                 10024
# Region                                                      East
# ProductId                                        TEC-MA-10002927
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Canon Imageclass Mf7460 Monochrome Digital Las...
# Sales                                                    3991.98
# Quantity                                                       2
# Discount                                                     0.0
# Profit                                                   1995.99
# FirstName                                                 Nathan
# LastName                                                   Mautz
# CatalogPrice                                             1995.99
# SupplierPrice                                              998.0
# NewProductId                                     TEC-MA-10006674
#
#                                                             7683  \
# PurchaseId                                        CA-2015-120782
# PurchaseDate                                 2015-04-28 00:00:00
# ShipDate                                     2015-05-01 00:00:00
# ShipMode                                             First Class
# CustomerId                                              SD-20485
# CustomerName                                     Shirley Daniels
# Segment                                              Home Office
# Country                                            United States
# City                                                     Midland
# State                                                   Michigan
# PostalCode                                                 48640
# Region                                                   Central
# ProductId                                        OFF-BI-10003527
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Fellowes Pb500 Electric Punch Plastic Comb Bin...
# Sales                                                    3812.97
# Quantity                                                       3
# Discount                                                     0.0
# Profit                                                   1906.48
# FirstName                                                Shirley
# LastName                                                 Daniels
# CatalogPrice                                             1270.99
# SupplierPrice                                              635.5
# NewProductId                                     OFF-BI-10005787
#
#                                                             8858  \
# PurchaseId                                        CA-2017-135909
# PurchaseDate                                 2017-10-13 00:00:00
# ShipDate                                     2017-10-20 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              JW-15220
# CustomerName                                           Jane Waco
# Segment                                                Corporate
# Country                                            United States
# City                                                  Sacramento
# State                                                 California
# PostalCode                                                 95823
# Region                                                      West
# ProductId                                        OFF-BI-10003527
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Fellowes Pb500 Electric Punch Plastic Comb Bin...
# Sales                                                    5083.96
# Quantity                                                       5
# Discount                                                     0.2
# Profit                                                   1906.48
# FirstName                                                   Jane
# LastName                                                    Waco
# CatalogPrice                                             1270.99
# SupplierPrice                                             889.69
# NewProductId                                     OFF-BI-10005787
#
#                                                             7914  \
# PurchaseId                                        CA-2017-165323
# PurchaseDate                                 2017-06-17 00:00:00
# ShipDate                                     2017-06-21 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              SR-20740
# CustomerName                                       Steven Roelle
# Segment                                              Home Office
# Country                                            United States
# City                                               New York City
# State                                                   New York
# PostalCode                                                 10024
# Region                                                      East
# ProductId                                        TEC-MA-10003673
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Hewlett-Packard Desktjet 6988Dt Refurbished Pr...
# Sales                                                     3404.5
# Quantity                                                       5
# Discount                                                     0.0
# Profit                                                    1668.2
# FirstName                                                 Steven
# LastName                                                  Roelle
# CatalogPrice                                               680.9
# SupplierPrice                                             347.26
# NewProductId                                     TEC-MA-10006691
#
#                                                7818
# PurchaseId                           CA-2016-138478
# PurchaseDate                    2016-10-21 00:00:00
# ShipDate                        2016-10-26 00:00:00
# ShipMode                               Second Class
# CustomerId                                 DP-13390
# CustomerName                          Dennis Pardue
# Segment                                 Home Office
# Country                               United States
# City                                North Las Vegas
# State                                        Nevada
# PostalCode                                    89031
# Region                                         West
# ProductId                           OFF-BI-10001120
# Category                            Office Supplies
# SubCategory                                 Binders
# ProductName    Ibico Epk-21 Electric Binding System
# Sales                                       4535.98
# Quantity                                          3
# Discount                                        0.2
# Profit                                      1644.29
# FirstName                                    Dennis
# LastName                                     Pardue
# CatalogPrice                                1889.99
# SupplierPrice                               1341.89
# NewProductId                        OFF-BI-10005692

# %%
# view the 20 smallest values in the Profit column

df.nsmallest(20, 'Profit').T
# Out:
#                                                     7772  \
# PurchaseId                                CA-2016-108196
# PurchaseDate                         2016-11-25 00:00:00
# ShipDate                             2016-12-02 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      CS-12505
# CustomerName                               Cindy Stewart
# Segment                                         Consumer
# Country                                    United States
# City                                           Lancaster
# State                                               Ohio
# PostalCode                                         43130
# Region                                              East
# ProductId                                TEC-MA-10000418
# Category                                      Technology
# SubCategory                                     Machines
# ProductName    Cubify Cubex 3D Printer Double Head Print
# Sales                                            4499.98
# Quantity                                               5
# Discount                                             0.7
# Profit                                          -6599.98
# FirstName                                          Cindy
# LastName                                         Stewart
# CatalogPrice                                     2999.99
# SupplierPrice                                    4319.99
# NewProductId                             TEC-MA-10006645
#
#                                                     683   \
# PurchaseId                                US-2017-168116
# PurchaseDate                         2017-11-04 00:00:00
# ShipDate                             2017-11-04 00:00:00
# ShipMode                                        Same Day
# CustomerId                                      GT-14635
# CustomerName                              Grant Thornton
# Segment                                        Corporate
# Country                                    United States
# City                                          Burlington
# State                                     North Carolina
# PostalCode                                         27217
# Region                                             South
# ProductId                                TEC-MA-10004125
# Category                                      Technology
# SubCategory                                     Machines
# ProductName    Cubify Cubex 3D Printer Triple Head Print
# Sales                                            7999.98
# Quantity                                               4
# Discount                                             0.5
# Profit                                          -3839.99
# FirstName                                          Grant
# LastName                                        Thornton
# CatalogPrice                                     3999.99
# SupplierPrice                                    4959.99
# NewProductId                             TEC-MA-10006696
#
#                                                     9774  \
# PurchaseId                                CA-2014-169019
# PurchaseDate                         2014-07-26 00:00:00
# ShipDate                             2014-07-30 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      LF-17185
# CustomerName                                 Luke Foster
# Segment                                         Consumer
# Country                                    United States
# City                                         San Antonio
# State                                              Texas
# PostalCode                                         78207
# Region                                           Central
# ProductId                                OFF-BI-10004995
# Category                                 Office Supplies
# SubCategory                                      Binders
# ProductName    Gbc Docubind P400 Electric Binding System
# Sales                                            2177.58
# Quantity                                               8
# Discount                                             0.8
# Profit                                          -3701.89
# FirstName                                           Luke
# LastName                                          Foster
# CatalogPrice                                     1360.99
# SupplierPrice                                    1823.73
# NewProductId                             OFF-BI-10005858
#
#                                                     3011  \
# PurchaseId                                CA-2017-134845
# PurchaseDate                         2017-04-17 00:00:00
# ShipDate                             2017-04-23 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      SR-20425
# CustomerName                              Sharelle Roach
# Segment                                      Home Office
# Country                                    United States
# City                                          Louisville
# State                                           Colorado
# PostalCode                                         80027
# Region                                              West
# ProductId                                TEC-MA-10000822
# Category                                      Technology
# SubCategory                                     Machines
# ProductName    Lexmark Mx611Dhe Monochrome Laser Printer
# Sales                                            2549.98
# Quantity                                               5
# Discount                                             0.7
# Profit                                          -3399.98
# FirstName                                       Sharelle
# LastName                                           Roach
# CatalogPrice                                     1699.99
# SupplierPrice                                    2379.99
# NewProductId                             TEC-MA-10006650
#
#                                                4991  \
# PurchaseId                           US-2017-122714
# PurchaseDate                    2017-12-07 00:00:00
# ShipDate                        2017-12-13 00:00:00
# ShipMode                             Standard Class
# CustomerId                                 HG-14965
# CustomerName                          Henry Goldwyn
# Segment                                   Corporate
# Country                               United States
# City                                        Chicago
# State                                      Illinois
# PostalCode                                    60653
# Region                                      Central
# ProductId                           OFF-BI-10001120
# Category                            Office Supplies
# SubCategory                                 Binders
# ProductName    Ibico Epk-21 Electric Binding System
# Sales                                       1889.99
# Quantity                                          5
# Discount                                        0.8
# Profit                                     -2929.48
# FirstName                                     Henry
# LastName                                    Goldwyn
# CatalogPrice                                1889.99
# SupplierPrice                               2475.89
# NewProductId                        OFF-BI-10005692
#
#                                                     3151  \
# PurchaseId                                CA-2015-147830
# PurchaseDate                         2015-12-15 00:00:00
# ShipDate                             2015-12-18 00:00:00
# ShipMode                                     First Class
# CustomerId                                      NF-18385
# CustomerName                            Natalie Fritzler
# Segment                                         Consumer
# Country                                    United States
# City                                              Newark
# State                                               Ohio
# PostalCode                                         43055
# Region                                              East
# ProductId                                TEC-MA-10000418
# Category                                      Technology
# SubCategory                                     Machines
# ProductName    Cubify Cubex 3D Printer Double Head Print
# Sales                                            1799.99
# Quantity                                               2
# Discount                                             0.7
# Profit                                          -2639.99
# FirstName                                        Natalie
# LastName                                        Fritzler
# CatalogPrice                                     2999.99
# SupplierPrice                                    4319.99
# NewProductId                             TEC-MA-10006645
#
#                                                             5310  \
# PurchaseId                                        CA-2017-131254
# PurchaseDate                                 2017-11-19 00:00:00
# ShipDate                                     2017-11-21 00:00:00
# ShipMode                                             First Class
# CustomerId                                              NC-18415
# CustomerName                                         Nathan Cano
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Houston
# State                                                      Texas
# PostalCode                                                 77095
# Region                                                   Central
# ProductId                                        OFF-BI-10003527
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Fellowes Pb500 Electric Punch Plastic Comb Bin...
# Sales                                                    1525.19
# Quantity                                                       6
# Discount                                                     0.8
# Profit                                                  -2287.78
# FirstName                                                 Nathan
# LastName                                                    Cano
# CatalogPrice                                             1270.99
# SupplierPrice                                            1652.29
# NewProductId                                     OFF-BI-10005787
#
#                                                             9639  \
# PurchaseId                                        CA-2015-116638
# PurchaseDate                                 2015-01-28 00:00:00
# ShipDate                                     2015-01-31 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              JH-15985
# CustomerName                                         Joseph Holt
# Segment                                                 Consumer
# Country                                            United States
# City                                                     Concord
# State                                             North Carolina
# PostalCode                                                 28027
# Region                                                     South
# ProductId                                        FUR-TA-10000198
# Category                                               Furniture
# SubCategory                                               Tables
# ProductName    Chromcraft Bull-Nose Wood Oval Conference Tabl...
# Sales                                                    4297.64
# Quantity                                                      13
# Discount                                                     0.4
# Profit                                                  -1862.31
# FirstName                                                 Joseph
# LastName                                                    Holt
# CatalogPrice                                              550.98
# SupplierPrice                                             694.23
# NewProductId                                     FUR-TA-10005326
#
#                                                     1199  \
# PurchaseId                                CA-2016-130946
# PurchaseDate                         2016-04-08 00:00:00
# ShipDate                             2016-04-12 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      ZC-21910
# CustomerName                            Zuschuss Carroll
# Segment                                         Consumer
# Country                                    United States
# City                                             Houston
# State                                              Texas
# PostalCode                                         77041
# Region                                           Central
# ProductId                                OFF-BI-10004995
# Category                                 Office Supplies
# SubCategory                                      Binders
# ProductName    Gbc Docubind P400 Electric Binding System
# Sales                                            1088.79
# Quantity                                               4
# Discount                                             0.8
# Profit                                          -1850.95
# FirstName                                       Zuschuss
# LastName                                         Carroll
# CatalogPrice                                     1360.99
# SupplierPrice                                    1823.73
# NewProductId                             OFF-BI-10005858
#
#                                                             2697  \
# PurchaseId                                        CA-2014-145317
# PurchaseDate                                 2014-03-18 00:00:00
# ShipDate                                     2014-03-23 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              SM-20320
# CustomerName                                         Sean Miller
# Segment                                              Home Office
# Country                                            United States
# City                                                Jacksonville
# State                                                    Florida
# PostalCode                                                 32216
# Region                                                     South
# ProductId                                        TEC-MA-10002412
# Category                                              Technology
# SubCategory                                             Machines
# ProductName    Cisco Telepresence System Ex90 Videoconferenci...
# Sales                                                   22638.48
# Quantity                                                       6
# Discount                                                     0.5
# Profit                                                  -1811.08
# FirstName                                                   Sean
# LastName                                                  Miller
# CatalogPrice                                             7546.16
# SupplierPrice                                            7848.01
# NewProductId                                     TEC-MA-10006669
#
#                                                             27    \
# PurchaseId                                        US-2015-150630
# PurchaseDate                                 2015-09-17 00:00:00
# ShipDate                                     2015-09-21 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              TB-21520
# CustomerName                                     Tracy Blumstein
# Segment                                                 Consumer
# Country                                            United States
# City                                                Philadelphia
# State                                               Pennsylvania
# PostalCode                                                 19140
# Region                                                      East
# ProductId                                        FUR-BO-10004834
# Category                                               Furniture
# SubCategory                                            Bookcases
# ProductName    Riverside Palais Royal Lawyers Bookcase, Royal...
# Sales                                                    3083.43
# Quantity                                                       7
# Discount                                                     0.5
# Profit                                                  -1665.05
# FirstName                                                  Tracy
# LastName                                               Blumstein
# CatalogPrice                                              880.98
# SupplierPrice                                            1118.84
# NewProductId                                     FUR-BO-10005049
#
#                                                      3324  \
# PurchaseId                                 CA-2014-165309
# PurchaseDate                          2014-11-11 00:00:00
# ShipDate                              2014-11-15 00:00:00
# ShipMode                                   Standard Class
# CustomerId                                       KD-16270
# CustomerName                                Karen Daniels
# Segment                                          Consumer
# Country                                     United States
# City                                              Houston
# State                                               Texas
# PostalCode                                          77095
# Region                                            Central
# ProductId                                 OFF-BI-10001359
# Category                                  Office Supplies
# SubCategory                                       Binders
# ProductName    Gbc Docubind Tl300 Electric Binding System
# Sales                                              896.99
# Quantity                                                5
# Discount                                              0.8
# Profit                                           -1480.03
# FirstName                                           Karen
# LastName                                          Daniels
# CatalogPrice                                       896.99
# SupplierPrice                                      1193.0
# NewProductId                              OFF-BI-10005701
#
#                                                     165   \
# PurchaseId                                CA-2014-139892
# PurchaseDate                         2014-09-08 00:00:00
# ShipDate                             2014-09-12 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      BM-11140
# CustomerName                                Becky Martin
# Segment                                         Consumer
# Country                                    United States
# City                                         San Antonio
# State                                              Texas
# PostalCode                                         78207
# Region                                           Central
# ProductId                                TEC-MA-10000822
# Category                                      Technology
# SubCategory                                     Machines
# ProductName    Lexmark Mx611Dhe Monochrome Laser Printer
# Sales                                            8159.95
# Quantity                                               8
# Discount                                             0.4
# Profit                                          -1359.99
# FirstName                                          Becky
# LastName                                          Martin
# CatalogPrice                                     1699.99
# SupplierPrice                                    1869.99
# NewProductId                             TEC-MA-10006650
#
#                                                     2928  \
# PurchaseId                                US-2017-120390
# PurchaseDate                         2017-10-19 00:00:00
# ShipDate                             2017-10-26 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      TH-21550
# CustomerName                               Tracy Hopkins
# Segment                                      Home Office
# Country                                    United States
# City                                          Burlington
# State                                     North Carolina
# PostalCode                                         27217
# Region                                             South
# ProductId                                OFF-BI-10004995
# Category                                 Office Supplies
# SubCategory                                      Binders
# ProductName    Gbc Docubind P400 Electric Binding System
# Sales                                            1633.19
# Quantity                                               4
# Discount                                             0.7
# Profit                                          -1306.55
# FirstName                                          Tracy
# LastName                                         Hopkins
# CatalogPrice                                     1360.99
# SupplierPrice                                    1687.63
# NewProductId                             OFF-BI-10005858
#
#                                                      7898  \
# PurchaseId                                 CA-2017-128363
# PurchaseDate                          2017-08-13 00:00:00
# ShipDate                              2017-08-18 00:00:00
# ShipMode                                   Standard Class
# CustomerId                                       DC-12850
# CustomerName                                 Dan Campbell
# Segment                                          Consumer
# Country                                     United States
# City                                              Memphis
# State                                           Tennessee
# PostalCode                                          38109
# Region                                              South
# ProductId                                 OFF-BI-10001359
# Category                                  Office Supplies
# SubCategory                                       Binders
# ProductName    Gbc Docubind Tl300 Electric Binding System
# Sales                                             1614.58
# Quantity                                                6
# Discount                                              0.7
# Profit                                           -1237.85
# FirstName                                             Dan
# LastName                                         Campbell
# CatalogPrice                                       896.99
# SupplierPrice                                      1103.3
# NewProductId                              OFF-BI-10005701
#
#                                               4820  \
# PurchaseId                          CA-2015-140025
# PurchaseDate                   2015-04-07 00:00:00
# ShipDate                       2015-04-11 00:00:00
# ShipMode                            Standard Class
# CustomerId                                PF-19120
# CustomerName                          Peter Fuller
# Segment                                   Consumer
# Country                              United States
# City                                   San Antonio
# State                                        Texas
# PostalCode                                   78207
# Region                                     Central
# ProductId                          OFF-AP-10002651
# Category                           Office Supplies
# SubCategory                             Appliances
# ProductName    Hoover Upright Vacuum With Dirt Cup
# Sales                                       463.25
# Quantity                                         8
# Discount                                       0.8
# Profit                                    -1181.28
# FirstName                                    Peter
# LastName                                    Fuller
# CatalogPrice                                289.53
# SupplierPrice                               437.19
# NewProductId                       OFF-AP-10005440
#
#                                                             2846  \
# PurchaseId                                        CA-2017-152093
# PurchaseDate                                 2017-09-10 00:00:00
# ShipDate                                     2017-09-15 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              SN-20560
# CustomerName                                        Skye Norling
# Segment                                              Home Office
# Country                                            United States
# City                                                     Chicago
# State                                                   Illinois
# PostalCode                                                 60653
# Region                                                   Central
# ProductId                                        OFF-BI-10003527
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Fellowes Pb500 Electric Punch Plastic Comb Bin...
# Sales                                                     762.59
# Quantity                                                       3
# Discount                                                     0.8
# Profit                                                  -1143.89
# FirstName                                                   Skye
# LastName                                                 Norling
# CatalogPrice                                             1270.99
# SupplierPrice                                            1652.29
# NewProductId                                     OFF-BI-10005787
#
#                                                            8640  \
# PurchaseId                                       US-2017-148551
# PurchaseDate                                2017-01-12 00:00:00
# ShipDate                                    2017-01-16 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             DB-13120
# CustomerName                                       David Bremer
# Segment                                               Corporate
# Country                                           United States
# City                                                     Dallas
# State                                                     Texas
# PostalCode                                                75217
# Region                                                  Central
# ProductId                                       OFF-BI-10000545
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName    Gbc Ibimaster 500 Manual Proclick Binding System
# Sales                                                    760.98
# Quantity                                                      5
# Discount                                                    0.8
# Profit                                                 -1141.47
# FirstName                                                 David
# LastName                                                 Bremer
# CatalogPrice                                             760.98
# SupplierPrice                                            989.27
# NewProductId                                    OFF-BI-10005667
#
#                                                            4355  \
# PurchaseId                                       CA-2015-155600
# PurchaseDate                                2015-12-04 00:00:00
# ShipDate                                    2015-12-07 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             RO-19780
# CustomerName                                       Rose O'Brian
# Segment                                                Consumer
# Country                                           United States
# City                                                Clarksville
# State                                                 Tennessee
# PostalCode                                                37042
# Region                                                    South
# ProductId                                       OFF-BI-10000545
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName    Gbc Ibimaster 500 Manual Proclick Binding System
# Sales                                                   1598.06
# Quantity                                                      7
# Discount                                                    0.7
# Profit                                                 -1065.37
# FirstName                                                  Rose
# LastName                                                O'Brian
# CatalogPrice                                             760.98
# SupplierPrice                                            913.18
# NewProductId                                    OFF-BI-10005667
#
#                                                             1803
# PurchaseId                                        CA-2017-158379
# PurchaseDate                                 2017-09-22 00:00:00
# ShipDate                                     2017-09-26 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              JA-15970
# CustomerName                                        Joseph Airdo
# Segment                                                 Consumer
# Country                                            United States
# City                                                Philadelphia
# State                                               Pennsylvania
# PostalCode                                                 19134
# Region                                                      East
# ProductId                                        OFF-SU-10002881
# Category                                         Office Supplies
# SubCategory                                             Supplies
# ProductName    Martin Yale Chadless Opener Electric Letter Op...
# Sales                                                    4663.74
# Quantity                                                       7
# Discount                                                     0.2
# Profit                                                  -1049.34
# FirstName                                                 Joseph
# LastName                                                   Airdo
# CatalogPrice                                              832.81
# SupplierPrice                                             982.72
# NewProductId                                     OFF-SU-10006465

# %% [markdown]
# ### The highest and lowest values in the Payment, Quantity, Discount, and Profit columns have been reviewed.
# ### No inconsistencies were detected in these columns

# %%
# Create the new DataFrame with SupplierPrice higher than CatalogPrice 

minus_sale_df = df[df['SupplierPrice'] > df['CatalogPrice']]
minus_sale_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1871 entries, 3 to 9962
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PurchaseId     1871 non-null   object
#  1   PurchaseDate   1871 non-null   datetime64[ns]
#  2   ShipDate       1871 non-null   datetime64[ns]
#  3   ShipMode       1871 non-null   object
#  4   CustomerId     1871 non-null   object
#  5   CustomerName   1871 non-null   object
#  6   Segment        1871 non-null   object
#  7   Country        1871 non-null   object
#  8   City           1871 non-null   object
#  9   State          1871 non-null   object
#  10  PostalCode     1871 non-null   object
#  11  Region         1871 non-null   object
#  12  ProductId      1871 non-null   object
#  13  Category       1871 non-null   object
#  14  SubCategory    1871 non-null   object
#  15  ProductName    1871 non-null   object
#  16  Sales          1871 non-null   float64
#  17  Quantity       1871 non-null   int32
#  18  Discount       1871 non-null   float64
#  19  Profit         1871 non-null   float64
#  20  FirstName      1871 non-null   object
#  21  LastName       1871 non-null   object
#  22  CatalogPrice   1871 non-null   float64
#  23  SupplierPrice  1871 non-null   float64
#  24  NewProductId   1871 non-null   object
# dtypes: datetime64[ns](2), float64(5), int32(1), object(17)
# memory usage: 372.7+ KB

# %%
minus_sale_df.describe()
# Out:
#                         PurchaseDate                       ShipDate  \
# count                           1871                           1871
# mean   2016-04-27 03:02:24.307856896  2016-05-01 02:22:23.025120256
# min              2014-01-04 00:00:00            2014-01-08 00:00:00
# 25%              2015-05-10 00:00:00            2015-05-13 12:00:00
# 50%              2016-06-12 00:00:00            2016-06-17 00:00:00
# 75%              2017-05-05 12:00:00            2017-05-10 00:00:00
# max              2017-12-30 00:00:00            2018-01-03 00:00:00
# std                              NaN                            NaN
#
#               Sales     Quantity     Discount       Profit  CatalogPrice  \
# count   1871.000000  1871.000000  1871.000000  1871.000000   1871.000000
# mean     250.511513     3.762694     0.480887   -83.448231    116.873030
# min        0.440000     1.000000     0.100000 -6599.980000      1.260000
# 25%       12.500000     2.000000     0.200000   -58.660000     11.490000
# 50%       71.090000     3.000000     0.400000   -18.090000     44.430000
# 75%      284.920000     5.000000     0.700000    -6.265000    135.650000
# max    22638.480000    14.000000     0.800000    -0.090000   7546.160000
# std      715.067234     2.141347     0.235080   284.423355    279.409746
#
#        SupplierPrice
# count    1871.000000
# mean      138.169220
# min         1.460000
# 25%        14.380000
# 50%        54.340000
# 75%       157.290000
# max      7848.010000
# std       330.443249

# %%
minus_sale_df.head()
# Out:
#         PurchaseId PurchaseDate   ShipDate        ShipMode CustomerId  \
# 3   US-2015-108966   2015-10-11 2015-10-18  Standard Class   SO-20335
# 14  US-2015-118983   2015-11-22 2015-11-26  Standard Class   HP-14815
# 15  US-2015-118983   2015-11-22 2015-11-26  Standard Class   HP-14815
# 23  US-2017-156909   2017-07-16 2017-07-18    Second Class   SF-20065
# 27  US-2015-150630   2015-09-17 2015-09-21  Standard Class   TB-21520
#
#        CustomerName      Segment        Country             City  \
# 3    Sean O'Donnell     Consumer  United States  Fort Lauderdale
# 14    Harold Pawlan  Home Office  United States       Fort Worth
# 15    Harold Pawlan  Home Office  United States       Fort Worth
# 23  Sandra Flanagan     Consumer  United States     Philadelphia
# 27  Tracy Blumstein     Consumer  United States     Philadelphia
#
#            State PostalCode   Region        ProductId         Category  \
# 3        Florida      33311    South  FUR-TA-10000577        Furniture
# 14         Texas      76106  Central  OFF-AP-10002311  Office Supplies
# 15         Texas      76106  Central  OFF-BI-10000756  Office Supplies
# 23  Pennsylvania      19140     East  FUR-CH-10002774        Furniture
# 27  Pennsylvania      19140     East  FUR-BO-10004834        Furniture
#
#    SubCategory                                        ProductName    Sales  \
# 3       Tables      Bretford Cr4500 Series Slim Rectangular Table   957.58
# 14  Appliances  Holmes Replacement Filter For Hepa Air Cleaner...    68.81
# 15     Binders   Storex Duratech Recycled Plastic Frosted Binders     2.54
# 23      Chairs                 Global Deluxe Stacking Chair, Gray    71.37
# 27   Bookcases  Riverside Palais Royal Lawyers Bookcase, Royal...  3083.43
#
#     Quantity  Discount   Profit FirstName   LastName  CatalogPrice  \
# 3          5      0.45  -383.03      Sean  O'Donnell        348.21
# 14         5      0.80  -123.86    Harold     Pawlan         68.81
# 15         3      0.80    -3.82    Harold     Pawlan          4.24
# 23         2      0.30    -1.02    Sandra   Flanagan         50.98
# 27         7      0.50 -1665.05     Tracy  Blumstein        880.98
#
#     SupplierPrice     NewProductId
# 3          424.82  FUR-TA-10005327
# 14          93.58  OFF-AP-10005430
# 15           5.51  OFF-BI-10005673
# 23          51.49  FUR-CH-10005097
# 27        1118.84  FUR-BO-10005049

# %% [markdown]
# ### there are 1871 sales  in DF which causes loss, will be reviewed in next steps to find the reason of it

# %% [markdown]
# ## 21: Check if columns create unique pairs <a id="21"></a>

# %%
df.rename(columns={'ProductId': 'OldProductId'}, inplace=True)


df.rename(columns={'NewProductId': 'ProductId'}, inplace=True)

# %%
df.columns
# Out:
# Index(['PurchaseId', 'PurchaseDate', 'ShipDate', 'ShipMode', 'CustomerId',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'OldProductId', 'Category', 'SubCategory', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'FirstName', 'LastName',
#        'CatalogPrice', 'SupplierPrice', 'ProductId'],
#       dtype='object')

# %%
# Identify rows where the combination of PurchaseId and ProductId is duplicated

duplicates = df[df.duplicated(subset=['PurchaseId', 'ProductId'], keep=False)]

duplicates.head(30).T
# Out:
#                               350                  352   \
# PurchaseId          CA-2016-129714       CA-2016-129714
# PurchaseDate   2016-09-01 00:00:00  2016-09-01 00:00:00
# ShipDate       2016-09-03 00:00:00  2016-09-03 00:00:00
# ShipMode               First Class          First Class
# CustomerId                AB-10060             AB-10060
# CustomerName       Adam Bellavance      Adam Bellavance
# Segment                Home Office          Home Office
# Country              United States        United States
# City                 New York City        New York City
# State                     New York             New York
# PostalCode                   10009                10009
# Region                        East                 East
# OldProductId       OFF-PA-10001970      OFF-PA-10001970
# Category           Office Supplies      Office Supplies
# SubCategory                  Paper                Paper
# ProductName             Xerox 1881           Xerox 1881
# Sales                        24.56                49.12
# Quantity                         2                    4
# Discount                       0.0                  0.0
# Profit                       11.54                23.09
# FirstName                     Adam                 Adam
# LastName                Bellavance           Bellavance
# CatalogPrice                 12.28                12.28
# SupplierPrice                 6.51                 6.51
# ProductId          OFF-PA-10006161      OFF-PA-10006161
#
#                                                             430   \
# PurchaseId                                        US-2016-123750
# PurchaseDate                                 2016-04-15 00:00:00
# ShipDate                                     2016-04-21 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              RB-19795
# CustomerName                                          Ross Baird
# Segment                                              Home Office
# Country                                            United States
# City                                                    Gastonia
# State                                             North Carolina
# PostalCode                                                 28052
# Region                                                     South
# OldProductId                                     TEC-AC-10004659
# Category                                              Technology
# SubCategory                                          Accessories
# ProductName    Imation Secure+ Hardware Encrypted Usb 2.0 Fla...
# Sales                                                     408.74
# Quantity                                                       7
# Discount                                                     0.2
# Profit                                                     76.64
# FirstName                                                   Ross
# LastName                                                   Baird
# CatalogPrice                                               72.99
# SupplierPrice                                              62.04
# ProductId                                        TEC-AC-10006615
#
#                                                             431   \
# PurchaseId                                        US-2016-123750
# PurchaseDate                                 2016-04-15 00:00:00
# ShipDate                                     2016-04-21 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              RB-19795
# CustomerName                                          Ross Baird
# Segment                                              Home Office
# Country                                            United States
# City                                                    Gastonia
# State                                             North Carolina
# PostalCode                                                 28052
# Region                                                     South
# OldProductId                                     TEC-AC-10004659
# Category                                              Technology
# SubCategory                                          Accessories
# ProductName    Imation Secure+ Hardware Encrypted Usb 2.0 Fla...
# Sales                                                     291.96
# Quantity                                                       5
# Discount                                                     0.2
# Profit                                                     54.74
# FirstName                                                   Ross
# LastName                                                   Baird
# CatalogPrice                                               72.99
# SupplierPrice                                              62.04
# ProductId                                        TEC-AC-10006615
#
#                                                             1300  \
# PurchaseId                                        CA-2016-137043
# PurchaseDate                                 2016-12-23 00:00:00
# ShipDate                                     2016-12-25 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              LC-17140
# CustomerName                                        Logan Currie
# Segment                                                 Consumer
# Country                                            United States
# City                                                 Springfield
# State                                                   Virginia
# PostalCode                                                 22153
# Region                                                     South
# OldProductId                                     FUR-FU-10003664
# Category                                               Furniture
# SubCategory                                          Furnishings
# ProductName    Electrix Architect'S Clamp-On Swing Arm Lamp, ...
# Sales                                                     572.76
# Quantity                                                       6
# Discount                                                     0.0
# Profit                                                     166.1
# FirstName                                                  Logan
# LastName                                                  Currie
# CatalogPrice                                               95.46
# SupplierPrice                                              67.78
# ProductId                                        FUR-FU-10005268
#
#                                                             1301  \
# PurchaseId                                        CA-2016-137043
# PurchaseDate                                 2016-12-23 00:00:00
# ShipDate                                     2016-12-25 00:00:00
# ShipMode                                            Second Class
# CustomerId                                              LC-17140
# CustomerName                                        Logan Currie
# Segment                                                 Consumer
# Country                                            United States
# City                                                 Springfield
# State                                                   Virginia
# PostalCode                                                 22153
# Region                                                     South
# OldProductId                                     FUR-FU-10003664
# Category                                               Furniture
# SubCategory                                          Furnishings
# ProductName    Electrix Architect'S Clamp-On Swing Arm Lamp, ...
# Sales                                                     286.38
# Quantity                                                       3
# Discount                                                     0.0
# Profit                                                     83.05
# FirstName                                                  Logan
# LastName                                                  Currie
# CatalogPrice                                               95.46
# SupplierPrice                                              67.78
# ProductId                                        FUR-FU-10005268
#
#                                              3183  \
# PurchaseId                         CA-2017-152912
# PurchaseDate                  2017-11-09 00:00:00
# ShipDate                      2017-11-12 00:00:00
# ShipMode                             Second Class
# CustomerId                               BM-11650
# CustomerName                           Brian Moss
# Segment                                 Corporate
# Country                             United States
# City                                     Columbia
# State                                    Maryland
# PostalCode                                  21044
# Region                                       East
# OldProductId                      OFF-ST-10003208
# Category                          Office Supplies
# SubCategory                               Storage
# ProductName    Adjustable Depth Letter/Legal Cart
# Sales                                     1633.14
# Quantity                                        9
# Discount                                      0.0
# Profit                                     473.61
# FirstName                                   Brian
# LastName                                     Moss
# CatalogPrice                               181.46
# SupplierPrice                              128.84
# ProductId                         OFF-ST-10006407
#
#                                              3184  \
# PurchaseId                         CA-2017-152912
# PurchaseDate                  2017-11-09 00:00:00
# ShipDate                      2017-11-12 00:00:00
# ShipMode                             Second Class
# CustomerId                               BM-11650
# CustomerName                           Brian Moss
# Segment                                 Corporate
# Country                             United States
# City                                     Columbia
# State                                    Maryland
# PostalCode                                  21044
# Region                                       East
# OldProductId                      OFF-ST-10003208
# Category                          Office Supplies
# SubCategory                               Storage
# ProductName    Adjustable Depth Letter/Legal Cart
# Sales                                      544.38
# Quantity                                        3
# Discount                                      0.0
# Profit                                     157.87
# FirstName                                   Brian
# LastName                                     Moss
# CatalogPrice                               181.46
# SupplierPrice                              128.84
# ProductId                         OFF-ST-10006407
#
#                                                             3405  \
# PurchaseId                                        US-2014-150119
# PurchaseDate                                 2014-04-23 00:00:00
# ShipDate                                     2014-04-27 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              LB-16795
# CustomerName                                      Laurel Beltran
# Segment                                              Home Office
# Country                                            United States
# City                                                    Columbus
# State                                                       Ohio
# PostalCode                                                 43229
# Region                                                      East
# OldProductId                                     FUR-CH-10002965
# Category                                               Furniture
# SubCategory                                               Chairs
# ProductName    Global Leather Highback Executive Chair With P...
# Sales                                                     281.37
# Quantity                                                       2
# Discount                                                     0.3
# Profit                                                    -12.06
# FirstName                                                 Laurel
# LastName                                                 Beltran
# CatalogPrice                                              200.98
# SupplierPrice                                             207.01
# ProductId                                        FUR-CH-10005101
#
#                                                             3406  \
# PurchaseId                                        US-2014-150119
# PurchaseDate                                 2014-04-23 00:00:00
# ShipDate                                     2014-04-27 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              LB-16795
# CustomerName                                      Laurel Beltran
# Segment                                              Home Office
# Country                                            United States
# City                                                    Columbus
# State                                                       Ohio
# PostalCode                                                 43229
# Region                                                      East
# OldProductId                                     FUR-CH-10002965
# Category                                               Furniture
# SubCategory                                               Chairs
# ProductName    Global Leather Highback Executive Chair With P...
# Sales                                                     281.37
# Quantity                                                       2
# Discount                                                     0.3
# Profit                                                    -12.06
# FirstName                                                 Laurel
# LastName                                                 Beltran
# CatalogPrice                                              200.98
# SupplierPrice                                             207.01
# ProductId                                        FUR-CH-10005101
#
#                                                             6498  \
# PurchaseId                                        CA-2015-103135
# PurchaseDate                                 2015-07-24 00:00:00
# ShipDate                                     2015-07-28 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              SS-20515
# CustomerName                                     Shirley Schmidt
# Segment                                              Home Office
# Country                                            United States
# City                                                  Louisville
# State                                                   Kentucky
# PostalCode                                                 40214
# Region                                                     South
# OldProductId                                     OFF-BI-10000069
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Gbc Prepunched Paper, 19-Hole, For Binding Sys...
# Sales                                                     135.09
# Quantity                                                       9
# Discount                                                     0.0
# Profit                                                     62.14
# FirstName                                                Shirley
# LastName                                                 Schmidt
# CatalogPrice                                               15.01
# SupplierPrice                                               8.11
# ProductId                                        OFF-BI-10005649
#
#                                                             6500  \
# PurchaseId                                        CA-2015-103135
# PurchaseDate                                 2015-07-24 00:00:00
# ShipDate                                     2015-07-28 00:00:00
# ShipMode                                          Standard Class
# CustomerId                                              SS-20515
# CustomerName                                     Shirley Schmidt
# Segment                                              Home Office
# Country                                            United States
# City                                                  Louisville
# State                                                   Kentucky
# PostalCode                                                 40214
# Region                                                     South
# OldProductId                                     OFF-BI-10000069
# Category                                         Office Supplies
# SubCategory                                              Binders
# ProductName    Gbc Prepunched Paper, 19-Hole, For Binding Sys...
# Sales                                                      90.06
# Quantity                                                       6
# Discount                                                     0.0
# Profit                                                     41.43
# FirstName                                                Shirley
# LastName                                                 Schmidt
# CatalogPrice                                               15.01
# SupplierPrice                                               8.11
# ProductId                                        OFF-BI-10005649
#
#                                            7881  \
# PurchaseId                       CA-2017-118017
# PurchaseDate                2017-12-03 00:00:00
# ShipDate                    2017-12-06 00:00:00
# ShipMode                           Second Class
# CustomerId                             LC-16870
# CustomerName                      Lena Cacioppo
# Segment                                Consumer
# Country                           United States
# City                                   Thornton
# State                                  Colorado
# PostalCode                                80229
# Region                                     West
# OldProductId                    TEC-AC-10002006
# Category                             Technology
# SubCategory                         Accessories
# ProductName    Memorex Micro Travel Drive 16 Gb
# Sales                                     76.75
# Quantity                                      6
# Discount                                    0.2
# Profit                                    10.55
# FirstName                                  Lena
# LastName                               Cacioppo
# CatalogPrice                              15.99
# SupplierPrice                             14.23
# ProductId                       TEC-AC-10006538
#
#                                            7882                 9168  \
# PurchaseId                       CA-2017-118017       CA-2016-140571
# PurchaseDate                2017-12-03 00:00:00  2016-03-15 00:00:00
# ShipDate                    2017-12-06 00:00:00  2016-03-19 00:00:00
# ShipMode                           Second Class       Standard Class
# CustomerId                             LC-16870             SJ-20125
# CustomerName                      Lena Cacioppo        Sanjit Jacobs
# Segment                                Consumer          Home Office
# Country                           United States        United States
# City                                   Thornton              Jackson
# State                                  Colorado          Mississippi
# PostalCode                                80229                39212
# Region                                     West                South
# OldProductId                    TEC-AC-10002006      OFF-PA-10001954
# Category                             Technology      Office Supplies
# SubCategory                         Accessories                Paper
# ProductName    Memorex Micro Travel Drive 16 Gb           Xerox 1964
# Sales                                    102.34               319.76
# Quantity                                      8                   14
# Discount                                    0.2                  0.0
# Profit                                    14.07               147.09
# FirstName                                  Lena               Sanjit
# LastName                               Cacioppo               Jacobs
# CatalogPrice                              15.99                22.84
# SupplierPrice                             14.23                12.33
# ProductId                       TEC-AC-10006538      OFF-PA-10006160
#
#                               9169
# PurchaseId          CA-2016-140571
# PurchaseDate   2016-03-15 00:00:00
# ShipDate       2016-03-19 00:00:00
# ShipMode            Standard Class
# CustomerId                SJ-20125
# CustomerName         Sanjit Jacobs
# Segment                Home Office
# Country              United States
# City                       Jackson
# State                  Mississippi
# PostalCode                   39212
# Region                       South
# OldProductId       OFF-PA-10001954
# Category           Office Supplies
# SubCategory                  Paper
# ProductName             Xerox 1964
# Sales                        45.68
# Quantity                         2
# Discount                       0.0
# Profit                       21.01
# FirstName                   Sanjit
# LastName                    Jacobs
# CatalogPrice                 22.84
# SupplierPrice                12.33
# ProductId          OFF-PA-10006160

# %%
duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 350 to 9169
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PurchaseId     16 non-null     object
#  1   PurchaseDate   16 non-null     datetime64[ns]
#  2   ShipDate       16 non-null     datetime64[ns]
#  3   ShipMode       16 non-null     object
#  4   CustomerId     16 non-null     object
#  5   CustomerName   16 non-null     object
#  6   Segment        16 non-null     object
#  7   Country        16 non-null     object
#  8   City           16 non-null     object
#  9   State          16 non-null     object
#  10  PostalCode     16 non-null     object
#  11  Region         16 non-null     object
#  12  OldProductId   16 non-null     object
#  13  Category       16 non-null     object
#  14  SubCategory    16 non-null     object
#  15  ProductName    16 non-null     object
#  16  Sales          16 non-null     float64
#  17  Quantity       16 non-null     int32
#  18  Discount       16 non-null     float64
#  19  Profit         16 non-null     float64
#  20  FirstName      16 non-null     object
#  21  LastName       16 non-null     object
#  22  CatalogPrice   16 non-null     float64
#  23  SupplierPrice  16 non-null     float64
#  24  ProductId      16 non-null     object
# dtypes: datetime64[ns](2), float64(5), int32(1), object(17)
# memory usage: 3.2+ KB

# %%
df[(df['PurchaseId'] == 'CA-2016-137043') & (df['ProductId'] == 'FUR-FU-10005268')]
# Out:
#           PurchaseId PurchaseDate   ShipDate      ShipMode CustomerId  \
# 1300  CA-2016-137043   2016-12-23 2016-12-25  Second Class   LC-17140
# 1301  CA-2016-137043   2016-12-23 2016-12-25  Second Class   LC-17140
#
#       CustomerName   Segment        Country         City     State PostalCode  \
# 1300  Logan Currie  Consumer  United States  Springfield  Virginia      22153
# 1301  Logan Currie  Consumer  United States  Springfield  Virginia      22153
#
#      Region     OldProductId   Category  SubCategory  \
# 1300  South  FUR-FU-10003664  Furniture  Furnishings
# 1301  South  FUR-FU-10003664  Furniture  Furnishings
#
#                                             ProductName   Sales  Quantity  \
# 1300  Electrix Architect'S Clamp-On Swing Arm Lamp, ...  572.76         6
# 1301  Electrix Architect'S Clamp-On Swing Arm Lamp, ...  286.38         3
#
#       Discount  Profit FirstName LastName  CatalogPrice  SupplierPrice  \
# 1300       0.0  166.10     Logan   Currie         95.46          67.78
# 1301       0.0   83.05     Logan   Currie         95.46          67.78
#
#             ProductId
# 1300  FUR-FU-10005268
# 1301  FUR-FU-10005268

# %% [markdown]
# #### we have 16 duplicated entries for PurchaseId - ProductId pairs in df
# #### Duplicate pairs have same PurchaseId, ProductId, PurchaseDate, Discount and almost all other columns except Payment and Quantity columns.
# #### They may have been calculated or added to Order after main order but these values share same PurchaseId-ProductId pair, which may cause error to use PurchaseId-ProductId as composite PK
# #### We will sum the Payment and Quantity columns values in 1 row and delete the other to avoid duplicated PK values for PruchaseDetail table

# %%
# List of index pairs to process
index_pairs = [
    (350, 352),
    (430, 431),
    (1300, 1301),
    (3183, 3184),
    (3405, 3406),
    (6498, 6500),
    (7881, 7882),
    (9168, 9169)
]

# Ensure indices are in descending order for proper processing
index_pairs = sorted(index_pairs, reverse=True)

# Process each pair of indices
for idx1, idx2 in index_pairs:
    if idx1 in df.index and idx2 in df.index:
        # Extract values
        row_1 = df.loc[idx1]
        row_2 = df.loc[idx2]
        
        # Update the second row with the values from the first row
        df.at[idx2, 'Quantity'] += row_1['Quantity']
        df.at[idx2, 'Sales'] += row_1['Sales']
        
        # Drop the first row
        df = df.drop(idx1)

# %%
df[(df['PurchaseId'] == 'CA-2016-137043') & (df['ProductId'] == 'FUR-FU-10005268')]
# Out:
#           PurchaseId PurchaseDate   ShipDate      ShipMode CustomerId  \
# 1301  CA-2016-137043   2016-12-23 2016-12-25  Second Class   LC-17140
#
#       CustomerName   Segment        Country         City     State PostalCode  \
# 1301  Logan Currie  Consumer  United States  Springfield  Virginia      22153
#
#      Region     OldProductId   Category  SubCategory  \
# 1301  South  FUR-FU-10003664  Furniture  Furnishings
#
#                                             ProductName   Sales  Quantity  \
# 1301  Electrix Architect'S Clamp-On Swing Arm Lamp, ...  859.14         9
#
#       Discount  Profit FirstName LastName  CatalogPrice  SupplierPrice  \
# 1301       0.0   83.05     Logan   Currie         95.46          67.78
#
#             ProductId
# 1301  FUR-FU-10005268

# %%
# Confirm changes 

# Identify rows where the combination of PurchaseId and ProductId is duplicated

duplicates = df[df.duplicated(subset=['PurchaseId', 'ProductId'], keep=False)]

duplicates.head()
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, OldProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit, FirstName, LastName, CatalogPrice, SupplierPrice, ProductId]
# Index: []

# %% [markdown]
# ## 22: Create Data Frames from SQLite tables <a id="22"></a>

# %%
# PurchaseDetail DataFrame

df_PurchaseDetail = df[['PurchaseId', 'ProductId', 'Quantity', 'Sales', 'Discount', 'Profit', 'ShipDate', 'ShipMode']]
df_PurchaseDetail = df_PurchaseDetail.sort_values(by=['PurchaseId', 'ProductId'], ascending=[False, True])

# df_Purchase DataFrame - Group by PurchaseId
df_Purchase = df.groupby('PurchaseId').first().reset_index()[['PurchaseId', 'CustomerId', 'PurchaseDate']]

# Sort by PurchaseDate (latest first) and CustomerId
df_Purchase = df_Purchase.sort_values(by=['PurchaseDate', 'CustomerId'], ascending=[False, True])

# df_Customer DataFrame - Group by CustomerId

df_Customer = df.groupby('CustomerId').first().reset_index()[['CustomerId', 'FirstName', 'LastName', 'Segment']]
df_Customer = df_Customer.sort_values(by=['CustomerId', 'LastName', 'FirstName'])

# Drop duplicates to get each unique pair of CustomerId and PostalCode

df_CustomerLocation = df.drop_duplicates(subset=['CustomerId', 'PostalCode'], keep='first')[['CustomerId', 'PostalCode', 'City', 'Region', 'State', 'Country']]
df_CustomerLocation = df_CustomerLocation.sort_values(by=['CustomerId', 'PostalCode'])

# Drop duplicates to get the unique pair of ProductId and SubCategory

df_Category = df.drop_duplicates(subset=['ProductId', 'SubCategory'], keep='first')[['ProductId', 'Category', 'SubCategory']]
df_Category = df_Category.sort_values(by=['ProductId', 'SubCategory'])

# df_Product DataFrame - Use most recent values for CatalogPrice and SupplierPrice
# Group by ProductId and PurchaseDate to get the latest rows based on PurchaseDate

df_Product = df.groupby('ProductId').apply(lambda x: x.sort_values('PurchaseDate').iloc[-1]).reset_index(drop=True)[['ProductId', 'ProductName', 'CatalogPrice', 'SupplierPrice']]
df_Product = df_Product.sort_values(by=['ProductId', 'ProductName'])

# %%
df_PurchaseDetail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9986 entries, 5929 to 2717
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PurchaseId  9986 non-null   object
#  1   ProductId   9986 non-null   object
#  2   Quantity    9986 non-null   int32
#  3   Sales       9986 non-null   float64
#  4   Discount    9986 non-null   float64
#  5   Profit      9986 non-null   float64
#  6   ShipDate    9986 non-null   datetime64[ns]
#  7   ShipMode    9986 non-null   object
# dtypes: datetime64[ns](1), float64(3), int32(1), object(3)
# memory usage: 663.1+ KB

# %%
df_Purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5009 entries, 3328 to 56
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    5009 non-null   object
#  1   CustomerId    5009 non-null   object
#  2   PurchaseDate  5009 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 156.5+ KB

# %%
df_Customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerId  793 non-null    object
#  1   FirstName   793 non-null    object
#  2   LastName    793 non-null    object
#  3   Segment     793 non-null    object
# dtypes: object(4)
# memory usage: 24.9+ KB

# %%
df_CustomerLocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4910 entries, 7468 to 18
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerId  4910 non-null   object
#  1   PostalCode  4910 non-null   object
#  2   City        4910 non-null   object
#  3   Region      4910 non-null   object
#  4   State       4910 non-null   object
#  5   Country     4910 non-null   object
# dtypes: object(6)
# memory usage: 268.5+ KB

# %%
df_Product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1894 entries, 0 to 1893
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProductId      1894 non-null   object
#  1   ProductName    1894 non-null   object
#  2   CatalogPrice   1894 non-null   float64
#  3   SupplierPrice  1894 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 59.3+ KB

# %%
df_Category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1894 entries, 3512 to 35
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductId    1894 non-null   object
#  1   Category     1894 non-null   object
#  2   SubCategory  1894 non-null   object
# dtypes: object(3)
# memory usage: 59.2+ KB

# %% [markdown]
# ## 23: CustomerLocation and CustomerId Distribution <a id="23"></a>

# %% [markdown]
# #### check the ratio between CustomerLocation and CustomerId counts. It shows that each customer has averagly almost 7 different locations.

# %%
unique_pairs = df[['PostalCode', 'CustomerId']].drop_duplicates()

unique_pairs = unique_pairs.sort_values(by='CustomerId')

# %%
unique_pairs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4910 entries, 1159 to 8341
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PostalCode  4910 non-null   object
#  1   CustomerId  4910 non-null   object
# dtypes: object(2)
# memory usage: 115.1+ KB

# %%
unique_pairs.value_counts('CustomerId')
# Out:
# CustomerId
# EP-13915    17
# JE-15745    13
# ZC-21910    13
# EA-14035    13
# SH-19975    13
#             ..
# RM-19750     1
# JR-15700     1
# HH-15010     1
# TC-21145     1
# MG-18205     1
# Name: count, Length: 793, dtype: int64

# %% [markdown]
# ### It may be about the business model, it is true that each Customer has averagely 7 different Postcodes, which means minimum 7 different locations.

# %% [markdown]
# ## 24: Create and Populate Tables <a id="24"></a>

# %%
# before populating data to tables, create a new df to see total reveneu of each customer which we will use for ML Clustering with K-means 

df_monetary = df.groupby('CustomerId', as_index=False)['Sales'].sum()
df_monetary.head()
# Out:
#   CustomerId    Sales
# 0   AA-10315  5563.56
# 1   AA-10375  1056.39
# 2   AA-10480  1790.51
# 3   AA-10645  5086.93
# 4   AB-10015   886.15

# %%
# Create new attribute: Recency
# Compute Max Date to detect last transaction 

max_date = max(df['PurchaseDate'])
max_date
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
df['Diff'] = max_date - df['PurchaseDate']

df.head()
# Out:
#        PurchaseId PurchaseDate   ShipDate        ShipMode CustomerId  \
# 0  CA-2016-152156   2016-11-08 2016-11-11    Second Class   CG-12520
# 1  CA-2016-152156   2016-11-08 2016-11-11    Second Class   CG-12520
# 2  CA-2016-138688   2016-06-12 2016-06-16    Second Class   DV-13045
# 3  US-2015-108966   2015-10-11 2015-10-18  Standard Class   SO-20335
# 4  US-2015-108966   2015-10-11 2015-10-18  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#   PostalCode Region     OldProductId         Category SubCategory  \
# 0      42420  South  FUR-BO-10001798        Furniture   Bookcases
# 1      42420  South  FUR-CH-10000454        Furniture      Chairs
# 2      90036   West  OFF-LA-10000240  Office Supplies      Labels
# 3      33311  South  FUR-TA-10000577        Furniture      Tables
# 4      33311  South  OFF-ST-10000760  Office Supplies     Storage
#
#                                          ProductName   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94         3
# 2  Self-Adhesive Address Labels For Typewriters B...   14.62         2
# 3      Bretford Cr4500 Series Slim Rectangular Table  957.58         5
# 4                     Eldon Fold 'N Roll Cart System   22.37         2
#
#    Discount  Profit FirstName   LastName  CatalogPrice  SupplierPrice  \
# 0      0.00   41.91    Claire       Gute        130.98         110.02
# 1      0.00  219.58    Claire       Gute        243.98         170.79
# 2      0.00    6.87    Darrin   Van Huff          7.31           3.87
# 3      0.45 -383.03      Sean  O'Donnell        348.21         424.82
# 4      0.20    2.52      Sean  O'Donnell         13.98          12.72
#
#          ProductId     Diff
# 0  FUR-BO-10005012 417 days
# 1  FUR-CH-10005056 417 days
# 2  OFF-LA-10005959 566 days
# 3  FUR-TA-10005327 811 days
# 4  OFF-ST-10006337 811 days

# %%
# Convert 'Diff' column to numeric days

df['Recency'] = df['Diff'].dt.days
df.head(1)
# Out:
#        PurchaseId PurchaseDate   ShipDate      ShipMode CustomerId  \
# 0  CA-2016-152156   2016-11-08 2016-11-11  Second Class   CG-12520
#
#   CustomerName   Segment        Country       City     State PostalCode  \
# 0  Claire Gute  Consumer  United States  Henderson  Kentucky      42420
#
#   Region     OldProductId   Category SubCategory  \
# 0  South  FUR-BO-10001798  Furniture   Bookcases
#
#                          ProductName   Sales  Quantity  Discount  Profit  \
# 0  Bush Somerset Collection Bookcase  261.96         2       0.0   41.91
#
#   FirstName LastName  CatalogPrice  SupplierPrice        ProductId     Diff  \
# 0    Claire     Gute        130.98         110.02  FUR-BO-10005012 417 days
#
#    Recency
# 0      417

# %%
# Group by 'CustomerId' and get the minimum 'Recency' value

df_Recency = df.groupby('CustomerId')['Recency'].min().reset_index()
df_Recency.head()
# Out:
#   CustomerId  Recency
# 0   AA-10315      184
# 1   AA-10375       19
# 2   AA-10480      259
# 3   AA-10645       55
# 4   AB-10015      415

# %%
# Step 1: Calculate total sales (sum of 'Sales') per CustomerId

df_monetary = df.groupby('CustomerId', as_index=False)['Sales'].sum()

# Merge df_Recency into df_monetary based on 'CustomerId'

df_monetary = df_monetary.merge(df_Recency, on='CustomerId', how='left')

# Display the updated df_monetary DataFrame

df_monetary.head()
# Out:
#   CustomerId    Sales  Recency
# 0   AA-10315  5563.56      184
# 1   AA-10375  1056.39       19
# 2   AA-10480  1790.51      259
# 3   AA-10645  5086.93       55
# 4   AB-10015   886.15      415

# %%
# Count the number of PurchaseId values (including duplicates) for each CustomerId in the main DataFrame (df)
df_purchase_frequency = df.groupby('CustomerId')['PurchaseId'].size().reset_index(name='Frequency')

# Merge the frequency into df_monetary
df_monetary = df_monetary.merge(df_purchase_frequency, on='CustomerId', how='left')

# Display the updated df_monetary DataFrame
df_monetary.head()
# Out:
#   CustomerId    Sales  Recency  Frequency
# 0   AA-10315  5563.56      184         11
# 1   AA-10375  1056.39       19         15
# 2   AA-10480  1790.51      259         12
# 3   AA-10645  5086.93       55         18
# 4   AB-10015   886.15      415          6

# %%
df = df.drop(columns=['Diff'])

# %%
import sqlite3

#### Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('database.db')
cursor = conn.cursor()

#### SQL commands to create tables 
create_tables_sql = ''' 
-- Create the Customer table 
CREATE TABLE IF NOT EXISTS Customer (
    CustomerId TEXT PRIMARY KEY NOT NULL,                
    FirstName TEXT NOT NULL CHECK(length(FirstName) <= 100), 
    LastName TEXT NOT NULL CHECK(length(LastName) <= 100),   
    Segment TEXT NOT NULL CHECK(length(Segment) <= 50)
);

-- Create the CustomerLocation table
CREATE TABLE IF NOT EXISTS CustomerLocation (
    CustomerId TEXT NOT NULL, 
    PostalCode TEXT NOT NULL,
    City TEXT NOT NULL,
    Region TEXT,
    State TEXT NOT NULL,
    Country TEXT NOT NULL,
    PRIMARY KEY (PostalCode, CustomerId),
    FOREIGN KEY (CustomerId) REFERENCES Customer(CustomerId)
);

-- Create the Purchase table
CREATE TABLE IF NOT EXISTS Purchase (
    PurchaseId TEXT PRIMARY KEY NOT NULL,                
    CustomerId TEXT NOT NULL, 
    PurchaseDate DATE NOT NULL,
    FOREIGN KEY (CustomerId) REFERENCES Customer(CustomerId)
);

-- Create the PurchaseDetail table
CREATE TABLE IF NOT EXISTS PurchaseDetail (
    PurchaseId TEXT NOT NULL,
    ProductId TEXT NOT NULL,
    Quantity INTEGER NOT NULL,
    Sales DECIMAL NOT NULL,
    Discount DECIMAL NOT NULL,
    Profit DECIMAL NOT NULL,
    ShipDate DATE,
    ShipMode TEXT,
    PRIMARY KEY (PurchaseId, ProductId),
    FOREIGN KEY (PurchaseId) REFERENCES Purchase(PurchaseId),
    FOREIGN KEY (ProductId) REFERENCES Product(ProductId)
);

-- Create the Product table
CREATE TABLE IF NOT EXISTS Product (
    ProductId TEXT PRIMARY KEY NOT NULL,
    ProductName TEXT NOT NULL,
    CatalogPrice DECIMAL NOT NULL,
    SupplierPrice DECIMAL NOT NULL
);

-- Create the Category table
CREATE TABLE IF NOT EXISTS Category (
    ProductId TEXT NOT NULL,
    SubCategory TEXT NOT NULL,
    Category TEXT NOT NULL,
    PRIMARY KEY (ProductId, SubCategory),
    FOREIGN KEY (ProductId) REFERENCES Product(ProductId)
);
'''

#### Execute the SQL commands to create tables
cursor.executescript(create_tables_sql)

#### Commit changes and close the connection
conn.commit()

print("Database and tables created successfully.")
# Out:
# Database and tables created successfully.

# %% [markdown]
# ### Populate data to Tables

# %%
df_Customer.to_sql('Customer', conn, if_exists='append', index=False)

df_CustomerLocation.to_sql('CustomerLocation', conn, if_exists='append', index=False)

df_Purchase.to_sql('Purchase', conn, if_exists='append', index=False)

df_PurchaseDetail.to_sql('PurchaseDetail', conn, if_exists='append', index=False)

df_Product.to_sql('Product', conn, if_exists='append', index=False)

df_Category.to_sql('Category', conn, if_exists='append', index=False)
# Out:
# 1894

# %% [markdown]
# ## 25: Run Some Queries to discover data

# %%
# Total Reveneu per Category

conn = sqlite3.connect('database.db')
cursor = conn.cursor()

# Define the path to your SQLite database
db_path = 'database.db'

# Connect to the SQLite database
conn = sqlite3.connect(db_path)


query = """
SELECT Category.Category, 
       SUM(PurchaseDetail.Sales) AS TotalRevenue
FROM PurchaseDetail
JOIN Product ON PurchaseDetail.ProductId = Product.ProductId
JOIN Category ON Product.ProductId = Category.ProductId
GROUP BY Category.Category
ORDER BY TotalRevenue DESC
LIMIT 5;
"""

# Execute the query and fetch the results into a DataFrame
pd.read_sql_query(query, conn)
# Out:
#           Category  TotalRevenue
# 0       Technology     836154.02
# 1        Furniture     741999.73
# 2  Office Supplies     719046.90
