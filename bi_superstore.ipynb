# %%
# import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import chardet

import re

import os
import sqlite3
from sqlite3 import Error

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %% [markdown]
# ### 1: Load & Discover Data

# %%
with open('Sample-Superstore.csv', 'rb') as file:
    rawdata = file.read(10000)
    result = chardet.detect(rawdata)
    encoding = result['encoding'] 

df = pd.read_csv('Sample-Superstore.csv', encoding=encoding)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 1.6+ MB

# %%
df.head().T
# Out:
#                                                0  \
# Row ID                                         1
# Order ID                          CA-2016-152156
# Order Date                             11/8/2016
# Ship Date                             11/11/2016
# Ship Mode                           Second Class
# Customer ID                             CG-12520
# Customer Name                        Claire Gute
# Segment                                 Consumer
# Country                            United States
# City                                   Henderson
# State                                   Kentucky
# Postal Code                                42420
# Region                                     South
# Product ID                       FUR-BO-10001798
# Category                               Furniture
# Sub-Category                           Bookcases
# Product Name   Bush Somerset Collection Bookcase
# Sales                                     261.96
# Quantity                                       2
# Discount                                     0.0
# Profit                                   41.9136
#
#                                                                1  \
# Row ID                                                         2
# Order ID                                          CA-2016-152156
# Order Date                                             11/8/2016
# Ship Date                                             11/11/2016
# Ship Mode                                           Second Class
# Customer ID                                             CG-12520
# Customer Name                                        Claire Gute
# Segment                                                 Consumer
# Country                                            United States
# City                                                   Henderson
# State                                                   Kentucky
# Postal Code                                                42420
# Region                                                     South
# Product ID                                       FUR-CH-10000454
# Category                                               Furniture
# Sub-Category                                              Chairs
# Product Name   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# Sales                                                     731.94
# Quantity                                                       3
# Discount                                                     0.0
# Profit                                                   219.582
#
#                                                                2  \
# Row ID                                                         3
# Order ID                                          CA-2016-138688
# Order Date                                             6/12/2016
# Ship Date                                              6/16/2016
# Ship Mode                                           Second Class
# Customer ID                                             DV-13045
# Customer Name                                    Darrin Van Huff
# Segment                                                Corporate
# Country                                            United States
# City                                                 Los Angeles
# State                                                 California
# Postal Code                                                90036
# Region                                                      West
# Product ID                                       OFF-LA-10000240
# Category                                         Office Supplies
# Sub-Category                                              Labels
# Product Name   Self-Adhesive Address Labels for Typewriters b...
# Sales                                                      14.62
# Quantity                                                       2
# Discount                                                     0.0
# Profit                                                    6.8714
#
#                                                            3  \
# Row ID                                                     4
# Order ID                                      US-2015-108966
# Order Date                                        10/11/2015
# Ship Date                                         10/18/2015
# Ship Mode                                     Standard Class
# Customer ID                                         SO-20335
# Customer Name                                 Sean O'Donnell
# Segment                                             Consumer
# Country                                        United States
# City                                         Fort Lauderdale
# State                                                Florida
# Postal Code                                            33311
# Region                                                 South
# Product ID                                   FUR-TA-10000577
# Category                                           Furniture
# Sub-Category                                          Tables
# Product Name   Bretford CR4500 Series Slim Rectangular Table
# Sales                                               957.5775
# Quantity                                                   5
# Discount                                                0.45
# Profit                                              -383.031
#
#                                             4
# Row ID                                      5
# Order ID                       US-2015-108966
# Order Date                         10/11/2015
# Ship Date                          10/18/2015
# Ship Mode                      Standard Class
# Customer ID                          SO-20335
# Customer Name                  Sean O'Donnell
# Segment                              Consumer
# Country                         United States
# City                          Fort Lauderdale
# State                                 Florida
# Postal Code                             33311
# Region                                  South
# Product ID                    OFF-ST-10000760
# Category                      Office Supplies
# Sub-Category                          Storage
# Product Name   Eldon Fold 'N Roll Cart System
# Sales                                  22.368
# Quantity                                    2
# Discount                                  0.2
# Profit                                 2.5164

# %%
df = df.drop(columns=['Row ID'])

# %%
# Rename columns 

df.rename(columns={
    'Order ID': 'PurchaseId',
    'Order Date': 'PurchaseDate',
    'Ship Date': 'ShipDate',
    'Ship Mode': 'ShipMode',  
    'Customer ID': 'CustomerId',
    'Customer Name': 'CustomerName',
    'Segment': 'Segment',
    'Country': 'Country',
    'City': 'City',
    'State': 'State',
    'Postal Code': 'PostalCode',
    'Region': 'Region',
    'Product ID': 'ProductId',
    'Category': 'Category',
    'Sub-Category': 'SubCategory',
    'Product Name': 'ProductName',
    'Sales': 'Sales',
    'Quantity': 'Quantity',
    'Discount': 'Discount',
    'Profit': 'Profit'
}, inplace=True)

# %%
df.dtypes
# Out:
# PurchaseId       object
# PurchaseDate     object
# ShipDate         object
# ShipMode         object
# CustomerId       object
# CustomerName     object
# Segment          object
# Country          object
# City             object
# State            object
# PostalCode        int64
# Region           object
# ProductId        object
# Category         object
# SubCategory      object
# ProductName      object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %%
df.nunique()
# Out:
# PurchaseId      5009
# PurchaseDate    1237
# ShipDate        1334
# ShipMode           4
# CustomerId       793
# CustomerName     793
# Segment            3
# Country            1
# City             531
# State             49
# PostalCode       631
# Region             4
# ProductId       1862
# Category           3
# SubCategory       17
# ProductName     1850
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# ### 2: Review columns

# %%
# check if entries have the same format in PurchaseId column

pattern = r'^[A-Z]{2}-\d{4}-\d{6}$' #  string starting with 2 uppercase letters, followed by a hyphen, 4 digits, another hyphen, and 6 digits

df[~df['PurchaseId'].str.match(pattern)]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# trim whitespaces

df['PurchaseId'] = df['PurchaseId'].str.strip()

# %%
# ensure that letters are uppercase  

df['PurchaseId'] = df['PurchaseId'].str.upper()

# %%
# check if there is any unexpected characters or symbols 

df[df['PurchaseId'].str.contains(r'[^A-Z0-9-]')]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# check if the year starts with 20 and followed with same pattern 

df[~df['PurchaseId'].str.contains(r'-20\d{2}-')]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# Convert data types for columns 

df['PurchaseDate'] = pd.to_datetime(df['PurchaseDate'])  

df['ShipDate'] = pd.to_datetime(df['ShipDate'])

# %%
# ensure that the PurchaseDate is always earlier than the ShipDate 

df[df['PurchaseDate'] > df['ShipDate']]
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# check entries where OrderDate and ShipDate is same

df_filtered = df[df['PurchaseDate'] == df['ShipDate']]
df_filtered
# Out:
#           PurchaseId PurchaseDate   ShipDate  ShipMode CustomerId  \
# 366   CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 367   CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 368   CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 369   CA-2016-155516   2016-10-21 2016-10-21  Same Day   MK-17905
# 657   US-2016-156097   2016-09-19 2016-09-19  Same Day   EH-14125
# ...              ...          ...        ...       ...        ...
# 9871  CA-2017-146269   2017-10-06 2017-10-06  Same Day   MH-17455
# 9872  CA-2017-146269   2017-10-06 2017-10-06  Same Day   MH-17455
# 9928  CA-2016-129630   2016-09-04 2016-09-04  Same Day   IM-15055
# 9929  CA-2016-129630   2016-09-04 2016-09-04  Same Day   IM-15055
# 9963  CA-2015-143700   2015-07-26 2015-07-26  Same Day   AS-10240
#
#            CustomerName      Segment        Country           City  \
# 366     Michael Kennedy    Corporate  United States     Manchester
# 367     Michael Kennedy    Corporate  United States     Manchester
# 368     Michael Kennedy    Corporate  United States     Manchester
# 369     Michael Kennedy    Corporate  United States     Manchester
# 657   Eugene Hildebrand  Home Office  United States         Aurora
# ...                 ...          ...            ...            ...
# 9871      Mark Hamilton     Consumer  United States        Chicago
# 9872      Mark Hamilton     Consumer  United States        Chicago
# 9928      Ionia McGrath     Consumer  United States  San Francisco
# 9929      Ionia McGrath     Consumer  United States  San Francisco
# 9963       Alan Shonely     Consumer  United States   Philadelphia
#
#              State  PostalCode   Region        ProductId         Category  \
# 366    Connecticut        6040     East  OFF-BI-10002412  Office Supplies
# 367    Connecticut        6040     East  OFF-SU-10001225  Office Supplies
# 368    Connecticut        6040     East  OFF-ST-10002406  Office Supplies
# 369    Connecticut        6040     East  FUR-BO-10002545        Furniture
# 657       Illinois       60505  Central  FUR-CH-10001215        Furniture
# ...            ...         ...      ...              ...              ...
# 9871      Illinois       60623  Central  OFF-ST-10003208  Office Supplies
# 9872      Illinois       60623  Central  OFF-AR-10004790  Office Supplies
# 9928    California       94122     West  FUR-FU-10000260        Furniture
# 9929    California       94122     West  TEC-CO-10003763       Technology
# 9963  Pennsylvania       19140     East  OFF-PA-10003072  Office Supplies
#
#       SubCategory                                        ProductName  \
# 366       Binders  Wilson Jones Snap Scratch Pad Binder Tool fo...
# 367      Supplies                                     Staple remover
# 368       Storage                           Pizazz Global Quick File
# 369     Bookcases  Atlantic Metals Mobile 3-Shelf Bookcases, Cust...
# 657        Chairs      Global Troy Executive Leather Low-Back Tilter
# ...           ...                                                ...
# 9871      Storage                 Adjustable Depth Letter/Legal Cart
# 9872          Art                            Staples in misc. colors
# 9928  Furnishings                       6" Cubicle Wall Clock, Black
# 9929      Copiers                 Canon PC1060 Personal Laser Copier
# 9963        Paper      Eureka Recycled Copy Paper 8 1/2" x 11", Ream
#
#          Sales  Quantity  Discount    Profit
# 366     23.200         4       0.0   10.4400
# 367      7.360         2       0.0    0.1472
# 368    104.790         7       0.0   29.3412
# 369   1043.920         4       0.0  271.4192
# 657    701.372         2       0.3  -50.0980
# ...        ...       ...       ...       ...
# 9871   290.336         2       0.2   32.6628
# 9872    19.152         2       0.2    1.1970
# 9928    24.270         3       0.0    8.7372
# 9929  2799.960         5       0.2  944.9865
# 9963    10.368         2       0.2    3.6288
#
# [519 rows x 20 columns]

# %%
df_filtered['ShipMode'].unique()
# Out:
# array(['Same Day'], dtype=object)

# %%
df['ShipMode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'First Class', 'Same Day'],
#       dtype=object)

# %%
# remove whitespaces, capitlize letters for ShipMode column

df['ShipMode'] = df['ShipMode'].str.strip().str.title()

# %%
df['ShipMode'].value_counts()
# Out:
# ShipMode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
# make sure all CustomerId values follow a consistent format 

valid_id_pattern = r'^[A-Z]{2}-\d{5}$' # string starting with 2 uppercase, followed by a hyphen and exactly 5 digits

df[~df['CustomerId'].str.match(valid_id_pattern)].T
# Out:
#                                                            261   \
# PurchaseId                                       US-2017-155299
# PurchaseDate                                2017-06-08 00:00:00
# ShipDate                                    2017-06-12 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dl-13600
# CustomerName                                       Dorris liebe
# Segment                                               Corporate
# Country                                           United States
# City                                                   Pasadena
# State                                                     Texas
# PostalCode                                                77506
# Region                                                  Central
# ProductId                                       OFF-AP-10002203
# Category                                        Office Supplies
# SubCategory                                          Appliances
# ProductName   Eureka Disposable Bags for Sanitaire Vibra Gro...
# Sales                                                     1.624
# Quantity                                                      2
# Discount                                                    0.8
# Profit                                                   -4.466
#
#                                                     701   \
# PurchaseId                                CA-2017-114552
# PurchaseDate                         2017-09-02 00:00:00
# ShipDate                             2017-09-08 00:00:00
# ShipMode                                  Standard Class
# CustomerId                                      Dl-13600
# CustomerName                                Dorris liebe
# Segment                                        Corporate
# Country                                    United States
# City                                           Cleveland
# State                                               Ohio
# PostalCode                                         44105
# Region                                              East
# ProductId                                FUR-FU-10002960
# Category                                       Furniture
# SubCategory                                  Furnishings
# ProductName   Eldon 200 Class Desk Accessories, Burgundy
# Sales                                             15.072
# Quantity                                               3
# Discount                                             0.2
# Profit                                            4.1448
#
#                                                715                  1489  \
# PurchaseId                           CA-2014-153150       CA-2014-136280
# PurchaseDate                    2014-07-01 00:00:00  2014-11-29 00:00:00
# ShipDate                        2014-07-06 00:00:00  2014-12-06 00:00:00
# ShipMode                               Second Class       Standard Class
# CustomerId                                 Dl-13600             Co-12640
# CustomerName                           Dorris liebe           Corey-Lock
# Segment                                   Corporate             Consumer
# Country                               United States        United States
# City                                        Seattle         Philadelphia
# State                                    Washington         Pennsylvania
# PostalCode                                    98105                19143
# Region                                         West                 East
# ProductId                           OFF-BI-10003355      OFF-LA-10000452
# Category                            Office Supplies      Office Supplies
# SubCategory                                 Binders               Labels
# ProductName   Cardinal Holdit Business Card Pockets            Avery 488
# Sales                                         19.92                 5.04
# Quantity                                          5                    2
# Discount                                        0.2                  0.2
# Profit                                        6.972                1.764
#
#                                                      1900  \
# PurchaseId                                 CA-2016-140543
# PurchaseDate                          2016-06-29 00:00:00
# ShipDate                              2016-07-03 00:00:00
# ShipMode                                     Second Class
# CustomerId                                       Co-12640
# CustomerName                                   Corey-Lock
# Segment                                          Consumer
# Country                                     United States
# City                                             Florence
# State                                      South Carolina
# PostalCode                                          29501
# Region                                              South
# ProductId                                 OFF-ST-10000563
# Category                                  Office Supplies
# SubCategory                                       Storage
# ProductName   Fellowes Bankers Box Stor/Drawer Steel Plus
# Sales                                              191.88
# Quantity                                                6
# Discount                                              0.0
# Profit                                             19.188
#
#                                                    2760  \
# PurchaseId                               CA-2014-129574
# PurchaseDate                        2014-05-26 00:00:00
# ShipDate                            2014-05-29 00:00:00
# ShipMode                                    First Class
# CustomerId                                     Dp-13240
# CustomerName                                Dean percer
# Segment                                     Home Office
# Country                                   United States
# City                                             Murray
# State                                              Utah
# PostalCode                                        84107
# Region                                             West
# ProductId                               OFF-PA-10002893
# Category                                Office Supplies
# SubCategory                                       Paper
# ProductName   Wirebound Service Call Books, 5 1/2" x 4"
# Sales                                              48.4
# Quantity                                              5
# Discount                                            0.0
# Profit                                           23.232
#
#                                          2877                 2878  \
# PurchaseId                     CA-2016-152072       CA-2016-152072
# PurchaseDate              2016-01-15 00:00:00  2016-01-15 00:00:00
# ShipDate                  2016-01-19 00:00:00  2016-01-19 00:00:00
# ShipMode                       Standard Class       Standard Class
# CustomerId                           Dp-13240             Dp-13240
# CustomerName                      Dean percer          Dean percer
# Segment                           Home Office          Home Office
# Country                         United States        United States
# City                                Westfield            Westfield
# State                              New Jersey           New Jersey
# PostalCode                               7090                 7090
# Region                                   East                 East
# ProductId                     OFF-EN-10003040      OFF-AR-10001573
# Category                      Office Supplies      Office Supplies
# SubCategory                         Envelopes                  Art
# ProductName   Quality Park Security Envelopes      American Pencil
# Sales                                   52.34                 4.66
# Quantity                                    2                    2
# Discount                                  0.0                  0.0
# Profit                                24.5998               1.3514
#
#                                           2879                     2966  \
# PurchaseId                      CA-2016-152072           CA-2014-162866
# PurchaseDate               2016-01-15 00:00:00      2014-12-27 00:00:00
# ShipDate                   2016-01-19 00:00:00      2014-12-31 00:00:00
# ShipMode                        Standard Class           Standard Class
# CustomerId                            Dp-13240                 Co-12640
# CustomerName                       Dean percer               Corey-Lock
# Segment                            Home Office                 Consumer
# Country                          United States            United States
# City                                 Westfield                   Skokie
# State                               New Jersey                 Illinois
# PostalCode                                7090                    60076
# Region                                    East                  Central
# ProductId                      TEC-AC-10000844          FUR-FU-10001473
# Category                            Technology                Furniture
# SubCategory                        Accessories              Furnishings
# ProductName   Logitech Gaming G510s - Keyboard  DAX Wood Document Frame
# Sales                                   254.97                   32.952
# Quantity                                     3                        6
# Discount                                   0.0                      0.6
# Profit                                 91.7892                 -19.7712
#
#                              2967                 3362  \
# PurchaseId         CA-2014-162866       CA-2015-139962
# PurchaseDate  2014-12-27 00:00:00  2015-12-13 00:00:00
# ShipDate      2014-12-31 00:00:00  2015-12-20 00:00:00
# ShipMode           Standard Class       Standard Class
# CustomerId               Co-12640             Dp-13240
# CustomerName           Corey-Lock          Dean percer
# Segment                  Consumer          Home Office
# Country             United States        United States
# City                       Skokie               Revere
# State                    Illinois        Massachusetts
# PostalCode                  60076                 2151
# Region                    Central                 East
# ProductId         OFF-ST-10002562      OFF-PA-10004451
# Category          Office Supplies      Office Supplies
# SubCategory               Storage                Paper
# ProductName         Staple magnet            Xerox 222
# Sales                      30.016                19.44
# Quantity                        4                    3
# Discount                      0.2                  0.0
# Profit                     3.0016               9.3312
#
#                                                            3363  \
# PurchaseId                                       CA-2015-139962
# PurchaseDate                                2015-12-13 00:00:00
# ShipDate                                    2015-12-20 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                     Revere
# State                                             Massachusetts
# PostalCode                                                 2151
# Region                                                     East
# ProductId                                       OFF-BI-10004738
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   Flexible Leather- Look Classic Collection Ring...
# Sales                                                     37.88
# Quantity                                                      2
# Discount                                                    0.0
# Profit                                                    18.94
#
#                                             3385                 3386  \
# PurchaseId                        CA-2017-148404       CA-2017-148404
# PurchaseDate                 2017-10-07 00:00:00  2017-10-07 00:00:00
# ShipDate                     2017-10-11 00:00:00  2017-10-11 00:00:00
# ShipMode                          Standard Class       Standard Class
# CustomerId                              Dp-13240             Dp-13240
# CustomerName                         Dean percer          Dean percer
# Segment                              Home Office          Home Office
# Country                            United States        United States
# City                                   Charlotte            Charlotte
# State                             North Carolina       North Carolina
# PostalCode                                 28205                28205
# Region                                     South                South
# ProductId                        OFF-ST-10003208      OFF-FA-10003112
# Category                         Office Supplies      Office Supplies
# SubCategory                              Storage            Fasteners
# ProductName   Adjustable Depth Letter/Legal Cart              Staples
# Sales                                    580.672               18.936
# Quantity                                       4                    3
# Discount                                     0.2                  0.2
# Profit                                   65.3256               5.9175
#
#                                          3387  \
# PurchaseId                     CA-2017-148404
# PurchaseDate              2017-10-07 00:00:00
# ShipDate                  2017-10-11 00:00:00
# ShipMode                       Standard Class
# CustomerId                           Dp-13240
# CustomerName                      Dean percer
# Segment                           Home Office
# Country                         United States
# City                                Charlotte
# State                          North Carolina
# PostalCode                              28205
# Region                                  South
# ProductId                     TEC-PH-10004447
# Category                           Technology
# SubCategory                            Phones
# ProductName   Toshiba IPT2010-SD IP Telephone
# Sales                                 222.384
# Quantity                                    2
# Discount                                  0.2
# Profit                                16.6788
#
#                                              3388                        3389  \
# PurchaseId                         CA-2017-148404              CA-2017-148404
# PurchaseDate                  2017-10-07 00:00:00         2017-10-07 00:00:00
# ShipDate                      2017-10-11 00:00:00         2017-10-11 00:00:00
# ShipMode                           Standard Class              Standard Class
# CustomerId                               Dp-13240                    Dp-13240
# CustomerName                          Dean percer                 Dean percer
# Segment                               Home Office                 Home Office
# Country                             United States               United States
# City                                    Charlotte                   Charlotte
# State                              North Carolina              North Carolina
# PostalCode                                  28205                       28205
# Region                                      South                       South
# ProductId                         OFF-BI-10002854             FUR-TA-10001039
# Category                          Office Supplies                   Furniture
# SubCategory                               Binders                      Tables
# ProductName   Performers Binder/Pad Holder, Black  KI Adjustable-Height Table
# Sales                                      50.454                     154.764
# Quantity                                        6                           3
# Discount                                      0.7                         0.4
# Profit                                    -33.636                    -36.1116
#
#                                    4000  \
# PurchaseId               CA-2014-116834
# PurchaseDate        2014-10-11 00:00:00
# ShipDate            2014-10-16 00:00:00
# ShipMode                 Standard Class
# CustomerId                     Dp-13240
# CustomerName                Dean percer
# Segment                     Home Office
# Country                   United States
# City                            Seattle
# State                        Washington
# PostalCode                        98115
# Region                             West
# ProductId               FUR-FU-10001196
# Category                      Furniture
# SubCategory                 Furnishings
# ProductName   DAX Cubicle Frames - 8x10
# Sales                             63.47
# Quantity                             11
# Discount                            0.0
# Profit                           19.041
#
#                                                            4001  \
# PurchaseId                                       CA-2014-116834
# PurchaseDate                                2014-10-11 00:00:00
# ShipDate                                    2014-10-16 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                    Seattle
# State                                                Washington
# PostalCode                                                98115
# Region                                                     West
# ProductId                                       TEC-AC-10002942
# Category                                             Technology
# SubCategory                                         Accessories
# ProductName   WD My Passport Ultra 1TB Portable External Har...
# Sales                                                     345.0
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                    58.65
#
#                                                            4084  \
# PurchaseId                                       CA-2017-163692
# PurchaseDate                                2017-09-07 00:00:00
# ShipDate                                    2017-09-09 00:00:00
# ShipMode                                            First Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                    Phoenix
# State                                                   Arizona
# PostalCode                                                85023
# Region                                                     West
# ProductId                                       OFF-BI-10003291
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   Wilson Jones Leather-Like Binders with DublLoc...
# Sales                                                     7.857
# Quantity                                                      3
# Discount                                                    0.7
# Profit                                                  -6.0237
#
#                                                       4643  \
# PurchaseId                                  CA-2015-147501
# PurchaseDate                           2015-08-02 00:00:00
# ShipDate                               2015-08-06 00:00:00
# ShipMode                                    Standard Class
# CustomerId                                        Co-12640
# CustomerName                                    Corey-Lock
# Segment                                           Consumer
# Country                                      United States
# City                                               Seattle
# State                                           Washington
# PostalCode                                           98105
# Region                                                West
# ProductId                                  OFF-BI-10002003
# Category                                   Office Supplies
# SubCategory                                        Binders
# ProductName   Ibico Presentation Index for Binding Systems
# Sales                                                6.368
# Quantity                                                 2
# Discount                                               0.2
# Profit                                              2.1492
#
#                                 4644  \
# PurchaseId            CA-2015-147501
# PurchaseDate     2015-08-02 00:00:00
# ShipDate         2015-08-06 00:00:00
# ShipMode              Standard Class
# CustomerId                  Co-12640
# CustomerName              Corey-Lock
# Segment                     Consumer
# Country                United States
# City                         Seattle
# State                     Washington
# PostalCode                     98105
# Region                          West
# ProductId            TEC-MA-10001972
# Category                  Technology
# SubCategory                 Machines
# ProductName   Okidata C331dn Printer
# Sales                          558.4
# Quantity                           2
# Discount                         0.2
# Profit                         41.88
#
#                                                            4734  \
# PurchaseId                                       CA-2016-120530
# PurchaseDate                                2016-04-07 00:00:00
# ShipDate                                    2016-04-12 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dl-13600
# CustomerName                                       Dorris liebe
# Segment                                               Corporate
# Country                                           United States
# City                                              New York City
# State                                                  New York
# PostalCode                                                10035
# Region                                                     East
# ProductId                                       FUR-CH-10000454
# Category                                              Furniture
# SubCategory                                              Chairs
# ProductName   Hon Deluxe Fabric Upholstered Stacking Chairs,...
# Sales                                                   658.746
# Quantity                                                      3
# Discount                                                    0.1
# Profit                                                  146.388
#
#                                            5006  \
# PurchaseId                       CA-2015-169796
# PurchaseDate                2015-11-09 00:00:00
# ShipDate                    2015-11-14 00:00:00
# ShipMode                         Standard Class
# CustomerId                             Dp-13240
# CustomerName                        Dean percer
# Segment                             Home Office
# Country                           United States
# City                              New York City
# State                                  New York
# PostalCode                                10035
# Region                                     East
# ProductId                       TEC-MA-10000045
# Category                             Technology
# SubCategory                            Machines
# ProductName   Zebra ZM400 Thermal Label Printer
# Sales                                    2321.9
# Quantity                                      2
# Discount                                    0.0
# Profit                                 1114.512
#
#                                                            5007  \
# PurchaseId                                       CA-2015-169796
# PurchaseDate                                2015-11-09 00:00:00
# ShipDate                                    2015-11-14 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                              New York City
# State                                                  New York
# PostalCode                                                10035
# Region                                                     East
# ProductId                                       OFF-ST-10001505
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Perma STOR-ALL Hanging File Box, 13 1/8"W x 12...
# Sales                                                     17.94
# Quantity                                                      3
# Discount                                                    0.0
# Profit                                                   3.0498
#
#                                                 5283                 5284  \
# PurchaseId                            CA-2014-133424       CA-2014-133424
# PurchaseDate                     2014-03-30 00:00:00  2014-03-30 00:00:00
# ShipDate                         2014-04-04 00:00:00  2014-04-04 00:00:00
# ShipMode                              Standard Class       Standard Class
# CustomerId                                  Dl-13600             Dl-13600
# CustomerName                            Dorris liebe         Dorris liebe
# Segment                                    Corporate            Corporate
# Country                                United States        United States
# City                                         Seattle              Seattle
# State                                     Washington           Washington
# PostalCode                                     98105                98105
# Region                                          West                 West
# ProductId                            OFF-ST-10002957      OFF-LA-10002312
# Category                             Office Supplies      Office Supplies
# SubCategory                                  Storage               Labels
# ProductName   Sterilite Show Offs Storage Containers            Avery 490
# Sales                                          15.84                 44.4
# Quantity                                           3                    3
# Discount                                         0.0                  0.0
# Profit                                           0.0                 22.2
#
#                                                       5316  \
# PurchaseId                                  US-2017-162558
# PurchaseDate                           2017-10-02 00:00:00
# ShipDate                               2017-10-05 00:00:00
# ShipMode                                       First Class
# CustomerId                                        Dp-13240
# CustomerName                                   Dean percer
# Segment                                        Home Office
# Country                                      United States
# City                                             Knoxville
# State                                            Tennessee
# PostalCode                                           37918
# Region                                               South
# ProductId                                  FUR-FU-10002364
# Category                                         Furniture
# SubCategory                                    Furnishings
# ProductName   Eldon Expressions Wood Desk Accessories, Oak
# Sales                                               11.808
# Quantity                                                 2
# Discount                                               0.2
# Profit                                              1.3284
#
#                                           5317                 5318  \
# PurchaseId                      US-2017-162558       US-2017-162558
# PurchaseDate               2017-10-02 00:00:00  2017-10-02 00:00:00
# ShipDate                   2017-10-05 00:00:00  2017-10-05 00:00:00
# ShipMode                           First Class          First Class
# CustomerId                            Dp-13240             Dp-13240
# CustomerName                       Dean percer          Dean percer
# Segment                            Home Office          Home Office
# Country                          United States        United States
# City                                 Knoxville            Knoxville
# State                                Tennessee            Tennessee
# PostalCode                               37918                37918
# Region                                   South                South
# ProductId                      FUR-FU-10004864      OFF-PA-10003172
# Category                             Furniture      Office Supplies
# SubCategory                        Furnishings                Paper
# ProductName   Eldon 500 Class Desk Accessories           Xerox 1996
# Sales                                    9.656               20.736
# Quantity                                     1                    4
# Discount                                   0.2                  0.2
# Profit                                  1.5691               7.2576
#
#                                             5319  \
# PurchaseId                        US-2017-162558
# PurchaseDate                 2017-10-02 00:00:00
# ShipDate                     2017-10-05 00:00:00
# ShipMode                             First Class
# CustomerId                              Dp-13240
# CustomerName                         Dean percer
# Segment                              Home Office
# Country                            United States
# City                                   Knoxville
# State                                  Tennessee
# PostalCode                                 37918
# Region                                     South
# ProductId                        OFF-BI-10000977
# Category                         Office Supplies
# SubCategory                              Binders
# ProductName   Ibico Plastic Spiral Binding Combs
# Sales                                      27.36
# Quantity                                       3
# Discount                                     0.7
# Profit                                   -21.888
#
#                                                            5320  \
# PurchaseId                                       US-2017-162558
# PurchaseDate                                2017-10-02 00:00:00
# ShipDate                                    2017-10-05 00:00:00
# ShipMode                                            First Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                  Knoxville
# State                                                 Tennessee
# PostalCode                                                37918
# Region                                                    South
# ProductId                                       FUR-TA-10000198
# Category                                              Furniture
# SubCategory                                              Tables
# ProductName   Chromcraft Bull-Nose Wood Oval Conference Tabl...
# Sales                                                  2314.116
# Quantity                                                      7
# Discount                                                    0.4
# Profit                                               -1002.7836
#
#                                      5321  \
# PurchaseId                 US-2017-162558
# PurchaseDate          2017-10-02 00:00:00
# ShipDate              2017-10-05 00:00:00
# ShipMode                      First Class
# CustomerId                       Dp-13240
# CustomerName                  Dean percer
# Segment                       Home Office
# Country                     United States
# City                            Knoxville
# State                           Tennessee
# PostalCode                          37918
# Region                              South
# ProductId                 OFF-BI-10003984
# Category                  Office Supplies
# SubCategory                       Binders
# ProductName   Lock-Up Easel 'Spel-Binder'
# Sales                              34.236
# Quantity                                4
# Discount                              0.7
# Profit                           -26.2476
#
#                                                     5322                 5475  \
# PurchaseId                                US-2017-162558       CA-2017-169691
# PurchaseDate                         2017-10-02 00:00:00  2017-06-15 00:00:00
# ShipDate                             2017-10-05 00:00:00  2017-06-18 00:00:00
# ShipMode                                     First Class          First Class
# CustomerId                                      Dp-13240             Dp-13240
# CustomerName                                 Dean percer          Dean percer
# Segment                                      Home Office          Home Office
# Country                                    United States        United States
# City                                           Knoxville          Maple Grove
# State                                          Tennessee            Minnesota
# PostalCode                                         37918                55369
# Region                                             South              Central
# ProductId                                FUR-FU-10003691      OFF-LA-10002312
# Category                                       Furniture      Office Supplies
# SubCategory                                  Furnishings               Labels
# ProductName   Eldon Image Series Desk Accessories, Ebony            Avery 490
# Sales                                              19.76                 44.4
# Quantity                                               2                    3
# Discount                                             0.2                  0.0
# Profit                                             5.928                 22.2
#
#                                                            5476  \
# PurchaseId                                       CA-2017-169691
# PurchaseDate                                2017-06-15 00:00:00
# ShipDate                                    2017-06-18 00:00:00
# ShipMode                                            First Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                Maple Grove
# State                                                 Minnesota
# PostalCode                                                55369
# Region                                                  Central
# ProductId                                       OFF-ST-10001291
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Tenex Personal Self-Stacking Standard File Box...
# Sales                                                     84.55
# Quantity                                                      5
# Discount                                                    0.0
# Profit                                                  22.8285
#
#                              5477                                6104  \
# PurchaseId         CA-2017-169691                      US-2017-132381
# PurchaseDate  2017-06-15 00:00:00                 2017-08-22 00:00:00
# ShipDate      2017-06-18 00:00:00                 2017-08-24 00:00:00
# ShipMode              First Class                         First Class
# CustomerId               Dp-13240                            Dp-13240
# CustomerName          Dean percer                         Dean percer
# Segment               Home Office                         Home Office
# Country             United States                       United States
# City                  Maple Grove                        Philadelphia
# State                   Minnesota                        Pennsylvania
# PostalCode                  55369                               19143
# Region                    Central                                East
# ProductId         OFF-PA-10003022                     FUR-TA-10002356
# Category          Office Supplies                           Furniture
# SubCategory                 Paper                              Tables
# ProductName            Xerox 1992  Bevis Boat-Shaped Conference Table
# Sales                       17.94                             314.532
# Quantity                        3                                   2
# Discount                      0.0                                 0.4
# Profit                     8.7906                            -83.8752
#
#                                                            7919  \
# PurchaseId                                       CA-2017-139822
# PurchaseDate                                2017-09-15 00:00:00
# ShipDate                                    2017-09-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                  Waterbury
# State                                               Connecticut
# PostalCode                                                 6708
# Region                                                     East
# ProductId                                       OFF-ST-10000943
# Category                                        Office Supplies
# SubCategory                                             Storage
# ProductName   Eldon ProFile File 'N Store Portable File Tub ...
# Sales                                                     38.62
# Quantity                                                      2
# Discount                                                    0.0
# Profit                                                  10.8136
#
#                                                            7920  \
# PurchaseId                                       CA-2017-139822
# PurchaseDate                                2017-09-15 00:00:00
# ShipDate                                    2017-09-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             Dp-13240
# CustomerName                                        Dean percer
# Segment                                             Home Office
# Country                                           United States
# City                                                  Waterbury
# State                                               Connecticut
# PostalCode                                                 6708
# Region                                                     East
# ProductId                                       TEC-AC-10001090
# Category                                             Technology
# SubCategory                                         Accessories
# ProductName   Micro Innovations Wireless Classic Keyboard wi...
# Sales                                                     59.98
# Quantity                                                      2
# Discount                                                    0.0
# Profit                                                  10.7964
#
#                                               8145                 8146
# PurchaseId                          US-2014-112949       US-2014-112949
# PurchaseDate                   2014-06-20 00:00:00  2014-06-20 00:00:00
# ShipDate                       2014-06-27 00:00:00  2014-06-27 00:00:00
# ShipMode                            Standard Class       Standard Class
# CustomerId                                Co-12640             Co-12640
# CustomerName                            Corey-Lock           Corey-Lock
# Segment                                   Consumer             Consumer
# Country                              United States        United States
# City                                        Lawton               Lawton
# State                                     Oklahoma             Oklahoma
# PostalCode                                   73505                73505
# Region                                     Central              Central
# ProductId                          OFF-AP-10001005      OFF-AR-10003469
# Category                           Office Supplies      Office Supplies
# SubCategory                             Appliances                  Art
# ProductName   Honeywell Quietcare HEPA Air Cleaner       Nontoxic Chalk
# Sales                                        471.9                 3.52
# Quantity                                         6                    2
# Discount                                       0.0                  0.0
# Profit                                     155.727               1.6896

# %%
# 3 CustomerName have issues about it: Dorris liebe, Corey-Lock and Dean percer
# Manually update customer names and IDs

df.loc[df['CustomerId'] == 'Dl-13600', 'CustomerId'] = 'DL-13600'
df.loc[df['CustomerId'] == 'Co-12640', 'CustomerId'] = 'CL-12640'
df.loc[df['CustomerId'] == 'Dp-13240', 'CustomerId'] = 'DP-13240'

df.loc[df['CustomerId'] == 'DL-13600', 'CustomerName'] = 'Dorris Liebe'
df.loc[df['CustomerId'] == 'CL-12640', 'CustomerName'] = 'Corey Lock'
df.loc[df['CustomerId'] == 'DP-13240', 'CustomerName'] = 'Dean Percer'

# %%
valid_id_pattern = r'^[A-Z]{2}-\d{5}$' # string starting with 2 uppercase, followed by a hyphen and exactly 5 digits

df[~df['CustomerId'].str.match(valid_id_pattern)].T
# Out:
# Empty DataFrame
# Columns: []
# Index: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]

# %%
# trim whitespaces from 'CustomerName' values

df['CustomerName'] = df['CustomerName'].str.strip()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    9994 non-null   object
#  1   PurchaseDate  9994 non-null   datetime64[ns]
#  2   ShipDate      9994 non-null   datetime64[ns]
#  3   ShipMode      9994 non-null   object
#  4   CustomerId    9994 non-null   object
#  5   CustomerName  9994 non-null   object
#  6   Segment       9994 non-null   object
#  7   Country       9994 non-null   object
#  8   City          9994 non-null   object
#  9   State         9994 non-null   object
#  10  PostalCode    9994 non-null   int64
#  11  Region        9994 non-null   object
#  12  ProductId     9994 non-null   object
#  13  Category      9994 non-null   object
#  14  SubCategory   9994 non-null   object
#  15  ProductName   9994 non-null   object
#  16  Sales         9994 non-null   float64
#  17  Quantity      9994 non-null   int64
#  18  Discount      9994 non-null   float64
#  19  Profit        9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(13)
# memory usage: 1.5+ MB

# %%
df['Segment'].value_counts()
# Out:
# Segment
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: count, dtype: int64

# %%
df['Country'].unique()
# Out:
# array(['United States'], dtype=object)

# %%
df['State'].nunique()
# Out:
# 49

# %%
df['State'].unique()
# Out:
# array(['Kentucky', 'California', 'Florida', 'North Carolina',
#        'Washington', 'Texas', 'Wisconsin', 'Utah', 'Nebraska',
#        'Pennsylvania', 'Illinois', 'Minnesota', 'Michigan', 'Delaware',
#        'Indiana', 'New York', 'Arizona', 'Virginia', 'Tennessee',
#        'Alabama', 'South Carolina', 'Oregon', 'Colorado', 'Iowa', 'Ohio',
#        'Missouri', 'Oklahoma', 'New Mexico', 'Louisiana', 'Connecticut',
#        'New Jersey', 'Massachusetts', 'Georgia', 'Nevada', 'Rhode Island',
#        'Mississippi', 'Arkansas', 'Montana', 'New Hampshire', 'Maryland',
#        'District of Columbia', 'Kansas', 'Vermont', 'Maine',
#        'South Dakota', 'Idaho', 'North Dakota', 'Wyoming',
#        'West Virginia'], dtype=object)

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df['Category'].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df['Category'].value_counts()
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df['SubCategory'].nunique()
# Out:
# 17

# %%
df['SubCategory'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['SubCategory'].value_counts()
# Out:
# SubCategory
# Binders        1523
# Paper          1370
# Furnishings     957
# Phones          889
# Storage         846
# Art             796
# Accessories     775
# Chairs          617
# Appliances      466
# Labels          364
# Tables          319
# Envelopes       254
# Bookcases       228
# Fasteners       217
# Supplies        190
# Machines        115
# Copiers          68
# Name: count, dtype: int64

# %%
df['ProductName'].nunique()
# Out:
# 1850

# %%
df.columns
# Out:
# Index(['PurchaseId', 'PurchaseDate', 'ShipDate', 'ShipMode', 'CustomerId',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductId', 'Category', 'SubCategory', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.describe(include='all').T
# Out:
#                count unique              top  freq  \
# PurchaseId      9994   5009   CA-2017-100111    14
# PurchaseDate    9994    NaN              NaN   NaN
# ShipDate        9994    NaN              NaN   NaN
# ShipMode        9994      4   Standard Class  5968
# CustomerId      9994    793         WB-21850    37
# CustomerName    9994    793    William Brown    37
# Segment         9994      3         Consumer  5191
# Country         9994      1    United States  9994
# City            9994    531    New York City   915
# State           9994     49       California  2001
# PostalCode    9994.0    NaN              NaN   NaN
# Region          9994      4             West  3203
# ProductId       9994   1862  OFF-PA-10001970    19
# Category        9994      3  Office Supplies  6026
# SubCategory     9994     17          Binders  1523
# ProductName     9994   1850  Staple envelope    48
# Sales         9994.0    NaN              NaN   NaN
# Quantity      9994.0    NaN              NaN   NaN
# Discount      9994.0    NaN              NaN   NaN
# Profit        9994.0    NaN              NaN   NaN
#
#                                        mean                  min  \
# PurchaseId                              NaN                  NaN
# PurchaseDate  2016-04-30 00:07:12.259355648  2014-01-03 00:00:00
# ShipDate      2016-05-03 23:06:58.571142912  2014-01-07 00:00:00
# ShipMode                                NaN                  NaN
# CustomerId                              NaN                  NaN
# CustomerName                            NaN                  NaN
# Segment                                 NaN                  NaN
# Country                                 NaN                  NaN
# City                                    NaN                  NaN
# State                                   NaN                  NaN
# PostalCode                     55190.379428               1040.0
# Region                                  NaN                  NaN
# ProductId                               NaN                  NaN
# Category                                NaN                  NaN
# SubCategory                             NaN                  NaN
# ProductName                             NaN                  NaN
# Sales                            229.858001                0.444
# Quantity                           3.789574                  1.0
# Discount                           0.156203                  0.0
# Profit                            28.656896            -6599.978
#
#                               25%                  50%                  75%  \
# PurchaseId                    NaN                  NaN                  NaN
# PurchaseDate  2015-05-23 00:00:00  2016-06-26 00:00:00  2017-05-14 00:00:00
# ShipDate      2015-05-27 00:00:00  2016-06-29 00:00:00  2017-05-18 00:00:00
# ShipMode                      NaN                  NaN                  NaN
# CustomerId                    NaN                  NaN                  NaN
# CustomerName                  NaN                  NaN                  NaN
# Segment                       NaN                  NaN                  NaN
# Country                       NaN                  NaN                  NaN
# City                          NaN                  NaN                  NaN
# State                         NaN                  NaN                  NaN
# PostalCode                23223.0              56430.5              90008.0
# Region                        NaN                  NaN                  NaN
# ProductId                     NaN                  NaN                  NaN
# Category                      NaN                  NaN                  NaN
# SubCategory                   NaN                  NaN                  NaN
# ProductName                   NaN                  NaN                  NaN
# Sales                       17.28                54.49               209.94
# Quantity                      2.0                  3.0                  5.0
# Discount                      0.0                  0.2                  0.2
# Profit                    1.72875               8.6665               29.364
#
#                               max          std
# PurchaseId                    NaN          NaN
# PurchaseDate  2017-12-30 00:00:00          NaN
# ShipDate      2018-01-05 00:00:00          NaN
# ShipMode                      NaN          NaN
# CustomerId                    NaN          NaN
# CustomerName                  NaN          NaN
# Segment                       NaN          NaN
# Country                       NaN          NaN
# City                          NaN          NaN
# State                         NaN          NaN
# PostalCode                99301.0  32063.69335
# Region                        NaN          NaN
# ProductId                     NaN          NaN
# Category                      NaN          NaN
# SubCategory                   NaN          NaN
# ProductName                   NaN          NaN
# Sales                    22638.48   623.245101
# Quantity                     14.0      2.22511
# Discount                      0.8     0.206452
# Profit                   8399.976   234.260108

# %%
# check if rows have duplicatedof PurchaseId and ProductId pairs ( for sql table ) 

df_filtered = df[df.duplicated(subset=['PurchaseId', 'ProductId'], keep=False)]

df_filtered.head(20).T
# Out:
#                              350                  352   \
# PurchaseId         CA-2016-129714       CA-2016-129714
# PurchaseDate  2016-09-01 00:00:00  2016-09-01 00:00:00
# ShipDate      2016-09-03 00:00:00  2016-09-03 00:00:00
# ShipMode              First Class          First Class
# CustomerId               AB-10060             AB-10060
# CustomerName      Adam Bellavance      Adam Bellavance
# Segment               Home Office          Home Office
# Country             United States        United States
# City                New York City        New York City
# State                    New York             New York
# PostalCode                  10009                10009
# Region                       East                 East
# ProductId         OFF-PA-10001970      OFF-PA-10001970
# Category          Office Supplies      Office Supplies
# SubCategory                 Paper                Paper
# ProductName            Xerox 1881           Xerox 1881
# Sales                       24.56                49.12
# Quantity                        2                    4
# Discount                      0.0                  0.0
# Profit                    11.5432              23.0864
#
#                                                            430   \
# PurchaseId                                       US-2016-123750
# PurchaseDate                                2016-04-15 00:00:00
# ShipDate                                    2016-04-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             RB-19795
# CustomerName                                         Ross Baird
# Segment                                             Home Office
# Country                                           United States
# City                                                   Gastonia
# State                                            North Carolina
# PostalCode                                                28052
# Region                                                    South
# ProductId                                       TEC-AC-10004659
# Category                                             Technology
# SubCategory                                         Accessories
# ProductName   Imation Secure+ Hardware Encrypted USB 2.0 Fla...
# Sales                                                   408.744
# Quantity                                                      7
# Discount                                                    0.2
# Profit                                                  76.6395
#
#                                                            431   \
# PurchaseId                                       US-2016-123750
# PurchaseDate                                2016-04-15 00:00:00
# ShipDate                                    2016-04-21 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             RB-19795
# CustomerName                                         Ross Baird
# Segment                                             Home Office
# Country                                           United States
# City                                                   Gastonia
# State                                            North Carolina
# PostalCode                                                28052
# Region                                                    South
# ProductId                                       TEC-AC-10004659
# Category                                             Technology
# SubCategory                                         Accessories
# ProductName   Imation Secure+ Hardware Encrypted USB 2.0 Fla...
# Sales                                                    291.96
# Quantity                                                      5
# Discount                                                    0.2
# Profit                                                  54.7425
#
#                                                            1300  \
# PurchaseId                                       CA-2016-137043
# PurchaseDate                                2016-12-23 00:00:00
# ShipDate                                    2016-12-25 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             LC-17140
# CustomerName                                       Logan Currie
# Segment                                                Consumer
# Country                                           United States
# City                                                Springfield
# State                                                  Virginia
# PostalCode                                                22153
# Region                                                    South
# ProductId                                       FUR-FU-10003664
# Category                                              Furniture
# SubCategory                                         Furnishings
# ProductName   Electrix Architect's Clamp-On Swing Arm Lamp, ...
# Sales                                                    572.76
# Quantity                                                      6
# Discount                                                    0.0
# Profit                                                 166.1004
#
#                                                            1301  \
# PurchaseId                                       CA-2016-137043
# PurchaseDate                                2016-12-23 00:00:00
# ShipDate                                    2016-12-25 00:00:00
# ShipMode                                           Second Class
# CustomerId                                             LC-17140
# CustomerName                                       Logan Currie
# Segment                                                Consumer
# Country                                           United States
# City                                                Springfield
# State                                                  Virginia
# PostalCode                                                22153
# Region                                                    South
# ProductId                                       FUR-FU-10003664
# Category                                              Furniture
# SubCategory                                         Furnishings
# ProductName   Electrix Architect's Clamp-On Swing Arm Lamp, ...
# Sales                                                    286.38
# Quantity                                                      3
# Discount                                                    0.0
# Profit                                                  83.0502
#
#                                             3183  \
# PurchaseId                        CA-2017-152912
# PurchaseDate                 2017-11-09 00:00:00
# ShipDate                     2017-11-12 00:00:00
# ShipMode                            Second Class
# CustomerId                              BM-11650
# CustomerName                          Brian Moss
# Segment                                Corporate
# Country                            United States
# City                                    Columbia
# State                                   Maryland
# PostalCode                                 21044
# Region                                      East
# ProductId                        OFF-ST-10003208
# Category                         Office Supplies
# SubCategory                              Storage
# ProductName   Adjustable Depth Letter/Legal Cart
# Sales                                    1633.14
# Quantity                                       9
# Discount                                     0.0
# Profit                                  473.6106
#
#                                             3184  \
# PurchaseId                        CA-2017-152912
# PurchaseDate                 2017-11-09 00:00:00
# ShipDate                     2017-11-12 00:00:00
# ShipMode                            Second Class
# CustomerId                              BM-11650
# CustomerName                          Brian Moss
# Segment                                Corporate
# Country                            United States
# City                                    Columbia
# State                                   Maryland
# PostalCode                                 21044
# Region                                      East
# ProductId                        OFF-ST-10003208
# Category                         Office Supplies
# SubCategory                              Storage
# ProductName   Adjustable Depth Letter/Legal Cart
# Sales                                     544.38
# Quantity                                       3
# Discount                                     0.0
# Profit                                  157.8702
#
#                                                            3405  \
# PurchaseId                                       US-2014-150119
# PurchaseDate                                2014-04-23 00:00:00
# ShipDate                                    2014-04-27 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             LB-16795
# CustomerName                                     Laurel Beltran
# Segment                                             Home Office
# Country                                           United States
# City                                                   Columbus
# State                                                      Ohio
# PostalCode                                                43229
# Region                                                     East
# ProductId                                       FUR-CH-10002965
# Category                                              Furniture
# SubCategory                                              Chairs
# ProductName   Global Leather Highback Executive Chair with P...
# Sales                                                   281.372
# Quantity                                                      2
# Discount                                                    0.3
# Profit                                                 -12.0588
#
#                                                            3406  \
# PurchaseId                                       US-2014-150119
# PurchaseDate                                2014-04-23 00:00:00
# ShipDate                                    2014-04-27 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             LB-16795
# CustomerName                                     Laurel Beltran
# Segment                                             Home Office
# Country                                           United States
# City                                                   Columbus
# State                                                      Ohio
# PostalCode                                                43229
# Region                                                     East
# ProductId                                       FUR-CH-10002965
# Category                                              Furniture
# SubCategory                                              Chairs
# ProductName   Global Leather Highback Executive Chair with P...
# Sales                                                   281.372
# Quantity                                                      2
# Discount                                                    0.3
# Profit                                                 -12.0588
#
#                                                            6498  \
# PurchaseId                                       CA-2015-103135
# PurchaseDate                                2015-07-24 00:00:00
# ShipDate                                    2015-07-28 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             SS-20515
# CustomerName                                    Shirley Schmidt
# Segment                                             Home Office
# Country                                           United States
# City                                                 Louisville
# State                                                  Kentucky
# PostalCode                                                40214
# Region                                                    South
# ProductId                                       OFF-BI-10000069
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   GBC Prepunched Paper, 19-Hole, for Binding Sys...
# Sales                                                    135.09
# Quantity                                                      9
# Discount                                                    0.0
# Profit                                                  62.1414
#
#                                                            6500  \
# PurchaseId                                       CA-2015-103135
# PurchaseDate                                2015-07-24 00:00:00
# ShipDate                                    2015-07-28 00:00:00
# ShipMode                                         Standard Class
# CustomerId                                             SS-20515
# CustomerName                                    Shirley Schmidt
# Segment                                             Home Office
# Country                                           United States
# City                                                 Louisville
# State                                                  Kentucky
# PostalCode                                                40214
# Region                                                    South
# ProductId                                       OFF-BI-10000069
# Category                                        Office Supplies
# SubCategory                                             Binders
# ProductName   GBC Prepunched Paper, 19-Hole, for Binding Sys...
# Sales                                                     90.06
# Quantity                                                      6
# Discount                                                    0.0
# Profit                                                  41.4276
#
#                                           7881  \
# PurchaseId                      CA-2017-118017
# PurchaseDate               2017-12-03 00:00:00
# ShipDate                   2017-12-06 00:00:00
# ShipMode                          Second Class
# CustomerId                            LC-16870
# CustomerName                     Lena Cacioppo
# Segment                               Consumer
# Country                          United States
# City                                  Thornton
# State                                 Colorado
# PostalCode                               80229
# Region                                    West
# ProductId                      TEC-AC-10002006
# Category                            Technology
# SubCategory                        Accessories
# ProductName   Memorex Micro Travel Drive 16 GB
# Sales                                   76.752
# Quantity                                     6
# Discount                                   0.2
# Profit                                 10.5534
#
#                                           7882                 9168  \
# PurchaseId                      CA-2017-118017       CA-2016-140571
# PurchaseDate               2017-12-03 00:00:00  2016-03-15 00:00:00
# ShipDate                   2017-12-06 00:00:00  2016-03-19 00:00:00
# ShipMode                          Second Class       Standard Class
# CustomerId                            LC-16870             SJ-20125
# CustomerName                     Lena Cacioppo        Sanjit Jacobs
# Segment                               Consumer          Home Office
# Country                          United States        United States
# City                                  Thornton              Jackson
# State                                 Colorado          Mississippi
# PostalCode                               80229                39212
# Region                                    West                South
# ProductId                      TEC-AC-10002006      OFF-PA-10001954
# Category                            Technology      Office Supplies
# SubCategory                        Accessories                Paper
# ProductName   Memorex Micro Travel Drive 16 GB           Xerox 1964
# Sales                                  102.336               319.76
# Quantity                                     8                   14
# Discount                                   0.2                  0.0
# Profit                                 14.0712             147.0896
#
#                              9169
# PurchaseId         CA-2016-140571
# PurchaseDate  2016-03-15 00:00:00
# ShipDate      2016-03-19 00:00:00
# ShipMode           Standard Class
# CustomerId               SJ-20125
# CustomerName        Sanjit Jacobs
# Segment               Home Office
# Country             United States
# City                      Jackson
# State                 Mississippi
# PostalCode                  39212
# Region                      South
# ProductId         OFF-PA-10001954
# Category          Office Supplies
# SubCategory                 Paper
# ProductName            Xerox 1964
# Sales                       45.68
# Quantity                        2
# Discount                      0.0
# Profit                    21.0128

# %%
df_filtered.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 350 to 9169
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    16 non-null     object
#  1   PurchaseDate  16 non-null     datetime64[ns]
#  2   ShipDate      16 non-null     datetime64[ns]
#  3   ShipMode      16 non-null     object
#  4   CustomerId    16 non-null     object
#  5   CustomerName  16 non-null     object
#  6   Segment       16 non-null     object
#  7   Country       16 non-null     object
#  8   City          16 non-null     object
#  9   State         16 non-null     object
#  10  PostalCode    16 non-null     int64
#  11  Region        16 non-null     object
#  12  ProductId     16 non-null     object
#  13  Category      16 non-null     object
#  14  SubCategory   16 non-null     object
#  15  ProductName   16 non-null     object
#  16  Sales         16 non-null     float64
#  17  Quantity      16 non-null     int64
#  18  Discount      16 non-null     float64
#  19  Profit        16 non-null     float64
# dtypes: datetime64[ns](2), float64(3), int64(2), object(13)
# memory usage: 2.6+ KB

# %% [markdown]
# * records appear to be legitimate, with additional items added to the same purchase on the same day. We should therefore sum the values and consolidate them into 6 unique pairs of PurchaseId and ProductId.

# %%
# list of index pairs to process
index_pairs = [
    (350, 352),
    (1300, 1301),
    (3183, 3184),
    (3405, 3406),
    (6498, 6500),
    (7881, 7882),
    (430, 431),
    (9168, 9169)
]

# order indices in descending order 
index_pairs = sorted(index_pairs, reverse=True)

# process each pair of indices
for idx1, idx2 in index_pairs:
    if idx1 in df.index and idx2 in df.index:
        # Extract values
        row_1 = df.loc[idx1]
        row_2 = df.loc[idx2]
        
        # Update the second row with the values from the first row (sum)
        df.at[idx2, 'Quantity'] += row_1['Quantity']
        df.at[idx2, 'Sales'] += row_1['Sales']
        df.at[idx2, 'Profit'] += row_1['Profit']  # add the sum of Profit
        
        # drop the first idx1 row
        df = df.drop(idx1)

# %%
df_filtered = df[df.duplicated(subset=['PurchaseId', 'ProductId'], keep=False)]

df_filtered.head()
# Out:
# Empty DataFrame
# Columns: [PurchaseId, PurchaseDate, ShipDate, ShipMode, CustomerId, CustomerName, Segment, Country, City, State, PostalCode, Region, ProductId, Category, SubCategory, ProductName, Sales, Quantity, Discount, Profit]
# Index: []

# %%
df[df['PurchaseId'] == 'US-2014-150119']
# Out:
#           PurchaseId PurchaseDate   ShipDate        ShipMode CustomerId  \
# 3406  US-2014-150119   2014-04-23 2014-04-27  Standard Class   LB-16795
# 3407  US-2014-150119   2014-04-23 2014-04-27  Standard Class   LB-16795
# 3408  US-2014-150119   2014-04-23 2014-04-27  Standard Class   LB-16795
#
#         CustomerName      Segment        Country      City State  PostalCode  \
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio       43229
# 3407  Laurel Beltran  Home Office  United States  Columbus  Ohio       43229
# 3408  Laurel Beltran  Home Office  United States  Columbus  Ohio       43229
#
#      Region        ProductId         Category  SubCategory  \
# 3406   East  FUR-CH-10002965        Furniture       Chairs
# 3407   East  OFF-BI-10000145  Office Supplies      Binders
# 3408   East  FUR-FU-10002191        Furniture  Furnishings
#
#                                             ProductName    Sales  Quantity  \
# 3406  Global Leather Highback Executive Chair with P...  562.744         4
# 3407                         Zipper Ring Binder Pockets    7.488         8
# 3408                       G.E. Halogen Desk Lamp Bulbs   22.336         4
#
#       Discount   Profit
# 3406       0.3 -24.1176
# 3407       0.7  -5.2416
# 3408       0.2   7.8176

# %% [markdown]
# ### 3: Create new columns

# %%
# CatalogPrice
df['CatalogPrice'] = (df['Sales'] / (df['Quantity'] * (1 - df['Discount']))).round(2)

# SupplierPrice
df['SupplierPrice'] = (df['CatalogPrice'] - (df['Profit'] / df['Quantity'])).round(2)

# ensure no negative SupplierPrice values
df.loc[df['SupplierPrice'] < 0, 'SupplierPrice'] = 0

# %%
# check the sales with loss

df_filtered = df[df['SupplierPrice'] > df['CatalogPrice']]
df_filtered.shape
# Out:
# (1870, 22)

# %%
df_filtered.describe()
# Out:
#                         PurchaseDate                       ShipDate  \
# count                           1870                           1870
# mean   2016-04-27 12:28:29.518716672  2016-05-01 11:48:26.951871744
# min              2014-01-04 00:00:00            2014-01-08 00:00:00
# 25%              2015-05-10 12:00:00            2015-05-15 12:00:00
# 50%              2016-06-13 00:00:00            2016-06-17 00:00:00
# 75%              2017-05-05 18:00:00            2017-05-10 00:00:00
# max              2017-12-30 00:00:00            2018-01-03 00:00:00
# std                              NaN                            NaN
#
#          PostalCode         Sales     Quantity     Discount       Profit  \
# count   1870.000000   1870.000000  1870.000000  1870.000000  1870.000000
# mean   55997.947594    250.645537     3.764706     0.480984   -83.492666
# min     1841.000000      0.444000     1.000000     0.100000 -6599.978000
# 25%    33024.000000     12.482500     2.000000     0.200000   -58.674075
# 50%    60623.000000     71.029000     3.000000     0.400000   -18.112200
# 75%    77095.000000    285.552000     5.000000     0.700000    -6.249250
# max    98198.000000  22638.480000    14.000000     0.800000    -0.089500
# std    26046.794089    715.294305     2.141150     0.235106   284.493224
#
#        CatalogPrice  SupplierPrice
# count   1870.000000    1870.000000
# mean     116.828053     138.132406
# min        1.260000       1.460000
# 25%       11.485000      14.380000
# 50%       44.430000      54.295000
# 75%      135.230000     157.285000
# max     7546.160000    7848.010000
# std      279.477709     330.527801

# %% [markdown]
# * all records which result losses are discunted prices

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df = df.sort_values(by=['PurchaseDate', 'CustomerId']).reset_index(drop=True)
df.head()
# Out:
#        PurchaseId PurchaseDate   ShipDate        ShipMode CustomerId  \
# 0  CA-2014-103800   2014-01-03 2014-01-07  Standard Class   DP-13000
# 1  CA-2014-112326   2014-01-04 2014-01-08  Standard Class   PO-19195
# 2  CA-2014-112326   2014-01-04 2014-01-08  Standard Class   PO-19195
# 3  CA-2014-112326   2014-01-04 2014-01-08  Standard Class   PO-19195
# 4  CA-2014-141817   2014-01-05 2014-01-12  Standard Class   MB-18085
#
#     CustomerName      Segment        Country          City         State  \
# 0  Darren Powers     Consumer  United States       Houston         Texas
# 1  Phillina Ober  Home Office  United States    Naperville      Illinois
# 2  Phillina Ober  Home Office  United States    Naperville      Illinois
# 3  Phillina Ober  Home Office  United States    Naperville      Illinois
# 4     Mick Brown     Consumer  United States  Philadelphia  Pennsylvania
#
#    PostalCode   Region        ProductId         Category SubCategory  \
# 0       77095  Central  OFF-PA-10000174  Office Supplies       Paper
# 1       60540  Central  OFF-LA-10003223  Office Supplies      Labels
# 2       60540  Central  OFF-ST-10002743  Office Supplies     Storage
# 3       60540  Central  OFF-BI-10004094  Office Supplies     Binders
# 4       19143     East  OFF-AR-10003478  Office Supplies         Art
#
#                                          ProductName    Sales  Quantity  \
# 0  Message Book, Wirebound, Four 5 1/2" X 4" Form...   16.448         2
# 1                                          Avery 508   11.784         3
# 2                      SAFCO Boltless Steel Shelving  272.736         3
# 3         GBC Standard Plastic Binding Systems Combs    3.540         2
# 4  Avery Hi-Liter EverBold Pen Style Fluorescent ...   19.536         3
#
#    Discount   Profit  CatalogPrice  SupplierPrice
# 0       0.2   5.5512         10.28           7.50
# 1       0.2   4.2717          4.91           3.49
# 2       0.2 -64.7748        113.64         135.23
# 3       0.8  -5.4870          8.85          11.59
# 4       0.2   4.8840          8.14           6.51

# %% [markdown]
# ### 4: Create data frames for SQL tables

# %%
# PurchaseDetail DataFrame

df_PurchaseDetail = df[['PurchaseId', 'ProductId', 'Quantity', 'Sales', 'Discount', 'Profit', 'ShipDate', 'ShipMode']]
df_PurchaseDetail = df_PurchaseDetail.sort_values(by=['PurchaseId', 'ProductId'], ascending=[False, True])

# df_Purchase DataFrame - Group by PurchaseId
df_Purchase = df.groupby('PurchaseId').first().reset_index()[['PurchaseId', 'CustomerId', 'PurchaseDate']]

# Sort by PurchaseDate (latest first) and CustomerId
df_Purchase = df_Purchase.sort_values(by=['PurchaseDate', 'CustomerId'], ascending=[False, True])

# df_Customer DataFrame - Group by CustomerId

df_Customer = df.groupby('CustomerId').first().reset_index()[['CustomerId', 'CustomerName', 'Segment']]
df_Customer = df_Customer.sort_values(by=['CustomerId', 'CustomerName'])

# Drop duplicates to get each unique pair of CustomerId and PostalCode

df_CustomerLocation = df.drop_duplicates(subset=['CustomerId', 'PostalCode'], keep='first')[['CustomerId', 'PostalCode', 'City', 'Region', 'State', 'Country']]
df_CustomerLocation = df_CustomerLocation.sort_values(by=['CustomerId', 'PostalCode'])

# Drop duplicates to get the unique pair of ProductId and SubCategory

df_Category = df.drop_duplicates(subset=['ProductId', 'SubCategory'], keep='first')[['ProductId', 'Category', 'SubCategory']]
df_Category = df_Category.sort_values(by=['ProductId', 'SubCategory'])

# df_Product DataFrame - Use most recent values for CatalogPrice and SupplierPrice
# Group by ProductId and PurchaseDate to get the latest rows based on PurchaseDate

df_Product = df.groupby('ProductId').apply(lambda x: x.sort_values('PurchaseDate').iloc[-1]).reset_index(drop=True)[['ProductId', 'ProductName', 'CatalogPrice', 'SupplierPrice']]
df_Product = df_Product.sort_values(by=['ProductId', 'ProductName'])

# %%
df_PurchaseDetail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9986 entries, 7904 to 989
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   PurchaseId  9986 non-null   object
#  1   ProductId   9986 non-null   object
#  2   Quantity    9986 non-null   int64
#  3   Sales       9986 non-null   float64
#  4   Discount    9986 non-null   float64
#  5   Profit      9986 non-null   float64
#  6   ShipDate    9986 non-null   datetime64[ns]
#  7   ShipMode    9986 non-null   object
# dtypes: datetime64[ns](1), float64(3), int64(1), object(3)
# memory usage: 702.1+ KB

# %%
df_Purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5009 entries, 3328 to 56
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PurchaseId    5009 non-null   object
#  1   CustomerId    5009 non-null   object
#  2   PurchaseDate  5009 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 156.5+ KB

# %%
df_Customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 793 entries, 0 to 792
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CustomerId    793 non-null    object
#  1   CustomerName  793 non-null    object
#  2   Segment       793 non-null    object
# dtypes: object(3)
# memory usage: 18.7+ KB

# %%
df_CustomerLocation.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4910 entries, 1105 to 958
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerId  4910 non-null   object
#  1   PostalCode  4910 non-null   int64
#  2   City        4910 non-null   object
#  3   Region      4910 non-null   object
#  4   State       4910 non-null   object
#  5   Country     4910 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 268.5+ KB

# %%
df_Product.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1862 entries, 0 to 1861
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   ProductId      1862 non-null   object
#  1   ProductName    1862 non-null   object
#  2   CatalogPrice   1862 non-null   float64
#  3   SupplierPrice  1862 non-null   float64
# dtypes: float64(2), object(2)
# memory usage: 58.3+ KB

# %%
df_Category.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1862 entries, 8373 to 10
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ProductId    1862 non-null   object
#  1   Category     1862 non-null   object
#  2   SubCategory  1862 non-null   object
# dtypes: object(3)
# memory usage: 58.2+ KB

# %% [markdown]
# ### 5: Create and populate tables

# %%
# Connect to SQLite database (or create it if it doesn't exist)
conn = sqlite3.connect('database.db')
cursor = conn.cursor()

# SQL commands to create tables 
create_tables_sql = ''' 
-- Create the Customer table 
CREATE TABLE IF NOT EXISTS Customer (
    CustomerId TEXT PRIMARY KEY,                
    CustomerName TEXT NOT NULL, 
    Segment TEXT NOT NULL
);

-- Create the CustomerLocation table
CREATE TABLE IF NOT EXISTS CustomerLocation (
    CustomerId TEXT NOT NULL, 
    PostalCode TEXT NOT NULL,
    City TEXT NOT NULL,
    Region TEXT,
    State TEXT NOT NULL,
    Country TEXT NOT NULL,
    PRIMARY KEY (PostalCode, CustomerId),
    FOREIGN KEY (CustomerId) REFERENCES Customer(CustomerId)
);

-- Create the Purchase table
CREATE TABLE IF NOT EXISTS Purchase (
    PurchaseId TEXT PRIMARY KEY,                
    CustomerId TEXT NOT NULL, 
    PurchaseDate DATE NOT NULL,
    FOREIGN KEY (CustomerId) REFERENCES Customer(CustomerId)
);

-- Create the Product table
CREATE TABLE IF NOT EXISTS Product (
    ProductId TEXT PRIMARY KEY,
    ProductName TEXT NOT NULL,
    CatalogPrice DECIMAL NOT NULL,
    SupplierPrice DECIMAL NOT NULL
);

-- Create the PurchaseDetail table
CREATE TABLE IF NOT EXISTS PurchaseDetail (
    PurchaseId TEXT NOT NULL,
    ProductId TEXT NOT NULL,
    Quantity INTEGER NOT NULL,
    Sales DECIMAL NOT NULL,
    Discount DECIMAL NOT NULL,
    Profit DECIMAL NOT NULL,
    ShipDate DATE,
    ShipMode TEXT,
    PRIMARY KEY (PurchaseId, ProductId),
    FOREIGN KEY (PurchaseId) REFERENCES Purchase(PurchaseId),
    FOREIGN KEY (ProductId) REFERENCES Product(ProductId)
);

-- Create the Category table
CREATE TABLE IF NOT EXISTS Category (
    ProductId TEXT NOT NULL,
    SubCategory TEXT NOT NULL,
    Category TEXT NOT NULL,
    PRIMARY KEY (ProductId, SubCategory),
    FOREIGN KEY (ProductId) REFERENCES Product(ProductId)
);
'''

# Execute the SQL commands to create tables
cursor.executescript(create_tables_sql)

# Commit changes and close the connection
conn.commit()

print("Database and tables created successfully.")
# Out:
# Database and tables created successfully.

# %%
# Populate data to tables
df_Customer.to_sql('Customer', conn, if_exists='append', index=False)
df_CustomerLocation.to_sql('CustomerLocation', conn, if_exists='append', index=False)
df_Purchase.to_sql('Purchase', conn, if_exists='append', index=False)
df_PurchaseDetail.to_sql('PurchaseDetail', conn, if_exists='append', index=False)
df_Product.to_sql('Product', conn, if_exists='append', index=False)
df_Category.to_sql('Category', conn, if_exists='append', index=False)
# Out:
# 1862

# %% [markdown]
# * run some queries

# %%
# view categories by total revenue

query = """
SELECT Category.Category, 
       SUM(PurchaseDetail.Sales) AS TotalRevenue
FROM PurchaseDetail
JOIN Product ON PurchaseDetail.ProductId = Product.ProductId
JOIN Category ON Product.ProductId = Category.ProductId
GROUP BY Category.Category
ORDER BY TotalRevenue DESC;
"""

# execute the query and fetch the results into a DataFrame
pd.read_sql_query(query, conn)
# Out:
#           Category  TotalRevenue
# 0       Technology   836154.0330
# 1        Furniture   741999.7953
# 2  Office Supplies   719047.0320

# %%
# view top 10 ProductName by reveneu

query = """
SELECT Product.ProductName, 
       SUM(PurchaseDetail.Profit) AS TotalProfit
FROM PurchaseDetail
JOIN Product ON PurchaseDetail.ProductId = Product.ProductId
JOIN Category ON Product.ProductId = Category.ProductId
WHERE Category.Category = 'Technology'
GROUP BY Product.ProductName
ORDER BY TotalProfit DESC
LIMIT 10;
"""

pd.read_sql_query(query, conn)
# Out:
#                                          ProductName  TotalProfit
# 0              Canon imageCLASS 2200 Advanced Copier   25199.9280
# 1               Hewlett Packard LaserJet 3310 Copier    6983.8836
# 2                 Canon PC1060 Personal Laser Copier    4570.9347
# 3          Logitech G19 Programmable Gaming Keyboard    4425.3432
# 4  HP Designjet T520 Inkjet Large Format Printer ...    4094.9766
# 5                  Ativa V4110MDD Micro-Cut Shredder    3772.9461
# 6   3D Systems Cube Printer, 2nd Generation, Magenta    3717.9714
# 7                  Zebra ZM400 Thermal Label Printer    3343.5360
# 8  Hewlett Packard 610 Color Digital Copier / Pri...    3124.9375
# 9  Plantronics CS510 - Over-the-Head monaural Wir...    3085.0325

# %%
conn.close()
